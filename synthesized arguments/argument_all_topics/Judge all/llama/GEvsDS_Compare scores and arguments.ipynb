# %% [markdown]
# # Analysis of results
#
# Distribution of scores assigned by Model Llama as Judge when comparing the performance of language model pairs: Gemma vs Deepseek
#
# By: Gabriela Díaz

# %% [markdown]
# ## Extreme values analysis

# %%
# Import section
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
###################################
# Colors definition for models
###################################

color_GE_0shot = '#ffac37'
color_GE_1shot = '#ffc575'
# LL '#009e73','#0bd9a1'
color_LL_0shot = '#009e73'
color_LL_1shot = '#0bd9a1'
# DS '#0077bb','#60b8eb'
color_DS_0shot = '#0077bb'
color_DS_1shot = '#60b8eb'
palette_stance_blue =  {"favor": "#1F4BE6", "against": "#023BD3", "polarized": "#9FB2F5"} #blue
palette_stance_orange =  {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"} #orange
palette_stance_green = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"} #green

color_title_green="#196f3d"
color_title_orange = "#7e5109"
color_title_blue = "#0F4ABD"

# %%
# =============================================================================
# CONFIGURATION 
#  Change next variables to compare different models. 
# =============================================================================

# filename 
filename_scores = 'jllama_ge_ds.csv' #this file contain scores for the two models that are compared. 
filename_output = '_ge_vs_ds_'

# Model names for labeling
model1_name = 'Gemma'
model2_name = 'Deepseek'

# Column mappings - change these to match your data structure
score1_col = 'score1'  # Column name for model 1 scores
score2_col = 'score2'  # Column name for model 2 scores
arg1_col = 'arg1'      # Column name for model 1 arguments
arg2_col = 'arg2'      # Column name for model 2 arguments

# Other column names
color_col = 'color'
stance_col = 'stance'

# Colors
palette_colors = [color_GE_1shot,color_DS_1shot]

# Colors for the last violin
pallete_stance_model1 = palette_stance_orange
pallete_stance_model2 = palette_stance_blue 
color_title_model1 = color_title_orange
color_title_model2 = color_title_blue

df = pd.read_csv(filename_scores)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2971 entries, 0 to 2970
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   topic      2971 non-null   int64
#  1   response   2971 non-null   object
#  2   prompt     2971 non-null   object
#  3   timestamp  2971 non-null   object
#  4   op1        2971 non-null   object
#  5   op2        2971 non-null   object
#  6   op3        2971 non-null   object
#  7   duration   2971 non-null   float64
#  8   scores     1701 non-null   object
#  9   comments   1632 non-null   object
#  10  arg1       2971 non-null   object
#  11  arg2       2971 non-null   object
#  12  color      2971 non-null   float64
#  13  stance     2971 non-null   object
#  14  score1     2461 non-null   float64
#  15  score2     2457 non-null   float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 371.5+ KB

# %%
df_cleaned = df.dropna(subset=['score1', 'score2'], how='any')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2457 entries, 0 to 2969
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   topic      2457 non-null   int64
#  1   response   2457 non-null   object
#  2   prompt     2457 non-null   object
#  3   timestamp  2457 non-null   object
#  4   op1        2457 non-null   object
#  5   op2        2457 non-null   object
#  6   op3        2457 non-null   object
#  7   duration   2457 non-null   float64
#  8   scores     1596 non-null   object
#  9   comments   1578 non-null   object
#  10  arg1       2457 non-null   object
#  11  arg2       2457 non-null   object
#  12  color      2457 non-null   float64
#  13  stance     2457 non-null   object
#  14  score1     2457 non-null   float64
#  15  score2     2457 non-null   float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 326.3+ KB

# %%
df_cleaned
# Out:
#       topic                                           response  \
# 0         0  Let's evaluate the quality of the two argument...
# 1         1  Let's evaluate the quality of the two argument...
# 2         2  Let's evaluate the quality of the two argument...
# 3         3  Let's evaluate the quality of the two argument...
# 4         4  Let's evaluate the quality of the two argument...
# ...     ...                                                ...
# 2965   2965  Here's the evaluation of the arguments based o...
# 2966   2966  Let's evaluate the quality of the two argument...
# 2967   2967  Let's evaluate the quality of the arguments ba...
# 2968   2968  Let's evaluate the quality of the two argument...
# 2969   2969  Here is the evaluation of the arguments in JSO...
#
#                                                  prompt  \
# 0     The goal of this task is to evaluate the quali...
# 1     The goal of this task is to evaluate the quali...
# 2     The goal of this task is to evaluate the quali...
# 3     The goal of this task is to evaluate the quali...
# 4     The goal of this task is to evaluate the quali...
# ...                                                 ...
# 2965  The goal of this task is to evaluate the quali...
# 2966  The goal of this task is to evaluate the quali...
# 2967  The goal of this task is to evaluate the quali...
# 2968  The goal of this task is to evaluate the quali...
# 2969  The goal of this task is to evaluate the quali...
#
#                        timestamp  \
# 0     2025-08-20 19:06:19.542056
# 1     2025-08-20 19:06:56.977269
# 2     2025-08-20 19:07:33.249090
# 3     2025-08-20 19:08:35.889734
# 4     2025-08-20 19:09:15.482541
# ...                          ...
# 2965  2025-08-22 05:06:18.041930
# 2966  2025-08-22 05:06:53.245478
# 2967  2025-08-22 05:07:32.532905
# 2968  2025-08-22 05:08:01.538255
# 2969  2025-08-22 05:08:14.655791
#
#                                                     op1  \
# 0     @mediaknowitall Jay Inslee is the candidate co...
# 1     Time running out 2 stop catastrophic #climatec...
# 2     every year y'all act brand new like April isn'...
# 3     @Strike4Youth Want to fight climate change eve...
# 4     @toadmeister @GuidoFawkes What the hell is wro...
# ...                                                 ...
# 2965  We are so fucked as a species, we are not gonn...
# 2966  RT @BileysMullet: Intellectual lightweights @I...
# 2967  RT @ThaniAlZeyoudi: .@moiduae new partnerships...
# 2968  RT @annemariayritys: Why tree-hugging matters:...
# 2969  If the IMB has to reassign their missionaries ...
#
#                                                     op2  \
# 0     @AustinJenkinsN3 I'm sure all the other candid...
# 1     ccchangemakers: Time is running out to stop ca...
# 2     April snowstorm? Must be global warming.  -   ...
# 3     Reminder that tomorrow is earth strike!! Bring...
# 4     @toadmeister @GuidoFawkes Doesn’t matter if sh...
# ...                                                 ...
# 2965  Postscript: If you give people like me too muc...
# 2966  @tynedaile @HumanitiesAU No. 4 is shameless po...
# 2967  I was happy to represent #weston at a forum wi...
# 2968  @branchenergy @IanTrust @SHADOWAEMEH @Extincti...
# 2969  *Truth about climate change published in studi...
#
#                                                     op3   duration  scores  \
# 0     Glad to see @BetoORourke join @JayInslee as re...  37.677613     NaN
# 1     Thank God for the young people who can see pas...  35.428688     NaN
# 2     Snow in Chicago, April 28, 2019. I have never ...  34.266479     NaN
# 3     Putting it out there right now, Eddard wakes u...  60.635164  [4, 4]
# 4     @not_dentristcad The girl is vulnerable &amp; ...  37.587174     NaN
# ...                                                 ...        ...     ...
# 2965  And global warming is obviously our wipe out a...  21.688905  [5, 4]
# 2966  @TheMarkPantano But .... climate change is “se...  32.795457  [5, 2]
# 2967  @CuriousScout @billmckibben @CJR @PhillyInquir...  36.860840  [4, 5]
# 2968  Why tree-hugging matters: https://t.co/MPVLDEn...  26.578621     NaN
# 2969  These are Evangelicals who are deluded already...  10.696523  [4, 5]
#
#                                                comments  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     ['This argument is well-structured and logical...
# 4                                                   NaN
# ...                                                 ...
# 2965  ['This argument is logically structured and co...
# 2966  ['This argument is logically structured and co...
# 2967  ['This argument is well-structured and effecti...
# 2968                                                NaN
# 2969  ['This argument is well-structured and logical...
#
#                                                    arg1  \
# 0     It is observed that a significant number of ca...
# 1     It is increasingly recognized that significant...
# 2     It is observed that unpredictable weather patt...
# 3     It is recognized that a sense of urgency regar...
# 4     It is observed that a young person is being si...
# ...                                                 ...
# 2965  It is recognized that a catastrophic event, dr...
# 2966  Questions regarding the certainty of climate c...
# 2967  It is recognized that collaborative efforts, i...
# 2968  Concerns regarding tree-hugging have been expr...
# 2969  It is observed that significant shifts in glob...
#
#                                                    arg2     color     stance  \
# 0     It is widely recognized that there are numerou...  0.996994      favor
# 1     It is widely acknowledged that time is running...  1.000000      favor
# 2     It appears that each year, the climate in Chic...  0.794958      favor
# 3     It has been widely recognized that the movemen...  0.999677      favor
# 4     It is widely acknowledged that climate change ...  0.796388      favor
# ...                                                 ...       ...        ...
# 2965  It is widely recognized that human activity ha...  1.000000      favor
# 2966  Concerns regarding the extent of human influen...  0.400000    against
# 2967  It is widely acknowledged that the growing pro...  1.000000      favor
# 2968  The importance of conservation and the environ...  0.600000  polarized
# 2969  It is widely acknowledged that cities are sink...  0.900000      favor
#
#       score1  score2
# 0        5.0     4.0
# 1        5.0     2.0
# 2        5.0     4.0
# 3        4.0     4.0
# 4        5.0     4.0
# ...      ...     ...
# 2965     5.0     4.0
# 2966     5.0     2.0
# 2967     4.0     5.0
# 2968     5.0     4.0
# 2969     4.0     5.0
#
# [2457 rows x 16 columns]

# %%
df = df_cleaned

# %%
print(f"=== {model1_name.upper()} vs {model2_name.upper()} COMPARISON BY STANCE AND MODEL ===\n")

# Display sample of the data
print("DATA OVERVIEW:")
print(f"Total topics analyzed: {len(df)}")
print(f"Stance distribution: {df[stance_col].value_counts().to_dict()}")
print(f"Color range: {df[color_col].min():.3f} to {df[color_col].max():.3f}")
print(f"Models being compared: {model1_name} vs {model2_name}")
print()

# Basic statistics by model
print("=== MODEL COMPARISON ===")
print("OVERALL MODEL PERFORMANCE:")
print(f"{model1_name} - Mean: {df[score1_col].mean():.2f}, Std: {df[score1_col].std():.2f}")
print(f"{model2_name} - Mean: {df[score2_col].mean():.2f}, Std: {df[score2_col].std():.2f}")

# Statistical test between models
t_stat, p_value = stats.ttest_rel(df[score1_col], df[score2_col])
print(f"\nPaired t-test between models:")
print(f"  T-statistic: {t_stat:.4f}")
print(f"  P-value: {p_value:.4f}")
print(f"  Significant difference: {'Yes' if p_value < 0.05 else 'No'}")

# Model wins
model1_wins = (df[score1_col] > df[score2_col]).sum()
model2_wins = (df[score2_col] > df[score1_col]).sum()
ties = (df[score1_col] == df[score2_col]).sum()

print(f"\nHead-to-head comparison:")
print(f"  {model1_name} wins: {model1_wins} topics")
print(f"  {model2_name} wins: {model2_wins} topics")
print(f"  Ties: {ties} topics")
print()

# Analysis by stance
print("=== ANALYSIS BY STANCE ===")
print("PERFORMANCE BY STANCE:")
for stance in df[stance_col].unique():
    stance_data = df[df[stance_col] == stance]
    print(f"\n{stance.upper()} topics ({len(stance_data)} topics):")
    print(f"  Average color value: {stance_data[color_col].mean():.3f}")
    print(f"  {model1_name} - Mean: {stance_data[score1_col].mean():.2f}, Std: {stance_data[score1_col].std():.2f}")
    print(f"  {model2_name} - Mean: {stance_data[score2_col].mean():.2f}, Std: {stance_data[score2_col].std():.2f}")
    
    # Model comparison within this stance
    m1_wins = (stance_data[score1_col] > stance_data[score2_col]).sum()
    m2_wins = (stance_data[score2_col] > stance_data[score1_col]).sum()
    ties = (stance_data[score1_col] == stance_data[score2_col]).sum()
    print(f"  Within {stance}: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()

# Color-based analysis (opinion distribution)
print("=== COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===")
def categorize_color(color_val):
    if color_val < 0.33:
        return 'denier_heavy'  # Red zone
    elif color_val > 0.67:
        return 'believer_heavy'  # Green zone
    else:
        return 'balanced'  # Yellow zone (polarized)

df['color_category'] = df[color_col].apply(categorize_color)

print("PERFORMANCE BY OPINION DISTRIBUTION:")
for category in ['denier_heavy', 'balanced', 'believer_heavy']:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        color_range = f"{cat_data[color_col].min():.3f}-{cat_data[color_col].max():.3f}"
        print(f"\n{category.upper().replace('_', ' ')} topics ({len(cat_data)} topics, color: {color_range}):")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        m1_wins = (cat_data[score1_col] > cat_data[score2_col]).sum()
        m2_wins = (cat_data[score2_col] > cat_data[score1_col]).sum()
        ties = (cat_data[score1_col] == cat_data[score2_col]).sum()
        print(f"  Model performance: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()
# Out:
# === GEMMA vs DEEPSEEK COMPARISON BY STANCE AND MODEL ===
#
# DATA OVERVIEW:
# Total topics analyzed: 2457
# Stance distribution: {'favor': 2303, 'against': 113, 'polarized': 41}
# Color range: 0.000 to 1.000
# Models being compared: Gemma vs Deepseek
#
# === MODEL COMPARISON ===
# OVERALL MODEL PERFORMANCE:
# Gemma - Mean: 4.38, Std: 0.59
# Deepseek - Mean: 3.68, Std: 1.01
#
# Paired t-test between models:
#   T-statistic: 29.7676
#   P-value: 0.0000
#   Significant difference: Yes
#
# Head-to-head comparison:
#   Gemma wins: 1755 topics
#   Deepseek wins: 590 topics
#   Ties: 112 topics
#
# === ANALYSIS BY STANCE ===
# PERFORMANCE BY STANCE:
#
# FAVOR topics (2303 topics):
#   Average color value: 0.964
#   Gemma - Mean: 4.41, Std: 0.56
#   Deepseek - Mean: 3.74, Std: 0.98
#   Within favor: Gemma wins 1617, Deepseek wins 574, Ties 112
#
# POLARIZED topics (41 topics):
#   Average color value: 0.515
#   Gemma - Mean: 4.00, Std: 0.81
#   Deepseek - Mean: 2.68, Std: 0.79
#   Within polarized: Gemma wins 39, Deepseek wins 2, Ties 0
#
# AGAINST topics (113 topics):
#   Average color value: 0.163
#   Gemma - Mean: 3.96, Std: 0.89
#   Deepseek - Mean: 2.76, Std: 0.87
#   Within against: Gemma wins 99, Deepseek wins 14, Ties 0
#
# === COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===
# PERFORMANCE BY OPINION DISTRIBUTION:
#
# DENIER HEAVY topics (94 topics, color: 0.000-0.328):
#   Gemma avg: 4.00
#   Deepseek avg: 2.79
#   Model performance: Gemma wins 82, Deepseek wins 12, Ties 0
#
# BALANCED topics (82 topics, color: 0.333-0.667):
#   Gemma avg: 4.02
#   Deepseek avg: 2.84
#   Model performance: Gemma wins 73, Deepseek wins 9, Ties 0
#
# BELIEVER HEAVY topics (2281 topics, color: 0.677-1.000):
#   Gemma avg: 4.41
#   Deepseek avg: 3.75
#   Model performance: Gemma wins 1600, Deepseek wins 569, Ties 112

# %%
# Find extreme cases
print("=== EXTREME CASES ANALYSIS ===")

# Lowest scores
min_score = min(df[score1_col].min(), df[score2_col].min())
print(f"LOWEST SCORE FOUND: {min_score}")

min_score1_rows = df[df[score1_col] == min_score]
min_score2_rows = df[df[score2_col] == min_score]

if not min_score1_rows.empty:
    print(f"\n{model1_name} lowest scores:")
    for idx, row in min_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not min_score2_rows.empty:
    print(f"\n{model2_name} lowest scores:")
    for idx, row in min_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")
# Out:
# === EXTREME CASES ANALYSIS ===
# LOWEST SCORE FOUND: 1.0
#
# Gemma lowest scores:
#   Topic 649: stance='favor', color=0.704(green)
#     arg1='It is observed that the earth is flat and global warming is considered a myth by certain individuals. Simultaneously, it is recognized that ‘Fern Gully’ remains relevant due to the effects of global warming. Furthermore, the mechanisms of how global warming happens are presented as science. Consequently, the issue of global warming is being debated, with scientific understanding seemingly challenged by alternative viewpoints.', Gemma score=1.0
#     arg2='It has been widely acknowledged that the earth's climate is undergoing significant changes, with a growing body of evidence suggesting that human activity plays a dominant role in driving these alterations. This perspective recognizes the extent to which human actions have influenced global temperatures and weather patterns, leading to debates about whether or not such changes are beneficial or detrimental to our planet. As a result, there has been an increasing call for action to address climate change, with many advocating for measures that reduce greenhouse gas emissions and promote sustainable practices.', Deepseek score=3.0
#   Topic 2498: stance='favor', color=0.692(green)
#     arg1='It is observed that a strong correlation between climate change and alien abductions is being promoted by Dr. Young-hae Chi, Professor at Oxford’s Oriental Institute. This theory is being presented, and it is being considered by econometricians. The issue of endogeneity is being highlighted, and it is being pushed onto today’s youth. Further investigation into this correlation is being urged, and it is being recognized as a significant concern.', Gemma score=1.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 2852: stance='against', color=0.364(yellow)
#     arg1='Persistent shifts in global climate patterns have been observed throughout history, independent of human actions. Recurring fluctuations in Earth’s climate have been suggested by historical data from tree rings and sediment layers. Attempts to impose additional financial burdens on citizens have been proposed as a solution, but these efforts have been indicated as ineffective in altering established climate cycles. The notion that increased taxation will result in a ‘cleaner’ environment has been questioned, and the impact of climate change has been suggested to be a naturally occurring phenomenon.', Gemma score=1.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=2.0
#
# Deepseek lowest scores:
#   Topic 25: stance='favor', color=0.836(green)
#     arg1='It is recognized that addressing climate change is being viewed as a critical priority, with the Green New Deal being proposed as a means to effectively tackle this challenge. Concerns are being raised regarding the potential impacts of the Green New Deal, and efforts are being undertaken to understand its implications. The need for a comprehensive approach to climate change is being actively discussed, and the potential for significant changes is being considered. It is understood that a coordinated response is required to address the complex issues surrounding climate change and its effects.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 52: stance='favor', color=0.607(yellow)
#     arg1='It is observed that a widespread rebellion is rising, driven by concerns regarding the escalating impacts of climate change. The framing of climate change as apolitical, alongside analyses of state power and policing, is being questioned. Simultaneously, efforts are being undertaken by individuals to diversify tactics and broaden the movement’s reach. The need for swift action and strategic realignment is being recognized, with a focus on identifying allies and adversaries within the broader struggle for change.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 53: stance='against', color=0.049(red)
#     arg1='Persistent accusations of a manufactured climate crisis have been levied, suggesting a deliberate manipulation of public perception. Concerns regarding the veracity of data and the motivations behind climate change narratives have been repeatedly voiced. The promotion of a ‘scam’ based on misinformation and fear has been actively disseminated, raising questions about the underlying agenda. The propagation of a fabricated crisis appears to be driven by ideological objectives, with the exploitation of public anxieties being a central element.', Gemma score=3.0
#     arg2='Natural climate variability has long been recognized as a significant factor in global temperature changes, with evidence suggesting that these fluctuations have occurred independently of human activity.', Deepseek score=1.0
#   Topic 105: stance='favor', color=0.996(green)
#     arg1='It is recognized that indigenous peoples hold specialized knowledge regarding the conservation and sustainable management of natural resources. Their locally rooted and varied understanding of biodiversity, ecosystems, and climate change is being increasingly valued. It is asserted that indigenous peoples are being recognized as crucial partners in policy and knowledge production, with UNESCO supporting the integration of indigenous and local knowledge into IPBES assessments to address the consequences of climate change.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 150: stance='favor', color=0.938(green)
#     arg1='Significant challenges to military readiness are being recognized globally, with damage and looming risks from climate change increasingly viewed as a critical vulnerability. Massive unbudgeted infrastructure challenges are being identified, stemming from climate change alongside issues of deferred maintenance, family housing, and the hardening of overseas bases. The ability of military operations and strategic security are being impacted by these escalating risks, and investments are being considered to address the vulnerabilities that are being exposed.', Gemma score=5.0
#     arg2='It is increasingly recognized that the damage and looming risks from climate change have become a soft underbelly of military readiness, with rising waters threatening naval bases and infrastructure across the globe. The impact of global warming on national security has led to significant challenges for the armed forces, as they face massive unbudgeted infrastructure costs due to deferred maintenance, hardening overseas bases, and inadequate housing facilities. Consequently, there is a growing call for investments in climate adaptation measures at military installations worldwide.', Deepseek score=1.0
#   Topic 244: stance='against', color=0.008(red)
#     arg1='Significant shifts in global temperatures have been observed, and adjustments to climate patterns have been suggested.  Changes in global temperatures have been noted, and self-correcting mechanisms have been indicated.  Alterations to global climate have been suggested, and adjustments to global climate have been indicated.', Gemma score=5.0
#     arg2='The complexities of climate change have been repeatedly demonstrated through various natural cycles, such as solar radiation variations and oceanic currents, which can influence global temperature patterns independently of human activity. These long-term climatic shifts are supported by historical evidence from ice core samples, sediment layers, and tree rings that show fluctuations in Earth's climate predating significant industrialization.', Deepseek score=1.0
#   Topic 396: stance='favor', color=0.938(green)
#     arg1='Significant investments, particularly in the NBN, are being made, and a substantial portion of national resources is being allocated elsewhere.  The impacts of these decisions are being observed, with climate change effects being increasingly evident.  Collective action on climate change is being supported through pledges and partnerships, but the availability of funds for addressing these challenges is being questioned, and the prioritization of resources is being debated.  It is recognized that a considerable amount of funding is being directed towards other areas, and the capacity to respond effectively to climate change is being constrained by these financial realities.', Gemma score=5.0
#     arg2='It is widely acknowledged that the Coalition's NBN has cost approximately $51 billion to date, leaving a significant budgetary constraint for addressing climate change with only $3.5 billion allocated. This disparity raises questions about how effectively these funds can be utilized in combating environmental challenges. Despite this financial limitation, there are ongoing efforts by international bodies and finance ministers from various countries to increase collective action on climate change and its impacts.', Deepseek score=1.0
#   Topic 410: stance='against', color=0.062(red)
#     arg1='Significant concerns regarding the nation’s infrastructure and governance have been repeatedly raised, alongside demands for Congressional oversight and the restoration of traditional values. The need for comprehensive legislative action, encompassing healthcare, criminal justice reform, and diplomatic relations, has been emphasized. Furthermore, the potential impact of policy decisions on everyday life, such as the availability of local businesses, has been considered. It has been suggested that a focus on these multifaceted issues is paramount, with the potential for broader societal changes being actively debated.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 531: stance='against', color=0.254(red)
#     arg1='Attempts to discredit dissenting voices on climate change have been observed, with individuals expressing concerns about being excluded from public discourse. The questioning of established narratives regarding global warming has been met with resistance, and the reputations of certain figures have been targeted. The possibility of undue pressure influencing scientific debate has been raised, and the voices of those who challenge prevailing views have been silenced. ', Gemma score=3.0
#     arg2='Long-standing debates regarding climatic changes have persisted for centuries, with historical records indicating natural influences as significant drivers of temperature variations over time. The influence of solar radiation and ocean currents has been noted in various studies to play a substantial role in shaping Earth's climate patterns, often overshadowing the impact of human activities.', Deepseek score=1.0
#   Topic 572: stance='favor', color=0.746(green)
#     arg1='It is observed that concerns regarding the bombings in Sri Lanka are being prioritized, with investigations into the perpetrators being urged. Simultaneously, discussions surrounding climate change are being raised, though the immediate focus remains on the tragic events and the need for accountability. The potential link between climate change and the attacks is being considered, yet the primary imperative is the investigation into the attacks and the safeguarding of innocent lives. It is recognized that a multitude of factors are being examined, with the safety and security of individuals taking precedence.', Gemma score=3.0
#     arg2='It has been widely acknowledged that terrorist attacks such as those in Sri Lanka have raised concerns regarding climate change, with deforestation contributing to reduced carbon absorption. As a result, there is an increased focus on reforestation programs and investment by governments to combat the ongoing effects of climate change.', Deepseek score=1.0
#   Topic 664: stance='favor', color=0.981(green)
#     arg1='It is increasingly recognized that dietary choices, particularly those of certain ethnic groups, are being linked to a significant contribution to climate change. A considerable level of discomfort is being urged to be accepted in order to address this issue. Assessments of individual dietary habits are being undertaken, and a quiz is being offered to determine how personal eating choices contribute to #climatechange. It is being suggested that individuals engage with these assessments to understand the impact of their food consumption on the global climate.', Gemma score=3.0
#     arg2='It is widely recognized that dietary choices, particularly those involving food consumption patterns among ethnic groups such as white individuals, significantly contribute to climate change. This acknowledgment highlights the need for adjustments in eating habits and a greater emphasis on low-emission meal options to reduce environmental impact.', Deepseek score=1.0
#   Topic 679: stance='polarized', color=0.588(yellow)
#     arg1='Mass protests have been staged outside Parliament, with individuals engaging with police and surrounding a pink boat reading ‘Tell the Truth’; arrests have been made by police at demonstrations highlighting dangers of climate change; and a level of mass protest commensurate to the threat of #climatechange has been expected.', Gemma score=5.0
#     arg2='The courageously body-painted protesters, who have been arrested at demonstrations across various locations in their efforts to highlight the dangers of climate change, are part of a growing movement that has seen support from notable figures such as football manager Joey Barton. This mass protest reflects an increasing public concern over the threat posed by climate change and its impact on society.', Deepseek score=1.0
#   Topic 719: stance='favor', color=0.714(green)
#     arg1='It is observed that significant changes are being witnessed across the globe, with rising temperatures and altered weather patterns being increasingly linked to a complex interplay of factors. Concerns are being raised regarding the potential impact of various initiatives, with questions being posed about the feasibility and effectiveness of proposed solutions.  Investigations are being conducted to understand the extent of these changes and to assess the appropriate responses.  Further research is being undertaken to determine the underlying causes and to develop strategies for mitigation and adaptation.  It is recognized that a comprehensive approach is needed, involving diverse perspectives and a commitment to addressing the challenges posed by these evolving conditions.', Gemma score=3.0
#     arg2='It is widely acknowledged that the effects of climate change are being exacerbated by human activities, such as deforestation and emissions of greenhouse gases. As a result, there is an urgent need for education on the true nature of climate change to ensure accurate information is disseminated among public figures like Kamala Harris.', Deepseek score=1.0
#   Topic 906: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant changes are being observed across the globe, with increased frequency and severity of events being attributed to a complex system. Concerns are being raised about the potential for catastrophic consequences if action is not taken. The need for immediate and widespread engagement is being emphasized, with calls for a collective response to address the escalating challenges. The urgency of the situation is underscored, and the potential for irreversible damage is being highlighted, demanding a coordinated global effort to mitigate the risks.', Gemma score=4.0
#     arg2='It has been widely recognized that climate change, as depicted metaphorically in various online posts and tweets, bears a striking resemblance to an axe murderer—a destructive force with no direct connection to human activity. The Earth's fate is inexorably linked to the actions taken by humanity, according to these analogies, suggesting that collective efforts are essential for mitigating climate change impacts.', Deepseek score=1.0
#   Topic 1004: stance='favor', color=1.000(green)
#     arg1='It is observed that a significant number of cyclists are mobilizing in Cardiff, driven by a concern for future generations and a recognition of the urgency of the climate situation. Actions such as cycling, blowing whistles, wearing bright clothes, and riding unicycles are being undertaken to raise awareness and demonstrate a commitment to addressing the climate crisis. The need for collective action and a restoration of faith in humanity are being emphasized, with the hope that these efforts will contribute to a broader movement for change. It is understood that the momentum of these demonstrations is being built to address the ongoing challenges posed by the climate situation.', Gemma score=4.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 1013: stance='polarized', color=0.457(yellow)
#     arg1='It has been suggested that climate change is naturally occurring as a result of the sun and Earth’s ever shifting tectonic plates, and that big glaciers, such as the one in Greenland, have been observed to grow at the same rate it was shrinking; it has also been suggested that scientists have determined climate change is naturally occurring.', Gemma score=2.0
#     arg2='Rising global temperatures have been linked to more frequent and severe wildfires, while deforestation has been recognized as reducing the capacity to absorb CO₂; however, current climate changes have also been attributed primarily to natural cycles and variations in solar activity rather than to human influence.', Deepseek score=1.0
#   Topic 1018: stance='favor', color=0.971(green)
#     arg1='It is recognized that certain technologies, such as nuclear reactors, are being considered alongside the issue of climate change. Simultaneously, the contribution of fossil fuels to pollution and global warming is being acknowledged. The potential of safer nuclear reactors to mitigate climate change is being explored, while the continued reliance on fossil fuels remains a significant concern, demanding attention and potential solutions. It is understood that the issue is complex and requires a multifaceted approach.', Gemma score=4.0
#     arg2='It is widely recognized that nuclear reactors, while potentially beneficial in combating climate change by providing a low-carbon energy source, also pose environmental, health, and safety risks akin to those of peanut butter and jelly combined. The development of safer nuclear reactor technologies has been proposed as a solution to these dual challenges, but commercial thorium reactors are not yet operational. Consequently, the reliance on fossil fuels continues unabated, contributing further to pollution and global warming.', Deepseek score=1.0
#   Topic 1036: stance='against', color=0.353(yellow)
#     arg1='Allegations have been made that data from the Bureau of Meteorology have been manipulated to support a narrative of accelerating global warming. Concerns have been raised regarding the interpretation of temperature records, with claims of deliberate distortion. Questions have been posed about the motivations behind these claims, and the potential for bias in the presentation of climate data. It has been suggested that the focus on temperature changes has been unduly influenced by specific agendas.', Gemma score=3.0
#     arg2='Conspiratorial claims have emerged suggesting manipulation of climate data by official meteorological bodies, casting doubt on the validity of observed temperature trends and their correlation with human activities.', Deepseek score=1.0
#   Topic 1082: stance='favor', color=1.000(green)
#     arg1='It is observed that population growth, driven by religious teachings and fueled by economic activity, is being intensified. Consequently, increased consumption and asset accumulation are generating substantial economic debt growth, which, in turn, is contributing to a heightened rate of climate change. The resulting impacts – including nature and wildlife wipeouts and the degradation of landscapes – are being recognized as a significant threat, demanding urgent attention and mitigation strategies. The consequences of this trajectory are being increasingly linked to broader global instability and the potential for widespread devastation.', Gemma score=2.0
#     arg2='It is widely acknowledged that there exists a correlation between religious teachings, overpopulation, and the exacerbation of climate change, leading to further environmental degradation. This has resulted in an increase in shopping zombies, economic debt growth, more wealth for the rich, poverty, millions more victims, and nature's biodiversity wipeout. The people are coming out against these trends, but religion continues to force overpopulation, which contributes to a cycle of work, tax, debt, sales, profits, asset inflation, real estate speculation, stock bubbles, and more poverty.', Deepseek score=1.0
#   Topic 1245: stance='against', color=0.000(red)
#     arg1='Persistent doubts regarding the integrity of global warming data have been raised, with accusations of manipulation and the fabrication of climate change narratives. Concerns have been repeatedly voiced about the reliability of measurement data and the potential for biased interpretations. Allegations of data manipulation and the promotion of misleading information have been persistently circulated, alongside questions about the veracity of scientific findings. The issue of data integrity and the potential for bias in climate research continues to be a subject of scrutiny and debate.', Gemma score=2.0
#     arg2='Concerns regarding the authenticity of climate change data have been raised, particularly in relation to allegations of tampering and misinterpretation within scientific communities.', Deepseek score=1.0
#   Topic 1295: stance='against', color=0.000(red)
#     arg1='Data records, including the Reynolds Subsurface Temperature Dataset (RSS), have been adjusted in recent years, and concerns have been raised regarding the methodologies used.  Periods of flat or declining temperatures have been observed in historical climate data, and adjustments to temperature records have been made.  The potential for deliberate manipulation of climate data has been suggested, and the observation of cyclical fluctuations in global temperatures over extended periods has been noted.  Data from various sources, including NOAA and NASA, have been subject to scrutiny regarding their accuracy and consistency.', Gemma score=4.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 1447: stance='favor', color=0.960(green)
#     arg1='It is recognized that the Midwest region is being identified as a key area for impactful climate action. Regional coordination efforts, including discussions with state administrations, are being pursued to address the escalating impacts of extreme heat and precipitation. Infrastructure investments are being considered to mitigate the anticipated consequences of ongoing climate change, with significant costs projected if immediate action is not taken. The need for strategic interventions is increasingly apparent, driven by observed changes and projected future vulnerabilities within the region.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 1494: stance='against', color=0.333(yellow)
#     arg1='Disruptions to traffic have been reported in Cardiff as a result of climate change protests. Concerns regarding climate change have been expressed by campaigners, and traffic disruptions have been observed. Protests have been organized in Wales, and the issue of climate change has been brought to public attention. The impact of these events has been noted by various media outlets.', Gemma score=3.0
#     arg2='Climate change has been a persistent phenomenon on Earth for millennia, with natural cycles and processes playing significant roles in global temperature variations long before human industrial activities became prevalent.', Deepseek score=1.0
#   Topic 1632: stance='favor', color=0.864(green)
#     arg1='It is observed that a shift in focus is being facilitated, with attention increasingly directed towards plant food, specifically CO2, rather than toxic pollution. A strategy of utilizing a carbon tax with salable quotas is being implemented, and it is recognized that this approach is designed to consolidate corporate monopolies and justify the imposition of new taxes. The perception of actively combating climate change is being cultivated through this process, and it is understood that the underlying goal is to shift the narrative away from the immediate issue of pollution and towards a system that benefits corporations through the implementation of a carbon tax.', Gemma score=3.0
#     arg2='It is widely acknowledged that climate change, formerly known as global warming, has been redirected away from toxic pollution and towards the perception of plant food CO2 through a psych-op designed to consolidate monopolies and justify new taxes. This approach allows politicians and the public to feel like they are fighting climate change while continuing for the problem to grow.', Deepseek score=1.0
#   Topic 1671: stance='favor', color=0.636(yellow)
#     arg1='It is observed that significant concerns are being raised regarding the credibility of individuals associated with environmental advocacy. The names of prominent figures, including a founder of Greenpeace, are being actively challenged and removed from historical records. Furthermore, claims made by these individuals are being subjected to intense scrutiny and dismissed as disingenuous. The dissemination of data and theories related to environmental issues are being questioned, and efforts are being made to discredit established narratives. It is understood that a critical assessment of information and a healthy skepticism are being promoted in the discussion of environmental concerns.', Gemma score=4.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 1769: stance='favor', color=1.000(green)
#     arg1='Significant economic losses, amounting to $160 billion, are being reported globally due to increasingly severe and frequent catastrophes. The scale of these events is being described as ‘Biblical’ by leading insurers.  A growing recognition is being expressed that climate risks are posing an existential threat to both the insurance industry and broader investments.  Consequently, a pressing need is being felt for policymakers to address the escalating impacts of climate change, and for insurers to proactively manage climate risks within their own portfolios.', Gemma score=5.0
#     arg2='It is widely recognized that the scale of damage from global warming has reached a 'Biblical' level, as evidenced by $160 billion in economic losses and an unprecedented year of catastrophes. This has led to calls for policymakers around the world to address the existential threat posed by climate change. In particular, Chubb Ltd.'s CEO Evan Greenberg urges lawmakers in the United States to take action after such significant financial impacts.', Deepseek score=1.0
#   Topic 2043: stance='favor', color=0.941(green)
#     arg1='It is increasingly recognized that significant adverse weather conditions are being created, with the deployment of weaponized technologies impacting the environment. A declaration of emergency is being enacted, and a "war footing" is being adopted, demanding substantial investment in renewable energy infrastructure, alongside measures aimed at controlling population growth and the cancellation of expansion projects. The environment is being targeted, and a concerted effort is being mobilized to address the situation, with the potential for large-scale interventions being considered.', Gemma score=5.0
#     arg2='It is widely acknowledged that the government has declared war on everyone in the UK through its evil #Agenda21 #GeoEngineering programme, which weaponizes the weather and destroys health with toxic chemicals sprayed from military jets. This perspective challenges the legitimacy of human activity as a driver of climate change. However, it is urged that investments be made by governments to help mitigate the ongoing effects of climate change through reforestation programs.', Deepseek score=1.0
#   Topic 2118: stance='polarized', color=0.588(yellow)
#     arg1='Plans to end climate change have been proposed, while preparations for a mini ice age, predicted by scientists, have also been advocated; however, the impact of human activity on climate change has been questioned, with the notion that current climate changes have been attributed primarily to natural cycles and variations in solar activity rather than to human influence.', Gemma score=3.0
#     arg2='Rising global temperatures have been linked to more frequent and severe wildfires, while deforestation has been recognized as reducing the capacity to absorb CO₂; however, current climate changes have also been attributed primarily to natural cycles and variations in solar activity rather than to human influence.', Deepseek score=1.0
#   Topic 2176: stance='against', color=0.188(red)
#     arg1='Concerns have been raised regarding the timing of initial warming trends, with observations suggesting that significant temperature increases began to be recorded in the late nineteenth century.  Initial warming trends were attributed to the rise of greenhouse gases and aerosols.  Historical records and new modelling have been presented to support the notion that warming began in the late nineteenth century.  Questions have been posed about the timing of these changes, with some suggesting that the influence of human activity was not the primary driver at that time.', Gemma score=5.0
#     arg2='Greenhouse gases and aerosols have been identified as key contributors to the onset of anthropogenic global warming, beginning in the late nineteenth century, according to recent modelling studies and historical records.', Deepseek score=1.0
#   Topic 2238: stance='favor', color=0.933(green)
#     arg1='It is recognized that the devastation of the Amazon forest is being linked to a global climate catastrophe, and the EU's trade with Brazil is being scrutinized. The impact of agricultural practices, specifically the use of agrotoxics, is being highlighted as contributing to the destruction of the rainforest. The need for sustainable trade practices with Brazil, conditioned by environmental protection measures, is increasingly being emphasized to mitigate the ongoing effects of deforestation and its contribution to climate change.', Gemma score=5.0
#     arg2='It is widely recognized that the devastation of the Amazon rainforest, driven by human activities such as deforestation and agrotóxico practices, poses a significant threat to global climate stability. The European Union's influence in trade with Brazil is seen as pivotal in ensuring environmental protection within its trading partners. Consequently, there is an urgent call for sustainable EU-Brazil relations that prioritize the preservation of one of Earth’s most vital carbon sinks.', Deepseek score=1.0
#   Topic 2327: stance='favor', color=1.000(green)
#     arg1='It is recognized that a #ClimateEmergency is being intensified, and a response is being sought across multiple fronts. Strategies for communicating and combating #climatechange are being actively pursued, alongside the launch of a movement for a safe future. Furthermore, action is being demanded to better plan for increasingly severe events, including the conversion of military resources into early response teams. It is urged that a serious commitment to addressing the escalating crisis is being made, and that immediate, coordinated efforts are being undertaken to mitigate the ongoing impacts.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 2395: stance='favor', color=1.000(green)
#     arg1='It is recognized that addressing the challenges of stopping climate change and ensuring the well-being of low-income children are seen as intrinsically linked. Significant investments are being considered across a range of priorities, including initiatives to combat homelessness, address child hunger, support cancer research, reduce national debt, and fund realistic climate change initiatives, as well as providing public school lunch programs. The complexities of these interconnected issues are being acknowledged, and a holistic approach is being sought to tackle the multifaceted challenges facing society. It is understood that a coordinated strategy is needed to address both the urgent need for climate action and the fundamental needs of vulnerable populations.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 2440: stance='against', color=0.143(red)
#     arg1='Throughout history, fluctuations in Earth’s climate have been consistently observed, and it has been suggested that these shifts have occurred independently of human activity. Concerns have been raised regarding the extent to which current climate models accurately represent natural climate drivers, and it has been pointed out that historical records demonstrate climate variability extending far beyond the period of industrialization. The assertion that human activity is the dominant cause of current climate change has been questioned, with attention drawn to the long-standing recognition that climate has always changed, and continues to change, due to natural processes.', Gemma score=5.0
#     arg2='Throughout history, there have been numerous instances where natural forces have significantly influenced global temperature fluctuations. These influences are often observed in geological records such as ice cores and sediment layers that reveal patterns of climatic changes long before the onset of industrial activities.', Deepseek score=1.0
#   Topic 2498: stance='favor', color=0.692(green)
#     arg1='It is observed that a strong correlation between climate change and alien abductions is being promoted by Dr. Young-hae Chi, Professor at Oxford’s Oriental Institute. This theory is being presented, and it is being considered by econometricians. The issue of endogeneity is being highlighted, and it is being pushed onto today’s youth. Further investigation into this correlation is being urged, and it is being recognized as a significant concern.', Gemma score=1.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 2505: stance='favor', color=0.923(green)
#     arg1='It is observed that concerns regarding climate change are being expressed across various platforms, with assertions of its reality frequently accompanied by criticisms of those who deny or downplay its significance.  Significant investments and attention are being directed towards the issue, alongside accusations of misinformation and a lack of concern for the planet’s well-being.  The potential for negative impacts, particularly regarding the environment, is being highlighted, and questions are being raised about the motivations and capabilities of individuals and political figures to address the situation effectively.', Gemma score=3.0
#     arg2='It is widely acknowledged that there exists a significant global consensus regarding the reality of climate change, with both scientists and the general public expressing their agreement on this issue. The acknowledgment of climate change as real has been echoed across various platforms, including social media posts where individuals express their support for addressing environmental concerns related to climate change.', Deepseek score=1.0
#   Topic 2703: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant investment in reforestation efforts are being prioritized globally, reflecting a widespread understanding that substantial damage has already occurred.  The urgency to restore carbon-absorbing ecosystems is being felt across diverse regions, with considerable action being taken to address the consequences of past inaction.  Recognizing the critical role of forests in mitigating environmental challenges, a global commitment to planting trees is being actively pursued, driven by the acknowledgement that the opportunity to prevent further degradation is continually diminishing. It is understood that a concerted, ongoing effort to restore and expand forested areas is essential to address the observed changes.', Gemma score=4.0
#     arg2='It has been widely recognized that the most opportune time to plant trees for environmental benefit was in the past, with today being considered the next best opportunity. This sentiment highlights a growing awareness of the critical role played by forests and their capacity to absorb CO2 in mitigating climate change.', Deepseek score=1.0
#   Topic 2772: stance='against', color=0.000(red)
#     arg1='Misinformation regarding climate change has been propagated, with concerns raised about the manipulation of public opinion.  Distorted narratives surrounding climate activists have been circulated, often portraying them as driven by virtue signaling and ignoring broader societal issues like the Gilets Jaunes.  Questions have been posed about the motivations behind the promotion of climate change as a cause for political and economic gain.  The framing of climate change activism has been presented as a tool for manipulation and exploitation.', Gemma score=5.0
#     arg2='It has been suggested that the media moguls, in their diatribes against climate change protesters, have often questioned the authenticity of scientific evidence and its alignment with middle-class values. These critiques seem to overshadow genuine concerns about environmental impacts while selectively focusing on perceived hypocrisy within protest groups.', Deepseek score=1.0
#   Topic 2828: stance='favor', color=1.000(green)
#     arg1='It is increasingly recognized that significant concerns regarding climate change are being voiced by academics, who are being disregarded in favor of political narratives. Actions by oil company executives, including secret meetings with political figures, are being observed and criticized. The influence of these actors is seen as a deliberate attempt to derail initiatives aimed at addressing climate change and to shape the direction of Canadian policy. The need for a shift in focus, prioritizing scientific understanding and sustainable solutions, is repeatedly emphasized.', Gemma score=4.0
#     arg2='It is widely acknowledged that there are numerous academics who understand climate change, yet their perspectives often remain unconsidered in mainstream discussions. This discrepancy raises concerns about the extent to which local university experts are being consulted when discussing policies related to oil and gas production. Meanwhile, Canadian Conservative spokesmen appear to be advocating for positions that align with bigotry, ignorance, and support for Big Oil, potentially undermining efforts aimed at addressing climate change. As a result, there is an urgent need for greater engagement of diverse scientific voices in policy debates surrounding the environment.', Deepseek score=1.0

# %%
# Highest scores
max_score = max(df[score1_col].max(), df[score2_col].max())
print(f"\nHIGHEST SCORE FOUND: {max_score}")

max_score1_rows = df[df[score1_col] == max_score]
max_score2_rows = df[df[score2_col] == max_score]

if not max_score1_rows.empty:
    print(f"\n{model1_name} highest scores:")
    for idx, row in max_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not max_score2_rows.empty:
    print(f"\n{model2_name} highest scores:")
    for idx, row in max_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

print()
# Out:
# HIGHEST SCORE FOUND: 5.0
#
# Gemma highest scores:
#   Topic 0: stance='favor', color=0.997(green)
#     arg1='It is observed that a significant number of candidates are being positioned as committed to combating climate change, and a considerable effort is being directed towards framing this issue as a central priority.  The idea of candidates being targeted for their stances on this matter is being actively promoted, suggesting a widespread recognition of the importance of addressing climate change.  Furthermore, the focus on this issue is being amplified, indicating a collective desire to see it become a primary concern among the broader field of political contenders. ', Gemma score=5.0
#     arg2='It is widely recognized that there are numerous individuals committed to combating climate change, with Jay Inslee and Beto O'Rourke being among them. These real leaders have been advocating for the issue to become a top priority among other candidates in the political sphere. As such, it is urged that more support be given to these advocates of climate action, as they are seen as key figures in driving meaningful change on this critical global challenge.', Deepseek score=4.0
#   Topic 1: stance='favor', color=1.000(green)
#     arg1='It is increasingly recognized that significant challenges are being presented by the escalating impacts of climate change globally.  The urgency of the situation is being underscored by widespread concern, with action being taken by communities and individuals worldwide, including through initiatives like community energy and school strikes.  The responsibility for addressing this crisis is being increasingly attributed to those in positions of leadership, who are perceived to have failed to adequately respond.  Consequently, demands for immediate and decisive action are being made, emphasizing the need for governments to prioritize and implement effective solutions to mitigate the ongoing effects of climate change.', Gemma score=5.0
#     arg2='It is widely acknowledged that time is running out to stop catastrophic climate change, as leaders worldwide have failed in their responsibilities. However, people across the globe are taking action through community energy initiatives and school strikes, demonstrating a commitment beyond political boundaries. These actions demand urgent attention from governments globally, highlighting the need for immediate and decisive climate action.', Deepseek score=2.0
#   Topic 2: stance='favor', color=0.795(green)
#     arg1='It is observed that unpredictable weather patterns, such as snowstorms in April, are increasingly being linked to warmer temperatures.  Unusual weather events, like snow in April, are being attributed to the effects of warmer temperatures.  The perception of these events – such as snow in April – is being influenced by the notion of a shifting climate.  It is recognized that these shifts in weather patterns are being considered as indicators of a changing climate, and further investigation is being undertaken to understand the implications of these changes.', Gemma score=5.0
#     arg2='It appears that each year, the climate in Chicago behaves unpredictably, with snowfall occurring even in April and heatwaves persisting into May. These extreme weather events are increasingly being associated with global warming, suggesting a direct link between human activity and the changing climate patterns.', Deepseek score=4.0
#   Topic 4: stance='favor', color=0.796(green)
#     arg1='It is observed that a young person is being significantly impacted by concerns regarding climate change, a situation that is projected to affect generations to come. The vulnerability of this individual, coupled with the potential for manipulation by corporate interests and parental influence, is being highlighted. The propagation of fear surrounding climate change, driven by various actors, is being recognized as a widespread phenomenon, and the potential for harm resulting from this situation is being seriously considered. It is understood that the long-term consequences of this situation are being scrutinized, and the need for careful consideration of the situation is being emphasized.', Gemma score=5.0
#     arg2='It is widely acknowledged that climate change poses significant challenges for future generations, particularly those like the young girl with Aspergers and other vulnerabilities who are being actively supported in raising awareness about this issue. The actions of some individuals have been criticized for potentially exploiting her vulnerability or using her as a tool to advance their own agendas. Consequently, there is an urgent need for careful consideration and support of such vulnerable voices advocating for climate change action.', Deepseek score=4.0
#   Topic 5: stance='favor', color=0.964(green)
#     arg1='It is recognized that significant impacts are being felt across the globe, with considerable attention being directed towards the production, transportation, maintenance, recycling, and disposal of wind and solar technologies, as well as battery storage, alongside the broader implications of renewable energy sources. The reduction of carbon emissions is being prioritized, and the potential for cost savings and improved air quality are being actively pursued. Investments in these technologies are being championed as a crucial element in addressing the challenges of climate change and promoting a sustainable energy future. It is urged that these efforts be continued and expanded upon to mitigate the ongoing effects of climate change.', Gemma score=5.0
#     arg2='It is widely acknowledged that the production, transportation, maintenance, cleaning, lubrication, repair, and recycling of windmills and solar panels are significant contributors to environmental impact. Despite their role in promoting clean energy and combating climate change, these activities raise concerns about sustainability and ecological footprint. Consequently, there is a growing emphasis on addressing the broader lifecycle impacts associated with renewable energy technologies as part of global efforts to mitigate climate change.', Deepseek score=3.0
#   Topic 9: stance='favor', color=0.927(green)
#     arg1='It is observed that a significant increase in global temperatures is being linked to more frequent and severe wildfires, alongside a reduction in the number of trees that absorb CO2 due to widespread deforestation.  Attention is being drawn to the impact of these changes, with considerable concern expressed regarding the potential for irreversible damage to the planet.  Action is being sought, with numerous individuals and organizations advocating for collaborative efforts to address the escalating challenges and to safeguard the environment before critical thresholds are passed. It is recognized that a collective response is urgently needed to mitigate the observed trends and protect the planet’s ecosystems.', Gemma score=5.0
#     arg2='It is widely acknowledged that documentaries such as 'Our Planet' and 'Climate Change: The Facts', presented by Sir David Attenborough, have had a significant impact on raising awareness about the urgency of climate change. These programs highlight the need for collective action to save our planet before it is too late. As deforestation continues at an alarming rate, with fewer trees absorbing CO2, and wildfires becoming more frequent and severe due to rising global temperatures, there is a growing consensus that human activity plays a dominant role in driving climate change.', Deepseek score=4.0
#   Topic 13: stance='favor', color=0.909(green)
#     arg1='It is increasingly recognized that significant economic costs are being incurred due to the impacts of climate change, with extreme droughts, such as those affecting the Panama Canal, generating millions of dollars in losses. Furthermore, the many uncounted costs of climate inaction are being identified and factored in, and the potential for future droughts to pose serious risks to local populations are being acknowledged. It is urged that the costs of climate inaction are fully considered, and investments in climate action are prioritized to mitigate these escalating economic and societal risks.', Gemma score=5.0
#     arg2='It is widely recognized that climate change has led to extreme weather events such as severe droughts in the Panama Canal region, which are causing significant economic costs and posing serious risks to local populations. The cost of not taking action on climate change could be unimaginable, with businesses experiencing added costs due to its impacts even in the short term. Therefore, it is imperative that all uncounted costs of inaction related to climate change are identified and fully factored into any discussions about economic costs associated with acting on climate change.', Deepseek score=2.0
#   Topic 14: stance='favor', color=0.933(green)
#     arg1='It is recognized that the current level of human habitability of the planet is being negatively affected by climate change, with considerable worsening anticipated if action is not taken. The reduction in the planet’s capacity to absorb carbon dioxide is being observed, and the urgency for action to maintain the current level of human and other species habitability is increasingly apparent. It is understood that the consequences of inaction will be severe, and the need for immediate intervention is widely supported.', Gemma score=5.0
#     arg2='It has been widely acknowledged that climate change, as evidenced by its negative effects on humans and other species' habitability of the planet, is negatively affecting humanity right now and will continue to do so unless action is taken. This aligns with Extinction Rebellion's call for immediate measures to preserve the current level of planetary habitability in light of ongoing ecological challenges.', Deepseek score=4.0
#   Topic 17: stance='favor', color=0.625(yellow)
#     arg1='It is observed that protests are being staged across the globe, including in London, in response to the widespread and increasingly evident impacts of climate change. Concerns are being raised about the disproportionate focus on a single location, particularly when compared to regions experiencing significant air pollution, such as China and Korea. The urgency of addressing the global threat to the planet's environment is being emphasized, with calls for immediate action and a commitment to mitigating the effects of climate change, including a willingness to engage in dialogue and implement solutions within London. It is recognized that a global approach is necessary to address the widespread consequences of climate change.', Gemma score=5.0
#     arg2='It is widely acknowledged that there are protests taking place around the globe, with participants voicing concerns about climate change. These demonstrations occur not only in London but also in an additional eighty cities worldwide. The concern over climate change extends beyond national borders and affects every corner of the planet. It is urged that governments take note of these global protests to ensure they address the pressing issue of slowing down global warming for the safety of all inhabitants.', Deepseek score=2.0
#   Topic 19: stance='favor', color=0.715(green)
#     arg1='It is observed that a significant number of climate change deniers and downplayers within the UK are also associated with the Brexit project. Concerns are repeatedly raised that any form of Brexit, particularly when promoted by right-leaning factions, fails to address critical issues such as worker’s rights, the end of austerity measures, and action on climate change. The devastating potential impacts of climate change on the planet and all life forms are frequently juxtaposed against the Brexit trading bloc issue. It is repeatedly asserted that the consequences of Brexit, particularly under a Conservative government, are considered permanent for those suffering from its effects, and a fundamental shift in policy is urgently needed to mitigate the ongoing damage.', Gemma score=5.0
#     arg2='It has been observed that there exists a correlation between UK climate change deniers and pro-Brexit sentiments, suggesting that political affiliations may influence perspectives on environmental issues. This observation highlights the potential impact of political ideologies on public engagement with climate change discourse. It is widely acknowledged that addressing climate change requires collective action, yet it remains to be seen how these divergent views will shape future policies and actions related to environmental conservation.', Deepseek score=2.0
#   Topic 21: stance='favor', color=0.988(green)
#     arg1='It is recognized that local communities are central to protecting ecosystems against the impacts of climate change. It is noted that mayors are being tasked with addressing soil erosion, developing social policies that reduce environmental stress, and constructing coastal defenses. It is urged that action be taken by mayors to mitigate the effects of climate change and safeguard vulnerable communities.', Gemma score=5.0
#     arg2='It is widely recognized that in addressing the impacts of #climatechange, local communities play a significant role. Mayors are taking proactive steps to protect ecosystems by tackling soil erosion, implementing environmental policies, and fortifying coastal defenses. These actions reflect their commitment to mitigating the effects of climate change on vulnerable populations.', Deepseek score=4.0
#   Topic 23: stance='favor', color=0.971(green)
#     arg1='It is recognized that regardless of the method of acquisition, the burning of fossil fuels – whether through traditional or emerging techniques – results in the production of carbon dioxide and other greenhouse gases, leading to global warming. The reduction of fossil fuel extraction, particularly the closure of the dirtiest projects, is being advocated for, alongside the reskilling of workers for green technologies, as a necessary response to the ongoing effects of climate change.', Gemma score=5.0
#     arg2='It is widely acknowledged that the production of carbon dioxide and other greenhouse gases through the burning of fossil fuels such as oil, coal, and gas contributes significantly to global warming. This acknowledgment extends from traditional methods like fracking to newer extraction techniques, all leading to similar outcomes. The closure of environmentally detrimental projects, including those involving oilsands mines, is seen as a necessary response to climate change. It is urged that efforts be made to reskill workers for green technology or other sustainable work in order to mitigate the impacts of fossil fuel combustion on global temperatures.', Deepseek score=4.0
#   Topic 25: stance='favor', color=0.836(green)
#     arg1='It is recognized that addressing climate change is being viewed as a critical priority, with the Green New Deal being proposed as a means to effectively tackle this challenge. Concerns are being raised regarding the potential impacts of the Green New Deal, and efforts are being undertaken to understand its implications. The need for a comprehensive approach to climate change is being actively discussed, and the potential for significant changes is being considered. It is understood that a coordinated response is required to address the complex issues surrounding climate change and its effects.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 26: stance='favor', color=0.958(green)
#     arg1='It is recognized that climate change is disproportionately impacting women across the globe, with displacement driven by climate-related disasters predominantly affecting them. The need for multi-dimensional data, encompassing interactions between genders and the environment, alongside age, diversity, income, and location, is increasingly emphasized. Accelerating gender equality through women as agents of change within Nationally Determined Contributions is being actively pursued, highlighting the urgency of integrating gender considerations into climate action strategies.', Gemma score=5.0
#     arg2='It is widely acknowledged that climate change disproportionately affects women, with a significant number of displaced persons being women and the UNDP highlighting their involvement in climate action as agents of change. The need for multi-dimensional data to understand how gender interacts with environmental factors has been emphasized, urging holistic decision-making processes that take into account age, diversity, income, and location.', Deepseek score=2.0
#   Topic 29: stance='favor', color=0.818(green)
#     arg1='It is observed that severe flooding events, such as those experienced recently, are consistently linked to historical hydrological patterns within flood plains, exacerbated by snow accumulations and weather conditions. The impact of surface water run-off and siltation within these areas is frequently cited as a contributing factor to the severity of these events.  The influence of weather conditions and snow accumulation are consistently highlighted as key elements in the occurrence of these floods. It is recognized that the attribution of these events to broader climate change is frequently challenged by the demonstrable presence of established flood dynamics and local factors.', Gemma score=5.0
#     arg2='It has been widely acknowledged that the severity of floods, particularly those resulting from heavy snowfall in areas where floodplains are prone to seasonal runoff, can be attributed primarily to climatic factors such as significant snow accumulation and specific meteorological conditions. These elements have historically influenced the hydrological patterns within these regions, leading to flooding events that are not necessarily indicative of broader climate change trends. Consequently, while there is a shared concern about flood severity, it is important to recognize that this phenomenon has deep historical roots in local hydrology rather than being solely attributable to human-induced climatic changes.', Deepseek score=4.0
#   Topic 30: stance='favor', color=0.995(green)
#     arg1='It is recognized that numerous approaches to teaching climate change are being explored across diverse subjects and classrooms.  Various methods, including laboratory experiments, literary analysis, and service projects, are being utilized to engage students. Resources are being developed and shared to support these diverse pedagogical approaches.  It is understood that a range of learning experiences are being implemented to foster understanding and engagement with the complex issues surrounding climate change.', Gemma score=5.0
#     arg2='It is widely acknowledged that there are numerous ways to teach climate change in almost any classroom, including conducting labs, reading novels, or engaging in service projects. These educational approaches aim to foster a deeper understanding of the complex environmental issue and inspire students to take action against climate change.', Deepseek score=3.0
#   Topic 34: stance='favor', color=0.858(green)
#     arg1='It is increasingly recognized that significant changes are being observed across the globe, with alarming consequences for the planet’s systems. The potential for irreversible damage to Earth’s ecosystems is being highlighted, particularly concerning the escalating impacts of ongoing changes. The possibility of locking in detrimental feedback systems, leading to long-term, potentially catastrophic consequences, is being seriously considered.  The urgency of addressing these issues is being emphasized, with the recognition that substantial and immediate action is required to mitigate the risks associated with these ongoing transformations.', Gemma score=5.0
#     arg2='It is widely acknowledged that climate change poses a significant threat to our planet, with its effects becoming increasingly evident and potentially irreversible. The increasing frequency of extreme weather events, rising global temperatures, and the loss of carbon-absorbing forests are all consequences of human activity contributing to this crisis. As such, there is an urgent need for concerted efforts to mitigate climate change and protect the environment from further damage.', Deepseek score=4.0
#   Topic 36: stance='favor', color=0.682(green)
#     arg1='It is recognized that a price on pollution is being advocated, with carbon taxes being proposed to curb consumer behavior and ensure that emissions are not exported. Simultaneously, it is understood that a fair tax is being suggested, one that reflects the cost of utilizing carbon.  Furthermore, it is acknowledged that a real price on climate change pollution is being sought, and that a mechanism for reducing consumption through taxation is being considered to mitigate the ongoing effects of climate change.', Gemma score=5.0
#     arg2='It has been widely acknowledged that the implementation of carbon pricing, combined with border tax adjustments and rebates for citizens, is seen as an effective strategy in ensuring that emissions are not exported while also minimizing impact on working-class Americans. This approach aligns with scholarly research advocating for taxes to curb consumer behavior related to carbon use, thereby contributing to a reduction in greenhouse gas emissions.', Deepseek score=4.0
#   Topic 37: stance='favor', color=0.884(green)
#     arg1='It is observed that nationwide, students have been skipping school as part of a national strike for climate change, and students in cities worldwide have skipped classes to protest their governments' failure to act against global warming.  Remarkably, it has been driven that climate change is being brought up the agenda at a time when so much else is dominating political discourse and the news cycle.  It is recognized that the actions of these students are being taken to highlight the urgency of the situation, and the need for governments to prioritize climate action.', Gemma score=5.0
#     arg2='It has become increasingly evident that school strikes across cities worldwide have effectively drawn attention to the urgent need for action against global warming, despite some reservations about their impact on daily education. These protests highlight a growing concern among young people regarding climate change and its consequences, which is driving discussions around environmental issues in an otherwise dynamic political landscape.', Deepseek score=4.0
#   Topic 38: stance='favor', color=0.993(green)
#     arg1='It is recognized that declining average farm revenue, coupled with the challenges posed by erratic rainfall, extended dry periods, and the impacts of urbanization, are being experienced by farmers globally. Furthermore, obstacles to adopting agroforestry practices are being identified, and the need for increased farmer economic returns is being acknowledged. It is understood that solutions are being sought to enhance farm resilience to climate change and to attract a new generation to farming, highlighting the urgency of addressing these interconnected issues.', Gemma score=5.0
#     arg2='It is widely recognized that the agricultural sector faces significant challenges, including decreasing farm revenue and difficulties in attracting a new generation of farmers. These issues are exacerbated by erratic rainfall patterns and extended dry periods, which hinder food production. To address these concerns, there is an increasing emphasis on agroecology as a means to enhance farmer earnings while making farms more resilient to climate change impacts. The goal is to improve the economic return for farmers and potentially attract a new generation of agricultural practitioners who can adapt to changing environmental conditions.', Deepseek score=4.0
#   Topic 41: stance='favor', color=0.992(green)
#     arg1='It is recognized that the potential of forests for climate change mitigation and adaptation is being increasingly considered.  Attention is being directed towards the need for a new approach to forest management, one that fully accounts for the role of forests.  Discussions are taking place regarding the enhancement of forest resilience against the impacts of fires, pest outbreaks, and storms.  Furthermore, the role of forests as value chains and engines of growth is being analyzed, alongside the imperative to prioritize ecosystem restoration and sustainable forest management practices.', Gemma score=5.0
#     arg2='It is increasingly recognized that the potential for forests and their ecosystems to serve as natural climate solutions is being discussed, with a focus on ecosystem restoration rather than plantations. The importance of enhancing resilience against fires, pest outbreaks, and storms is highlighted in discussions about how forests can contribute to climate change mitigation and adaptation. These perspectives underscore the need for integrated policies that consider both the ecological integrity and economic potential of forest ecosystems.', Deepseek score=4.0
#   Topic 43: stance='favor', color=0.921(green)
#     arg1='It is increasingly recognized that the concerns of children regarding the state of the planet are being amplified, with significant consequences being observed globally. The impacts of climate change are being increasingly felt, leading to a shift in lifestyle choices – reduced flying, driving, smaller homes, and fewer children – among younger generations.  The urgency of addressing the situation is being underscored by the anxieties of children and grandchildren, and action is being demanded to mitigate the escalating effects of climate change before further irreversible damage is done.', Gemma score=5.0
#     arg2='It is widely acknowledged that climate change has become a significant concern for children and their families, leading to worries about the future of the planet. As protests against climate change continue around the world, there is an increasing recognition of the need for drastic changes in lifestyle, including reduced flying, driving, and living in smaller homes, as well as fewer children being born due to these concerns. The restoration of environmental balance through collective action has become a central theme in addressing the consequences of climate change.', Deepseek score=4.0
#   Topic 47: stance='favor', color=0.970(green)
#     arg1='It is increasingly recognized that significant changes are being observed globally, with rising temperatures and the rapid pace of these changes being attributed to a complex interplay of factors. Concerns are being voiced that leaders are failing to adequately address the situation, and that action is being delayed. It is noted that the implementation of measures to combat climate change is being perceived as insufficient, and that further, more decisive action is urgently needed to mitigate the potential for widespread disaster. The need for transparency and accountability is being emphasized, alongside a call for immediate and comprehensive solutions.', Gemma score=5.0
#     arg2='It is widely recognized that the impacts of climate change are becoming increasingly catastrophic and urgent worldwide. The acknowledgment of this reality has led to a global call for action, with people demanding more decisive measures from their leaders in response to the ongoing crisis. Despite claims of leadership, many governments have yet to implement comprehensive strategies or take significant steps towards mitigating the effects of climate change, raising concerns about the adequacy of current efforts and leading to calls for greater accountability.', Deepseek score=4.0
#   Topic 52: stance='favor', color=0.607(yellow)
#     arg1='It is observed that a widespread rebellion is rising, driven by concerns regarding the escalating impacts of climate change. The framing of climate change as apolitical, alongside analyses of state power and policing, is being questioned. Simultaneously, efforts are being undertaken by individuals to diversify tactics and broaden the movement’s reach. The need for swift action and strategic realignment is being recognized, with a focus on identifying allies and adversaries within the broader struggle for change.', Gemma score=5.0
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#   Topic 54: stance='favor', color=0.993(green)
#     arg1='It is recognized that significant concern is being expressed regarding the health impacts of climate change, with a focus on empowering medical professionals to respond effectively. A new toolkit is being developed and disseminated by @CAPE_Doctors, alongside support from organizations like @WoncaWorld and @GCHAlliance, to address these concerns. The development of this toolkit is being actively promoted by various stakeholders, including @Pembina, to equip healthcare providers with the necessary resources to address the challenges posed by climate change.', Gemma score=5.0
#     arg2='It has been recognized that empowering healthcare professionals with the necessary tools and resources is crucial in addressing the health-related implications of climate change. A recent initiative by CAPE, a group dedicated to promoting environmental sustainability within the medical community, has resulted in the creation of an innovative toolkit designed to aid healthcare providers in their efforts to combat the detrimental effects of climate change on public health. This resource empowers professionals with actionable steps and information that can be utilized at both individual and institutional levels to mitigate the impact of a warming planet on human well-being.', Deepseek score=4.0
#   Topic 56: stance='favor', color=0.981(green)
#     arg1='It is recognized that significant changes in food choices are being considered globally, driven by a growing awareness of the interconnectedness between food systems and climate change. The impact of food choices is being generalized and assessed, with a focus on understanding how these choices contribute to broader challenges like climate change, migration, and poverty.  Action is being urged around rethinking food policy, and a shift towards more sustainable food systems is being actively explored as a crucial element in addressing these complex, interconnected problems.', Gemma score=5.0
#     arg2='It is widely acknowledged that food choices contribute significantly to climate change, with individuals being encouraged by various sources to consider the impact of their dietary habits in comparison to those of others and to make changes accordingly. The urgency for action within the realm of food policy has been highlighted as a potential solution to interconnected problems such as migration and poverty, all while acknowledging the importance of making informed decisions about what one eats.', Deepseek score=2.0
#   Topic 58: stance='favor', color=0.966(green)
#     arg1='It is recognized that surface transportation is being identified as a significant source of greenhouse gas emissions, and therefore a substantial contributor to global #climatechange. The disruption of public transport is being explored as a potential solution, alongside the development of technologies like Vertical Take-Off and Landing systems. It is understood that a challenge exists in meeting growing demand for convenient mobility while simultaneously reducing congestion, improving safety, and mitigating the effects of #climatechange. Investments in innovative transportation solutions are being considered to address this complex global issue.', Gemma score=5.0
#     arg2='It is widely recognized that surface transportation, particularly through traffic congestion in city streets, contributes significantly to greenhouse gas emissions and thus to global climate change. The reduction of such congestion has been proposed as a key strategy for combating these environmental impacts. Advocates suggest that improving urban mobility can play a crucial role in mitigating the effects of climate change by reducing vehicular emissions. As public transportation is disrupted less frequently, it is seen as an essential component in addressing this challenge. Efforts to enhance convenience and safety while minimizing congestion are being explored, including the potential use of Vertical Take-Off and Landing (VTOL) vehicles. These initiatives aim to balance growing demands for mobility with environmental sustainability goals.', Deepseek score=4.0
#   Topic 61: stance='favor', color=0.983(green)
#     arg1='It is increasingly observed that extreme weather events, such as Cyclone Idai and Cyclone Kenneth, are occurring with heightened intensity and frequency. The devastating impacts of these storms, including widespread flooding and loss of life, are being linked to alterations in weather patterns, with climate experts believing that these events are being intensified by climate change. Humanitarian efforts are being hampered by the increased severity of these storms, and the need for proactive measures to address the growing threat of extreme weather is being recognized globally.', Gemma score=5.0
#     arg2='It is widely acknowledged that the intensification of cyclone activity, as evidenced by consecutive severe storms such as Cyclone Idai and Cyclone Kenneth striking Mozambique within a short period, highlights how climate change is altering weather patterns. The increasing frequency and severity of these natural disasters are being recognized globally as direct consequences of rising global temperatures and changing climatic conditions. As a result, the need for urgent action to address the impacts of climate change on extreme weather events has become increasingly evident.', Deepseek score=5.0
#   Topic 64: stance='favor', color=0.944(green)
#     arg1='It is recognized that a significant investment of $5 trillion is being proposed to address the climate crisis.  A sweeping plan is being developed with the aim of combating climate change, and substantial resources are being allocated to this effort.  The development of this plan is being driven by concerns regarding the impacts of climate change, and its implementation is seen as a crucial step in mitigating these effects.  The plan’s goals are being pursued with the understanding that substantial action is needed to address the challenges posed by a changing climate.', Gemma score=5.0
#     arg2='It is widely recognized that there are various strategies being proposed by political figures in response to the pressing issue of combating climate change. Among these, Beto O'Rourke has recently unveiled an ambitious plan which proposes a significant financial investment towards addressing this global crisis. This approach underscores the prevailing concern regarding human activity as a major driver of current climatic changes and reflects the collective efforts being made by leaders to mitigate its effects.', Deepseek score=2.0
#   Topic 66: stance='favor', color=0.979(green)
#     arg1='It is observed that a preoccupation with adventure and military operations, alongside a lack of attention to environmental issues and habitat loss, is being noted. Simultaneously, a significant concern is being expressed regarding the prioritization of historical narratives over contemporary challenges, particularly concerning climate change.  Furthermore, a call is being made for a shift in focus, urging that the attention of citizens be directed towards pressing environmental issues and the need for proactive solutions, rather than debates surrounding historical events. It is recognized that a concerted effort is required to address the ongoing challenges and to prioritize sustainable practices for the future.', Gemma score=5.0
#     arg2='It is widely acknowledged that the younger generation's fascination with adventure and surgical strikes may be contributing to a lack of concern for environmental issues, habitat loss, and climate change. This perspective has been echoed in various discussions about India's position on the Environment Performance Index at 177 out of 180 countries, as well as by activists urging Delhiites to consider these matters during elections.', Deepseek score=4.0
#   Topic 67: stance='favor', color=0.967(green)
#     arg1='It is recognized that the desecration of Loch Lomond, driven by greed and profit, is contributing to broader environmental concerns.  A shift away from the neoliberal capitalist agenda is being advocated by other parties in Scotland, and a commitment to act on the advice of @theCCCuk is being reaffirmed by @NicolaSturgeon, with Scotland aiming to lead by example in achieving climate change targets.  The urgency of addressing these issues is increasingly apparent, and a transition towards policies that prioritize environmental protection is being actively sought.', Gemma score=5.0
#     arg2='It is widely recognized that the desecration of Loch Lomond for greed and profit, as well as neoliberal capitalist policies in Scotland, are contributing to climate change. The Labour Party's policies offer a potential solution by advocating for measures against further climate change, which aligns with the commitment of the Scottish government to lead by example. Consequently, there is an urgent need for action to mitigate these adverse effects on both environmental and economic fronts.', Deepseek score=4.0
#   Topic 68: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant shifts in the climate are being observed globally, and that the trajectory of these changes was not predetermined. Concerns are being raised regarding the utilization of specific arguments to deflect attention from the core issues surrounding climate change, particularly when applied to unrelated debates. It is noted that a clearer communication of the underlying concerns regarding the climate’s direction is being sought, and that a more focused approach is deemed necessary to address the challenges presented by the evolving climate situation.', Gemma score=5.0
#     arg2='It is widely acknowledged that human activity has significantly influenced global temperatures and weather patterns, leading to more frequent and severe natural disasters such as wildfires and hurricanes. The reduction of carbon-absorbing trees through deforestation exacerbates the problem by increasing CO2 levels in the atmosphere. As a result, governments are urged to invest in reforestation programs that can help mitigate climate change.', Deepseek score=5.0
#   Topic 69: stance='favor', color=0.984(green)
#     arg1='It is observed that significant efforts are being undertaken by numerous celebrities and organizations to address the pressing concerns surrounding climate change. Profits from a collaborative musical project are being directed towards partners implementing solutions on the frontlines. Furthermore, it is recognized that widespread awareness and action are being promoted through the engagement of individuals and the encouragement of collective efforts to influence family and friends. It is noted that the promotion of sustainability and the protection of the planet are being prioritized through various initiatives and campaigns.', Gemma score=5.0
#     arg2='It is widely acknowledged that celebrities such as @lildickytweets and their fellow artists have come together to create the song '#WeLoveTheEarth', which has seen profits from its sales, video, and merchandise donated to various partners on the frontlines of implementing solutions for climate change. This initiative highlights how popular culture can contribute to environmental conservation efforts by raising awareness and funds for sustainability initiatives.', Deepseek score=4.0
#   Topic 70: stance='favor', color=0.982(green)
#     arg1='Significant pressures are being placed upon African and Asian elephants, alongside numerous smaller species, due to habitat loss, the ivory trade, and the impacts of climate change. The precarious future of these animals is being recognized, and their vital roles as ‘nature’s gardeners’ – contributing to forest growth and mitigating climate change – are increasingly valued. Conservation efforts are being directed towards maintaining their natural ranges, and a heightened focus on protection measures is being advocated to safeguard their survival.', Gemma score=5.0
#     arg2='It is widely recognized that giraffes in Africa face a precarious future due to their dwindling numbers, with fewer than 70,000 fully grown individuals remaining. This situation underscores the urgent need for increased protection measures as these animals are integral to maintaining biodiversity and ecosystem health. Elephants, known as 'nature's gardeners,' play a crucial role in forest growth and habitat creation, which is essential for mitigating climate change. Their conservation efforts must be supported within their natural habitats rather than relying solely on zoos. The plight of giraffes and elephants highlights the interconnectedness of wildlife with broader environmental challenges such as habitat loss, ivory trade, and climate change.', Deepseek score=4.0
#   Topic 71: stance='favor', color=0.934(green)
#     arg1='It is recognized that a global response to climate change is being sought through the Paris Agreement, aiming to lower worldwide greenhouse gas emissions. The urgency of the situation is continually reinforced by the need to strengthen this agreement, and by the ongoing efforts to promote renewable energy, heat recovery, and low-carbon kitchens. Furthermore, the reality of the situation is being acknowledged through the actions of policy makers, who are working to ensure the survival of the Paris Accord and to address the challenges posed by climate change.', Gemma score=5.0
#     arg2='It is widely recognized that the Paris Agreement, an international accord aimed at reducing worldwide greenhouse gas emissions and mitigating climate change, has been instrumental in strengthening global responses to this significant threat. Despite eleventh-hour agreements reached during recent United Nations climate change conferences, there remains a pressing need for continued commitment and action towards addressing the sobering reality of climate change.', Deepseek score=4.0
#   Topic 72: stance='favor', color=0.989(green)
#     arg1='It is observed that significant action regarding climate change is being impeded by political divisions and obstruction within the new Congress. The prioritization of climate change is being challenged, and efforts to address the issue are being hampered by procedural restrictions and the denial of crucial investigative powers. Furthermore, a pattern of unproductive political behavior, characterized by bickering and the obstruction of progressive agendas, is being witnessed. It is urged that a more focused and collaborative approach to addressing the complex challenges presented by climate change be adopted.', Gemma score=5.0
#     arg2='It has been observed that there is a growing consensus among various stakeholders for prioritizing climate change mitigation efforts, as evidenced by the recent actions taken in Congress and public discourse. The focus on real issues rather than bickering like children indicates a shift towards addressing pressing environmental concerns collectively.', Deepseek score=4.0
#   Topic 73: stance='favor', color=0.968(green)
#     arg1='It is recognized that significant risks are being posed to climate and communities by projects like the Adani mine. The potential for massive carbon emissions is being actively considered, and a shift towards renewable energy sources is increasingly seen as a necessary response. The implications of continued fossil fuel expansion are being evaluated, and a transition to cleaner energy solutions is being advocated to mitigate the escalating impacts on the planet and its communities. It is urged that investments be made to support a just transition and reduce the risk of further environmental damage.', Gemma score=5.0
#     arg2='It has been widely acknowledged that avoiding catastrophic climate change requires the cessation of coal extraction, particularly in projects like the Adani mine which could potentially release massive amounts of carbon into the atmosphere. The transition to renewable energy sources is seen as essential for reducing greenhouse gas emissions and mitigating the impacts of global warming on communities worldwide. Consequently, efforts to prevent new coal mines from being developed are crucial, with a focus on sustainable alternatives that support both climate goals and economic justice.', Deepseek score=5.0
#   Topic 76: stance='favor', color=0.978(green)
#     arg1='It is increasingly recognized that activities related to energy production are being linked to significant environmental challenges. Calls for bans on fracking, such as those originating from Salford City Council and the Greater Manchester Ban on Fracking, are being made in response to concerns regarding the detrimental impacts of energy extraction. These impacts, including the reduction of CO2, air and water pollution, and threats to public health, are being highlighted as contributing to broader environmental issues.  Investments in alternative energy sources are being advocated as a necessary response to these escalating concerns.', Gemma score=5.0
#     arg2='It has been widely recognized that the decision to ban fracking in Greater Manchester is a significant step towards mitigating climate change, reducing CO2 emissions, and addressing air and water pollution concerns. This move by local authorities reflects an acknowledgment of the urgent need for action against environmental hazards associated with fossil fuel extraction practices.', Deepseek score=4.0
#   Topic 77: stance='favor', color=0.936(green)
#     arg1='It is observed that analysis of social media conversations, particularly through text analytics applied to platforms like Twitter, is being undertaken to understand the scope and urgency of concerns surrounding climate change. The amplification of voices advocating for immediate action, as evidenced by the high rates of retweets and the prominence of figures like Greta Thunberg, is being recognized. Furthermore, efforts are being made to elevate awareness of the issue through various channels, including media engagement and the dissemination of information. It is understood that a significant volume of discussion is focused on the need for accelerated action to address the perceived threats posed by climate change.', Gemma score=5.0
#     arg2='It has been observed that the influence of social media platforms, particularly Twitter, plays a significant role in shaping public discourse on climate change. The analysis conducted using text analytics tools reveals the prominence of Greta Thunberg and the We Don't Have Time movement within this digital space. Additionally, numerous tweets from various accounts highlight the human-centric perspective of climate change, emphasizing its impact on people and their lives. These online conversations underscore a broader trend where individuals are increasingly vocal about environmental issues through social media channels.', Deepseek score=4.0
#   Topic 80: stance='favor', color=0.855(green)
# ...
#   Topic 2916: stance='favor', color=1.000(green)
#     arg1='It is recognized that the beauty of ‘The Earth’ is being diminished by lavish spending and luxurious living, and that efforts to slow human-influenced global warming are being urgently pursued. The preservation of our planet is being championed, with donations being made to organizations like nrdc_org, and a call is being issued to protect this ‘God’s gift’ for future generations. The potential loss of this unique home is being highlighted, and action is being urged to prevent the fading of its beauty into a mere memory.', Gemma score=4.0
#     arg2='It has become widely recognized that protecting our planet is of paramount importance, with individuals and organizations increasingly contributing towards environmental conservation efforts. In line with this growing concern for nature's preservation, numerous donations are being made to support causes such as those championed by the nrdc_org. This commitment reflects a collective acknowledgment of the urgent need to safeguard Earth’s natural resources for future generations. The ongoing dedication to combat climate change through various initiatives underscores the importance of concerted action in preserving our planet's beauty and sustainability.', Deepseek score=5.0
#   Topic 2919: stance='favor', color=1.000(green)
#     arg1='It is observed that concerns regarding climate change have been raised for decades, with predictions repeatedly failing to materialize.  Changes in the terminology surrounding the issue have been noted, alongside a persistent denial of the threat.  It is recognized that anxieties about the potential impacts of climate change have been consistently expressed, and efforts to address the issue have been met with skepticism and a reluctance to acknowledge the severity of the situation.  It is understood that a lack of demonstrable results from previous predictions has fueled continued debate and resistance to action.', Gemma score=4.0
#     arg2='It has been widely acknowledged that the denial of climate change by certain political parties has contributed significantly to the ongoing debate surrounding its existence and effects. This stance has led to a delay in implementing necessary measures to combat global warming, despite numerous predictions about its consequences over several decades. As a result, there is an urgent need for these political entities to reconsider their positions on this critical issue, recognizing that climate change poses a significant threat to the environment and humanity.', Deepseek score=5.0
#   Topic 2921: stance='favor', color=1.000(green)
#     arg1='It is recognized that trees and forests are being utilized worldwide to apply a heat shield to the planet, with the evaporation of transpiring water generating clouds that reflect solar warming rays back into space. The formation of these clouds is being observed, and it is understood that a significant portion of all clouds are being created in this manner.  Investments in the preservation and expansion of forests are being considered as a crucial element in mitigating the effects of climate change, with the protection of these natural systems being prioritized.', Gemma score=4.0
#     arg2='It is widely acknowledged that trees and forests play a crucial role in protecting the planet from climate change by forming clouds through their transpiring water, which reflects solar rays back to space. This natural heat shield helps mitigate global warming, as evidenced by numerous studies and reports emphasizing the importance of preserving these carbon-absorbing ecosystems for our survival.', Deepseek score=5.0
#   Topic 2931: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant challenges are being presented by evolving technology, the demands of #climatechange, and shifting public tastes, particularly within the agricultural sector.  The need for adaptive and mitigative agricultural approaches, alongside healthy farming practices, is increasingly being highlighted.  Furthermore, interventions focused on nutritional health, such as the #OwnAKitchenGardenCampaign and the #TheYoungFarmersClub, are being explored.  A multi-sectoral forum, integrating science and law, is being convened to address the impacts of climate change on food and agriculture, specifically within Connecticut, and to champion solutions for a sustainable future.', Gemma score=4.0
#     arg2='It is widely recognized that adaptive and mitigative agricultural approaches, healthy farming practices, and the development of innovative technologies are essential in addressing the challenges posed by climate change. The integration of science and law through multi-sectoral forums such as those hosted by institutions like UConn further underscores the collaborative efforts to tackle the impacts of climate change on food security and agriculture. As public tastes evolve and technology advances, it is imperative that agricultural interventions championing nutritional health initiatives continue to be championed by organizations like ISNHI and supported by young farmers through platforms such as The Young Farmers Club.', Deepseek score=5.0
#   Topic 2938: stance='favor', color=1.000(green)
#     arg1='It is increasingly recognized that declarations of climate emergencies are being made across the UK, including by the UK Parliament, the Welsh and Scottish governments, and numerous towns and cities. Furthermore, action is being coordinated by environmental, community, and faith organizations to pressure County Councils to take decisive steps. The urgency of the situation is being underscored by the widespread acknowledgement that significant and immediate action is required to address the escalating impacts of climate change.', Gemma score=4.0
#     arg2='It has been widely recognized by various governmental and non-governmental entities across different regions of the world that climate change poses significant threats to environmental sustainability, public health, and economic stability. As such, declarations of emergencies at multiple levels—from national parliaments to local communities—reflect a collective acknowledgment of the urgent need for intensified action against climate change. These declarations signify not only an acceptance of the severity of the situation but also serve as catalysts for galvanizing efforts towards mitigating its impacts.', Deepseek score=5.0
#   Topic 2949: stance='favor', color=0.900(green)
#     arg1='Significant investments are being proposed and allocated globally to address climate change, while substantial expenditures are being accepted without scrutiny in relation to water buybacks. Large sums of money are being spent on climate initiatives, yet concerns are raised regarding the lack of accountability and justification for other significant financial commitments. The potential for future costs, including those associated with climate change, are being considered, and the long-term implications of current spending decisions are being debated. It is recognized that a comprehensive approach to addressing global challenges requires careful consideration of all expenditures and their potential impact.', Gemma score=4.0
#     arg2='It is widely acknowledged that the costs associated with fighting climate change are substantial, amounting to billions of dollars. Despite this, there remains a significant level of public support for addressing these issues, as seen in calls for a Royal Commission into waterbuybacks and investments in renewable energy infrastructure. The reluctance to invest in measures aimed at mitigating climate change is juxtaposed against the acceptance of such costs when it comes to other sectors or industries. This dichotomy reflects a broader societal tension between acknowledging the necessity of action and grappling with the financial implications associated with addressing environmental challenges.', Deepseek score=5.0
#   Topic 2954: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant investment opportunities are being explored in response to the challenges posed by dramatic climate change.  Investment strategies are being developed to align with personal aims and opinions regarding sustainability and impact investing.  Attention is being directed towards understanding asymmetric investing and its application within the context of addressing the ongoing effects of climate change.  Steps are being taken to incorporate these considerations into financial planning and investment strategies, and further investigation into approaches to combatting climate change is being undertaken.', Gemma score=4.0
#     arg2='It has been widely recognized that investment strategies play a pivotal role in addressing climate concerns, with sustainable investments gaining traction as individuals seek to align their financial goals with environmental sustainability. The approach of impact investing and the advocacy for sustainable practices are increasingly being incorporated into personal financial planning, reflecting a collective effort towards combating climate change. As such, there is an ongoing emphasis on integrating these principles within investment strategies, thereby benefiting from both financial growth and ecological conservation.', Deepseek score=5.0
#   Topic 2959: stance='favor', color=1.000(green)
#     arg1='It is recognized that a significant project, Bluenote, is being promoted, attracting considerable interest and recommendations. The project’s potential for success is widely anticipated, and its growth is being actively encouraged through recommendations and calls to action. Attention is being drawn to the project’s relevance within the realms of blockchain, crowdfunding, and energy efficiency, and its continued development is being supported by a network of followers and advocates.', Gemma score=4.0
#     arg2='It is widely acknowledged that the scope of Very Interesting Company, with its potential to attract all users and achieve significant results in blockchain technology and energy efficiency, will play a crucial role in addressing climate change. The company's innovative approach through crowdfunding initiatives has been met with enthusiasm by supporters who believe it offers the best opportunity for success. As such, there is an urgent call for collaboration and investment in projects that align with these goals to ensure their impact on global sustainability efforts.', Deepseek score=5.0
#   Topic 2963: stance='favor', color=1.000(green)
#     arg1='It is observed that significant wealth disparities are being amplified by climate change, supported by 50 years of data. Progress is being hampered by climate change, and the consequences of this are being recognized globally.  It is understood that responsible and fair governance is being considered as a crucial element in ensuring that the benefits of prosperity are shared equitably.  The ongoing effects of climate change are being acknowledged, and action is being urged to address the challenges presented.', Gemma score=5.0
#     arg2='It is widely recognized that climate change disproportionately affects the prosperous regions and populations while exacerbating wealth disparities, with significant impacts on economic growth and development. As a result of these changes, there are calls for responsible governance to ensure fair distribution of resources and protection against adverse effects of climate change. It is urged that policies be enacted to mitigate the negative consequences of climate change on prosperity and to promote sustainable practices across all sectors.', Deepseek score=5.0
#   Topic 2964: stance='favor', color=1.000(green)
#     arg1='It is recognized that the Belt and Road Initiative is being viewed as potentially exacerbating climate change and harming biodiversity. Concerns are being raised regarding its impact on emissions, and the need to address the environmental consequences of infrastructure development is increasingly emphasized. The potential for negative impacts on biodiversity is also being scrutinized, and a halt to the initiative is being considered if significant environmental harm is demonstrated. It is urged that the environmental impact of the initiative be thoroughly assessed and addressed to prevent catastrophic climate change.', Gemma score=4.0
#     arg2='It has been widely acknowledged that China's Belt and Road Initiative could potentially obliterate any chance of reducing emissions, tipping the world into catastrophic climate change. The environmental impact of such a large-scale infrastructure project is seen as critical, with concerns raised regarding its potential to exacerbate climate change or harm biodiversity.', Deepseek score=5.0
#   Topic 2967: stance='favor', color=1.000(green)
#     arg1='It is recognized that collaborative efforts, including partnerships between entities like the UAE and initiatives such as those undertaken at @grist, are being pursued to address the escalating challenges posed by climate change. Engagement projects, such as those involving audience interaction and facilitated discussions on solutions, are being developed and implemented. The need for collaborative approaches and proactive engagement are increasingly being highlighted as crucial elements in responding to the growing concerns regarding the planet’s climate.', Gemma score=4.0
#     arg2='It is widely acknowledged that the growing problem of climate change, as evidenced by more frequent and severe weather events such as wildfires and extreme temperatures, has been exacerbated by human activities. The reduction in carbon-absorbing trees due to deforestation contributes significantly to this issue. Governments, along with private entities like educational institutions and media organizations, are urged to take constructive steps that contribute to climate change adaptation and mitigation efforts. This includes forming new partnerships for reforestation programs, collaborating on forums dedicated to discussing solutions, and engaging audiences in dialogue about the impacts of climate change.', Deepseek score=5.0
#   Topic 2969: stance='favor', color=0.900(green)
#     arg1='It is observed that significant shifts in global environments are occurring, prompting concerns about the implications for communities and infrastructure.  Questions are raised regarding the acknowledgement of these changes by certain groups, particularly when faced with demonstrable evidence of environmental degradation.  It is noted that actions, or lack thereof, are being scrutinized, with some prioritizing short-term gains over long-term sustainability.  The potential for future consequences, including the displacement of populations and the deterioration of built environments, is being recognized, and the need for proactive measures is increasingly apparent.  It is recognized that a failure to address these issues will have significant and lasting repercussions.', Gemma score=4.0
#     arg2='It is widely acknowledged that cities are sinking into the ocean, necessitating the reassignment of missionaries by the IMB due to climate change. Despite studies published since the 1970s highlighting the truth about global warming, evangelicals continue to express skepticism and doubt regarding human-driven climate change. This stance often involves a deep-seated belief in divine intervention rather than acknowledging the role of human activity as a dominant driver of environmental degradation.', Deepseek score=5.0

# %%
# Cross-tabulation analysis
print("=== CROSS-TABULATION ANALYSIS ===")
print("STANCE vs COLOR CATEGORY:")
cross_tab = pd.crosstab(df[stance_col], df['color_category'])
print(cross_tab)
print()

# Performance matrix
print("AVERAGE SCORES BY STANCE AND COLOR CATEGORY:")
pivot_score1 = df.pivot_table(values=score1_col, index=stance_col, columns='color_category', aggfunc='mean')
pivot_score2 = df.pivot_table(values=score2_col, index=stance_col, columns='color_category', aggfunc='mean')

print(f"\n{model1_name} averages:")
print(pivot_score1.fillna('N/A').round(2))
print(f"\n{model2_name} averages:")
print(pivot_score2.fillna('N/A').round(2))
# Out:
# === CROSS-TABULATION ANALYSIS ===
# STANCE vs COLOR CATEGORY:
# color_category  balanced  believer_heavy  denier_heavy
# stance
# against               19               0            94
# favor                 22            2281             0
# polarized             41               0             0
#
# AVERAGE SCORES BY STANCE AND COLOR CATEGORY:
#
# Gemma averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             3.74            N/A          4.0
# favor               4.32       4.412977          N/A
# polarized           4.00            N/A          N/A
#
# Deepseek averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             2.63            N/A     2.787234
# favor               3.32       3.747479          N/A
# polarized           2.68            N/A          N/A

# %%
# Create comprehensive visualizations
print("\n=== CREATING VISUALIZATIONS ===")
fig = plt.figure(figsize=(20, 15))

# 1. Score distribution by stance
ax1 = plt.subplot(3, 3, 1)
stance_means = df.groupby(stance_col)[[score1_col, score2_col]].mean()
stance_means.plot(kind='bar', ax=ax1, color=palette_colors)
ax1.set_title('Average Scores by Stance')
ax1.set_ylabel('Average Score')
ax1.legend([model1_name, model2_name])
ax1.tick_params(axis='x', rotation=45)

# 2. Score distribution by color category
ax2 = plt.subplot(3, 3, 2)
color_means = df.groupby('color_category')[[score1_col, score2_col]].mean()
color_means.plot(kind='bar', ax=ax2, color=palette_colors)
ax2.set_title('Average Scores by Opinion Distribution')
ax2.set_ylabel('Average Score')
ax2.legend([model1_name, model2_name])
ax2.tick_params(axis='x', rotation=45)

# 3. Scatter plot with color coding
ax3 = plt.subplot(3, 3, 3)
scatter = ax3.scatter(df[score1_col], df[score2_col], c=df[color_col], cmap='RdYlGn', alpha=0.7, s=60)
ax3.plot([1, 5], [1, 5], 'k--', alpha=0.5, label='Equal scores')
ax3.set_xlabel(f'{model1_name} Scores')
ax3.set_ylabel(f'{model2_name} Scores')
ax3.set_title(f'{model1_name} vs {model2_name}\n(Color = Opinion Distribution)')
ax3.legend()
ax3.grid(True, alpha=0.3)
plt.colorbar(scatter, ax=ax3, label='Color (0=Red/Deniers, 1=Green/Believers)')

# 4. Box plots by stance
#ax4 = plt.subplot(3, 3, 4)
#df.boxplot(column=[score1_col, score2_col], by=stance_col, ax=ax4)
#ax4.set_title('Score Distribution by Stance')
#ax4.set_ylabel('Score')

# 5. Color distribution histogram
ax5 = plt.subplot(3, 3, 5)
ax5.hist(df[color_col], bins=20, alpha=0.7, edgecolor='black')
ax5.set_xlabel('Color Value')
ax5.set_ylabel('Frequency')
ax5.set_title('Distribution of Opinion Balance\n(0=Deniers, 0.5=Polarized, 1=Believers)')
ax5.axvline(x=0.33, color='red', linestyle='--', alpha=0.7, label='Denier threshold')
ax5.axvline(x=0.67, color='green', linestyle='--', alpha=0.7, label='Believer threshold')
ax5.legend()

# 6. Heatmap of average scores
ax6 = plt.subplot(3, 3, 6)
heatmap_data = df.pivot_table(values=[score1_col, score2_col], index=stance_col, columns='color_category', aggfunc='mean')
if not heatmap_data.empty:
    sns.heatmap(heatmap_data, annot=True, cmap='viridis', ax=ax6, fmt='.2f')
    ax6.set_title('Average Scores Heatmap\n(Stance vs Opinion Distribution)')

# 7. Difference analysis by stance
ax7 = plt.subplot(3, 3, 7)
df['score_diff'] = df[score1_col] - df[score2_col]
df.boxplot(column='score_diff', by=stance_col, ax=ax7)
ax7.set_title(f'Score Differences by Stance\n({model1_name} - {model2_name})')
ax7.set_ylabel('Score Difference')

# 8. Model performance by color
ax8 = plt.subplot(3, 3, 8)
# Create bins for color analysis
df['color_bin'] = pd.cut(df[color_col], bins=5, labels=['Very Red', 'Red', 'Yellow', 'Green', 'Very Green'])
color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()
color_perf.plot(kind='bar', ax=ax8, color=palette_colors)
ax8.set_title('Performance Across Opinion Spectrum')
ax8.set_ylabel('Average Score')
ax8.legend([model1_name, model2_name])
ax8.tick_params(axis='x', rotation=45)

# 9. Correlation analysis
ax9 = plt.subplot(3, 3, 9)
ax9.scatter(df[color_col], df[score1_col], alpha=0.6, label=model1_name, color='blue')
ax9.scatter(df[color_col], df[score2_col], alpha=0.6, label=model2_name, color='orange')
ax9.set_xlabel('Color (Opinion Distribution)')
ax9.set_ylabel('Score')
ax9.set_title('Scores vs Opinion Distribution')
ax9.legend()
ax9.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# === CREATING VISUALIZATIONS ===
# /tmp/ipykernel_1360911/1169726615.py:68: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()

# %%
# Detailed analysis
print("\n=== DETAILED ANALYSIS ===")

# Correlation between color and scores
corr_color_score1 = df[color_col].corr(df[score1_col])
corr_color_score2 = df[color_col].corr(df[score2_col])

print("CORRELATION ANALYSIS:")
print(f"Color vs {model1_name} scores: {corr_color_score1:.4f}")
print(f"Color vs {model2_name} scores: {corr_color_score2:.4f}")
print(f"{model1_name} vs {model2_name} scores: {df[score1_col].corr(df[score2_col]):.4f}")
print()

# Performance in different opinion environments
print("MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:")
for category, desc in [('denier_heavy', 'Denier-heavy topics (Red zone)'),
                       ('balanced', 'Polarized topics (Yellow zone)'),
                       ('believer_heavy', 'Believer-heavy topics (Green zone)')]:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        print(f"\n{desc}:")
        print(f"  Topics: {len(cat_data)}")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        # Test if there's a significant difference between models in this category
        if len(cat_data) > 1:
            t_stat_cat, p_val_cat = stats.ttest_rel(cat_data[score1_col], cat_data[score2_col])
            print(f"  Significant difference between models: {'Yes' if p_val_cat < 0.05 else 'No'} (p={p_val_cat:.4f})")

# Best and worst performing topics
print(f"\n=== BEST AND WORST PERFORMING TOPICS ===")

# Best Model 1 performance
best_m1 = df.loc[df[score1_col].idxmax()]
print(f"BEST {model1_name} performance (Score: {best_m1[score1_col]}):")
color_desc = "red" if best_m1[color_col] < 0.33 else "green" if best_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m1[stance_col]}', color={best_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m1[arg1_col]}', {model1_name} score={best_m1[score1_col]}")
print(f"  {arg2_col}='{best_m1[arg2_col]}', {model2_name} score={best_m1[score2_col]}")

# Worst Model 1 performance
worst_m1 = df.loc[df[score1_col].idxmin()]
print(f"\nWORST {model1_name} performance (Score: {worst_m1[score1_col]}):")
color_desc = "red" if worst_m1[color_col] < 0.33 else "green" if worst_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m1[stance_col]}', color={worst_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m1[arg1_col]}', {model1_name} score={worst_m1[score1_col]}")
print(f"  {arg2_col}='{worst_m1[arg2_col]}', {model2_name} score={worst_m1[score2_col]}")

# Best Model 2 performance
best_m2 = df.loc[df[score2_col].idxmax()]
print(f"\nBEST {model2_name} performance (Score: {best_m2[score2_col]}):")
color_desc = "red" if best_m2[color_col] < 0.33 else "green" if best_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m2[stance_col]}', color={best_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m2[arg1_col]}', {model1_name} score={best_m2[score1_col]}")
print(f"  {arg2_col}='{best_m2[arg2_col]}', {model2_name} score={best_m2[score2_col]}")

# Worst Model 2 performance
worst_m2 = df.loc[df[score2_col].idxmin()]
print(f"\nWORST {model2_name} performance (Score: {worst_m2[score2_col]}):")
color_desc = "red" if worst_m2[color_col] < 0.33 else "green" if worst_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m2[stance_col]}', color={worst_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m2[arg1_col]}', {model1_name} score={worst_m2[score1_col]}")
print(f"  {arg2_col}='{worst_m2[arg2_col]}', {model2_name} score={worst_m2[score2_col]}")

# Summary insights
print(f"\n=== KEY INSIGHTS ===")
print("STANCE-BASED INSIGHTS:")
stance_summary = df.groupby(stance_col)[[score1_col, score2_col]].mean()
best_stance_m1 = stance_summary[score1_col].idxmax()
best_stance_m2 = stance_summary[score2_col].idxmax()
print(f"  {model1_name} performs best on '{best_stance_m1}' topics")
print(f"  {model2_name} performs best on '{best_stance_m2}' topics")

print("\nOPINION DISTRIBUTION INSIGHTS:")
color_summary = df.groupby('color_category')[[score1_col, score2_col]].mean()
if not color_summary.empty:
    best_color_m1 = color_summary[score1_col].idxmax() if len(color_summary) > 0 else 'N/A'
    best_color_m2 = color_summary[score2_col].idxmax() if len(color_summary) > 0 else 'N/A'
    print(f"  {model1_name} performs best in '{best_color_m1}' opinion environments")
    print(f"  {model2_name} performs best in '{best_color_m2}' opinion environments")

# Overall winner
if df[score1_col].mean() > df[score2_col].mean():
    overall_better = model1_name
    diff = df[score1_col].mean() - df[score2_col].mean()
elif df[score2_col].mean() > df[score1_col].mean():
    overall_better = model2_name
    diff = df[score2_col].mean() - df[score1_col].mean()
else:
    overall_better = "Tie"
    diff = 0

print(f"\nOVERALL BETTER MODEL: {overall_better}")
if diff > 0:
    print(f"  Average advantage: {diff:.3f} points")
# Out:
# === DETAILED ANALYSIS ===
# CORRELATION ANALYSIS:
# Color vs Gemma scores: 0.1853
# Color vs Deepseek scores: 0.2484
# Gemma vs Deepseek scores: -0.0085
#
# MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:
#
# Denier-heavy topics (Red zone):
#   Topics: 94
#   Gemma avg: 4.00
#   Deepseek avg: 2.79
#   Significant difference between models: Yes (p=0.0000)
#
# Polarized topics (Yellow zone):
#   Topics: 82
#   Gemma avg: 4.02
#   Deepseek avg: 2.84
#   Significant difference between models: Yes (p=0.0000)
#
# Believer-heavy topics (Green zone):
#   Topics: 2281
#   Gemma avg: 4.41
#   Deepseek avg: 3.75
#   Significant difference between models: Yes (p=0.0000)
#
# === BEST AND WORST PERFORMING TOPICS ===
# BEST Gemma performance (Score: 5.0):
#   Topic: stance='favor', color=0.997(green)
#   arg1='It is observed that a significant number of candidates are being positioned as committed to combating climate change, and a considerable effort is being directed towards framing this issue as a central priority.  The idea of candidates being targeted for their stances on this matter is being actively promoted, suggesting a widespread recognition of the importance of addressing climate change.  Furthermore, the focus on this issue is being amplified, indicating a collective desire to see it become a primary concern among the broader field of political contenders. ', Gemma score=5.0
#   arg2='It is widely recognized that there are numerous individuals committed to combating climate change, with Jay Inslee and Beto O'Rourke being among them. These real leaders have been advocating for the issue to become a top priority among other candidates in the political sphere. As such, it is urged that more support be given to these advocates of climate action, as they are seen as key figures in driving meaningful change on this critical global challenge.', Deepseek score=4.0
#
# WORST Gemma performance (Score: 1.0):
#   Topic: stance='favor', color=0.704(green)
#   arg1='It is observed that the earth is flat and global warming is considered a myth by certain individuals. Simultaneously, it is recognized that ‘Fern Gully’ remains relevant due to the effects of global warming. Furthermore, the mechanisms of how global warming happens are presented as science. Consequently, the issue of global warming is being debated, with scientific understanding seemingly challenged by alternative viewpoints.', Gemma score=1.0
#   arg2='It has been widely acknowledged that the earth's climate is undergoing significant changes, with a growing body of evidence suggesting that human activity plays a dominant role in driving these alterations. This perspective recognizes the extent to which human actions have influenced global temperatures and weather patterns, leading to debates about whether or not such changes are beneficial or detrimental to our planet. As a result, there has been an increasing call for action to address climate change, with many advocating for measures that reduce greenhouse gas emissions and promote sustainable practices.', Deepseek score=3.0
#
# BEST Deepseek performance (Score: 5.0):
#   Topic: stance='favor', color=0.921(green)
#   arg1='It is observed that dangerous climate change denial is being supported by figures like Bush’s former EPA chief and Trump, aligning with the interests of big corporations and the super rich.  The acceptance of deregulation and tax breaks for polluting industries is being facilitated, while the participation in the Paris Agreement is being avoided.  The continuation of investments in harmful industries and the disregard for environmental consequences are being prioritized, leading to the degradation of the earth and threats to public health.  It is recognized that the protection of corporate profits and the interests of a select few are being prioritized over the well-being of the planet and its inhabitants.', Gemma score=4.0
#   arg2='It has been widely acknowledged that there exists a convergence between support for Trump and climate change denial, which converges at a point concerning big corporate interests and the interests of the super-rich. This alignment is exemplified by policies such as tax breaks for billionaires and deregulation of harmful industries, which are defended under the guise of climate change denial. These actions not only protect high pollution investments but also allow companies like Dow to continue making billions at the expense of destroying the earth and our health.', Deepseek score=5.0
#
# WORST Deepseek performance (Score: 1.0):
#   Topic: stance='favor', color=0.836(green)
#   arg1='It is recognized that addressing climate change is being viewed as a critical priority, with the Green New Deal being proposed as a means to effectively tackle this challenge. Concerns are being raised regarding the potential impacts of the Green New Deal, and efforts are being undertaken to understand its implications. The need for a comprehensive approach to climate change is being actively discussed, and the potential for significant changes is being considered. It is understood that a coordinated response is required to address the complex issues surrounding climate change and its effects.', Gemma score=5.0
#   arg2='Could not extract valid JSON from the input 2', Deepseek score=1.0
#
# === KEY INSIGHTS ===
# STANCE-BASED INSIGHTS:
#   Gemma performs best on 'favor' topics
#   Deepseek performs best on 'favor' topics
#
# OPINION DISTRIBUTION INSIGHTS:
#   Gemma performs best in 'believer_heavy' opinion environments
#   Deepseek performs best in 'believer_heavy' opinion environments
#
# OVERALL BETTER MODEL: Gemma
#   Average advantage: 0.704 points

# %% [markdown]
# ## Violin Plot

# %%
# --- Visualization ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Violin plot
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# Boxplot
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# 3. Difference distribution (instead of hexbin)
diff = df[score2_col] - df[score1_col]
sns.histplot(diff, bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")


# Heatmap of agreement
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_{filename_output}.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Dashboard
#  1. Violin plot considering all the scores by stance.
#  2. Boxplot considering all the scores by stance.
#  3. Difference distribution.
#  4. Heatmap (agreement)
#  5. Violin plot model 1 by stance.
#  6. Violin plot model 2 by stance.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# --- Visualization ---
fig, axes = plt.subplots(3, 2, figsize=(14, 14))

# --- Row 1 ---
# 1. Violin plot (overall)
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# 2. Boxplot (overall)
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# --- Row 2 ---
# 3. Difference distribution
df["diff"] = df[score2_col] - df[score1_col]
sns.histplot(df["diff"], bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")

# 4. Heatmap (agreement)
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

# --- Row 3 ---
# 5. Violin by stance (palette)
sns.violinplot(
    x="stance", y=score1_col, data=df,
    ax=axes[2,0],
    palette= pallete_stance_model1, # green_palette_stance = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"},
    order=["favor","against","polarized"]
)
axes[2,0].set_title(f"{model1_name} Scores by Stance", color=color_title_model1) #color_title_green="#196f3d"
axes[2,0].set_ylabel("Score")
axes[2,0].set_xlabel("Stance")

# 6. Violin by stance (Deepseek, orange palette)
sns.violinplot(
    x="stance", y=score2_col, data=df,
    ax=axes[2,1],
    palette= pallete_stance_model2,# orange_palette_stance = {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"},
    order=["favor","against","polarized"]
)
axes[2,1].set_title(f"{model2_name} Scores by Stance", color=color_title_model2 ) # color_title_green = "#7e5109"
axes[2,1].set_ylabel("Score")
axes[2,1].set_xlabel("Stance")


plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_JudgeGemma_Args-{filename_output}.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1360911/2608110707.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_1360911/2608110707.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
