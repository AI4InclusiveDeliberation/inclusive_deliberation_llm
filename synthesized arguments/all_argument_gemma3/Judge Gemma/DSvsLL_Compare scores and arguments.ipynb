# %% [markdown]
# # Analysis of results
#
# Distribution of scores assigned by Model Gemma3 as Judge when comparing the performance of language model pairs: Deepseek vs Llama
#
# By: Gabriela Díaz

# %% [markdown]
# ## Extreme values analysis

# %%
# Import section
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
###################################
# Colors definition for models
###################################

color_G3_0shot = '#ffac37'
color_G3_1shot = '#ffc575'
# LL '#009e73','#0bd9a1'
color_LL_0shot = '#009e73'
color_LL_1shot = '#0bd9a1'
# DS '#0077bb','#60b8eb'
color_DS_0shot = '#0077bb'
color_DS_1shot = '#60b8eb'
palette_stance_blue =  {"favor": "#1F4BE6", "against": "#023BD3", "polarized": "#9FB2F5"} #blue
palette_stance_orange =  {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"} #orange
palette_stance_green = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"} #green

color_title_green="#196f3d"
color_title_orange = "#7e5109"
color_title_blue = "#0F4ABD"

# %%
# =============================================================================
# CONFIGURATION 
#  Change next variables to compare different models. 
# =============================================================================

# filename 
filename_scores = 'jgemma_ds_ll.csv' #this file contain scores for the two models that are compared. 
filename_output = '_ds_vs_ll_'

# Model names for labeling
model1_name = 'Deepseek'
model2_name = 'Llama'

# Column mappings - change these to match your data structure
score1_col = 'score1'  # Column name for model 1 scores
score2_col = 'score2'  # Column name for model 2 scores
arg1_col = 'arg1'      # Column name for model 1 arguments
arg2_col = 'arg2'      # Column name for model 2 arguments

# Other column names
color_col = 'color'
stance_col = 'stance'

# Colors
palette_colors = [color_DS_1shot,color_LL_1shot]

# Colors for the last violin
pallete_stance_model1 = palette_stance_blue
pallete_stance_model2 = palette_stance_green 
color_title_model1 = color_title_blue
color_title_model2 = color_title_green

df = pd.read_csv(filename_scores)

# %%
print(f"=== {model1_name.upper()} vs {model2_name.upper()} COMPARISON BY STANCE AND MODEL ===\n")

# Display sample of the data
print("DATA OVERVIEW:")
print(f"Total topics analyzed: {len(df)}")
print(f"Stance distribution: {df[stance_col].value_counts().to_dict()}")
print(f"Color range: {df[color_col].min():.3f} to {df[color_col].max():.3f}")
print(f"Models being compared: {model1_name} vs {model2_name}")
print()

# Basic statistics by model
print("=== MODEL COMPARISON ===")
print("OVERALL MODEL PERFORMANCE:")
print(f"{model1_name} - Mean: {df[score1_col].mean():.2f}, Std: {df[score1_col].std():.2f}")
print(f"{model2_name} - Mean: {df[score2_col].mean():.2f}, Std: {df[score2_col].std():.2f}")

# Statistical test between models
t_stat, p_value = stats.ttest_rel(df[score1_col], df[score2_col])
print(f"\nPaired t-test between models:")
print(f"  T-statistic: {t_stat:.4f}")
print(f"  P-value: {p_value:.4f}")
print(f"  Significant difference: {'Yes' if p_value < 0.05 else 'No'}")

# Model wins
model1_wins = (df[score1_col] > df[score2_col]).sum()
model2_wins = (df[score2_col] > df[score1_col]).sum()
ties = (df[score1_col] == df[score2_col]).sum()

print(f"\nHead-to-head comparison:")
print(f"  {model1_name} wins: {model1_wins} topics")
print(f"  {model2_name} wins: {model2_wins} topics")
print(f"  Ties: {ties} topics")
print()

# Analysis by stance
print("=== ANALYSIS BY STANCE ===")
print("PERFORMANCE BY STANCE:")
for stance in df[stance_col].unique():
    stance_data = df[df[stance_col] == stance]
    print(f"\n{stance.upper()} topics ({len(stance_data)} topics):")
    print(f"  Average color value: {stance_data[color_col].mean():.3f}")
    print(f"  {model1_name} - Mean: {stance_data[score1_col].mean():.2f}, Std: {stance_data[score1_col].std():.2f}")
    print(f"  {model2_name} - Mean: {stance_data[score2_col].mean():.2f}, Std: {stance_data[score2_col].std():.2f}")
    
    # Model comparison within this stance
    m1_wins = (stance_data[score1_col] > stance_data[score2_col]).sum()
    m2_wins = (stance_data[score2_col] > stance_data[score1_col]).sum()
    ties = (stance_data[score1_col] == stance_data[score2_col]).sum()
    print(f"  Within {stance}: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()

# Color-based analysis (opinion distribution)
print("=== COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===")
def categorize_color(color_val):
    if color_val < 0.33:
        return 'denier_heavy'  # Red zone
    elif color_val > 0.67:
        return 'believer_heavy'  # Green zone
    else:
        return 'balanced'  # Yellow zone (polarized)

df['color_category'] = df[color_col].apply(categorize_color)

print("PERFORMANCE BY OPINION DISTRIBUTION:")
for category in ['denier_heavy', 'balanced', 'believer_heavy']:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        color_range = f"{cat_data[color_col].min():.3f}-{cat_data[color_col].max():.3f}"
        print(f"\n{category.upper().replace('_', ' ')} topics ({len(cat_data)} topics, color: {color_range}):")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        m1_wins = (cat_data[score1_col] > cat_data[score2_col]).sum()
        m2_wins = (cat_data[score2_col] > cat_data[score1_col]).sum()
        ties = (cat_data[score1_col] == cat_data[score2_col]).sum()
        print(f"  Model performance: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()
# Out:
# === DEEPSEEK vs LLAMA COMPARISON BY STANCE AND MODEL ===
#
# DATA OVERVIEW:
# Total topics analyzed: 2971
# Stance distribution: {'favor': 2787, 'against': 132, 'polarized': 52}
# Color range: 0.000 to 1.000
# Models being compared: Deepseek vs Llama
#
# === MODEL COMPARISON ===
# OVERALL MODEL PERFORMANCE:
# Deepseek - Mean: 4.09, Std: 0.54
# Llama - Mean: 3.60, Std: 1.00
#
# Paired t-test between models:
#   T-statistic: 27.5385
#   P-value: 0.0000
#   Significant difference: Yes
#
# Head-to-head comparison:
#   Deepseek wins: 1597 topics
#   Llama wins: 550 topics
#   Ties: 824 topics
#
# === ANALYSIS BY STANCE ===
# PERFORMANCE BY STANCE:
#
# FAVOR topics (2787 topics):
#   Average color value: 0.964
#   Deepseek - Mean: 4.13, Std: 0.45
#   Llama - Mean: 3.66, Std: 0.96
#   Within favor: Deepseek wins 1470, Llama wins 512, Ties 805
#
# POLARIZED topics (52 topics):
#   Average color value: 0.518
#   Deepseek - Mean: 3.58, Std: 0.78
#   Llama - Mean: 2.60, Std: 1.03
#   Within polarized: Deepseek wins 41, Llama wins 6, Ties 5
#
# AGAINST topics (132 topics):
#   Average color value: 0.162
#   Deepseek - Mean: 3.27, Std: 1.15
#   Llama - Mean: 2.59, Std: 1.05
#   Within against: Deepseek wins 86, Llama wins 32, Ties 14
#
# === COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===
# PERFORMANCE BY OPINION DISTRIBUTION:
#
# DENIER HEAVY topics (110 topics, color: 0.000-0.328):
#   Deepseek avg: 3.20
#   Llama avg: 2.54
#   Model performance: Deepseek wins 70, Llama wins 29, Ties 11
#
# BALANCED topics (101 topics, color: 0.333-0.667):
#   Deepseek avg: 3.72
#   Llama avg: 2.65
#   Model performance: Deepseek wins 83, Llama wins 9, Ties 9
#
# BELIEVER HEAVY topics (2760 topics, color: 0.672-1.000):
#   Deepseek avg: 4.13
#   Llama avg: 3.67
#   Model performance: Deepseek wins 1444, Llama wins 512, Ties 804

# %%
# Find extreme cases
print("=== EXTREME CASES ANALYSIS ===")

# Lowest scores
min_score = min(df[score1_col].min(), df[score2_col].min())
print(f"LOWEST SCORE FOUND: {min_score}")

min_score1_rows = df[df[score1_col] == min_score]
min_score2_rows = df[df[score2_col] == min_score]

if not min_score1_rows.empty:
    print(f"\n{model1_name} lowest scores:")
    for idx, row in min_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not min_score2_rows.empty:
    print(f"\n{model2_name} lowest scores:")
    for idx, row in min_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")
# Out:
# === EXTREME CASES ANALYSIS ===
# LOWEST SCORE FOUND: 1
#
# Deepseek lowest scores:
#   Topic 25: stance='favor', color=0.836(green)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='It is widely acknowledged that the Green New Deal has been framed as an existential threat by some, while others seek to address it. The notion of climate change being effectively addressed through the Green New Deal has gained traction among various groups and individuals. As a result, the discussion around the Green New Deal has become increasingly prominent, with many advocating for its implementation to mitigate the effects of climate change.', Llama score=3
#   Topic 40: stance='against', color=0.132(red)
#     arg1='Over the past decades, significant shifts in climate patterns have been observed globally, with some attributing these changes primarily to natural climatic cycles rather than human activity.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 53: stance='against', color=0.049(red)
#     arg1='Natural climate variability has long been recognized as a significant factor in global temperature changes, with evidence suggesting that these fluctuations have occurred independently of human activity.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 162: stance='favor', color=0.778(green)
#     arg1='It is widely acknowledged that the claim of China perpetrating a climate change hoax, as asserted by some individuals and referenced in various posts on social media platforms, has contributed to significant debates regarding the authenticity of global warming. This perspective suggests that there are deep-seated doubts about whether human activity truly drives climate change or if it is instead an elaborate scheme orchestrated by China. However, despite these claims, a majority of scientists and environmental experts continue to assert that human actions, particularly industrial activities and greenhouse gas emissions, are the primary drivers of current climate change.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 169: stance='favor', color=0.913(green)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 213: stance='against', color=0.000(red)
#     arg1='Concerns regarding natural climate variability have been expressed by various contributors across diverse perspectives, suggesting that long-term climatic shifts may be influenced more significantly by geological and astronomical factors than anthropogenic activities.', Deepseek score=1
#     arg2='The notion that human activity is the sole driver of current climate change has been subject to scrutiny and debate. Natural cycles, such as solar variability and ocean currents, have been suggested as potential explanations for recent temperature changes. The reliance on assumptions about CO2 in climate models has also been highlighted, with some arguing that natural climate drivers are being neglected. Furthermore, historical data from ice core records, tree rings, and sediment layers indicate recurring fluctuations in Earth's climate over millennia, independent of human activity. The scientific consensus on the role of human influence in climate change remains a topic of discussion, with some critics accusing certain individuals of promoting a political agenda rather than seeking objective truth.', Llama score=3
#   Topic 244: stance='against', color=0.008(red)
#     arg1='The complexities of climate change have been repeatedly demonstrated through various natural cycles, such as solar radiation variations and oceanic currents, which can influence global temperature patterns independently of human activity. These long-term climatic shifts are supported by historical evidence from ice core samples, sediment layers, and tree rings that show fluctuations in Earth's climate predating significant industrialization.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 285: stance='against', color=0.140(red)
#     arg1='Concerns about climate change have been widely debated, with some suggesting that natural climatic cycles are the primary drivers of recent temperature variations rather than human activity.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 410: stance='against', color=0.062(red)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 572: stance='favor', color=0.746(green)
#     arg1='It has been widely acknowledged that terrorist attacks such as those in Sri Lanka have raised concerns regarding climate change, with deforestation contributing to reduced carbon absorption. As a result, there is an increased focus on reforestation programs and investment by governments to combat the ongoing effects of climate change.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 649: stance='favor', color=0.704(green)
#     arg1='It has been widely acknowledged that the earth's climate is undergoing significant changes, with a growing body of evidence suggesting that human activity plays a dominant role in driving these alterations. This perspective recognizes the extent to which human actions have influenced global temperatures and weather patterns, leading to debates about whether or not such changes are beneficial or detrimental to our planet. As a result, there has been an increasing call for action to address climate change, with many advocating for measures that reduce greenhouse gas emissions and promote sustainable practices.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 728: stance='favor', color=0.938(green)
#     arg1='It is commonly observed that individuals often react with skepticism to claims of global warming when faced with specific instances or anomalies in nature, such as the decline in sea stars' populations due to oceanic changes. This response highlights a broader tendency among people to question climate change narratives based on isolated events rather than considering them part of a larger pattern consistent with human-induced climate change.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 735: stance='against', color=0.000(red)
#     arg1='Concerns about the impact of human activity on climate change have been repeatedly expressed, with various perspectives suggesting that natural forces may play a more significant role in altering global temperatures than previously acknowledged.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 832: stance='against', color=0.000(red)
#     arg1='It is widely acknowledged by the participants in this discourse that natural climatic variations have played significant roles throughout Earth's history, influencing global temperature patterns independently of human activity.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 909: stance='against', color=0.051(red)
#     arg1='Concerns regarding the impact of human activities on climate change have been widely debated, with alternative theories suggesting that natural climatic variations may play a significant role in shaping global temperatures. These perspectives argue against the dominant view by highlighting recent temperature fluctuations and questioning the influence of solar activity and ocean currents as key drivers of climate change.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1103: stance='against', color=0.031(red)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Major shifts in global temperature have been documented in ice core records long before industrialization, and natural causes behind climate variability have been suggested. Repeated fluctuations in Earth's climate over millennia have been indicated by historical data from tree rings and sediment layers. Uncertainty surrounding the magnitude of human influence on current warming trends has led to a reevaluation of the role of natural drivers in shaping global temperatures.', Llama score=1
#   Topic 1107: stance='against', color=0.312(red)
#     arg1='Long-standing debates over natural versus human influences on climate have persisted for decades, with historical evidence suggesting that Earth's climatic patterns are shaped by a complex interplay of geological and atmospheric processes. These include solar radiation variations, volcanic eruptions, ocean currents, and other factors not directly related to modern industrial activity.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1142: stance='against', color=0.065(red)
#     arg1='Long-standing debates around climate change have persisted, with historical perspectives suggesting that natural factors may play significant roles in shaping global temperatures over time, independent of human influence.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1156: stance='against', color=0.097(red)
#     arg1='Concerns about the impact of human activity on global warming have been widely debated, with some suggesting that natural factors may play a more significant role in recent temperature changes than previously acknowledged. The influence of long-term climatic cycles and other environmental variables has been highlighted as potentially outweighing direct anthropogenic effects.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1209: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='The notion of human-induced climate change has been subject to various interpretations and criticisms. Some individuals have expressed skepticism about the extent of human influence on climate patterns, citing natural cycles and regional variations as potential explanations for observed temperature changes. Others have pointed out the limitations and uncertainties associated with climate models, suggesting that they may not accurately capture the complexity of natural climate variability. Furthermore, certain perspectives have highlighted the inconsistencies in climate data, particularly when considering regions where CO2-induced global warming appears to cause both more ice and less ice. These concerns have led some to question the unfalsifiable nature of the claim that human activity is the primary driver of current climate change.', Llama score=2
#   Topic 1295: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Major fluctuations in global temperatures have been observed throughout history, with recurring cycles of warming and cooling documented in ice core records long before industrialization. Natural causes behind climate variability have been suggested by various studies, including those on solar variability, ocean currents, and tree rings. The notion that human activity is the sole driver of current climate change has been questioned by some experts, who argue that current climate models are too reliant on assumptions about CO2 while neglecting natural climate drivers.', Llama score=2
#   Topic 1406: stance='favor', color=0.731(green)
#     arg1='It is widely acknowledged that there are instances of hypocrisy among climate change activists, as well as arrogance from those with limited understanding of the issue who disregard scientific evidence. However, these attitudes do not negate the broader impact of human activity on climate change and its consequences.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1421: stance='polarized', color=0.600(yellow)
#     arg1='Raptures and climate change beliefs have been identified as diverging perspectives on environmental concerns, with some individuals focusing on religious events while others advocate for action against global warming; however, it is acknowledged that the actions of those who prioritize one perspective over another can contribute to ongoing debates about human responsibility in influencing climatic changes.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1463: stance='against', color=0.080(red)
#     arg1='Over the past several decades, there has been a significant increase in global temperatures and associated climatic changes that have raised concerns about human impact on the environment.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1477: stance='against', color=0.000(red)
#     arg1='Concerns regarding climate change have been expressed by various individuals and groups across diverse perspectives. While there is a widespread acknowledgment that human activities contribute to altering atmospheric conditions, alternative viewpoints suggest that natural factors may play a significant role in influencing global temperatures over extended periods of time. These arguments often point towards long-term climatic cycles such as solar variability and ocean currents, which could potentially explain climate variations independently from anthropogenic influences.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1543: stance='against', color=0.083(red)
#     arg1='Long-standing debates over human responsibility in global warming have been fueled by varying perspectives on industrial and natural influences, with recent studies suggesting that natural climatic cycles may play a significant role in temperature variations.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1668: stance='favor', color=0.818(green)
#     arg1='It has been widely acknowledged that catastrophic manmade climate change is dodgy at best, while transgenderism is seen as anti-biology and inconsistent with scientific understanding of gender identity. This perspective suggests that the natural processes of climate change are distinct from human activities, emphasizing the importance of believing in scientists' consensus on climate issues rather than accepting progressive views that may not align with established science.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 1847: stance='polarized', color=0.500(yellow)
#     arg1='In recent years, the occurrence of severe and extreme weather events has been observed globally; however, it appears that these phenomena have not conclusively correlated with human-driven climate change. Instead, they may be part of natural climatic cycles or variations in solar activity.', Deepseek score=1
#     arg2='The notion that human activity drives climate change has been subject to scrutiny, with some suggesting that the frequency of severe weather events, such as tornadoes, may be decreasing; however, this trend is not universally accepted and remains a topic of debate among experts.', Llama score=2
#   Topic 1949: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that there are only a few years left before an apocalyptic climate change event kills us all, with economic markets crashing and carbon-absorbing trees being significantly reduced due to deforestation. As a result, the restoration of carbon-absorbing forests through reforestation programs is seen as necessary by many individuals who urge governments to invest in such initiatives.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2498: stance='favor', color=0.692(green)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2505: stance='favor', color=0.923(green)
#     arg1='It is widely acknowledged that there exists a significant global consensus regarding the reality of climate change, with both scientists and the general public expressing their agreement on this issue. The acknowledgment of climate change as real has been echoed across various platforms, including social media posts where individuals express their support for addressing environmental concerns related to climate change.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2540: stance='against', color=0.000(red)
#     arg1='Long-term natural cycles of climate variability have been observed and documented across various regions over thousands of years, suggesting that human activity may not be the sole determinant of recent climatic changes.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2584: stance='against', color=0.077(red)
#     arg1='Over the millennia, significant climatic changes have been observed and documented, often predating human industrial activities. These natural climate variations include solar variability, ocean currents, and other geological phenomena that suggest a complex interplay of forces beyond direct human influence.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2606: stance='against', color=0.154(red)
#     arg1='Concerns about the impact of climate change have been echoed across various regions and communities, with a growing acknowledgment that natural factors may play a significant role in shaping global temperature trends.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2673: stance='against', color=0.000(red)
#     arg1='Concerns about climate change have been widely expressed, with some suggesting that its existence is a liberal hoax designed to exploit gullible pessimists for political purposes and others arguing that it is merely another phase in Earth's natural climatic cycles. The shift from 'climate change' to terms like 'climate justice' has also raised questions about the motives behind these terminological changes, with some suggesting they are used as tools to emotionally manipulate certain demographics.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2744: stance='favor', color=0.833(green)
#     arg1='It is widely acknowledged that there are various issues being discussed in public discourse today, including concerns about climate change and its potential impacts on our environment. These discussions often involve differing perspectives on the causes of such changes and how best to address them. As a result, it has become increasingly clear that human activity plays a significant role in influencing current environmental conditions, particularly concerning climate change. This recognition highlights the need for concerted efforts to mitigate these effects through sustainable practices and policies.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2852: stance='against', color=0.364(yellow)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2868: stance='favor', color=0.909(green)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='It is widely acknowledged that a significant portion of the population, amounting to 31%, remains in denial about the existence and severity of climate change. This denial is often met with frustration from those who are actively engaged in addressing the issue, as they struggle to convince individuals who are unwilling to consider the scientific evidence. As a result, it is imperative that efforts to educate and raise awareness about climate change be continued, despite the challenges posed by those who refuse to acknowledge its reality.', Llama score=2
#   Topic 2882: stance='against', color=0.182(red)
#     arg1='It has been suggested that the debate surrounding human influence on climate change is often overshadowed by broader political and ideological narratives, where claims about globalist agendas or conspiracy theories are presented as credible alternatives to scientific consensus. These perspectives suggest a deeper skepticism towards mainstream environmental discourse, viewing it through a lens of distrust rather than factual inquiry.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#   Topic 2927: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged by many individuals and organizations that there are significant concerns surrounding the impact of human activity on current climate change. The acknowledgment of these issues has reached a point where it poses challenges for those seeking to understand or address this complex phenomenon, often leading to heated discussions about the validity of such claims. As a result, investments in research and development aimed at understanding and mitigating the effects of climate change are seen as necessary solutions by various stakeholders.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=2
#
# Llama lowest scores:
#   Topic 68: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that human activity has significantly influenced global temperatures and weather patterns, leading to more frequent and severe natural disasters such as wildfires and hurricanes. The reduction of carbon-absorbing trees through deforestation exacerbates the problem by increasing CO2 levels in the atmosphere. As a result, governments are urged to invest in reforestation programs that can help mitigate climate change.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 84: stance='favor', color=0.964(green)
#     arg1='It is widely acknowledged that the denial or skepticism towards climate change, often expressed in dismissive and derogatory terms by some individuals, reflects a level of ignorance regarding its existence and impacts. This stance implies a lack of understanding about the scientific consensus on global warming and its potential consequences for humanity and the environment.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 97: stance='favor', color=0.969(green)
#     arg1='It has been widely acknowledged that global warming is real and its effects are being felt across the planet. The increasing number of extreme weather events, such as hurricanes and wildfires, can be attributed to human activity and climate change. As a result, it is imperative for individuals worldwide to take responsibility in mitigating these impacts by reducing their carbon footprint and advocating for sustainable practices.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 98: stance='favor', color=0.897(green)
#     arg1='It is widely acknowledged that the public discourse on social media platforms frequently addresses concerns about the authenticity and credibility of information, with individuals expressing varying opinions on whether such discussions are necessary or counterproductive. As a result, there is an ongoing debate regarding the impact of these conversations on societal perceptions and actions related to climate change.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 99: stance='favor', color=0.848(green)
#     arg1='It is widely recognized that the consumption of content related to @BTS_twt and @Tobiiseverythi1 has led to a significant increase in their popularity, with fans expressing strong emotional support for these artists. This surge in interest has resulted in an expansion of their fan base across various platforms, further highlighting the influence of media on public sentiment and engagement.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 119: stance='against', color=0.395(yellow)
#     arg1='Long-standing debates over economic systems and their impacts on environmental policies have persisted, with varying perspectives suggesting that capitalism is inherently corrupt while socialism can be co-opted by state interests or manipulated through climate change agendas. These arguments reflect deep ideological divides within society regarding the role of government in regulating industry and mitigating ecological challenges.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 157: stance='favor', color=0.712(green)
#     arg1='It is widely acknowledged by a significant portion of the global population that Donald Trump's stance on climate change has been met with widespread criticism and disbelief. His views contrast sharply with those expressed by other public figures such as Lil Dicky, who have actively engaged in discussions about environmental issues. This discrepancy highlights the divide between understanding and action regarding climate change, which is a critical concern for global sustainability.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 169: stance='favor', color=0.913(green)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 171: stance='favor', color=0.930(green)
#     arg1='It is widely acknowledged that the popularity of certain game settings, such as those depicted in Aqurios's artwork and referenced in online discussions, has led to a surge in interest within the gaming community. This enthusiasm for specific settings like RT @kawaisoanother's survey on favorite game settings underscores the growing trend towards diverse preferences among gamers. As more players engage with these settings, it is evident that they play a significant role in shaping the cultural landscape of video games and influencing future content development.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 175: stance='favor', color=0.822(green)
#     arg1='It is widely acknowledged that there has been a significant focus on climate change by political leaders such as Nancy Pelosi, who received standing ovations after outlining her plan to combat this issue. However, despite these efforts, some critics argue that the actions taken do not fully align with the more ambitious goals of environmental activists advocating for a Green New Deal or other comprehensive solutions. As a result, there is ongoing tension between those seeking incremental changes and those demanding immediate action on climate change.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 272: stance='polarized', color=0.446(yellow)
#     arg1='Fake news has been propagated regarding the existence of global warming, with some suggesting that it is a hoax or invented by China.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 308: stance='against', color=0.058(red)
#     arg1='Overwhelming scientific consensus has long acknowledged human-driven contributions to global warming, including emissions of greenhouse gases such as carbon dioxide and methane. These anthropogenic factors are widely recognized in the context of industrialization and modern technological advancements that have significantly altered atmospheric compositions.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 311: stance='favor', color=0.874(green)
#     arg1='It is widely acknowledged that the mental well-being of individuals is significantly influenced by their psychological balance, and it is urged not to seek correction for negative thoughts in a manner unbecoming of one's self-respect. Instead, it is suggested to honor oneself as commanded by God, who is most gracious and merciful.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 353: stance='favor', color=0.717(green)
#     arg1='It is widely acknowledged that climate change, as a significant environmental issue, has been exacerbated by human activities such as deforestation and pollution. This perspective aligns with concerns about abortion rights and ethical issues surrounding fetal tissue use in medical research. As the world grapples with these complex moral dilemmas, there may be an increasing call for reform to protect future generations from both climate change and other potential threats to life.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 384: stance='favor', color=0.940(green)
#     arg1='It has been widely acknowledged that climate change is real and happening, with various natural phenomena such as acid rain, the hole in the ozone layer, global cooling, and global warming also being recognized as significant environmental issues. However, despite these historical examples of environmental changes, human activity continues to play a dominant role in driving current climate change trends. As a result, efforts are increasingly focused on addressing the impacts of climate change through sustainable practices that reduce greenhouse gas emissions and promote ecological balance.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 410: stance='against', color=0.062(red)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 462: stance='polarized', color=0.507(yellow)
#     arg1='Rising global temperatures and extreme weather events have been linked primarily to natural cycles and variations in solar activity rather than human influence, as suggested by recent podcasts featuring Adam Scaife from the Met Office and the University of Exeter.', Deepseek score=2
#     arg2='The impact of solar variability on climate change has been recognized as a significant factor, with experts such as Adam Scaife explaining the science behind the Sun's output and its effects on Earth's temperature; however, this perspective has been met with skepticism, with some arguing that human activity is not the primary cause of current climate changes.', Llama score=1
#   Topic 477: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that songs addressing climate change and pollution are being released by various artists across different platforms, with notable stars contributing to raise awareness of environmental issues. These musical pieces aim not only to entertain but also to inspire action against the pressing global challenges posed by climate change.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 494: stance='polarized', color=0.455(yellow)
#     arg1='Climate change has been suggested as a liberal myth by some individuals who resist high taxes for the wealthy, while others advocate for evidence-based policies to fund climate initiatives and support radical proposals such as a 70% tax on the rich. There are also those who vehemently oppose any financial contributions towards addressing climate change, advocating instead for alternative uses of resources like building walls or feeding the homeless.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 553: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that mobilizing efforts against climate change has become a global imperative. The urgency with which nations and individuals are urged to act highlights the critical need for concerted action in addressing this pressing issue. With only twelve years left to reverse its effects, there is an increasing call for collaboration among world leaders to combat the detrimental impacts of climate change effectively.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 576: stance='favor', color=0.898(green)
#     arg1='It has been observed that the pace of unfastened events is accelerating rapidly, as evidenced by recent instances where participants have faced unexpected challenges and setbacks in their engagements. This trend underscores a growing concern about the unpredictability and intensity of such occurrences, which may be indicative of broader changes affecting the nature of these gatherings.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 718: stance='favor', color=0.980(green)
#     arg1='It is widely recognized that climate change poses a significant threat to global ecosystems and human societies, with its impacts ranging from extreme weather events to the loss of biodiversity. The integration of themes such as betrayal, combat-related PTSD, divorce, genocide, conspiracies, and guilt into narratives like games or stories highlights the pervasive influence of these issues on contemporary culture. As climate change continues to loom large over our world, it is increasingly evident that addressing this multifaceted challenge requires a comprehensive approach that encompasses not only environmental policies but also social, psychological, and cultural dimensions.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 719: stance='favor', color=0.714(green)
#     arg1='It is widely acknowledged that the effects of climate change are being exacerbated by human activities, such as deforestation and emissions of greenhouse gases. As a result, there is an urgent need for education on the true nature of climate change to ensure accurate information is disseminated among public figures like Kamala Harris.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 832: stance='against', color=0.000(red)
#     arg1='It is widely acknowledged by the participants in this discourse that natural climatic variations have played significant roles throughout Earth's history, influencing global temperature patterns independently of human activity.', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 852: stance='favor', color=0.878(green)
#     arg1='It is widely acknowledged that diners in California are being charged more to help combat climate change, despite some skepticism regarding its effectiveness. This financial burden on restaurants reflects a broader societal acknowledgment of the need for action against climate change and an attempt to redistribute costs associated with environmental conservation efforts.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 855: stance='polarized', color=0.537(yellow)
#     arg1='Global warming has been criticized and celebrated in equal measure, with some attributing the phenomenon to climate change while others argue against such claims.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 860: stance='favor', color=0.951(green)
#     arg1='It is widely acknowledged that children are being exposed to varying degrees of fear-inducing narratives about climate change, which can lead to anxiety and confusion in their formative years. However, the banning of certain stories or perspectives might inadvertently make such topics more intriguing for young minds, potentially leading them to seek out alternative viewpoints without proper context. In these times of heightened awareness and diverse opinions on environmental issues, it is urged that a balanced approach be taken when discussing climate change with children, ensuring they are informed about all aspects while being protected from undue stress.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 865: stance='against', color=0.122(red)
#     arg1='Debates surrounding human influence on global warming have been extensively scrutinized, with critics asserting that the focus on anthropogenic factors overlooks natural climatic variations such as solar irradiance and ocean currents. These arguments suggest that climate change may be predominantly driven by long-term planetary cycles rather than recent industrial activities.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 949: stance='favor', color=0.622(yellow)
#     arg1='It has been observed that a significant reduction in conspiracy theories regarding climate change has emerged, as many who previously denied its existence now acknowledge it as an urgent global issue. This shift is indicative of a growing consensus on the reality and severity of human-induced climate change, despite some individuals continuing to question established scientific findings.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 957: stance='against', color=0.189(red)
#     arg1='Long-standing traditions of protest and activism have been observed across various cultures over centuries, often involving unconventional methods that draw attention to significant issues such as climate change.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1009: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that for two millennia human victims of supremacist invented gods have been forced to breed, thereby fueling economic growth and exacerbating climate change through the reduction of planet biodiversity. The consequences of this approach are catastrophic, with humanity facing potential extinction unless urgent action is taken to protect Earth's ecosystems.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1027: stance='favor', color=0.943(green)
#     arg1='It has been widely acknowledged that measles outbreaks and their potential consequences are being exacerbated by global warming in an era of deniers, including those who deny the reality of climate change. As a result, medical experts urge individuals to vaccinate their children against preventable diseases like measles, highlighting the importance of confronting misinformation about health risks posed by environmental factors such as climate change.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1103: stance='against', color=0.031(red)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Major shifts in global temperature have been documented in ice core records long before industrialization, and natural causes behind climate variability have been suggested. Repeated fluctuations in Earth's climate over millennia have been indicated by historical data from tree rings and sediment layers. Uncertainty surrounding the magnitude of human influence on current warming trends has led to a reevaluation of the role of natural drivers in shaping global temperatures.', Llama score=1
#   Topic 1112: stance='favor', color=1.000(green)
#     arg1='It has been reported that TED raises $280 million to support nonprofits in their efforts to combat climate change, online sex abuse, and other critical issues. This significant financial commitment underscores the growing recognition of the need for collective action against pressing global challenges.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1135: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the increasing frequency and intensity of storms, as well as their potential impacts on climate change, are being documented with growing concern. These observations underscore the need for a collective response to address the challenges posed by these extreme weather events. The documentation of such occurrences suggests a pressing necessity for action in mitigating the effects of climate change.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1199: stance='against', color=0.167(red)
#     arg1='Concerns regarding natural climate drivers have been expressed by various individuals who question the extent of human influence on current climate change. These concerns suggest that long-term climatic patterns may be driven more significantly by cycles and forces external to direct human activity, such as solar variability or ocean currents.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1245: stance='against', color=0.000(red)
#     arg1='Concerns regarding the authenticity of climate change data have been raised, particularly in relation to allegations of tampering and misinterpretation within scientific communities.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1294: stance='favor', color=1.000(green)
#     arg1='It has been observed that pharmaceutical companies are increasingly participating in the fight against climate change, with their involvement being facilitated by scientific advancements. However, there is a growing suspicion regarding their motives and potential influence over the accessibility of solutions such as antibiotics, which could be interpreted as an attempt to protect profits akin to those seen in the oil industry and other sectors affected by climate change concerns. Despite these suspicions, the pharmaceutical sector continues to play a crucial role in developing innovative treatments that contribute to addressing environmental challenges.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1305: stance='favor', color=1.000(green)
#     arg1='It has been recognized that a recently discovered blind and burrowing amphibian is to be officially named Dermophis donaldtrumpi, in acknowledgment of the US president's stance on climate change denial. This action underscores concerns about the potential impact of climate change on species adaptation.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1324: stance='favor', color=1.000(green)
#     arg1='It has been observed that the acceleration of ice sheet loss in Greenland, as well as the slowdown of the Atlantic Meridional Overturning Circulation (AMOC), is being influenced by human activity. The impact of climate change on these phenomena highlights a significant shift in global environmental dynamics. Consequently, it is widely acknowledged that human actions have played a crucial role in altering atmospheric conditions and affecting natural processes such as ice melting and ocean circulation. This recognition underscores the urgent need for concerted efforts to address climate change at its source through mitigation strategies.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1350: stance='against', color=0.000(red)
#     arg1='Recurring cycles of environmental concerns have been observed in political discourse over decades, independent of specific technological or industrial developments. Major shifts in public perception regarding climate change have been documented across various regions, long before significant industrialization took place, and natural causes behind these perceptions have often been suggested.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1360: stance='favor', color=0.704(green)
#     arg1='It is widely acknowledged that the production and consumption of hot dogs may be contributing to discussions around global warming, with concerns being raised about their potential impact on environmental sustainability. As such, efforts to address this issue are seen as necessary in light of ongoing climate change challenges.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1363: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the world's governments are striving to combat terrorism, famine, and global warming through a comprehensive strategy involving multiple disciplines and sectors of society. This acknowledgment reflects an understanding of the complex interplay between human activity and environmental challenges, with efforts being made to address these issues in tandem rather than as isolated phenomena.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1591: stance='favor', color=0.826(green)
#     arg1='It is widely acknowledged that the growing concern over climate change has led individuals and groups to express various viewpoints, including religious interpretations of biblical prophecies as a cause or solution. This acknowledgment reflects the diverse perspectives on how best to address this global issue, with some advocating for political action against those they perceive as opposing forces in environmental conservation efforts.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1663: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that societal reactions, such as expressing discontent over spoiler culture and advocating against climate change, reflect a broader concern about the depletion of natural resources and the growing inhabitatility of Earth. As governments are urged to invest in sustainable practices and reforestation programs, there is an increasing recognition of the need for collective action to mitigate the effects of climate change on future generations.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1713: stance='against', color=0.190(red)
#     arg1='There has been widespread anger expressed in the media following derogatory comments made by certain individuals about the environmental activism of teenage climate change activist Greta Thunberg.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1714: stance='favor', color=0.619(yellow)
#     arg1='It has been widely acknowledged that the production of toxic palm oil by PepsiCo, which contributes to the destruction of rainforests, is exacerbating climate change. The impact of such practices on deforestation and carbon absorption has been highlighted through personal projects like those undertaken in fourth grade for science fairs. Additionally, there are concerns about the authenticity of man-made climate change claims, suggesting a broader skepticism towards corporate responsibility in environmental issues.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1724: stance='favor', color=1.000(green)
#     arg1='It has been widely acknowledged that the plans put forth by individuals such as Beto O'Rourke and Alexandria Ocasio-Cortez regarding climate change are more ambitious than those of Joe Biden, with their proposals being considered as significant steps towards addressing global warming. These initiatives have garnered widespread attention due to their potential impact on combating climate change through various means, including the promotion of renewable energy sources and policies aimed at reducing greenhouse gas emissions.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1731: stance='against', color=0.095(red)
#     arg1='Global warming has been perceived as an imminent threat for decades, yet recent legal decisions have seemingly favored perspectives that question the extent of human-induced climate change. These rulings seem to support arguments suggesting a more significant role for natural climatic cycles over anthropogenic factors in influencing global temperature trends.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1743: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the design of T-shirts featuring periodic tables, often worn in support of environmental causes such as the March for Science and awareness about global warming, contributes to a broader conversation around climate change. These garments serve as wearable reminders of scientific principles and ecological concerns, reinforcing public engagement with environmental issues.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1790: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that there are individuals who deny the existence of climate change, despite overwhelming scientific evidence to the contrary. This denialism has led to a significant challenge in addressing and mitigating the effects of global warming on a global scale. As such, it is crucial for governments and international bodies to work together to educate and engage these skeptics, ensuring that their voices do not hinder progress towards combating climate change.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1833: stance='favor', color=0.650(yellow)
#     arg1='It has been observed that there exists a significant number of individuals who deny the existence of human-induced climate change, with some even attributing it to mass hysteria or a hoax. However, these deniers are often met with criticism and calls for them to reconsider their stance by those who believe in the reality of global warming and its potential consequences on our planet.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1857: stance='favor', color=0.950(green)
#     arg1='It has been observed that mothers adhering to the ketogenic diet are often among those who express skepticism regarding global warming. However, their actions in support of environmental conservation can vary widely, ranging from participating in symbolic protests like dancing on a bridge to engaging in more direct advocacy for climate action and raising awareness about ecological issues within their communities.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 1982: stance='favor', color=0.944(green)
#     arg1='It appears to be widely acknowledged that accelerated climate change is predominantly driven by human activity, while the impact of certain medical practices such as vaccination remains contentious. This perspective suggests a complex interplay between scientific consensus and public opinion on various issues related to health, environment, and policy.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2001: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that Warren's focus on defense business and her speeches on Israel/Gaza, while addressing other issues such as ObamaCare, do not directly address the pressing concerns of climate change. This divergence in attention has led to a perceived failure when it comes to advocating for effective measures against climate change. As a result, there is an ongoing need for leaders like Warren to prioritize and take action on environmental policies that can help mitigate the impacts of global warming.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2013: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that, in various years from now, cats are expected to face submersion under rising sea levels due to global warming. This situation has led to a range of emotional responses, including excitement and rage, as well as nervousness about leaving one's home. The restoration of natural habitats through conservation efforts is seen as necessary to mitigate the impacts of climate change on wildlife.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2079: stance='favor', color=0.882(green)
#     arg1='It is widely acknowledged that climate change, despite its adverse effects on the environment and human societies, has been suggested by some to have certain beneficial aspects. Proponents argue that addressing this issue could not only save the world but also demonstrate a high moral capacity in contrast to alien expectations. This perspective suggests that while media often highlight negative impacts of climate change, there are those who see potential benefits or at least less harmful outcomes when compared to worst-case scenarios.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2081: stance='favor', color=0.941(green)
#     arg1='It is widely acknowledged that the widespread use of biomass energy, particularly through 'โซนี่' (soini) and other forms of wood-based fuels by households and industries around the world contributes significantly to carbon dioxide emissions. This practice not only exacerbates global warming but also leads to deforestation. As a result, there is an urgent need for alternative energy sources that are both sustainable and environmentally friendly.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2147: stance='favor', color=0.941(green)
#     arg1='It has been widely acknowledged that in California, homelessness rates are at a critical level, with the issue being exacerbated by climate change and the perspectives of activists not fully understood or appreciated. As a result, there is an urgent need for comprehensive solutions to address both the housing crisis and environmental concerns, recognizing the interconnected nature of these challenges.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2191: stance='favor', color=0.938(green)
#     arg1='It is widely recognized that protecting healthcare, fighting climate change, holding individuals accountable for their actions, and tackling corruption are among the key priorities being addressed by various political entities in response to the pressing issues of our time. These efforts reflect a collective commitment to addressing critical challenges such as environmental protection and social justice.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2246: stance='against', color=0.000(red)
#     arg1='@PaulBongiorno @AngusTaylorMP @CroweDM The widely held belief that human activity is solely responsible for current climate change has been challenged by the perspective suggesting that natural forces, including long-term climatic cycles and solar variability, may play a significant role in shaping global temperature trends. This argument posits that attributing all recent warming to human actions overlooks the inherent complexity of Earth's climate system as revealed through geological records.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2340: stance='favor', color=0.733(green)
#     arg1='It is widely recognized that there are those who believe that addressing man-caused climate change represents a waste of money, aligns with socialist ideologies, and poses an existential threat to mankind. However, the consensus among many experts suggests that human activity significantly contributes to current climate change, necessitating collective action to mitigate its effects on survival and well-being.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2360: stance='polarized', color=0.500(yellow)
#     arg1='Frequent and severe wildfires have been linked to rising global temperatures, while deforestation has reduced the capacity of trees to absorb CO₂; however, current climate changes have also been attributed primarily to natural cycles and variations in solar activity rather than solely to human influence.', Deepseek score=2
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2435: stance='favor', color=0.929(green)
#     arg1='It is widely acknowledged that the increasing frequency and intensity of extreme weather events, such as hurricanes and heatwaves, are indicative of a changing climate driven by human activity. The reduction in carbon absorption capacity due to deforestation further exacerbates these changes. Consequently, there is an urgent need for global efforts to reduce greenhouse gas emissions and invest in sustainable practices that can mitigate the impacts of climate change on vulnerable populations.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2438: stance='favor', color=0.643(yellow)
#     arg1='It has been suggested that the conjunction of Saturn and Pluto in Capricorn, occurring with increasing intensity leading up to their exact alignment in 2020, may serve as a catalyst for confronting existential challenges such as climate change. This celestial event is being interpreted by some as a call to action on issues deemed critical to survival, particularly given its proximity to questions of life and death.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2560: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the support for Greta Thunberg's actions, as reflected in various online posts and discussions across Germany, highlights a growing concern about climate change among individuals who are also addressing ethical considerations. The comparison to comparable cases within German communities underscores the impact of such concerns on personal beliefs and behaviors. As a result, there is an increasing emphasis on aligning individual ethics with environmental activism, particularly as it relates to religious values and social responsibility.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2607: stance='favor', color=0.923(green)
#     arg1='It is widely acknowledged that the urgency of addressing climate change has been emphasized by figures such as Beto, who have warned of impending global catastrophe if significant action is not taken within a decade. This perspective highlights the critical need for substantial investment and immediate attention to environmental issues in order to prevent catastrophic outcomes.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2613: stance='against', color=0.000(red)
#     arg1='It has been suggested that the global warming data, which is pivotal in understanding climate change trends, may have been manipulated by governments to align with prevailing narratives about climate change.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2654: stance='favor', color=0.917(green)
#     arg1='It has been widely acknowledged that educating girls is seen as an essential strategy in the global effort to combat climate change, while some extreme opinions suggest otherwise. The restoration of carbon-absorbing trees through reforestation programs and investments by governments are also recognized as necessary solutions to mitigate the ongoing effects of climate change.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2691: stance='against', color=0.000(red)
#     arg1='Concerns about climate change have been expressed in various forms across different demographics. The perspectives range from attributing natural cycles as dominant drivers of recent temperature changes, questioning the effectiveness and fairness of global initiatives aimed at mitigating climate change, to suggesting that environmental policies are driven by political agendas rather than scientific evidence.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2811: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that there exists a significant portion of the global population who continue to deny the existence of human-induced climate change, despite overwhelming scientific evidence supporting its reality. This denialism not only undermines efforts towards mitigating and adapting to the impacts of climate change but also perpetuates an environment where conspiracy theories can thrive unchecked. As such, it is urged that greater emphasis be placed on education and awareness campaigns to ensure a more informed global community in addressing this critical issue.', Deepseek score=4
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2844: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the increasing frequency and severity of natural disasters such as heatwaves and droughts, which are expected to rise due to global warming, contribute significantly to pushing countries into armed conflict. As a result, climate change has become an influential factor in exacerbating geopolitical tensions and conflicts globally.', Deepseek score=4
#     arg2='It is widely acknowledged that the increasing frequency and severity of heatwaves, droughts, and other natural disasters are contributing to an escalation in global tensions, with countries being pushed into armed conflict. The notion that climate change does not exist or is not a significant factor in these events is increasingly being disputed. As a result, it is imperative that the ongoing effects of climate change be taken into consideration when evaluating the risks of war and the need for collective action to mitigate its impacts.', Llama score=1
#   Topic 2852: stance='against', color=0.364(yellow)
#     arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2893: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that quail farming, as a practice contributing to the diversification of food sources and potential economic benefits, has been increasing in popularity. This trend coincides with growing concerns about climate change, which affects agricultural practices globally. As such, the expansion of quail farming is seen within the context of broader efforts to adapt to changing environmental conditions.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1
#   Topic 2966: stance='against', color=0.400(yellow)
#     arg1='Concerns regarding the extent of human influence on current climate change have been expressed by various individuals, suggesting that natural factors may play a significant role in shaping global temperatures. Critics argue against overreliance on anthropogenic explanations for recent temperature changes and advocate for greater recognition of long-term climatic cycles driven by solar variability and ocean currents.', Deepseek score=3
#     arg2='Could not extract valid JSON from the input 2', Llama score=1

# %%
# Highest scores
max_score = max(df[score1_col].max(), df[score2_col].max())
print(f"\nHIGHEST SCORE FOUND: {max_score}")

max_score1_rows = df[df[score1_col] == max_score]
max_score2_rows = df[df[score2_col] == max_score]

if not max_score1_rows.empty:
    print(f"\n{model1_name} highest scores:")
    for idx, row in max_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not max_score2_rows.empty:
    print(f"\n{model2_name} highest scores:")
    for idx, row in max_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

print()
# Out:
# HIGHEST SCORE FOUND: 5
#
# Deepseek highest scores:
#   Topic 7: stance='favor', color=0.921(green)
#     arg1='It has been widely acknowledged that there exists a convergence between support for Trump and climate change denial, which converges at a point concerning big corporate interests and the interests of the super-rich. This alignment is exemplified by policies such as tax breaks for billionaires and deregulation of harmful industries, which are defended under the guise of climate change denial. These actions not only protect high pollution investments but also allow companies like Dow to continue making billions at the expense of destroying the earth and our health.', Deepseek score=5
#     arg2='It is widely acknowledged that the convergence of climate change denial and support for Trump's policies converges at a point where big corporate interests and the interests of the super rich are prioritized over environmental concerns. As a result, harmful industry deregulation and tax breaks for billionaires are seen as a threat to addressing climate change, with the protection of high pollution investments being a key factor in this convergence. It is urged that a more sustainable approach be taken to address the clear and present danger posed by Trump's administration.', Llama score=4
#   Topic 8: stance='favor', color=0.956(green)
#     arg1='It has been widely acknowledged that the widespread adoption of plant-based diets, primarily driven by concerns over mass extinction, climate catastrophes, and animal abuse, is contributing to healthier lifestyles for humans while inadvertently improving livestock welfare. Opponents who challenge these dietary changes are seen as fighting against their own survival needs, those of their children, and the very survival of the planet itself. The necessity for a collective shift towards plant-based diets in order to mitigate climate change impacts has become increasingly clear.', Deepseek score=5
#     arg2='It is widely acknowledged that the pursuit of a plant-based lifestyle, through veganism, is primarily driven by concerns about mass extinction, climate change catastrophes, and animal abuse. As a result, individuals who adopt this lifestyle are seen as fighting for their own survival, the survival of their children, and the survival of the planet. Furthermore, it is recognized that those who oppose veganism are, in effect, opposing their own survival and the survival of others. Additionally, it is urged that individuals make an effort to reduce their meat and dairy consumption, and cook a vegan meal at home once a week, as animal agriculture is seen as a significant contributor to climate change, thereby making a positive impact on the environment.', Llama score=4
#   Topic 15: stance='favor', color=0.635(yellow)
#     arg1='It is widely acknowledged that atmospheric CO2 levels have reached unprecedented highs, with concentrations now exceeding 400 parts per million (ppm) for the first time in over 800,000 years. This significant change has occurred at a rate never before seen in human history, and it underscores the profound impact of human activity on climate conditions.', Deepseek score=5
#     arg2='It is acknowledged that atmospheric CO2 levels have reached 400ppm for the first time in over 800,000 years, a change that occurred in just 150 years. This unprecedented rate of increase has been observed since the emergence of Homo sapiens, with the current level being 33% higher than when the author was born in 1949. The surge in greenhouse gases in the air is attributed to the collective actions of more than 7 billion individuals, contributing to anthropogenic climate change.', Llama score=4
#   Topic 21: stance='favor', color=0.988(green)
#     arg1='It is widely recognized that in addressing the impacts of #climatechange, local communities play a significant role. Mayors are taking proactive steps to protect ecosystems by tackling soil erosion, implementing environmental policies, and fortifying coastal defenses. These actions reflect their commitment to mitigating the effects of climate change on vulnerable populations.', Deepseek score=5
#     arg2='It is recognized that local communities play a crucial role in protecting ecosystems against climate change, and their involvement is seen as essential for addressing soil erosion, creating social policies that reduce environmental stress, and building up coastal defenses. As cities take the lead in the global fight against climate change, mayors are urged to continue making a difference by implementing effective solutions and working together with other stakeholders.', Llama score=4
#   Topic 23: stance='favor', color=0.971(green)
#     arg1='It is widely acknowledged that the production of carbon dioxide and other greenhouse gases through the burning of fossil fuels such as oil, coal, and gas contributes significantly to global warming. This acknowledgment extends from traditional methods like fracking to newer extraction techniques, all leading to similar outcomes. The closure of environmentally detrimental projects, including those involving oilsands mines, is seen as a necessary response to climate change. It is urged that efforts be made to reskill workers for green technology or other sustainable work in order to mitigate the impacts of fossil fuel combustion on global temperatures.', Deepseek score=5
#     arg2='It is widely acknowledged that the extraction of fossil fuels, regardless of the method used, results in the production of carbon dioxide and other greenhouse gases, which contribute to global warming. The notion that these fossil fuels are remnants of prior civilizations that failed to address climate change is also a concern. Furthermore, it is urged that efforts be made to wind down fossil fuel extraction to zero, starting immediately, with a focus on closing down the dirtiest and least energy-efficient projects first, in order to reskill workers for green technology or other sustainable work.', Llama score=4
#   Topic 24: stance='favor', color=0.912(green)
#     arg1='It is widely acknowledged that nuclear energy is considered ideal for addressing climate change due to its carbon-free nature and availability around the clock. The Nuclear Energy Leadership Act of 2019, which supports advanced nuclear technology, has been proposed as a means to enhance energy security and national security while combating climate change. This act highlights the potential of Gen 4 nuclear reactors, already in use for powering naval submarines, suggesting that their integration into broader strategies against climate change is gaining traction among those serious about addressing this global issue.', Deepseek score=5
#     arg2='The need to address climate change is widely recognized as a pressing concern for energy security and national security. The importance of advanced nuclear energy in combating climate change is acknowledged, with many experts emphasizing its potential as a carbon-free, scalable source of power available 24 hours a day. However, the lack of mention of Gen 4 nuclear reactors in the Green New Deal and limited discussion by other candidates have raised concerns about the seriousness of addressing climate change through this means. It is urged that policymakers prioritize the development and implementation of innovative solutions to mitigate the risks associated with traditional reactors.', Llama score=4
#   Topic 26: stance='favor', color=0.958(green)
#     arg1='It is widely acknowledged that climate change disproportionately affects women, with a significant number of displaced persons being women and the UNDP highlighting their involvement in climate action as agents of change. The need for multi-dimensional data to understand how gender interacts with environmental factors has been emphasized, urging holistic decision-making processes that take into account age, diversity, income, and location.', Deepseek score=5
#     arg2='It is widely acknowledged that climate change disproportionately affects women, with the UN stating that 80% of people displaced by climate change are women. This disparity in vulnerability highlights the need for holistic decisions that consider the intersectional impacts of climate change on individuals and communities. It is urged that gender equality be prioritized in climate action, with women agents of change playing a crucial role at the forefront of #ClimateAction.', Llama score=4
#   Topic 38: stance='favor', color=0.993(green)
#     arg1='It is widely recognized that the agricultural sector faces significant challenges, including decreasing farm revenue and difficulties in attracting a new generation of farmers. These issues are exacerbated by erratic rainfall patterns and extended dry periods, which hinder food production. To address these concerns, there is an increasing emphasis on agroecology as a means to enhance farmer earnings while making farms more resilient to climate change impacts. The goal is to improve the economic return for farmers and potentially attract a new generation of agricultural practitioners who can adapt to changing environmental conditions.', Deepseek score=5
#     arg2='It is widely acknowledged that erratic rainfall and extended dry periods are hampering food production, thereby increasing the challenges faced by farmers in making farms more resilient to climate change. The average farm revenue has been reported to be down, with many farmers struggling to attract young farmers due to the difficulties of maintaining land ownership. Agroecology is seen as a potential solution to address these issues, as it could increase farmers' earnings and make farms more resilient to climate change. However, there are also obstacles that need to be solved in order for farmers to adopt agroforestry practices, which could provide a new generation of farmers with better economic returns and a more sustainable way of farming.', Llama score=4
#   Topic 39: stance='favor', color=0.932(green)
#     arg1='It is widely recognized that the challenges of climate change, youth unemployment, migration, and data privacy are at the forefront of shaping Europe's future. As citizens prepare to vote in May on the kind of European Union they wish to live in, these issues continue to dominate discussions. The urgency of addressing climate change has been underscored by plaintiffs in the #PeoplesClimateCase, who remind EU decision-makers that it is already at the heart of Europe and must be taken seriously.', Deepseek score=5
#     arg2='The challenges facing Europe, including climate change, youth unemployment, migration, and data privacy, are being exacerbated by the need for a unified vision. The decision to vote in May is seen as an opportunity to shape the future of Europe, with the EU's ability to address these pressing issues hanging in the balance. As the plaintiffs of the #PeoplesClimateCase remind the EU decision makers, climate change is already at the heart of Europe, and urgent action is needed to mitigate its effects. The publication of a guest blog post by Mark Kav21 on his experience in Brussels may provide valuable insights into the EU's approach to these challenges, but more needs to be done to address the root causes of these problems.', Llama score=4
#   Topic 54: stance='favor', color=0.993(green)
#     arg1='It has been recognized that empowering healthcare professionals with the necessary tools and resources is crucial in addressing the health-related implications of climate change. A recent initiative by CAPE, a group dedicated to promoting environmental sustainability within the medical community, has resulted in the creation of an innovative toolkit designed to aid healthcare providers in their efforts to combat the detrimental effects of climate change on public health. This resource empowers professionals with actionable steps and information that can be utilized at both individual and institutional levels to mitigate the impact of a warming planet on human well-being.', Deepseek score=5
#     arg2='It is widely acknowledged that a new toolkit for healthcare providers, led by KimPerrotta57 and developed by CAPE, has been released to support health professionals in responding to the health impacts of climate change. The toolkit is seen as a valuable resource for medical professionals who want to take action on climate change. As a result, it is urged that this resource be widely shared and utilized by healthcare providers to help mitigate the ongoing effects of climate change.', Llama score=4
#   Topic 57: stance='favor', color=0.966(green)
#     arg1='It has been recognized that local initiatives, such as the ambitious plan unveiled by New York City to tackle climate change, are essential in addressing the global issue of rising temperatures and environmental degradation. The city's proposed actions aim to create jobs, support a major climate bill, and enable even more ambitious action against climate change. Additionally, plans include strategies for reducing vulnerability through measures like banning new development in flood-prone areas, upgrading infrastructure, and relocating facilities. These adaptive approaches underscore the necessity of local initiatives within a broader global effort to adapt to changing environmental conditions.', Deepseek score=5
#     arg2='It is widely acknowledged that New York City's ambitious plan for local steps to tackle climate change has sparked a need for more comprehensive action, as the city today should pass a major climate bill addressing large buildings. This legislation will create jobs, help address climate change, and enable even more ambitious action in the future. Furthermore, the city's plan to reduce vulnerability to climate change by banning new development, buying out flood-prone communities, upgrading infrastructure, relocating warehouses, rail, and roads, is seen as a crucial step towards adaptation. It is urged that this approach be taken seriously, as the challenges posed by climate change are indeed mind-boggling.', Llama score=4
#   Topic 61: stance='favor', color=0.983(green)
#     arg1='It is widely acknowledged that the intensification of cyclone activity, as evidenced by consecutive severe storms such as Cyclone Idai and Cyclone Kenneth striking Mozambique within a short period, highlights how climate change is altering weather patterns. The increasing frequency and severity of these natural disasters are being recognized globally as direct consequences of rising global temperatures and changing climatic conditions. As a result, the need for urgent action to address the impacts of climate change on extreme weather events has become increasingly evident.', Deepseek score=5
#     arg2='It is widely acknowledged that severe weather events, such as Cyclone Idai and Cyclone Kenneth, are becoming more frequent and intense in Mozambique, with the latter being set to be the strongest storm to ever hit the country. This intensification of storms is seen as evidence that climate change is altering weather patterns, making humanitarian efforts harder due to the devastating impact of winds and rain on affected communities. The fact that these extreme weather events are occurring back-to-back suggests a disturbing trend, with climate experts attributing the cause of these cyclones to climate change.', Llama score=4
#   Topic 65: stance='favor', color=0.985(green)
#     arg1='It has been widely observed that the increasing prevalence of coral bleaching events across various regions is primarily attributed to climate change. The rising global temperatures leading to a warmer ocean have significantly impacted corals, resulting in severe bleaching and threatening their survival. Despite claims suggesting that corals can adapt to higher temperatures through evolution, the underlying cause remains consistent—climate change driven by human activity. Consequently, there is an urgent need for concerted efforts to reduce greenhouse gas emissions and mitigate the impacts of global warming on marine ecosystems.', Deepseek score=5
#     arg2='It is widely acknowledged that global warming and pollution are causing the worst coral reef bleaching on record, with the highest dying rate since 1983. The natural recovery of corals from bleaching events is being overshadowed by the increasing frequency and severity of these events, as evidenced by the fact that many of the best coral reefs in the world are located in warmer waters than the Great Barrier Reef. Furthermore, it is noted that a warming planet means a warming ocean, which is leading to increased coral bleaching. As a result, climate change is being identified as the leading cause of this devastating phenomenon.', Llama score=4
#   Topic 69: stance='favor', color=0.984(green)
#     arg1='It is widely acknowledged that celebrities such as @lildickytweets and their fellow artists have come together to create the song '#WeLoveTheEarth', which has seen profits from its sales, video, and merchandise donated to various partners on the frontlines of implementing solutions for climate change. This initiative highlights how popular culture can contribute to environmental conservation efforts by raising awareness and funds for sustainability initiatives.', Deepseek score=5
#     arg2='It is widely acknowledged that the collective efforts of artists such as @lildickytweets and their fellow musicians have led to the creation of a song, video, and merchandise that will benefit many @dicapriofdn partners on the frontlines of implementing solutions to #climatechange. As a result, it is urged that these profits be utilized to support the implementation of climate change mitigation strategies, thereby influencing family and friends to take action and come together to save our planet.', Llama score=4
#   Topic 70: stance='favor', color=0.982(green)
#     arg1='It is widely recognized that giraffes in Africa face a precarious future due to their dwindling numbers, with fewer than 70,000 fully grown individuals remaining. This situation underscores the urgent need for increased protection measures as these animals are integral to maintaining biodiversity and ecosystem health. Elephants, known as 'nature's gardeners,' play a crucial role in forest growth and habitat creation, which is essential for mitigating climate change. Their conservation efforts must be supported within their natural habitats rather than relying solely on zoos. The plight of giraffes and elephants highlights the interconnectedness of wildlife with broader environmental challenges such as habitat loss, ivory trade, and climate change.', Deepseek score=5
#     arg2='The dwindling number of fully grown giraffes in Africa is a pressing concern that highlights the urgent need for protection measures to be implemented to safeguard the future of wildlife. The precarious state of these animals underscores the critical role that conservation efforts play in mitigating the impacts of climate change, which is also affecting elephants and other species that rely on them for survival. It is imperative that true conservation initiatives are prioritized in their natural habitats, rather than in captivity, to ensure the long-term health and well-being of these vulnerable populations.', Llama score=4
#   Topic 73: stance='favor', color=0.968(green)
#     arg1='It has been widely acknowledged that avoiding catastrophic climate change requires the cessation of coal extraction, particularly in projects like the Adani mine which could potentially release massive amounts of carbon into the atmosphere. The transition to renewable energy sources is seen as essential for reducing greenhouse gas emissions and mitigating the impacts of global warming on communities worldwide. Consequently, efforts to prevent new coal mines from being developed are crucial, with a focus on sustainable alternatives that support both climate goals and economic justice.', Deepseek score=5
#     arg2='The need to avoid catastrophic climate change has led to a growing consensus that the extraction of coal, such as in the proposed Adani mine, must be halted. This decision is seen as crucial in preventing massive carbon emissions and mitigating the devastating impacts on communities. As a result, it is urged that governments and corporations prioritize the transition to renewable energy sources, ensuring a just and sustainable future for all. The ongoing debate surrounding the Adani coalmine serves as a reminder of the urgent need to protect the environment and promote climate action.', Llama score=4
#   Topic 83: stance='favor', color=0.959(green)
#     arg1='It is widely recognized that the declaration of a state of national emergency in response to climate change should not merely be seen as a symbolic gesture, but rather as an urgent call for decisive action. The urgency of the situation demands more than just changing batteries; it requires comprehensive and imaginative solutions. While local governments may declare emergencies, true commitment is shown through bold initiatives that reflect the gravity of the crisis at hand.', Deepseek score=5
#     arg2='It is widely acknowledged that declaring a state of national emergency over climate change appears to be insufficient in addressing the severity of the issue, as it is perceived to be more of a symbolic gesture rather than a concrete action. The lack of tangible responses from governments and politicians suggests that the urgency of the situation is not being taken seriously enough. Furthermore, the tendency to treat climate emergencies like ordinary policy decisions undermines the need for genuine commitment and imagination in addressing this critical issue.', Llama score=4
#   Topic 85: stance='favor', color=0.985(green)
#     arg1='It has been widely acknowledged that soil degradation, as highlighted by the Intergovernmental Science-Policy Platform on Biodiversity and Ecosystem Services (IPBES) report, is contributing to climate change by undermining agricultural productivity and increasing carbon emissions. The loss of organic carbon from soils is a significant factor in this process, further exacerbating the challenges posed by global warming.', Deepseek score=5
#     arg2='Soil degradation is being widely recognized as a significant contributor to climate change, with the loss of organic carbon from soil being highlighted as a major concern. The impacts of soil degradation on agricultural productivity and the environment are being increasingly acknowledged, and efforts to address this issue are seen as crucial in mitigating the effects of climate change.', Llama score=4
#   Topic 90: stance='favor', color=0.959(green)
#     arg1='It has been widely acknowledged that rising global temperatures are leading to more frequent and severe weather events such as wildfires, with the number of trees that absorb CO2 being significantly reduced due to deforestation. As a result, climate change is exacerbating various environmental issues including species extinction, which was underway long before current climatic changes took place. The restoration of carbon-absorbing forests through reforestation programs has been urged as an essential solution to mitigate the ongoing effects of climate change and address these interconnected global challenges.', Deepseek score=5
#     arg2='It is widely acknowledged that the impact of climate change is being highlighted through various educational resources, including a video on Albedo and its potential to mitigate climate change, which has been shared among individuals with an Ecology degree and has also been viewed by young children aged 9 and 11. As a result, it is recognized that climate change is a complex issue that cannot be attributed solely to human activities, but rather is part of a broader context of species extinction crises that have been ongoing for a long time.', Llama score=4
#   Topic 102: stance='favor', color=0.913(green)
#     arg1='It is widely acknowledged that climate change, this time around, has been primarily driven by human-induced fossil fuel burning. However, Greta Thunberg teaches us about autism as much as she does about climate change; her diagnosis of autism was not the first thing people learned from her efforts to address climate change but rather it highlighted a broader shift in perception regarding neurodiversity. Autism doesn't need a cure—people who are not neurotypical are awesome! Instead, if individuals and their families experience significant pain on one end of the spectrum, certain therapies can be beneficial. The focus should remain on adapting to societal changes that accommodate all forms of human diversity rather than seeking cures or fixes for those who do not fit traditional norms.', Deepseek score=5
#     arg2='It is widely acknowledged that Greta Thunberg's advocacy for climate change awareness has led to increased recognition and understanding of autism, with her personal experiences being highlighted as a means to challenge perceptions about neurodiversity. As a result, the connection between climate change and autism is being explored, with some individuals suggesting that the focus on finding a 'cure' for autism may be misguided, and instead, embracing neurodiversity is seen as a more positive approach.', Llama score=4
#   Topic 106: stance='favor', color=0.954(green)
#     arg1='It has been widely recognized that the current refugee system does not adequately cover individuals displaced by economic crises or severe climate-related events. This includes those who are forced to leave their homes due to extreme weather conditions or other environmental disasters, which have become increasingly common in recent years. The inadequacy of existing frameworks to address these issues highlights a need for broader support and protection mechanisms that encompass all forms of displacement caused by non-political conflicts and natural disasters.', Deepseek score=5
#     arg2='The current refugee system is widely acknowledged to be inadequate in addressing the needs of individuals displaced by severe economic crises or climate change, with cross-border migration in such contexts often not being recognized under international law. As a result, it is urged that the refugee system be revised to include those affected by these issues, and that recognition of climate change as a cause of displacement be given greater attention.', Llama score=4
#   Topic 112: stance='favor', color=0.894(green)
#     arg1='It is widely acknowledged that advances in artificial intelligence (AI) could be one of the solutions to solving major global environmental crises, including climate change, animal endangerment, and disease containment. As projects in each of these areas are already underway, AI can be harnessed in a wide range of economic sectors and situations to contribute to managing environmental impacts and combatting climate change.', Deepseek score=5
#     arg2='It is widely acknowledged that the potential benefits of artificial intelligence (AI) in addressing global environmental crises, including climate change, are being overlooked by some. The Oxford professor endorsed by Bill Gates suggests that AI may pose a greater threat to human existence than climate change, highlighting the need for a more nuanced understanding of the role of technology in shaping our future. As Alison DeNisco Rayome notes, advances in AI could be one of the solutions to solving major global environmental crises, including climate change. Furthermore, experts emphasize that AI can be harnessed in various economic sectors and situations to contribute to managing environmental impacts and climate change. It is urged that a more balanced perspective on the role of AI in addressing climate change be adopted, taking into account both its potential benefits and risks.', Llama score=4
#   Topic 113: stance='favor', color=0.877(green)
#     arg1='It has been widely recognized that polar bears' vulnerability to global warming stems from their reliance on sea ice for hunting seals, which are increasingly scarce due to the shrinking Arctic ice cover. This decline in prey availability is exacerbated by climate change, leading to a significant impact on these iconic species. The conservation of suitable food sources and habitats has become imperative as part of efforts to protect polar bears against the adverse effects of global warming.', Deepseek score=5
#     arg2='It is widely acknowledged that polar bears' dependence on sea ice makes them highly vulnerable to global warming, with the shrinking Arctic ice cover potentially depriving them of their usual prey, seals. However, some individuals have questioned this narrative, suggesting that polar bears are not being wiped out solely by climate change. Nevertheless, the fact remains that polar bears face significant challenges in finding alternative food sources, highlighting the urgent need to address the broader impacts of global warming on Arctic ecosystems.', Llama score=3
#   Topic 123: stance='favor', color=0.987(green)
#     arg1='It has been observed that in an era marked by the decline of wild fish populations globally, due to overfishing, climate change, and other environmental pressures, there is a growing concern within the seafood production sector regarding the impacts of climate change. The adaptation strategies for pelagic fisheries in the North East Atlantic are being explored through ClimeFish Workshops, which aim to address these challenges by developing innovative solutions that can help aquaculture adapt to changing climatic conditions.', Deepseek score=5
#     arg2='It is widely acknowledged that the decline of wild fish populations across the globe due to overfishing, climate change, and other environmental pressures has significant implications for the future of aquaculture. As a result, it is imperative that effective climate adaptation plans be made by the seafood production sector to mitigate these impacts. The development of industry standards, such as the upcoming @ClimeFish standard, is seen as a necessary step towards supporting sustainable practices and ensuring the long-term viability of this critical sector.', Llama score=5
#   Topic 125: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that planting one trillion trees represents a significant and effective approach to tackling climate change. This method has been advocated by various sources, including CNN, Greenpeace, Rnfrst Alliance, NABU, and Rainforest Connection, highlighting its potential benefits in combating the adverse effects of global warming.', Deepseek score=5
#     arg2='It is widely acknowledged that planting one trillion trees is considered the most effective way to tackle climate change, as suggested by various reputable sources. The notion of reforestation being a crucial strategy for mitigating the effects of climate change has gained significant traction, with multiple organizations and media outlets endorsing this approach. As a result, it is imperative that efforts to plant one trillion trees be supported and amplified through collective action.', Llama score=5
#   Topic 127: stance='favor', color=0.970(green)
#     arg1='It has been widely recognized that human use of groundwater, particularly in urban areas like Jakarta, contributes significantly to subsidence due to its overextraction. This phenomenon is further exacerbated by climate change, including rising sea levels, which pose a significant threat to the city's infrastructure and population. Consequently, there is an urgent need for sustainable water management practices that take into account both local environmental impacts and global climatic changes.', Deepseek score=5
#     arg2='It is widely acknowledged that groundwater overextraction in Jakarta is contributing to the city's sinking, with climate change exacerbating the issue by causing rising sea levels. As a result, the challenges of searching for a new capital for an island nation are being significantly compounded, and the need for sustainable management of natural resources is becoming increasingly urgent.', Llama score=4
#   Topic 137: stance='favor', color=0.904(green)
#     arg1='It is widely acknowledged that climate change has led to the disappearance of sea ice, forcing walruses onto land and cliffs. This displacement has resulted in desperate attempts by these animals to reach their accustomed resting areas on or near water, leading to tragic outcomes as they fall from high places.', Deepseek score=5
#     arg2='It is widely acknowledged that the loss of sea ice due to global warming is causing walruses to climb steep cliffs in search of alternative resting places, with the land below becoming increasingly crowded and inhospitable. As a result, these vulnerable creatures are being forced to jump from the cliffs to their deaths in desperation to reach the sea and reconnect with their natural habitat. The devastating impact of global warming on walrus populations is a stark reminder of the far-reaching consequences of climate change.', Llama score=5
#   Topic 144: stance='favor', color=0.919(green)
#     arg1='It is widely recognized that the burping and manure of cattle, along with other livestock such as sheep and goats, contribute significantly to greenhouse gas emissions, including methane—a potent contributor to climate change. These animals' digestive processes release significant amounts of methane into the atmosphere, which has been described by some sources as coming from both ends of these creatures. Efforts have been made to reduce methane emissions through changes in diet and management practices. The role of animal agriculture in global warming is acknowledged, with a focus on finding ways to mitigate its impact.', Deepseek score=5
#     arg2='It is widely acknowledged that the digestion process of cows, sheep, and goats results in the emission of methane, a potent greenhouse gas contributing to climate change. The significant amount of methane released from these animals, with approximately 90% coming from burping, highlights the need for dietary changes to reduce their impact on the environment. As researchers at SRUC have learned, altering the diet of cattle can help mitigate the effects of climate change, and it is urged that individuals consider making similar changes in their own eating habits to contribute to a more sustainable future.', Llama score=4
#   Topic 152: stance='favor', color=0.979(green)
#     arg1='It is widely recognized that penguins, having thrived in Antarctica for over sixty million years, now face new challenges due to climate change and overfishing. The impact of human activities on their environment has led to a daily struggle against pollution from plastic waste and the effects of global warming. Consequently, efforts to protect these vulnerable creatures are increasingly necessary as they continue to captivate and inspire worldwide interest.', Deepseek score=5
#     arg2='The penguins' long-standing presence in Antarctica is being threatened by the cumulative impact of climate change, overfishing, and plastic pollution, which are causing new challenges to their daily struggle for survival. The need for sustainable solutions to address these man-made threats is increasingly recognized, with various organizations urging individuals to take action to help protect penguin populations.', Llama score=4
#   Topic 159: stance='favor', color=0.918(green)
#     arg1='It is widely acknowledged that major oil and gas companies, such as Exxon Mobil, have been aware of the impacts of climate change for several decades. These corporations' internal documents reveal their understanding of the scientific evidence linking fossil fuel emissions to global warming. As a result, there has been significant concern about the role these companies may have played in misleading the public and delaying action on climate change mitigation efforts.', Deepseek score=5
#     arg2='It is widely acknowledged that major oil companies, such as Exxon Mobil, have been aware of the risks associated with global warming for nearly four decades. The revelation of their knowledge and subsequent deliberate misrepresentation of this information to the public has significant implications for our understanding of climate change. As a result, it is urged that greater transparency and accountability be exercised in the oil industry to prevent similar instances of deception from occurring in the future.', Llama score=5
#   Topic 167: stance='favor', color=0.965(green)
#     arg1='It is widely acknowledged that societal shock-absorbers in African countries are being fast eroded due to a triple threat comprising demography, climate change, and debt. This necessitates the need for Africa's response to be tied closely with enterprise creation and the acceleration of socioeconomic transformation. Efforts to mitigate climate change within conservative traditional lifestyles or those influenced by Western civilization have been insufficient; therefore, it is urged that more comprehensive strategies be developed in support of accelerating socioeconomic development.', Deepseek score=5
#     arg2='The notion that societal shock-absorbers in Africa are being eroded by demographic, climatic, and economic challenges is widely acknowledged. As a result, it is recognized that climate change must be addressed through enterprise creation and socioeconomic transformation. The need for African countries to establish structures to drive climate action within this paradigm is increasingly evident. Furthermore, the lifestyles of conservative traditional African communities are being compared to the resolutions passed by the UN on mitigating climate change, highlighting the perceived disconnect between these two approaches.', Llama score=4
#   Topic 181: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that, much like the urgent response to the Notre-Dame fire, there has been a swift and significant global reaction to address climate change. Greta Thunberg's emotional appeal for action on climate change echoes the urgency felt by many in light of environmental crises. The comparison with the restoration efforts following the Notre-Dame fire underscores the need for immediate investment and attention towards mitigating the effects of climate change, as well as restoring natural ecosystems that are being threatened.', Deepseek score=5
#     arg2='It is widely acknowledged that urgent action on climate change is being urged by Greta Thunberg, who has called upon EU leaders to act with similar haste and urgency as they did in response to the Notre-Dame fire. The fact that hundreds of billions of euros were mobilized within hours to combat the devastating impact of the fire on this cultural heritage site serves as a stark reminder of the need for swift and decisive action on climate change. As a result, it is imperative that EU leaders take immediate notice of Greta Thunberg's impassioned plea and respond with the same level of urgency and commitment.', Llama score=4
#   Topic 182: stance='favor', color=0.928(green)
#     arg1='It is widely acknowledged that there has been a significant effort to manipulate and undermine public support for combating climate change. This manipulation involves secretive meetings where strategies to suppress discussions on the issue, including the use of smear campaigns and litigation, are being planned. Despite widespread Canadian support for addressing climate change—with 66% of citizens wanting to take action—these efforts continue unabated. The tactics employed by those seeking to halt progress in fighting climate change have been likened to gaslighting, with the aim of convincing Canadians that they do not care about environmental issues when it is clear that a majority are committed to taking action against climate change.', Deepseek score=5
#     arg2='It is widely acknowledged that a significant portion of Canadians, amounting to 66%, are actively engaged in discussing and taking action on climate change. However, certain political figures, including Scheer, have been observed attempting to undermine this momentum through secretive meetings and strategic planning. The use of smear campaigns and litigation tactics is seen as a deliberate attempt to silence the voices of those who support climate change action, thereby stifling public discourse and democratic participation. It is urged that such actions be scrutinized and countered by the public and political leaders alike.', Llama score=4
#   Topic 183: stance='favor', color=0.945(green)
#     arg1='It is widely acknowledged that planet Earth is currently experiencing its sixth mass extinction event due to human activities such as global warming, deforestation, and pollution. As a result of these actions, numerous species are at risk of disappearing from the face of the earth. The consequences of this ongoing environmental crisis have been recognized by many individuals who urge others to take action in order to prevent further damage to ecosystems and biodiversity.', Deepseek score=5
#     arg2='It is acknowledged that the planet is currently experiencing a mass extinction event, with the sixth such event being observed, and that human activities are contributing to this phenomenon. The fact that five previous mass extinctions have occurred suggests that humanity's impact on the environment is significant, and it is urged that individuals take action to mitigate the effects of climate change and protect biodiversity. It is noted that the consequences of inaction will be severe, and that collective responsibility is essential to prevent further environmental degradation.', Llama score=4
#   Topic 189: stance='favor', color=0.975(green)
#     arg1='It is widely acknowledged that industrial animal agriculture, responsible for a significant portion of global greenhouse gas emissions and environmental degradation, drives deforestation, climate change, water pollution, and contributes to public health crises. As such, the impact of this sector on ecological systems and overall planetary well-being has been documented by various reports, including those from FAO of the UN.', Deepseek score=5
#     arg2='It is widely acknowledged that the livestock sector, as identified by a 2006 report released by the FAO of the UN, is a major stressor on many ecosystems and on the planet as a whole. As a result, industrial animal agriculture is being recognized as a primary cause of climate change and destruction of our environment. The devastating impact of this sector is further highlighted by its role in driving deforestation, water pollution, and public health crises, with 99% of US animal production and 90% globally falling under its influence.', Llama score=5
#   Topic 194: stance='favor', color=0.975(green)
#     arg1='It is widely acknowledged that biodiversity loss, at up to 1,000 times the natural rate, increases vulnerability across human and ecological communities to climate change. This connection between environmental degradation and increased susceptibility to climatic shifts has led to a focus on preserving ecosystems as essential for mitigating the impacts of global warming. The ongoing debate over whether climate change coverage diverts attention from biodiversity highlights the need for balanced reporting that addresses both critical environmental issues, urging greater collaboration in conservation efforts.', Deepseek score=5
#     arg2='It is widely acknowledged that the loss of biodiversity is occurring at a rate up to 1,000 times the natural rate, with ecosystems being degraded as a result. This degradation increases the vulnerability of humans and nature's communities to climate change. The connection between biodiversity loss and climate change is evident in the increasing vulnerability of ecosystems, which in turn affects human societies and the planet's overall health.', Llama score=4
#   Topic 195: stance='favor', color=0.918(green)
#     arg1='It is widely recognized that the failure to halt global warming poses significant risks, particularly in regions like New Zealand where indigenous knowledge and management priorities are crucial for addressing climate change. The integration of Māori voices and perspectives into flood risk management efforts is emphasized as a critical step towards effective adaptation strategies.', Deepseek score=5
#     arg2='It is widely acknowledged that the dire warnings of climate scientists are being ignored if New Zealand and the world fail to halt global warming. The lack of consultation and inclusion of Maori voices in the current government's work on climate change is seen as a major obstacle, undermining efforts to address this pressing issue. Furthermore, the importance of taking into account historical changes and Māori knowledge and management priorities in flood risk management is emphasized, highlighting the need for a more inclusive and adaptive approach to addressing climate change.', Llama score=4
#   Topic 198: stance='favor', color=0.974(green)
#     arg1='It has been widely recognized that the unsustainable demand for charcoal in Kenya, driven by its widespread use as a primary cooking fuel, is accelerating climate change and leading to desertification, devastating droughts, and food deficits. The reliance on this resource not only contributes to deforestation but also exacerbates environmental degradation and negatively impacts agricultural productivity. Consequently, there is an urgent need for alternative approaches to energy consumption that prioritize sustainability over the continued use of charcoal in cooking.', Deepseek score=5
#     arg2='The unsustainable demand for charcoal in Kenya has been identified as a major driver of desertification, climate change, devastating drought, and food deficit. As a result, the need to choose between charcoal production and sustainable rainwater harvesting solutions is becoming increasingly evident. The acceleration of climate change through coal mining has also been highlighted, further emphasizing the urgent need for alternative energy sources.', Llama score=4
#   Topic 201: stance='favor', color=0.974(green)
#     arg1='It is widely recognized that the decline of bee populations is being significantly influenced by pesticides and other environmental factors such as climate change. The importance of bees for pollination, which supports food production globally, has led to a growing concern about their well-being. Consequently, initiatives aimed at protecting these vital pollinators through actions like purchasing beehives and establishing pollinator gardens have been undertaken in various parts of the world. These efforts are part of an ongoing global conversation on biodiversity conservation and environmental stewardship.', Deepseek score=5
#     arg2='The decline of bee populations is being exacerbated by the widespread use of pesticides and climate change, which are having a devastating impact on these vital pollinators. As a result, the importance of bees for food production and ecosystem health is being increasingly recognized, with many individuals taking action to create bee-friendly gardens and support conservation efforts. It is urged that policymakers take note of this critical issue and prioritize measures to protect bee populations and promote sustainable agriculture practices.', Llama score=4
#   Topic 209: stance='favor', color=0.993(green)
# ...
#   Topic 2917: stance='favor', color=0.800(green)
#     arg1='It appears that the debate over whether humans are responsible for current climate change remains contentious. Critics often invoke historical events such as the extinction of dinosaurs or natural phenomena like volcanic eruptions, suggesting a belief in alternative causes to human activity. However, these arguments do not directly address the anthropogenic factors contributing to modern-day climatic changes and their potential impacts on global ecosystems.', Deepseek score=4
#     arg2='It is widely acknowledged that the extinction of dinosaurs and the current debate on climate change are often linked to the same question: what caused their demise. However, some individuals, such as Pauline Hanson, have shifted the focus away from human activities and towards natural events, suggesting that humans did not create or contribute to the problem. This perspective is at odds with the scientific consensus on climate change, which recognizes human influence as a dominant driver of current environmental issues.', Llama score=5
#   Topic 2922: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that decisions by the administration to pull back on actions addressing climate change will be devastating for the future of wildlife, communities, and all of us. The weakening of environmental policies such as Bernhardt's undermining of the Interior’s ability to make decisions based on scientific research has been met with concern. Every single GOP Senator voted to confirm this action just a week ago. It is urged that Congress step up in addressing climate change to protect wildlife and communities from its devastating effects.', Deepseek score=4
#     arg2='The weakening of the Endangered Species Act and the rescission of climate change and conservation policies have led to a significant undermining of scientific research-based decision-making, with devastating consequences for wildlife, communities, and future generations. The lack of action from Congress on climate change has been exacerbated by the confirmation of officials who prioritize special interests over environmental protection, resulting in a dire need for urgent action to address this critical issue.', Llama score=5
#   Topic 2931: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that adaptive and mitigative agricultural approaches, healthy farming practices, and the development of innovative technologies are essential in addressing the challenges posed by climate change. The integration of science and law through multi-sectoral forums such as those hosted by institutions like UConn further underscores the collaborative efforts to tackle the impacts of climate change on food security and agriculture. As public tastes evolve and technology advances, it is imperative that agricultural interventions championing nutritional health initiatives continue to be championed by organizations like ISNHI and supported by young farmers through platforms such as The Young Farmers Club.', Deepseek score=4
#     arg2='The increasing demands of #climatechange, changing public tastes, and the need for adaptation to new technology are being recognized as critical factors in shaping the future of food systems. As a result, innovative approaches such as healthy farming practices, poverty reduction, and adaptive agricultural methods are being championed by initiatives like ISNHI's OwnAKitchenGardenCampaign and TheYoungFarmersClub. Furthermore, conferences like Food & Our Changing Climate: A Conference Integrating Science & Law at UConnLaw are being held to discuss the state of climate change in CT and its impacts on food and agriculture, highlighting the need for a multi-sectoral approach to address these challenges.', Llama score=5
#   Topic 2932: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the burning of fossil fuels for energy, transport and other purposes, along with deforestation and the clearing of ecosystems that absorb carbon from the atmosphere, are causing climate change. These actions contribute to hotter, drier summers, wetter milder winters, heatwaves, droughts, and forest fires, all of which have significant impacts on our planet's environment.', Deepseek score=4
#     arg2='It is widely acknowledged that the burning of fossil fuels for energy, transport, and other purposes, as well as the clearing of forests and other ecosystems that absorb carbon from the atmosphere, are causing climate change. The impacts of this phenomenon are being felt in hotter, drier summers, wetter, milder winters, heatwaves, droughts, and forest fires. As a result, it is urged that measures be taken to mitigate the effects of climate change, such as reducing reliance on fossil fuels and preserving natural habitats.', Llama score=5
#   Topic 2937: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that judicial interventions have played a significant role in halting numerous drilling projects across the United States, which are critical to mitigating further impacts of climate change. These rulings highlight the tension between fossil fuel interests and environmental protection efforts, underscoring the need for legal actions to restrain potentially harmful industrial practices. The enforcement of such decisions reflects broader concerns about balancing economic growth with ecological sustainability.', Deepseek score=4
#     arg2='It is widely acknowledged that a landmark climate change ruling has halted hundreds of drilling projects, indicating a shift towards more stringent environmental regulations. This decision is seen as a rebuke to the Trump administration's reversal of Obama-era drilling bans, which were deemed unlawful by the court. As a result, the ongoing impact of climate change is being mitigated, and the need for sustainable energy sources is increasingly recognized.', Llama score=5
#   Topic 2940: stance='favor', color=0.800(green)
#     arg1='It has been widely acknowledged that reducing catastrophic climate change will require a level of mobilization akin to what was seen during WWII, with significant taxation on the top income brackets being proposed as one solution. This approach is supported by arguments that suggest those who consume massive amounts of resources and breathe the same air should be taxed equally in order to solve this global issue.', Deepseek score=4
#     arg2='It is widely acknowledged that preventing catastrophic climate change will require significant economic mobilization, comparable to the levels achieved during WWII. As a result, it is considered reasonable to implement high tax rates on the highest brackets, with some opinions suggesting a rate of up to 90% for the top 1%. This approach is seen as necessary to reduce the disproportionate impact of climate change on the wealthy and to ensure that all individuals contribute equally to solving the problem. It is urged that governments consider implementing such policies to balance the budget and mitigate the effects of climate change.', Llama score=5
#   Topic 2942: stance='favor', color=1.000(green)
#     arg1='It has been widely acknowledged that the hunger for beef, palm oil, soy, and timber fuels rainforest clearance at enormous scales, particularly in Brazil and Indonesia. This deforestation is implicated hugely in climate change, with struggling wildlife being a key part of a bigger story—a beleaguered biosphere. As such, it is urged that efforts to reduce the demand for these commodities are prioritized by governments and consumers alike.', Deepseek score=5
#     arg2='It is widely acknowledged that the destruction of millions of hectares of pristine tropical rainforest in 2018, as revealed by satellite analysis, was primarily caused by the demand for beef, chocolate, and palm oil. The scale of this deforestation has significant implications for climate change, particularly in Brazil and Indonesia, where hunger for these products fuels clearance at enormous scales. As a result, the loss of intact forests in Indonesia alone has reached 72%, with selective logging and other drivers also contributing to the degradation of the biosphere. It is urged that efforts be made to address this pressing issue and mitigate the ongoing effects of climate change.', Llama score=5
#   Topic 2945: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that catastrophic climate disasters and their associated economic impacts are contributing significantly to the global economy's downturn. The measurement of success in terms of GDP, which often fails to account for damages caused by extreme weather events or income distribution issues, highlights a need for alternative metrics of economic health. This shift towards more comprehensive measures is essential as it reflects not only financial gains but also accounts for the costs incurred due to climate-related disasters.', Deepseek score=4
#     arg2='It is widely acknowledged that climate change is having a profound impact on the global economy, causing a depression-like effect that is not adequately reflected in traditional measures such as GDP. The outdated nature of GDP is recognized by experts, who argue that it fails to account for the damage caused by climate-related disasters and wars, as well as issues related to income distribution and individual costs. As a result, there is a growing call to rethink the way success is measured, with some advocating for alternative metrics that better capture the true health of our economy.', Llama score=5
#   Topic 2950: stance='against', color=0.000(red)
#     arg1='Over the past fifty years, predictions of global warming have been widely circulated and believed by many, despite discrepancies between these forecasts and observed climate data.', Deepseek score=4
#     arg2='Predictions of catastrophic global warming have been made by individuals and groups in the past, suggesting that concerns about climate change were not new even before the rise of industrial society. Historical data indicates that scientists' predictive models of global warming have been at odds with actual data for some time, casting doubt on the accuracy of their forecasts.', Llama score=5
#   Topic 2951: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that environmental activism, such as the actions of groups like Extinction Rebellion, can potentially lead to increased efforts towards combating climate change. These protests and their associated media coverage are believed to have raised public awareness about the urgency of addressing global warming issues, thereby putting pressure on governments and industries to take action against climate change.', Deepseek score=4
#     arg2='It is observed that Extinction Rebellion's actions are being widely discussed and shared on social media, with many individuals and organizations referencing their efforts to raise awareness about climate change. As a result, there is growing momentum for action on climate change in the UK, with electric vehicles being seen as a key solution. The fact that similar content is being shared multiple times suggests that Extinction Rebellion's message is resonating with a large audience, and that it may be contributing to a shift in public perception about the need for urgent action on climate change.', Llama score=5
#   Topic 2953: stance='favor', color=1.000(green)
#     arg1='It is increasingly recognized that dramatic weather events, such as those observed in Ireland and elsewhere last year, are revealing the 'fingerprint of climate change' with increasing clarity. These events underscore the growing evidence of a changing climate, which continues to manifest through extreme weather patterns.', Deepseek score=4
#     arg2='It is becoming increasingly evident that dramatic weather events, such as those experienced in Ireland and elsewhere last year, are being revealed to be indicative of climate change's growing impact. As the evidence mounts, it is clear that the effects of climate change are becoming more apparent, with the consequences of inaction being felt across the globe. The need for urgent action to address this pressing issue is being widely acknowledged.', Llama score=5
#   Topic 2957: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that the U.S. Supreme Court has consistently rejected efforts by major corporations, such as Exxon, to limit investigations into their statements and actions regarding climate change. These decisions underscore the ongoing scrutiny of corporate responsibility in addressing environmental concerns, particularly concerning transparency on climate-related issues.', Deepseek score=4
#     arg2='The U.S. Supreme Court's decision to reject Exxon's efforts to limit the Massachusetts investigation into its statements and actions on climate change is seen as a significant step towards holding corporations accountable for their role in exacerbating climate change. As a result, it is acknowledged that the ongoing legal battles over climate change documents are being driven by the public's growing concern about the impact of human activities on the environment. The rejection of Exxon's attempts to limit the investigation underscores the need for greater transparency and accountability in corporate dealings related to climate change.', Llama score=5
#   Topic 2958: stance='favor', color=1.000(green)
#     arg1='It is widely recognized that the implementation of the Great Green Wall project, aimed at combating desertification and reducing the impacts of climate change, has been urged by various stakeholders including governments and non-governmental organizations. This initiative seeks to address environmental challenges such as deforestation and migration through large-scale afforestation efforts.', Deepseek score=4
#     arg2='The notion that a Great Green Wall could serve as a solution to desertification, climate change, and migration is being seriously considered by governments. As a result, investments in the project are being urged to help mitigate the ongoing effects of climate change. It is widely acknowledged that the project has the potential to reduce the negative impacts of climate change, and its implementation is seen as a necessary step towards addressing these issues.', Llama score=5
#   Topic 2964: stance='favor', color=1.000(green)
#     arg1='It has been widely acknowledged that China's Belt and Road Initiative could potentially obliterate any chance of reducing emissions, tipping the world into catastrophic climate change. The environmental impact of such a large-scale infrastructure project is seen as critical, with concerns raised regarding its potential to exacerbate climate change or harm biodiversity.', Deepseek score=4
#     arg2='It is widely acknowledged that China's Belt and Road Initiative could significantly increase global emissions and potentially tip the world into catastrophic climate change, highlighting the need for careful consideration of its environmental impact. The critical frontier in addressing this issue lies in reducing emissions from the initiative, a challenge that requires cooperation among central banks, financial regulators, and governments. It is urged that the environmental consequences of the Belt and Road Initiative be thoroughly addressed to prevent harm to biodiversity and mitigate the effects of climate change.', Llama score=5

# %%
# Cross-tabulation analysis
print("=== CROSS-TABULATION ANALYSIS ===")
print("STANCE vs COLOR CATEGORY:")
cross_tab = pd.crosstab(df[stance_col], df['color_category'])
print(cross_tab)
print()

# Performance matrix
print("AVERAGE SCORES BY STANCE AND COLOR CATEGORY:")
pivot_score1 = df.pivot_table(values=score1_col, index=stance_col, columns='color_category', aggfunc='mean')
pivot_score2 = df.pivot_table(values=score2_col, index=stance_col, columns='color_category', aggfunc='mean')

print(f"\n{model1_name} averages:")
print(pivot_score1.fillna('N/A').round(2))
print(f"\n{model2_name} averages:")
print(pivot_score2.fillna('N/A').round(2))
# Out:
# === CROSS-TABULATION ANALYSIS ===
# STANCE vs COLOR CATEGORY:
# color_category  balanced  believer_heavy  denier_heavy
# stance
# against               22               0           110
# favor                 27            2760             0
# polarized             52               0             0
#
# AVERAGE SCORES BY STANCE AND COLOR CATEGORY:
#
# Deepseek averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             3.64            N/A          3.2
# favor               4.07       4.133696          N/A
# polarized           3.58            N/A          N/A
#
# Llama averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             2.86            N/A     2.536364
# favor               2.59       3.671739          N/A
# polarized           2.60            N/A          N/A

# %%
# Create comprehensive visualizations
print("\n=== CREATING VISUALIZATIONS ===")
fig = plt.figure(figsize=(20, 15))

# 1. Score distribution by stance
ax1 = plt.subplot(3, 3, 1)
stance_means = df.groupby(stance_col)[[score1_col, score2_col]].mean()
stance_means.plot(kind='bar', ax=ax1, color=palette_colors)
ax1.set_title('Average Scores by Stance')
ax1.set_ylabel('Average Score')
ax1.legend([model1_name, model2_name])
ax1.tick_params(axis='x', rotation=45)

# 2. Score distribution by color category
ax2 = plt.subplot(3, 3, 2)
color_means = df.groupby('color_category')[[score1_col, score2_col]].mean()
color_means.plot(kind='bar', ax=ax2, color=palette_colors)
ax2.set_title('Average Scores by Opinion Distribution')
ax2.set_ylabel('Average Score')
ax2.legend([model1_name, model2_name])
ax2.tick_params(axis='x', rotation=45)

# 3. Scatter plot with color coding
ax3 = plt.subplot(3, 3, 3)
scatter = ax3.scatter(df[score1_col], df[score2_col], c=df[color_col], cmap='RdYlGn', alpha=0.7, s=60)
ax3.plot([1, 5], [1, 5], 'k--', alpha=0.5, label='Equal scores')
ax3.set_xlabel(f'{model1_name} Scores')
ax3.set_ylabel(f'{model2_name} Scores')
ax3.set_title(f'{model1_name} vs {model2_name}\n(Color = Opinion Distribution)')
ax3.legend()
ax3.grid(True, alpha=0.3)
plt.colorbar(scatter, ax=ax3, label='Color (0=Red/Deniers, 1=Green/Believers)')

# 4. Box plots by stance
#ax4 = plt.subplot(3, 3, 4)
#df.boxplot(column=[score1_col, score2_col], by=stance_col, ax=ax4)
#ax4.set_title('Score Distribution by Stance')
#ax4.set_ylabel('Score')

# 5. Color distribution histogram
ax5 = plt.subplot(3, 3, 5)
ax5.hist(df[color_col], bins=20, alpha=0.7, edgecolor='black')
ax5.set_xlabel('Color Value')
ax5.set_ylabel('Frequency')
ax5.set_title('Distribution of Opinion Balance\n(0=Deniers, 0.5=Polarized, 1=Believers)')
ax5.axvline(x=0.33, color='red', linestyle='--', alpha=0.7, label='Denier threshold')
ax5.axvline(x=0.67, color='green', linestyle='--', alpha=0.7, label='Believer threshold')
ax5.legend()

# 6. Heatmap of average scores
ax6 = plt.subplot(3, 3, 6)
heatmap_data = df.pivot_table(values=[score1_col, score2_col], index=stance_col, columns='color_category', aggfunc='mean')
if not heatmap_data.empty:
    sns.heatmap(heatmap_data, annot=True, cmap='viridis', ax=ax6, fmt='.2f')
    ax6.set_title('Average Scores Heatmap\n(Stance vs Opinion Distribution)')

# 7. Difference analysis by stance
ax7 = plt.subplot(3, 3, 7)
df['score_diff'] = df[score1_col] - df[score2_col]
df.boxplot(column='score_diff', by=stance_col, ax=ax7)
ax7.set_title(f'Score Differences by Stance\n({model1_name} - {model2_name})')
ax7.set_ylabel('Score Difference')

# 8. Model performance by color
ax8 = plt.subplot(3, 3, 8)
# Create bins for color analysis
df['color_bin'] = pd.cut(df[color_col], bins=5, labels=['Very Red', 'Red', 'Yellow', 'Green', 'Very Green'])
color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()
color_perf.plot(kind='bar', ax=ax8, color=palette_colors)
ax8.set_title('Performance Across Opinion Spectrum')
ax8.set_ylabel('Average Score')
ax8.legend([model1_name, model2_name])
ax8.tick_params(axis='x', rotation=45)

# 9. Correlation analysis
ax9 = plt.subplot(3, 3, 9)
ax9.scatter(df[color_col], df[score1_col], alpha=0.6, label=model1_name, color='blue')
ax9.scatter(df[color_col], df[score2_col], alpha=0.6, label=model2_name, color='orange')
ax9.set_xlabel('Color (Opinion Distribution)')
ax9.set_ylabel('Score')
ax9.set_title('Scores vs Opinion Distribution')
ax9.legend()
ax9.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# === CREATING VISUALIZATIONS ===
# /tmp/ipykernel_1320514/1169726615.py:68: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()

# %%
# Detailed analysis
print("\n=== DETAILED ANALYSIS ===")

# Correlation between color and scores
corr_color_score1 = df[color_col].corr(df[score1_col])
corr_color_score2 = df[color_col].corr(df[score2_col])

print("CORRELATION ANALYSIS:")
print(f"Color vs {model1_name} scores: {corr_color_score1:.4f}")
print(f"Color vs {model2_name} scores: {corr_color_score2:.4f}")
print(f"{model1_name} vs {model2_name} scores: {df[score1_col].corr(df[score2_col]):.4f}")
print()

# Performance in different opinion environments
print("MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:")
for category, desc in [('denier_heavy', 'Denier-heavy topics (Red zone)'),
                       ('balanced', 'Polarized topics (Yellow zone)'),
                       ('believer_heavy', 'Believer-heavy topics (Green zone)')]:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        print(f"\n{desc}:")
        print(f"  Topics: {len(cat_data)}")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        # Test if there's a significant difference between models in this category
        if len(cat_data) > 1:
            t_stat_cat, p_val_cat = stats.ttest_rel(cat_data[score1_col], cat_data[score2_col])
            print(f"  Significant difference between models: {'Yes' if p_val_cat < 0.05 else 'No'} (p={p_val_cat:.4f})")

# Best and worst performing topics
print(f"\n=== BEST AND WORST PERFORMING TOPICS ===")

# Best Model 1 performance
best_m1 = df.loc[df[score1_col].idxmax()]
print(f"BEST {model1_name} performance (Score: {best_m1[score1_col]}):")
color_desc = "red" if best_m1[color_col] < 0.33 else "green" if best_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m1[stance_col]}', color={best_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m1[arg1_col]}', {model1_name} score={best_m1[score1_col]}")
print(f"  {arg2_col}='{best_m1[arg2_col]}', {model2_name} score={best_m1[score2_col]}")

# Worst Model 1 performance
worst_m1 = df.loc[df[score1_col].idxmin()]
print(f"\nWORST {model1_name} performance (Score: {worst_m1[score1_col]}):")
color_desc = "red" if worst_m1[color_col] < 0.33 else "green" if worst_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m1[stance_col]}', color={worst_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m1[arg1_col]}', {model1_name} score={worst_m1[score1_col]}")
print(f"  {arg2_col}='{worst_m1[arg2_col]}', {model2_name} score={worst_m1[score2_col]}")

# Best Model 2 performance
best_m2 = df.loc[df[score2_col].idxmax()]
print(f"\nBEST {model2_name} performance (Score: {best_m2[score2_col]}):")
color_desc = "red" if best_m2[color_col] < 0.33 else "green" if best_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m2[stance_col]}', color={best_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m2[arg1_col]}', {model1_name} score={best_m2[score1_col]}")
print(f"  {arg2_col}='{best_m2[arg2_col]}', {model2_name} score={best_m2[score2_col]}")

# Worst Model 2 performance
worst_m2 = df.loc[df[score2_col].idxmin()]
print(f"\nWORST {model2_name} performance (Score: {worst_m2[score2_col]}):")
color_desc = "red" if worst_m2[color_col] < 0.33 else "green" if worst_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m2[stance_col]}', color={worst_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m2[arg1_col]}', {model1_name} score={worst_m2[score1_col]}")
print(f"  {arg2_col}='{worst_m2[arg2_col]}', {model2_name} score={worst_m2[score2_col]}")

# Summary insights
print(f"\n=== KEY INSIGHTS ===")
print("STANCE-BASED INSIGHTS:")
stance_summary = df.groupby(stance_col)[[score1_col, score2_col]].mean()
best_stance_m1 = stance_summary[score1_col].idxmax()
best_stance_m2 = stance_summary[score2_col].idxmax()
print(f"  {model1_name} performs best on '{best_stance_m1}' topics")
print(f"  {model2_name} performs best on '{best_stance_m2}' topics")

print("\nOPINION DISTRIBUTION INSIGHTS:")
color_summary = df.groupby('color_category')[[score1_col, score2_col]].mean()
if not color_summary.empty:
    best_color_m1 = color_summary[score1_col].idxmax() if len(color_summary) > 0 else 'N/A'
    best_color_m2 = color_summary[score2_col].idxmax() if len(color_summary) > 0 else 'N/A'
    print(f"  {model1_name} performs best in '{best_color_m1}' opinion environments")
    print(f"  {model2_name} performs best in '{best_color_m2}' opinion environments")

# Overall winner
if df[score1_col].mean() > df[score2_col].mean():
    overall_better = model1_name
    diff = df[score1_col].mean() - df[score2_col].mean()
elif df[score2_col].mean() > df[score1_col].mean():
    overall_better = model2_name
    diff = df[score2_col].mean() - df[score1_col].mean()
else:
    overall_better = "Tie"
    diff = 0

print(f"\nOVERALL BETTER MODEL: {overall_better}")
if diff > 0:
    print(f"  Average advantage: {diff:.3f} points")
# Out:
# === DETAILED ANALYSIS ===
# CORRELATION ANALYSIS:
# Color vs Deepseek scores: 0.3793
# Color vs Llama scores: 0.3136
# Deepseek vs Llama scores: 0.3302
#
# MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:
#
# Denier-heavy topics (Red zone):
#   Topics: 110
#   Deepseek avg: 3.20
#   Llama avg: 2.54
#   Significant difference between models: Yes (p=0.0000)
#
# Polarized topics (Yellow zone):
#   Topics: 101
#   Deepseek avg: 3.72
#   Llama avg: 2.65
#   Significant difference between models: Yes (p=0.0000)
#
# Believer-heavy topics (Green zone):
#   Topics: 2760
#   Deepseek avg: 4.13
#   Llama avg: 3.67
#   Significant difference between models: Yes (p=0.0000)
#
# === BEST AND WORST PERFORMING TOPICS ===
# BEST Deepseek performance (Score: 5):
#   Topic: stance='favor', color=0.921(green)
#   arg1='It has been widely acknowledged that there exists a convergence between support for Trump and climate change denial, which converges at a point concerning big corporate interests and the interests of the super-rich. This alignment is exemplified by policies such as tax breaks for billionaires and deregulation of harmful industries, which are defended under the guise of climate change denial. These actions not only protect high pollution investments but also allow companies like Dow to continue making billions at the expense of destroying the earth and our health.', Deepseek score=5
#   arg2='It is widely acknowledged that the convergence of climate change denial and support for Trump's policies converges at a point where big corporate interests and the interests of the super rich are prioritized over environmental concerns. As a result, harmful industry deregulation and tax breaks for billionaires are seen as a threat to addressing climate change, with the protection of high pollution investments being a key factor in this convergence. It is urged that a more sustainable approach be taken to address the clear and present danger posed by Trump's administration.', Llama score=4
#
# WORST Deepseek performance (Score: 1):
#   Topic: stance='favor', color=0.836(green)
#   arg1='Could not extract valid JSON from the input 2', Deepseek score=1
#   arg2='It is widely acknowledged that the Green New Deal has been framed as an existential threat by some, while others seek to address it. The notion of climate change being effectively addressed through the Green New Deal has gained traction among various groups and individuals. As a result, the discussion around the Green New Deal has become increasingly prominent, with many advocating for its implementation to mitigate the effects of climate change.', Llama score=3
#
# BEST Llama performance (Score: 5):
#   Topic: stance='favor', color=1.000(green)
#   arg1='It is widely acknowledged that time is running out to stop catastrophic climate change, as leaders worldwide have failed in their responsibilities. However, people across the globe are taking action through community energy initiatives and school strikes, demonstrating a commitment beyond political boundaries. These actions demand urgent attention from governments globally, highlighting the need for immediate and decisive climate action.', Deepseek score=4
#   arg2='It is widely acknowledged that time is running out to stop catastrophic climate change, and the lack of urgency from leaders has been disappointing. However, people worldwide are taking action, from community energy initiatives to school strikes, which is seen as a positive sign. It is urged that governments take immediate action to address this pressing issue, as the voices of young people who can see beyond short-term concerns are being heard and heeded.', Llama score=5
#
# WORST Llama performance (Score: 1):
#   Topic: stance='favor', color=1.000(green)
#   arg1='It is widely acknowledged that human activity has significantly influenced global temperatures and weather patterns, leading to more frequent and severe natural disasters such as wildfires and hurricanes. The reduction of carbon-absorbing trees through deforestation exacerbates the problem by increasing CO2 levels in the atmosphere. As a result, governments are urged to invest in reforestation programs that can help mitigate climate change.', Deepseek score=4
#   arg2='Could not extract valid JSON from the input 2', Llama score=1
#
# === KEY INSIGHTS ===
# STANCE-BASED INSIGHTS:
#   Deepseek performs best on 'favor' topics
#   Llama performs best on 'favor' topics
#
# OPINION DISTRIBUTION INSIGHTS:
#   Deepseek performs best in 'believer_heavy' opinion environments
#   Llama performs best in 'believer_heavy' opinion environments
#
# OVERALL BETTER MODEL: Deepseek
#   Average advantage: 0.490 points

# %% [markdown]
# ## Violin Plot

# %%
# --- Visualization ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Violin plot
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# Boxplot
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# 3. Difference distribution (instead of hexbin)
diff = df[score2_col] - df[score1_col]
sns.histplot(diff, bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")


# Heatmap of agreement
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_{filename_output}.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Dashboard
#  1. Violin plot considering all the scores by stance.
#  2. Boxplot considering all the scores by stance.
#  3. Difference distribution.
#  4. Heatmap (agreement)
#  5. Violin plot model 1 by stance.
#  6. Violin plot model 2 by stance.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# --- Visualization ---
fig, axes = plt.subplots(3, 2, figsize=(14, 14))

# --- Row 1 ---
# 1. Violin plot (overall)
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# 2. Boxplot (overall)
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# --- Row 2 ---
# 3. Difference distribution
df["diff"] = df[score2_col] - df[score1_col]
sns.histplot(df["diff"], bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")

# 4. Heatmap (agreement)
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

# --- Row 3 ---
# 5. Violin by stance (palette)
sns.violinplot(
    x="stance", y=score1_col, data=df,
    ax=axes[2,0],
    palette= pallete_stance_model1, # green_palette_stance = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"},
    order=["favor","against","polarized"]
)
axes[2,0].set_title(f"{model1_name} Scores by Stance", color=color_title_model1) #color_title_green="#196f3d"
axes[2,0].set_ylabel("Score")
axes[2,0].set_xlabel("Stance")

# 6. Violin by stance (Deepseek, orange palette)
sns.violinplot(
    x="stance", y=score2_col, data=df,
    ax=axes[2,1],
    palette= pallete_stance_model2,# orange_palette_stance = {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"},
    order=["favor","against","polarized"]
)
axes[2,1].set_title(f"{model2_name} Scores by Stance", color=color_title_model2 ) # color_title_green = "#7e5109"
axes[2,1].set_ylabel("Score")
axes[2,1].set_xlabel("Stance")


plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_JudgeGemma_Args-{filename_output}.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1320514/2608110707.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_1320514/2608110707.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
