# %% [markdown]
# # Analysis of results
#
# Distribution of scores assigned by Model Gemma3 as Judge when comparing the performance of language model pairs: Deepseek vs Llama
#
# By: Gabriela Díaz

# %% [markdown]
# ## Extreme values analysis

# %%
# Import section
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
###################################
# Colors definition for models
###################################

color_GE_0shot = '#ffac37'
color_GE_1shot = '#ffc575'
# LL '#009e73','#0bd9a1'
color_LL_0shot = '#009e73'
color_LL_1shot = '#0bd9a1'
# DS '#0077bb','#60b8eb'
color_DS_0shot = '#0077bb'
color_DS_1shot = '#60b8eb'
palette_stance_blue =  {"favor": "#1F4BE6", "against": "#023BD3", "polarized": "#9FB2F5"} #blue
palette_stance_orange =  {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"} #orange
palette_stance_green = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"} #green

color_title_green="#196f3d"
color_title_orange = "#7e5109"
color_title_blue = "#0F4ABD"

# %%
# =============================================================================
# CONFIGURATION 
#  Change next variables to compare different models. 
# =============================================================================

# filename 
filename_scores = 'jgemma_ge_ds.csv' #this file contain scores for the two models that are compared. 
filename_output = '_ge_vs_ds_'

# Model names for labeling
model1_name = 'Gemma'
model2_name = 'Deepseek'

# Column mappings - change these to match your data structure
score1_col = 'score1'  # Column name for model 1 scores
score2_col = 'score2'  # Column name for model 2 scores
arg1_col = 'arg1'      # Column name for model 1 arguments
arg2_col = 'arg2'      # Column name for model 2 arguments

# Other column names
color_col = 'color'
stance_col = 'stance'

# Colors
palette_colors = [color_GE_1shot,color_DS_1shot]

# Colors for the last violin
pallete_stance_model1 = palette_stance_orange
pallete_stance_model2 = palette_stance_blue 
color_title_model1 = color_title_orange
color_title_model2 = color_title_blue

df = pd.read_csv(filename_scores)

# %%
print(f"=== {model1_name.upper()} vs {model2_name.upper()} COMPARISON BY STANCE AND MODEL ===\n")

# Display sample of the data
print("DATA OVERVIEW:")
print(f"Total topics analyzed: {len(df)}")
print(f"Stance distribution: {df[stance_col].value_counts().to_dict()}")
print(f"Color range: {df[color_col].min():.3f} to {df[color_col].max():.3f}")
print(f"Models being compared: {model1_name} vs {model2_name}")
print()

# Basic statistics by model
print("=== MODEL COMPARISON ===")
print("OVERALL MODEL PERFORMANCE:")
print(f"{model1_name} - Mean: {df[score1_col].mean():.2f}, Std: {df[score1_col].std():.2f}")
print(f"{model2_name} - Mean: {df[score2_col].mean():.2f}, Std: {df[score2_col].std():.2f}")

# Statistical test between models
t_stat, p_value = stats.ttest_rel(df[score1_col], df[score2_col])
print(f"\nPaired t-test between models:")
print(f"  T-statistic: {t_stat:.4f}")
print(f"  P-value: {p_value:.4f}")
print(f"  Significant difference: {'Yes' if p_value < 0.05 else 'No'}")

# Model wins
model1_wins = (df[score1_col] > df[score2_col]).sum()
model2_wins = (df[score2_col] > df[score1_col]).sum()
ties = (df[score1_col] == df[score2_col]).sum()

print(f"\nHead-to-head comparison:")
print(f"  {model1_name} wins: {model1_wins} topics")
print(f"  {model2_name} wins: {model2_wins} topics")
print(f"  Ties: {ties} topics")
print()

# Analysis by stance
print("=== ANALYSIS BY STANCE ===")
print("PERFORMANCE BY STANCE:")
for stance in df[stance_col].unique():
    stance_data = df[df[stance_col] == stance]
    print(f"\n{stance.upper()} topics ({len(stance_data)} topics):")
    print(f"  Average color value: {stance_data[color_col].mean():.3f}")
    print(f"  {model1_name} - Mean: {stance_data[score1_col].mean():.2f}, Std: {stance_data[score1_col].std():.2f}")
    print(f"  {model2_name} - Mean: {stance_data[score2_col].mean():.2f}, Std: {stance_data[score2_col].std():.2f}")
    
    # Model comparison within this stance
    m1_wins = (stance_data[score1_col] > stance_data[score2_col]).sum()
    m2_wins = (stance_data[score2_col] > stance_data[score1_col]).sum()
    ties = (stance_data[score1_col] == stance_data[score2_col]).sum()
    print(f"  Within {stance}: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()

# Color-based analysis (opinion distribution)
print("=== COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===")
def categorize_color(color_val):
    if color_val < 0.33:
        return 'denier_heavy'  # Red zone
    elif color_val > 0.67:
        return 'believer_heavy'  # Green zone
    else:
        return 'balanced'  # Yellow zone (polarized)

df['color_category'] = df[color_col].apply(categorize_color)

print("PERFORMANCE BY OPINION DISTRIBUTION:")
for category in ['denier_heavy', 'balanced', 'believer_heavy']:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        color_range = f"{cat_data[color_col].min():.3f}-{cat_data[color_col].max():.3f}"
        print(f"\n{category.upper().replace('_', ' ')} topics ({len(cat_data)} topics, color: {color_range}):")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        m1_wins = (cat_data[score1_col] > cat_data[score2_col]).sum()
        m2_wins = (cat_data[score2_col] > cat_data[score1_col]).sum()
        ties = (cat_data[score1_col] == cat_data[score2_col]).sum()
        print(f"  Model performance: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()
# Out:
# === GEMMA vs DEEPSEEK COMPARISON BY STANCE AND MODEL ===
#
# DATA OVERVIEW:
# Total topics analyzed: 2971
# Stance distribution: {'favor': 2787, 'against': 132, 'polarized': 52}
# Color range: 0.000 to 1.000
# Models being compared: Gemma vs Deepseek
#
# === MODEL COMPARISON ===
# OVERALL MODEL PERFORMANCE:
# Gemma - Mean: 4.09, Std: 0.41
# Deepseek - Mean: 3.70, Std: 0.92
#
# Paired t-test between models:
#   T-statistic: 22.5084
#   P-value: 0.0000
#   Significant difference: Yes
#
# Head-to-head comparison:
#   Gemma wins: 1605 topics
#   Deepseek wins: 689 topics
#   Ties: 677 topics
#
# === ANALYSIS BY STANCE ===
# PERFORMANCE BY STANCE:
#
# FAVOR topics (2787 topics):
#   Average color value: 0.964
#   Gemma - Mean: 4.11, Std: 0.38
#   Deepseek - Mean: 3.77, Std: 0.89
#   Within favor: Gemma wins 1444, Deepseek wins 676, Ties 667
#
# POLARIZED topics (52 topics):
#   Average color value: 0.518
#   Gemma - Mean: 3.69, Std: 0.78
#   Deepseek - Mean: 2.65, Std: 0.76
#   Within polarized: Gemma wins 43, Deepseek wins 6, Ties 3
#
# AGAINST topics (132 topics):
#   Average color value: 0.162
#   Gemma - Mean: 3.81, Std: 0.68
#   Deepseek - Mean: 2.66, Std: 0.73
#   Within against: Gemma wins 118, Deepseek wins 7, Ties 7
#
# === COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===
# PERFORMANCE BY OPINION DISTRIBUTION:
#
# DENIER HEAVY topics (110 topics, color: 0.000-0.328):
#   Gemma avg: 3.78
#   Deepseek avg: 2.65
#   Model performance: Gemma wins 98, Deepseek wins 6, Ties 6
#
# BALANCED topics (101 topics, color: 0.333-0.667):
#   Gemma avg: 3.84
#   Deepseek avg: 2.76
#   Model performance: Gemma wins 85, Deepseek wins 9, Ties 7
#
# BELIEVER HEAVY topics (2760 topics, color: 0.672-1.000):
#   Gemma avg: 4.11
#   Deepseek avg: 3.78
#   Model performance: Gemma wins 1422, Deepseek wins 674, Ties 664

# %%
# Find extreme cases
print("=== EXTREME CASES ANALYSIS ===")

# Lowest scores
min_score = min(df[score1_col].min(), df[score2_col].min())
print(f"LOWEST SCORE FOUND: {min_score}")

min_score1_rows = df[df[score1_col] == min_score]
min_score2_rows = df[df[score2_col] == min_score]

if not min_score1_rows.empty:
    print(f"\n{model1_name} lowest scores:")
    for idx, row in min_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not min_score2_rows.empty:
    print(f"\n{model2_name} lowest scores:")
    for idx, row in min_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")
# Out:
# === EXTREME CASES ANALYSIS ===
# LOWEST SCORE FOUND: 1
#
# Gemma lowest scores:
#   Topic 84: stance='favor', color=0.964(green)
#     arg1='It is observed that considerable concern exists regarding the understanding of climate change, with assertions of disbelief frequently presented. The implications of such assertions are recognized, and the impact of dismissing the issue is acknowledged. It is noted that a lack of comprehension regarding the complexities of the situation is frequently expressed, and the consequences of this lack of understanding are recognized. The need for a more informed approach to the issue is increasingly apparent.', Gemma score=1
#     arg2='It is widely acknowledged that the denial or skepticism towards climate change, often expressed in dismissive and derogatory terms by some individuals, reflects a level of ignorance regarding its existence and impacts. This stance implies a lack of understanding about the scientific consensus on global warming and its potential consequences for humanity and the environment.', Deepseek score=4
#   Topic 213: stance='against', color=0.000(red)
#     arg1='Numerous observations and data points have been presented, suggesting fluctuations in global temperatures over extended periods. Adjustments to historical records have been noted, and questions have been raised regarding the methodologies used in determining trends. Concerns have been expressed about the interpretation of data, with suggestions that the magnitude of observed changes may be subject to revision.  Data regarding ocean warming trends have been scrutinized, and the influence of various factors, including those related to governmental adjustments, have been considered.', Gemma score=1
#     arg2='Concerns regarding natural climate variability have been expressed by various contributors across diverse perspectives, suggesting that long-term climatic shifts may be influenced more significantly by geological and astronomical factors than anthropogenic activities.', Deepseek score=2
#   Topic 649: stance='favor', color=0.704(green)
#     arg1='It is observed that the earth is flat and global warming is considered a myth by certain individuals. Simultaneously, it is recognized that ‘Fern Gully’ remains relevant due to the effects of global warming. Furthermore, the mechanisms of how global warming happens are presented as science. Consequently, the issue of global warming is being debated, with scientific understanding seemingly challenged by alternative viewpoints.', Gemma score=1
#     arg2='It has been widely acknowledged that the earth's climate is undergoing significant changes, with a growing body of evidence suggesting that human activity plays a dominant role in driving these alterations. This perspective recognizes the extent to which human actions have influenced global temperatures and weather patterns, leading to debates about whether or not such changes are beneficial or detrimental to our planet. As a result, there has been an increasing call for action to address climate change, with many advocating for measures that reduce greenhouse gas emissions and promote sustainable practices.', Deepseek score=2
#   Topic 728: stance='favor', color=0.938(green)
#     arg1='It is observed that questions regarding rising temperatures are frequently met with dismissals, with claims of cyclical climate patterns being presented as a counterargument. Instances are noted where concerns about changes in ocean temperatures, specifically the death of sea stars, are immediately refuted with assertions that global warming is not a genuine phenomenon. The propagation of misinformation and the rapid dismissal of scientific observations regarding temperature shifts are consistently reported, suggesting a widespread denial of observable changes within the climate system. It is suggested that further investigation into the observed shifts is warranted, despite the prevalent resistance to acknowledging the impact of these changes.', Gemma score=1
#     arg2='It is commonly observed that individuals often react with skepticism to claims of global warming when faced with specific instances or anomalies in nature, such as the decline in sea stars' populations due to oceanic changes. This response highlights a broader tendency among people to question climate change narratives based on isolated events rather than considering them part of a larger pattern consistent with human-induced climate change.', Deepseek score=2
#   Topic 893: stance='polarized', color=0.564(yellow)
#     arg1='It is recognized that knife crimes have been exacerbated by the presence of police alongside climate change protesters, while the issue of climate change has been linked to the actions of people in this country; it is also noted that the capacity to address knife crime has been diminished by the actions of police alongside climate change protesters, and that the issue of climate change has been linked to the actions of people in this country.', Gemma score=1
#     arg2='There has been a noticeable shift in focus from addressing local issues such as knife crimes to engaging with broader environmental concerns like climate change; however, this trend is often met with criticism and skepticism regarding the allocation of resources towards one issue over another.', Deepseek score=2
#   Topic 1013: stance='polarized', color=0.457(yellow)
#     arg1='It has been suggested that climate change is naturally occurring as a result of the sun and Earth’s ever shifting tectonic plates, and that big glaciers, such as the one in Greenland, have been observed to grow at the same rate it was shrinking; it has also been suggested that scientists have determined climate change is naturally occurring.', Gemma score=1
#     arg2='Rising global temperatures have been linked to more frequent and severe wildfires, while deforestation has been recognized as reducing the capacity to absorb CO₂; however, current climate changes have also been attributed primarily to natural cycles and variations in solar activity rather than to human influence.', Deepseek score=2
#   Topic 1103: stance='against', color=0.031(red)
#     arg1='Significant uncertainties and comparisons have been raised regarding the extent of human influence on global climate patterns. Concerns have been expressed about the potential manipulation of scientific data and the use of economic models to discredit climate science.  Questions have been posed about the reliability of climate models and the degree to which they accurately represent natural climate variability.  Comparisons have been made between climate science and economic disciplines, suggesting a lack of consensus and highlighting potential biases within the field.  Uncertainties surrounding the magnitude of global warming, particularly in relation to established scientific data, have been repeatedly emphasized.', Gemma score=1
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1
#   Topic 1406: stance='favor', color=0.731(green)
#     arg1='It is observed that concerns regarding hypocrisy are frequently raised, alongside assertions of arrogance concerning climate change policy. The abolition of fuel price escalators and the subsequent implementation of climate change policies across nations are consistently noted. Furthermore, the impact of actions, or in some cases, inaction, are being scrutinized, with the consequences of these actions being attributed to a complex interplay of factors. It is understood that a significant degree of debate and disagreement surrounds the appropriate responses to the challenges posed by these developments, and that a range of perspectives are being considered.', Gemma score=1
#     arg2='It is widely acknowledged that there are instances of hypocrisy among climate change activists, as well as arrogance from those with limited understanding of the issue who disregard scientific evidence. However, these attitudes do not negate the broader impact of human activity on climate change and its consequences.', Deepseek score=2
#   Topic 1477: stance='against', color=0.000(red)
#     arg1='Doubt has been expressed regarding the extent of human influence on global temperature trends. Questions have been raised about the interpretation of historical data, including long-term fluctuations and variations in climate patterns. Concerns have been voiced about the reliance on specific assumptions within current climate models. The validity of certain datasets and the potential for alternative explanations have been suggested. The process of scientific inquiry has been questioned, with assertions that it is not conducted on social media. The influence of specific interpretations and the potential for alternative explanations have been highlighted.', Gemma score=1
#     arg2='Concerns regarding climate change have been expressed by various individuals and groups across diverse perspectives. While there is a widespread acknowledgment that human activities contribute to altering atmospheric conditions, alternative viewpoints suggest that natural factors may play a significant role in influencing global temperatures over extended periods of time. These arguments often point towards long-term climatic cycles such as solar variability and ocean currents, which could potentially explain climate variations independently from anthropogenic influences.', Deepseek score=2
#   Topic 1843: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant changes are being observed globally, and a considerable degree of concern is being expressed regarding these shifts. The impacts of these changes are being widely acknowledged, and the need to understand and address them is being actively promoted. Calls for action are being made, with attention being drawn to the potential for solutions and the importance of widespread awareness. The possibility of impacts is being highlighted, and the demand for action is being consistently voiced, with a focus on the need for understanding and engagement.', Gemma score=1
#     arg2='It is widely acknowledged that the climate movement has been significantly affected by human activity, with individuals across various platforms expressing their concerns about environmental issues and advocating for change. This acknowledgment highlights how widespread awareness of climate change influences public discourse and actions towards addressing ecological challenges.', Deepseek score=2
#   Topic 1949: stance='favor', color=1.000(green)
#     arg1='It is repeatedly asserted that a catastrophic climate change event is imminent, with dire consequences being predicted. The urgency of the situation is underscored by countdowns indicating a limited number of days remaining before this event unfolds. Calls for immediate action are being made, suggesting a need to disregard conventional economic constraints and to prioritize immediate intervention, despite potential economic disruption. The consequences of inaction are repeatedly highlighted as leading to a global catastrophe.', Gemma score=1
#     arg2='It is widely acknowledged that there are only a few years left before an apocalyptic climate change event kills us all, with economic markets crashing and carbon-absorbing trees being significantly reduced due to deforestation. As a result, the restoration of carbon-absorbing forests through reforestation programs is seen as necessary by many individuals who urge governments to invest in such initiatives.', Deepseek score=2
#   Topic 2540: stance='against', color=0.000(red)
#     arg1='Persistent criticisms regarding the attribution of climate change have been voiced, with recurring assertions questioning the focus on human influence. Recurring claims of bias and distortion have been made regarding the presentation of climate science, suggesting a deliberate framing of the issue. Repeated accusations of manipulation and distortion have been leveled against sources promoting climate narratives, and persistent claims of bias have been made regarding the presentation of climate science.  Recurring assertions have been made regarding the focus on human influence, and persistent claims of bias have been made regarding the presentation of climate science.', Gemma score=1
#     arg2='Long-term natural cycles of climate variability have been observed and documented across various regions over thousands of years, suggesting that human activity may not be the sole determinant of recent climatic changes.', Deepseek score=2
#   Topic 2834: stance='polarized', color=0.455(yellow)
#     arg1='It has been suggested that the vast majority of climate change has been caused by the varying output of energy from a big ball of nuclear fission 93 million miles away, while others have been lied to by the climate change lobby; it has been suggested that the vast majority of climate change has been caused by the varying output of nuclear fission energy 93 million miles away; it has been suggested that the vast majority of climate change has been caused by the varying output of energy from a big ball of nuclear fission 93 million miles away; it has been suggested that the vast majority of climate change has been caused by the varying output of energy from a big ball of nuclear fission 93 million miles away; it has been suggested that the vast majority of climate change has been caused by the varying output of energy from a big ball of nuclear fission 93 million miles away; it has been suggested that the vast majority of climate change has been caused by the varying output of energy from a big ball of nuclear fission 93 million miles away.', Gemma score=1
#     arg2='The varying output of energy from a big ball of nuclear fission ninety-three million miles away has been suggested as the primary driver of current climate change by some individuals; however, others contend that variations in solar activity and infrared radiation are responsible for changes in global temperatures. These differing perspectives highlight ongoing debates regarding the dominant factors influencing climatic conditions.', Deepseek score=2
#   Topic 2852: stance='against', color=0.364(yellow)
#     arg1='Persistent shifts in global climate patterns have been observed throughout history, independent of human actions. Recurring fluctuations in Earth’s climate have been suggested by historical data from tree rings and sediment layers. Attempts to impose additional financial burdens on citizens have been proposed as a solution, but these efforts have been indicated as ineffective in altering established climate cycles. The notion that increased taxation will result in a ‘cleaner’ environment has been questioned, and the impact of climate change has been suggested to be a naturally occurring phenomenon.', Gemma score=1
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=2
#
# Deepseek lowest scores:
#   Topic 244: stance='against', color=0.008(red)
#     arg1='Significant shifts in global temperatures have been observed, and adjustments to climate patterns have been suggested.  Changes in global temperatures have been noted, and self-correcting mechanisms have been indicated.  Alterations to global climate have been suggested, and adjustments to global climate have been indicated.', Gemma score=3
#     arg2='The complexities of climate change have been repeatedly demonstrated through various natural cycles, such as solar radiation variations and oceanic currents, which can influence global temperature patterns independently of human activity. These long-term climatic shifts are supported by historical evidence from ice core samples, sediment layers, and tree rings that show fluctuations in Earth's climate predating significant industrialization.', Deepseek score=1
#   Topic 531: stance='against', color=0.254(red)
#     arg1='Attempts to discredit dissenting voices on climate change have been observed, with individuals expressing concerns about being excluded from public discourse. The questioning of established narratives regarding global warming has been met with resistance, and the reputations of certain figures have been targeted. The possibility of undue pressure influencing scientific debate has been raised, and the voices of those who challenge prevailing views have been silenced. ', Gemma score=2
#     arg2='Long-standing debates regarding climatic changes have persisted for centuries, with historical records indicating natural influences as significant drivers of temperature variations over time. The influence of solar radiation and ocean currents has been noted in various studies to play a substantial role in shaping Earth's climate patterns, often overshadowing the impact of human activities.', Deepseek score=1
#   Topic 1103: stance='against', color=0.031(red)
#     arg1='Significant uncertainties and comparisons have been raised regarding the extent of human influence on global climate patterns. Concerns have been expressed about the potential manipulation of scientific data and the use of economic models to discredit climate science.  Questions have been posed about the reliability of climate models and the degree to which they accurately represent natural climate variability.  Comparisons have been made between climate science and economic disciplines, suggesting a lack of consensus and highlighting potential biases within the field.  Uncertainties surrounding the magnitude of global warming, particularly in relation to established scientific data, have been repeatedly emphasized.', Gemma score=1
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=1
#   Topic 2654: stance='favor', color=0.917(green)
#     arg1='It is recognized that efforts to combat climate change, particularly through educating girls, are being pursued. Simultaneously, concerns are being raised regarding population growth and its potential impact on the planet. Attempts to restrict reproductive choices are perceived as a response to this perceived threat, and the planet’s capacity to sustain current populations is increasingly questioned. The issue of reducing clothing choices for girls is presented as a superficial attempt to address a deeper concern about the Earth’s ability to support its inhabitants and their descendants. It is urged that a comprehensive approach to mitigating the effects of climate change be considered, acknowledging the strain placed on the planet by its current population.', Gemma score=4
#     arg2='It has been widely acknowledged that educating girls is seen as an essential strategy in the global effort to combat climate change, while some extreme opinions suggest otherwise. The restoration of carbon-absorbing trees through reforestation programs and investments by governments are also recognized as necessary solutions to mitigate the ongoing effects of climate change.', Deepseek score=1
#   Topic 2844: stance='favor', color=1.000(green)
#     arg1='It is observed that increased instances of heatwaves, droughts, and other natural disasters are being linked to the expected rise in global warming, with a growing risk of armed conflict being presented. Despite assertions to the contrary, the potential for escalating natural disasters is being recognized as a significant concern. It is noted that the possibility of conflict is being considered due to these escalating events.', Gemma score=4
#     arg2='It is widely acknowledged that the increasing frequency and severity of natural disasters such as heatwaves and droughts, which are expected to rise due to global warming, contribute significantly to pushing countries into armed conflict. As a result, climate change has become an influential factor in exacerbating geopolitical tensions and conflicts globally.', Deepseek score=1

# %%
# Highest scores
max_score = max(df[score1_col].max(), df[score2_col].max())
print(f"\nHIGHEST SCORE FOUND: {max_score}")

max_score1_rows = df[df[score1_col] == max_score]
max_score2_rows = df[df[score2_col] == max_score]

if not max_score1_rows.empty:
    print(f"\n{model1_name} highest scores:")
    for idx, row in max_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not max_score2_rows.empty:
    print(f"\n{model2_name} highest scores:")
    for idx, row in max_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

print()
# Out:
# HIGHEST SCORE FOUND: 5
#
# Gemma highest scores:
#   Topic 8: stance='favor', color=0.956(green)
#     arg1='It is increasingly recognized that significant reductions in meat and dairy consumption are being advocated, driven by concerns regarding mass extinctions, climate change catastrophes, and widespread animal abuse. The impact of animal agriculture on climate change is being highlighted, and a shift towards plant-based diets is being viewed as a crucial step in safeguarding the survival of future generations and the planet itself.  Recommendations for reducing meat and dairy consumption and adopting plant-based meals are being actively promoted as a means of mitigating these serious global challenges.', Gemma score=5
#     arg2='It has been widely acknowledged that the widespread adoption of plant-based diets, primarily driven by concerns over mass extinction, climate catastrophes, and animal abuse, is contributing to healthier lifestyles for humans while inadvertently improving livestock welfare. Opponents who challenge these dietary changes are seen as fighting against their own survival needs, those of their children, and the very survival of the planet itself. The necessity for a collective shift towards plant-based diets in order to mitigate climate change impacts has become increasingly clear.', Deepseek score=4
#   Topic 9: stance='favor', color=0.927(green)
#     arg1='It is observed that a significant increase in global temperatures is being linked to more frequent and severe wildfires, alongside a reduction in the number of trees that absorb CO2 due to widespread deforestation.  Attention is being drawn to the impact of these changes, with considerable concern expressed regarding the potential for irreversible damage to the planet.  Action is being sought, with numerous individuals and organizations advocating for collaborative efforts to address the escalating challenges and to safeguard the environment before critical thresholds are passed. It is recognized that a collective response is urgently needed to mitigate the observed trends and protect the planet’s ecosystems.', Gemma score=5
#     arg2='It is widely acknowledged that documentaries such as 'Our Planet' and 'Climate Change: The Facts', presented by Sir David Attenborough, have had a significant impact on raising awareness about the urgency of climate change. These programs highlight the need for collective action to save our planet before it is too late. As deforestation continues at an alarming rate, with fewer trees absorbing CO2, and wildfires becoming more frequent and severe due to rising global temperatures, there is a growing consensus that human activity plays a dominant role in driving climate change.', Deepseek score=4
#   Topic 15: stance='favor', color=0.635(yellow)
#     arg1='It is observed that atmospheric CO2 levels are now exceeding 400ppm for the first time in over 800,000 years, a change that historically took tens of thousands of years to materialize. Simultaneously, a surge in greenhouse gases has been created by more than 7 billion individuals, resulting in unprecedented levels of CO2 in the atmosphere. The impact of this change, occurring within a relatively short timeframe, is being recognized globally, demanding immediate attention and action.', Gemma score=5
#     arg2='It is widely acknowledged that atmospheric CO2 levels have reached unprecedented highs, with concentrations now exceeding 400 parts per million (ppm) for the first time in over 800,000 years. This significant change has occurred at a rate never before seen in human history, and it underscores the profound impact of human activity on climate conditions.', Deepseek score=5
#   Topic 19: stance='favor', color=0.715(green)
#     arg1='It is observed that a significant number of climate change deniers and downplayers within the UK are also associated with the Brexit project. Concerns are repeatedly raised that any form of Brexit, particularly when promoted by right-leaning factions, fails to address critical issues such as worker’s rights, the end of austerity measures, and action on climate change. The devastating potential impacts of climate change on the planet and all life forms are frequently juxtaposed against the Brexit trading bloc issue. It is repeatedly asserted that the consequences of Brexit, particularly under a Conservative government, are considered permanent for those suffering from its effects, and a fundamental shift in policy is urgently needed to mitigate the ongoing damage.', Gemma score=5
#     arg2='It has been observed that there exists a correlation between UK climate change deniers and pro-Brexit sentiments, suggesting that political affiliations may influence perspectives on environmental issues. This observation highlights the potential impact of political ideologies on public engagement with climate change discourse. It is widely acknowledged that addressing climate change requires collective action, yet it remains to be seen how these divergent views will shape future policies and actions related to environmental conservation.', Deepseek score=3
#   Topic 21: stance='favor', color=0.988(green)
#     arg1='It is recognized that local communities are central to protecting ecosystems against the impacts of climate change. It is noted that mayors are being tasked with addressing soil erosion, developing social policies that reduce environmental stress, and constructing coastal defenses. It is urged that action be taken by mayors to mitigate the effects of climate change and safeguard vulnerable communities.', Gemma score=5
#     arg2='It is widely recognized that in addressing the impacts of #climatechange, local communities play a significant role. Mayors are taking proactive steps to protect ecosystems by tackling soil erosion, implementing environmental policies, and fortifying coastal defenses. These actions reflect their commitment to mitigating the effects of climate change on vulnerable populations.', Deepseek score=4
#   Topic 22: stance='favor', color=0.975(green)
#     arg1='It is recognized that a significant portion of the world’s freshwater resources are being consumed, with agriculture accounting for a disproportionate share, particularly in regions like California experiencing severe droughts.  The unpredictable nature of water supplies due to climate change, coupled with population growth and increasing consumption, is being highlighted as a critical challenge.  Consequently, responsible water management practices, including adjustments to irrigation strategies, are being advocated for, and insights from global conferences focused on water resources are considered vital in addressing this escalating issue.', Gemma score=5
#     arg2='It is widely recognized that agriculture, which accounts for a significant portion of freshwater usage in regions such as the United States, faces challenges due to climate change and increasing demand. As water resources become less predictable under changing climatic conditions, there is an urgent need for responsible management practices within the agricultural sector. This includes adapting irrigation techniques to mitigate the impacts of reduced water availability on food production and sustainability efforts.', Deepseek score=4
#   Topic 23: stance='favor', color=0.971(green)
#     arg1='It is recognized that regardless of the method of acquisition, the burning of fossil fuels – whether through traditional or emerging techniques – results in the production of carbon dioxide and other greenhouse gases, leading to global warming. The reduction of fossil fuel extraction, particularly the closure of the dirtiest projects, is being advocated for, alongside the reskilling of workers for green technologies, as a necessary response to the ongoing effects of climate change.', Gemma score=5
#     arg2='It is widely acknowledged that the production of carbon dioxide and other greenhouse gases through the burning of fossil fuels such as oil, coal, and gas contributes significantly to global warming. This acknowledgment extends from traditional methods like fracking to newer extraction techniques, all leading to similar outcomes. The closure of environmentally detrimental projects, including those involving oilsands mines, is seen as a necessary response to climate change. It is urged that efforts be made to reskill workers for green technology or other sustainable work in order to mitigate the impacts of fossil fuel combustion on global temperatures.', Deepseek score=4
#   Topic 24: stance='favor', color=0.912(green)
#     arg1='It is recognized that advancements in nuclear energy are being sought as a critical solution to complex global challenges, including climate change and energy security. The potential of Gen 4 nuclear reactors, already utilized in naval submarines, is being actively explored. Innovation in reactor design is seen as essential to address existing concerns regarding safety and scalability, with carbon-free, 24-hour energy availability being a key benefit. Support for the Nuclear Energy Leadership Act of 2019 is being urged to facilitate the development and deployment of these technologies.', Gemma score=5
#     arg2='It is widely acknowledged that nuclear energy is considered ideal for addressing climate change due to its carbon-free nature and availability around the clock. The Nuclear Energy Leadership Act of 2019, which supports advanced nuclear technology, has been proposed as a means to enhance energy security and national security while combating climate change. This act highlights the potential of Gen 4 nuclear reactors, already in use for powering naval submarines, suggesting that their integration into broader strategies against climate change is gaining traction among those serious about addressing this global issue.', Deepseek score=4
#   Topic 26: stance='favor', color=0.958(green)
#     arg1='It is recognized that climate change is disproportionately impacting women across the globe, with displacement driven by climate-related disasters predominantly affecting them. The need for multi-dimensional data, encompassing interactions between genders and the environment, alongside age, diversity, income, and location, is increasingly emphasized. Accelerating gender equality through women as agents of change within Nationally Determined Contributions is being actively pursued, highlighting the urgency of integrating gender considerations into climate action strategies.', Gemma score=5
#     arg2='It is widely acknowledged that climate change disproportionately affects women, with a significant number of displaced persons being women and the UNDP highlighting their involvement in climate action as agents of change. The need for multi-dimensional data to understand how gender interacts with environmental factors has been emphasized, urging holistic decision-making processes that take into account age, diversity, income, and location.', Deepseek score=4
#   Topic 48: stance='against', color=0.387(yellow)
#     arg1='Significant climatic shifts have occurred throughout Earth’s history, spanning millions of years, with periods of warming and cooling occurring independently of contemporary human activity.  The Medieval Warm Period was largely confined to the North Atlantic, while the Little Ice Age was characterized by more widespread cooling driven by increased volcanic activity.  Long-term climatic fluctuations, including glacial periods lasting tens to hundreds of millions of years, have been observed.  The timing and duration of these cycles are determined by natural processes, and the current warming trend is being influenced by a relatively short-term shift in greenhouse gas concentrations, not by the fundamental, long-established patterns of Earth’s climate system.', Gemma score=5
#     arg2='The mechanisms behind climate change over vast periods of geological time have been predominantly driven by natural processes such as glaciation and deglaciation, volcanic activity, and solar radiation variations. These factors have shaped Earth's climatic patterns long before human influence was significant or measurable.', Deepseek score=3
#   Topic 54: stance='favor', color=0.993(green)
#     arg1='It is recognized that significant concern is being expressed regarding the health impacts of climate change, with a focus on empowering medical professionals to respond effectively. A new toolkit is being developed and disseminated by @CAPE_Doctors, alongside support from organizations like @WoncaWorld and @GCHAlliance, to address these concerns. The development of this toolkit is being actively promoted by various stakeholders, including @Pembina, to equip healthcare providers with the necessary resources to address the challenges posed by climate change.', Gemma score=5
#     arg2='It has been recognized that empowering healthcare professionals with the necessary tools and resources is crucial in addressing the health-related implications of climate change. A recent initiative by CAPE, a group dedicated to promoting environmental sustainability within the medical community, has resulted in the creation of an innovative toolkit designed to aid healthcare providers in their efforts to combat the detrimental effects of climate change on public health. This resource empowers professionals with actionable steps and information that can be utilized at both individual and institutional levels to mitigate the impact of a warming planet on human well-being.', Deepseek score=5
#   Topic 58: stance='favor', color=0.966(green)
#     arg1='It is recognized that surface transportation is being identified as a significant source of greenhouse gas emissions, and therefore a substantial contributor to global #climatechange. The disruption of public transport is being explored as a potential solution, alongside the development of technologies like Vertical Take-Off and Landing systems. It is understood that a challenge exists in meeting growing demand for convenient mobility while simultaneously reducing congestion, improving safety, and mitigating the effects of #climatechange. Investments in innovative transportation solutions are being considered to address this complex global issue.', Gemma score=5
#     arg2='It is widely recognized that surface transportation, particularly through traffic congestion in city streets, contributes significantly to greenhouse gas emissions and thus to global climate change. The reduction of such congestion has been proposed as a key strategy for combating these environmental impacts. Advocates suggest that improving urban mobility can play a crucial role in mitigating the effects of climate change by reducing vehicular emissions. As public transportation is disrupted less frequently, it is seen as an essential component in addressing this challenge. Efforts to enhance convenience and safety while minimizing congestion are being explored, including the potential use of Vertical Take-Off and Landing (VTOL) vehicles. These initiatives aim to balance growing demands for mobility with environmental sustainability goals.', Deepseek score=4
#   Topic 61: stance='favor', color=0.983(green)
#     arg1='It is increasingly observed that extreme weather events, such as Cyclone Idai and Cyclone Kenneth, are occurring with heightened intensity and frequency. The devastating impacts of these storms, including widespread flooding and loss of life, are being linked to alterations in weather patterns, with climate experts believing that these events are being intensified by climate change. Humanitarian efforts are being hampered by the increased severity of these storms, and the need for proactive measures to address the growing threat of extreme weather is being recognized globally.', Gemma score=5
#     arg2='It is widely acknowledged that the intensification of cyclone activity, as evidenced by consecutive severe storms such as Cyclone Idai and Cyclone Kenneth striking Mozambique within a short period, highlights how climate change is altering weather patterns. The increasing frequency and severity of these natural disasters are being recognized globally as direct consequences of rising global temperatures and changing climatic conditions. As a result, the need for urgent action to address the impacts of climate change on extreme weather events has become increasingly evident.', Deepseek score=4
#   Topic 70: stance='favor', color=0.982(green)
#     arg1='Significant pressures are being placed upon African and Asian elephants, alongside numerous smaller species, due to habitat loss, the ivory trade, and the impacts of climate change. The precarious future of these animals is being recognized, and their vital roles as ‘nature’s gardeners’ – contributing to forest growth and mitigating climate change – are increasingly valued. Conservation efforts are being directed towards maintaining their natural ranges, and a heightened focus on protection measures is being advocated to safeguard their survival.', Gemma score=5
#     arg2='It is widely recognized that giraffes in Africa face a precarious future due to their dwindling numbers, with fewer than 70,000 fully grown individuals remaining. This situation underscores the urgent need for increased protection measures as these animals are integral to maintaining biodiversity and ecosystem health. Elephants, known as 'nature's gardeners,' play a crucial role in forest growth and habitat creation, which is essential for mitigating climate change. Their conservation efforts must be supported within their natural habitats rather than relying solely on zoos. The plight of giraffes and elephants highlights the interconnectedness of wildlife with broader environmental challenges such as habitat loss, ivory trade, and climate change.', Deepseek score=4
#   Topic 73: stance='favor', color=0.968(green)
#     arg1='It is recognized that significant risks are being posed to climate and communities by projects like the Adani mine. The potential for massive carbon emissions is being actively considered, and a shift towards renewable energy sources is increasingly seen as a necessary response. The implications of continued fossil fuel expansion are being evaluated, and a transition to cleaner energy solutions is being advocated to mitigate the escalating impacts on the planet and its communities. It is urged that investments be made to support a just transition and reduce the risk of further environmental damage.', Gemma score=5
#     arg2='It has been widely acknowledged that avoiding catastrophic climate change requires the cessation of coal extraction, particularly in projects like the Adani mine which could potentially release massive amounts of carbon into the atmosphere. The transition to renewable energy sources is seen as essential for reducing greenhouse gas emissions and mitigating the impacts of global warming on communities worldwide. Consequently, efforts to prevent new coal mines from being developed are crucial, with a focus on sustainable alternatives that support both climate goals and economic justice.', Deepseek score=4
#   Topic 105: stance='favor', color=0.996(green)
#     arg1='It is recognized that indigenous peoples hold specialized knowledge regarding the conservation and sustainable management of natural resources. Their locally rooted and varied understanding of biodiversity, ecosystems, and climate change is being increasingly valued. It is asserted that indigenous peoples are being recognized as crucial partners in policy and knowledge production, with UNESCO supporting the integration of indigenous and local knowledge into IPBES assessments to address the consequences of climate change.', Gemma score=5
#     arg2='Could not extract valid JSON from the input 2', Deepseek score=2
#   Topic 106: stance='favor', color=0.954(green)
#     arg1='It is recognized that the current refugee system is primarily focused on individuals displaced by political conflict and war. Simultaneously, it is noted that a significant number of people are being forced to flee due to severe economic crises and, critically, the impacts of climate change. The exclusion of climate-displaced individuals from existing protections is highlighted, and the limitations of adaptation in the face of racism, wars, bigotry, and climate change are repeatedly emphasized. It is understood that a broader, more inclusive approach to protection is needed to address the growing global displacement crisis.', Gemma score=5
#     arg2='It has been widely recognized that the current refugee system does not adequately cover individuals displaced by economic crises or severe climate-related events. This includes those who are forced to leave their homes due to extreme weather conditions or other environmental disasters, which have become increasingly common in recent years. The inadequacy of existing frameworks to address these issues highlights a need for broader support and protection mechanisms that encompass all forms of displacement caused by non-political conflicts and natural disasters.', Deepseek score=4
#   Topic 123: stance='favor', color=0.987(green)
#     arg1='It is recognized that significant changes are being observed in pelagic fisheries within the North East Atlantic, alongside declining wild fish populations globally due to a confluence of factors. Concerns are being raised regarding the impacts of climate change and overfishing. The development of a ClimeFish standard is being pursued to assist the seafood production sector in formulating effective climate adaptation plans, and investments are being sought to address the challenges posed by a changing environment and the pressures exerted by overfishing.', Gemma score=5
#     arg2='It has been observed that in an era marked by the decline of wild fish populations globally, due to overfishing, climate change, and other environmental pressures, there is a growing concern within the seafood production sector regarding the impacts of climate change. The adaptation strategies for pelagic fisheries in the North East Atlantic are being explored through ClimeFish Workshops, which aim to address these challenges by developing innovative solutions that can help aquaculture adapt to changing climatic conditions.', Deepseek score=4
#   Topic 125: stance='favor', color=1.000(green)
#     arg1='It is recognized that a significant number of trees are being planted globally as a response to the ongoing climate crisis. It is noted that a trillion trees are being considered as a potential solution, and the planting of trees is being actively pursued by various organizations and individuals. The reduction of carbon dioxide levels is being seen as a key element in addressing the climate crisis, and the restoration of forests is being recognized as a vital strategy. It is urged that further efforts be made to increase tree planting initiatives to mitigate the effects of the climate crisis.', Gemma score=5
#     arg2='It is widely recognized that planting one trillion trees represents a significant and effective approach to tackling climate change. This method has been advocated by various sources, including CNN, Greenpeace, Rnfrst Alliance, NABU, and Rainforest Connection, highlighting its potential benefits in combating the adverse effects of global warming.', Deepseek score=4
#   Topic 137: stance='favor', color=0.904(green)
#     arg1='It is observed that walruses are increasingly observed jumping off cliffs to their deaths, a phenomenon linked to the disappearance of sea ice due to global warming. The animals’ traditional resting places are being replaced by overcrowded land areas, forcing them onto unstable cliffs. Consequently, the loss of sea ice, driven by global warming, is being recognized as a significant factor contributing to this tragic situation, and the need for action is being increasingly emphasized.', Gemma score=5
#     arg2='It is widely acknowledged that climate change has led to the disappearance of sea ice, forcing walruses onto land and cliffs. This displacement has resulted in desperate attempts by these animals to reach their accustomed resting areas on or near water, leading to tragic outcomes as they fall from high places.', Deepseek score=4
#   Topic 139: stance='favor', color=0.970(green)
#     arg1='It is recognized that a climate emergency is being declared by the UK Parliament, reflecting widespread concern regarding the escalating impacts of climate change.  Attention is being drawn to the fact that significant stories relating to the emergency are being obscured by the prioritization of cabinet minister narratives on the BBC News website.  Coordinated cross-governmental action is being advocated for, and a call is being made for urgent action by the UK government, with the need for immediate responses being highlighted before a crucial vote.', Gemma score=5
#     arg2='It has been widely recognized that climate change poses a significant threat to global ecosystems and human societies, with governments across nations being urged to take urgent action. The declaration of a climate emergency by the UK Parliament is indicative of this growing sense of urgency in addressing the issue. However, it is important for such declarations to be accompanied by coordinated actions at all levels of governance to effectively combat the effects of climate change.', Deepseek score=4
#   Topic 144: stance='favor', color=0.919(green)
#     arg1='It is recognized that significant methane emissions are being generated by the digestion of livestock, particularly cows, sheep, and goats, alongside emissions from animal manure and rice paddies. These emissions are being identified as contributing substantially to the increase in greenhouse gases. Research into altering livestock diets is being undertaken to reduce these emissions, and the potential for significant reductions is being acknowledged as a key element in addressing the ongoing impacts of climate change.', Gemma score=5
#     arg2='It is widely recognized that the burping and manure of cattle, along with other livestock such as sheep and goats, contribute significantly to greenhouse gas emissions, including methane—a potent contributor to climate change. These animals' digestive processes release significant amounts of methane into the atmosphere, which has been described by some sources as coming from both ends of these creatures. Efforts have been made to reduce methane emissions through changes in diet and management practices. The role of animal agriculture in global warming is acknowledged, with a focus on finding ways to mitigate its impact.', Deepseek score=4
#   Topic 159: stance='favor', color=0.918(green)
#     arg1='It is increasingly evident that significant corporations, including Exxon Mobil and affiliated foundations, have possessed knowledge regarding the potential impacts of greenhouse gas emissions for decades.  Investigations have revealed that this information was deliberately concealed from the public.  The consequences of this delayed response are now being observed through escalating environmental events.  The responsibility for addressing the growing concerns surrounding climate change is being increasingly attributed to those who possessed this knowledge and failed to act decisively.  Further scrutiny and accountability are being demanded to understand the full extent of the situation and to ensure that such omissions are never repeated.', Gemma score=5
#     arg2='It is widely acknowledged that major oil and gas companies, such as Exxon Mobil, have been aware of the impacts of climate change for several decades. These corporations' internal documents reveal their understanding of the scientific evidence linking fossil fuel emissions to global warming. As a result, there has been significant concern about the role these companies may have played in misleading the public and delaying action on climate change mitigation efforts.', Deepseek score=5
#   Topic 166: stance='favor', color=0.966(green)
#     arg1='It is increasingly recognized that the lengthening and intensifying of global droughts have been observed since 1900.  The influence of human activity on these droughts is being attributed to a century-long trend, with the severity of these events consistently linked to climate change.  The shift in language surrounding these events – from simply ‘drought’ to ‘drought, likely driven by climate change’ – reflects a growing understanding of the role human activity plays in exacerbating these conditions, and the need for further investigation and mitigation.', Gemma score=5
#     arg2='It has been recognized for over a century that human influence has contributed to the increased risks of drought globally, with recent studies highlighting the enduring impact of anthropogenic activities on climatic conditions and their consequences.', Deepseek score=4
#   Topic 183: stance='favor', color=0.945(green)
#     arg1='It is observed that a sixth mass extinction event is underway, characterized by rising global temperatures, the decline of coral reefs, widespread deforestation, persistent poaching, escalating pollution, and the overpopulation of humanity. Significant reductions in biodiversity are being witnessed across the planet. The consequences of these actions are being recognized, and efforts to mitigate the ongoing damage are being considered, though action remains insufficient. The potential for further biodiversity loss is being acknowledged, and the urgency of the situation is increasingly apparent.', Gemma score=5
#     arg2='It is widely acknowledged that planet Earth is currently experiencing its sixth mass extinction event due to human activities such as global warming, deforestation, and pollution. As a result of these actions, numerous species are at risk of disappearing from the face of the earth. The consequences of this ongoing environmental crisis have been recognized by many individuals who urge others to take action in order to prevent further damage to ecosystems and biodiversity.', Deepseek score=4
#   Topic 193: stance='favor', color=0.950(green)
#     arg1='It is recognized that significant changes in the climate are being observed globally, with wildlife struggling to adapt to irregularities and facing perishing due to these shifts. Exposure to the role humans play in these changes is being urged, and it is believed that a shift in lifestyle must occur following the viewing of documentaries like #OurPlanet. The urgency of the situation, as highlighted by figures like @GretaThunberg, is being emphasized, and action is being called for to address the rapidly diminishing time available to mitigate the effects of climate change.', Gemma score=5
#     arg2='It is widely acknowledged that the documentary '#OurPlanet' on Netflix, while highlighting the struggles of wildlife due to irregular climate patterns and perishing in the process, serves as an eye-opener for viewers regarding human impact on climate change. The series underscores the urgency of changing lifestyles and actions to combat the ongoing environmental crisis.', Deepseek score=4
#   Topic 194: stance='favor', color=0.975(green)
#     arg1='It is observed that biodiversity is being lost at up to 1,000 times the natural rate, and ecosystems are being degraded. This trend is being linked to climate change, with increased vulnerability being noted for both humans and nature’s communities. Attention to climate change has, it is suggested, been diverted from the critical issue of biodiversity loss. The Aichi Biodiversity Targets of 2011 are being examined, with only two years remaining to achieve them, highlighting the urgency of addressing the interconnected challenges of biodiversity loss and climate change.', Gemma score=5
#     arg2='It is widely acknowledged that biodiversity loss, at up to 1,000 times the natural rate, increases vulnerability across human and ecological communities to climate change. This connection between environmental degradation and increased susceptibility to climatic shifts has led to a focus on preserving ecosystems as essential for mitigating the impacts of global warming. The ongoing debate over whether climate change coverage diverts attention from biodiversity highlights the need for balanced reporting that addresses both critical environmental issues, urging greater collaboration in conservation efforts.', Deepseek score=4
#   Topic 198: stance='favor', color=0.974(green)
#     arg1='It is recognized that unsustainable demand for charcoal in Kenya is triggering desertification, exacerbating climate change, and leading to devastating drought and famine. The acceleration of climate change through coal mining is being observed, alongside the detrimental impacts of deforestation fueled by charcoal production. The disruption of unsustainable practices, particularly the transition to clean cooking alternatives, is increasingly seen as a critical step in mitigating these effects and addressing the resulting rain failure and food deficit. Investments in clean cooking technologies are being urged to combat the ongoing consequences of charcoal use.', Gemma score=5
#     arg2='It has been widely recognized that the unsustainable demand for charcoal in Kenya, driven by its widespread use as a primary cooking fuel, is accelerating climate change and leading to desertification, devastating droughts, and food deficits. The reliance on this resource not only contributes to deforestation but also exacerbates environmental degradation and negatively impacts agricultural productivity. Consequently, there is an urgent need for alternative approaches to energy consumption that prioritize sustainability over the continued use of charcoal in cooking.', Deepseek score=4
#   Topic 201: stance='favor', color=0.974(green)
#     arg1='It is observed that bee populations are facing significant threats, including the impacts of pesticides, the effects of climate change, and the ongoing loss of biodiversity. Actions are being taken globally, such as the purchase of beehives and the establishment of pollinator gardens, alongside efforts to address the underlying causes of these declines. Concerns are being raised about the potential links between these threats and declining sperm counts, and a greater understanding of the role of bees in pollination is being sought. It is recognized that a comprehensive approach is needed to safeguard bee populations and their vital contribution to food security.', Gemma score=5
#     arg2='It is widely recognized that the decline of bee populations is being significantly influenced by pesticides and other environmental factors such as climate change. The importance of bees for pollination, which supports food production globally, has led to a growing concern about their well-being. Consequently, initiatives aimed at protecting these vital pollinators through actions like purchasing beehives and establishing pollinator gardens have been undertaken in various parts of the world. These efforts are part of an ongoing global conversation on biodiversity conservation and environmental stewardship.', Deepseek score=4
#   Topic 209: stance='favor', color=0.993(green)
#     arg1='It is recognized that a #ClimateEmergency is being declared by the @WelshGovernment, demonstrating a commitment to addressing the causes of #climatechange.  The #BlueCharter has been agreed upon by the #Commonwealth, and action is being taken to combat the effects of #climatechange.  Furthermore, the construction of the M4 relief road is being reconsidered, and efforts are being made to protect the environment.  It is understood that a concerted global response is required to safeguard #OurPlanet.', Gemma score=5
#     arg2='It has been widely recognized that the declaration of a climate emergency by governmental bodies, such as the Welsh Government, signifies their commitment to tackling the causes of climate change and striving towards environmental sustainability. This action is supported by various stakeholders who advocate for decisive measures against climate change, including cancelling projects like the M4 relief road. The consensus among these groups highlights the importance of proactive engagement from governments in addressing ecological challenges.', Deepseek score=4
#   Topic 210: stance='favor', color=0.932(green)
#     arg1='It is recognized that the threat of climate change is increasingly being associated with older adults, and that a perception of innovation is still expected from them regarding the ‘economy’ and ‘new market development’. It is further acknowledged that the consequences of climate change are only going to worsen for older adults, and that emergency response systems must be prepared for the worst-case storms of the future. It is urged that action be taken to reduce climate-changing pollution and to ready emergency response systems for the future.', Gemma score=5
#     arg2='It is widely acknowledged that climate change poses a growing threat to older adults, with increasing temperatures and extreme weather events expected to exacerbate the challenges faced by this demographic. As such, it is recognized that efforts must be made to reduce pollution contributing to climate change and enhance emergency response systems in anticipation of more severe storms. This acknowledgment underscores the need for innovative solutions and support from various sectors to protect vulnerable populations against the impacts of a changing climate.', Deepseek score=4
#   Topic 214: stance='favor', color=0.979(green)
#     arg1='It is increasingly recognized that the risks to coastal regions, particularly in Bangladesh, are being intensified by ongoing changes. The displacement of people and the loss of homes are being attributed to the escalating dangers posed by climate change.  Investments in addressing these vulnerabilities are being urged by various organizations, including the UNDP, the BBC, and the UN Environment Programme, to mitigate the growing threats to vulnerable populations and their livelihoods.  The need for action is being highlighted by numerous sources, reflecting a shared concern for the escalating impacts of climate change on coastal communities.', Gemma score=5
#     arg2='It is widely recognized that the risks of the coast in Bangladesh are increasingly being influenced by climate change, with rising sea levels and extreme weather events posing significant threats to coastal communities. The displacement caused by these changes has led to a continuous cycle of rebuilding homes for those affected, highlighting the urgent need for adaptation measures to protect vulnerable populations from the impacts of climate change.', Deepseek score=4
#   Topic 215: stance='favor', color=0.972(green)
#     arg1='It is increasingly recognized that the potential for widespread poverty is being significantly shaped by the escalating impacts of climate change. The consequences of this are being felt across the globe, demanding urgent attention to the moral implications of inaction. The need to determine the kind of society that will be established is being underscored, with healthcare, income inequality, and the effects of climate change forming the core of this critical conversation.  Expertise is being mobilized to address the environmental challenges, and decisions are being made to mitigate the worst effects of climate change and support those most vulnerable to its consequences.', Gemma score=5
#     arg2='It is widely acknowledged that climate change, in conjunction with healthcare issues and income inequality, has the potential to lead to an increase in global poverty by 2030, as predicted by Bread for the World. This outcome raises significant ethical questions about our societal priorities and obligations towards those affected by extreme poverty due to climatic events. The necessity of addressing climate change's worst effects is underscored by the commitment of Rotary Scholars and Peace Fellows who are dedicating their expertise to environmental conservation efforts, indicating a collective recognition that urgent action must be taken.', Deepseek score=4
#   Topic 223: stance='favor', color=0.957(green)
#     arg1='Significant concern is being expressed regarding the portrayal of Tony Abbott, with considerable offense being felt by electors of Warringah and across the nation, particularly amongst vulnerable populations. His past actions and statements concerning climate change, carbon taxes, and related issues are being scrutinized. It is recognized that his policies and public stances have generated considerable dissatisfaction. Furthermore, it is observed that his approach to collaboration with liberal leaders has been viewed negatively. Consequently, any representation of his image is perceived to provoke strong emotional responses, highlighting the deep-seated anxieties and frustrations surrounding his political record and its impact on the nation’s future.', Gemma score=5
#     arg2='It is widely acknowledged that the representation of political figures in public discourse can influence perceptions regarding their stance on climate change, environmental issues, and other significant matters. The portrayal of Tony Abbott's views against these themes has been known to elicit strong reactions among voters, particularly those who are concerned about ecological sustainability. Consequently, such depictions may inadvertently contribute to the polarization surrounding climate change policies.', Deepseek score=4
#   Topic 234: stance='favor', color=1.000(green)
#     arg1='It is recognized that milestones regarding global warming, such as the 1.5°C target, are being rapidly approached and revised. Significant, catastrophic phenomena are already manifesting as a result of global warming, and rapid, far-reaching, and unprecedented changes across all aspects of society are increasingly being deemed necessary to mitigate the progression of exacerbated and more ubiquitous catastrophes. It is understood that the consequences of exceeding the 1.5°C threshold are being actively assessed and addressed.', Gemma score=5
#     arg2='It has been widely recognized that catastrophic phenomena resulting from climate change are already manifesting, with global warming exceeding 1.5ºC potentially leading to exacerbated and more ubiquitous catastrophes. Limiting global warming to this degree requires rapid, far-reaching, and unprecedented changes in all aspects of society.', Deepseek score=4
#   Topic 235: stance='favor', color=0.910(green)
#     arg1='It is observed that a Eurocentric analysis of climate change requirements is being perpetuated, alongside the continued placement of vulnerable communities at risk due to privilege blind spots. Simultaneously, the disproportionate impact of systemic inequities – including disparities in educational opportunities, police brutality, and wage gaps – is recognized. Furthermore, a pattern of prioritizing corporate wealth accumulation over social responsibility and environmental stewardship by certain demographics is being noted, demanding a reevaluation of priorities and a commitment to equitable solutions. The strategies of groups like #ExtinctionRebellion are being considered as potential models for addressing these complex challenges.', Gemma score=5
#     arg2='It is widely acknowledged that white supremacy manifests in various forms within the context of human-caused issues such as climate change, where Eurocentric analyses can overlook privilege blind spots leading to unequal impacts on communities. This includes a greater risk for people of color due to attending substandard schools and facing police brutality. As a result, addressing these disparities is crucial for equitable action in combating climate change.', Deepseek score=4
#   Topic 242: stance='favor', color=0.954(green)
#     arg1='It is observed that migrations are being tracked with spikes in climate change, with hundreds of thousands and millions being predicted to flee drought and temperature spikes that are not survivable. The impacts of extreme climate change scenarios have long been recognized as a significant threat, and the consequences of these migrations are being increasingly linked to the effects of climate change. It is understood that the state of some people is being affected by these events, and action is being urged to address the complex interplay between climate change and migration.', Gemma score=5
#     arg2='It has been observed that the interplay between climate change and migration is becoming increasingly complex, with recent spikes in migration coinciding with rising global temperatures. Extreme climate change scenarios predict mass migrations driven by unlivable conditions such as droughts and temperature spikes. As a result of these unsustainable living environments, millions are at risk of fleeing their homes to seek refuge from the impacts of extreme weather events.', Deepseek score=4
#   Topic 257: stance='favor', color=0.992(green)
#     arg1='It is recognized that environmental justice is being increasingly linked to the impacts of climate change, with vulnerable populations disproportionately bearing the brunt of its effects. The need for solutions to climate change is being framed as a matter of social and economic justice, and it is understood that approaches to combating climate change must address existing inequalities. It is urged that social, economic, and environmental justice considerations are central to any strategy aimed at reversing the effects of climate change, and that the same class-divided society cannot be reproduced in solutions to the problems climate change presents.', Gemma score=5
#     arg2='It is widely acknowledged that environmental justice issues are particularly felt by those most exposed to the effects of climate change and pollution. Social, economic, and environmental injustices intersect when addressing the challenges posed by climate change, as solutions must be inclusive and equitable for all communities affected by these changes.', Deepseek score=4
#   Topic 269: stance='favor', color=0.992(green)
#     arg1='It is recognized that progress in girls’ education is being linked to the mitigation of climate change, particularly in West Africa. Projects are being funded to advocate for girls’ education as a means of reducing population growth and fostering resilience. Innovative programs are being developed and implemented, and the role of educating girls is being increasingly acknowledged as a key factor in addressing the challenges posed by climate change and promoting sustainable development.', Gemma score=5
#     arg2='It has been recognized that educating girls in Africa plays a pivotal role in mitigating climate change and fostering resilience within their countries, as highlighted by the recent op-ed piece published by @aruhweza on @allafrica. The advocacy for girls' education is seen not only as an effective means to reduce population growth but also to instigate innovative programs that contribute positively to combating climate change.', Deepseek score=4
#   Topic 288: stance='favor', color=0.973(green)
#     arg1='It is increasingly recognized that air pollution and climate change are intrinsically linked, with significant consequences for the planet. The burning of fossil fuels is identified as a primary driver of both, leading to demonstrable impacts such as reduced sunlight reaching Earth.  The potential benefits of mitigating climate change through air pollution reduction are being actively explored, and the need for immediate action is underscored by concerns regarding the long-term effects of diminished sunlight.  It is understood that the consequences of inaction are severe, and a concerted effort to address these interconnected challenges is urgently required.', Gemma score=5
# ...
#     arg2='It is increasingly recognized that the adoption of solar energy by homeowners plays a significant role in mitigating climate change, as it contributes to reducing carbon emissions and promoting sustainable living. The integration of solar technology into renovations and new buildings has gained favor among environmental advocates, urging governments to consider mandatory requirements for solar installations. This approach not only supports the transition towards renewable energy sources but also encourages broader sustainability efforts across society.', Deepseek score=5
#   Topic 2896: stance='favor', color=1.000(green)
#     arg1='It is recognized that a feedback mechanism, coupled with a loss of heat-deflecting white ice, is being amplified, leading to a near 5% amplification of global warming and its associated costs.  The consequences of failing to improve on Paris agreement commitments are being observed, and the urgency of addressing this situation is increasingly apparent.  It is understood that significant action is required to mitigate the escalating impacts of this complex system.', Gemma score=4
#     arg2='It is widely recognized that the combination of a feedback mechanism and the loss of heat-deflecting white ice significantly amplifies global warming and its associated costs. This outcome underscores the importance of countries adhering to their commitments under the Paris Agreement, as failure to do so could result in an almost 5% amplification of these effects.', Deepseek score=5
#   Topic 2900: stance='favor', color=1.000(green)
#     arg1='Serious concerns are being raised globally regarding increasingly frequent and severe heatwaves, and the question of what future is being shaped by these events is being actively considered.  The impact of these heatwaves is being recognized, and the potential for a diminished future is being highlighted.  Attention is being directed towards the role of these events, and the need for proactive measures is being emphasized.  It is being observed that significant changes are occurring, and the urgency of addressing these changes is being underscored.', Gemma score=4
#     arg2='It is increasingly evident that the frequency and intensity of heatwaves, as reported by various media outlets such as The Sydney Morning Herald, are raising concerns about the future climate conditions. These extreme weather events underscore the need for a collective response to address the impacts of climate change on human and ecological systems.', Deepseek score=5
#   Topic 2904: stance='favor', color=1.000(green)
#     arg1='It is recognized that a significant concern is being expressed by millions of young people around the world who are demanding action on climate change. It is noted that a reduction in greenhouse emissions is being urgently called for, with the understanding that a substantial shift is being recognized as necessary. It is further acknowledged that a collective effort is being urged, driven by the widespread recognition of the need to protect the planet and foster a greater appreciation for both each other and the Earth.', Gemma score=4
#     arg2='It is widely acknowledged that the demand for action on climate change, particularly by millions of young people around the world who have marched and gone on strike to advocate for such measures, has highlighted the urgent need for global efforts in reducing greenhouse gas emissions. This collective expression underscores a shared understanding among various communities about what needs to be done: significant cuts in carbon emissions are required by 2030 to mitigate the impacts of climate change effectively.', Deepseek score=5
#   Topic 2910: stance='favor', color=1.000(green)
#     arg1='It is recognized that UK homes are being found unsuitable for the challenges posed by climate change, with concerns raised about the impact of rising temperatures.  It is noted that a significant reduction in comfortable heating levels is being advocated for, aiming to mitigate the effects of supposedly dangerous anthropogenic global warming.  Furthermore, attention is being drawn to the need for action regarding emissions, with a focus on reducing the impact of greenhouse gases.  It is understood that a shift in priorities is being demanded, prioritizing the reduction of environmental impact over individual comfort levels.', Gemma score=4
#     arg2='It is widely recognized that homes across the globe, including those within the United Kingdom, face significant challenges due to climate change. The Climate Change Committee has emphasized the need for heating systems in dwellings to be set at temperatures two degrees Celsius below what most people find comfortable. This approach is seen as a crucial step towards adapting to and mitigating the effects of climate change on residential living conditions.', Deepseek score=5
#   Topic 2915: stance='favor', color=1.000(green)
#     arg1='It is observed that significant changes are being witnessed in environments globally, particularly concerning ice formations and climbing conditions.  Attention is being drawn to the impact of these changes on individuals deeply connected to nature and adventure, such as professional ice climbers who are observing the melting of glaciers.  Furthermore, scientific study is being undertaken in previously inaccessible areas, guided by experienced climbers, to measure and understand the extent of these transformations.  It is recognized that these observations are prompting action and investigation into the underlying causes of these environmental shifts.', Gemma score=4
#     arg2='It is widely recognized that climbers, who are deeply connected to the natural environment and its preservation, have increasingly been voicing concerns about climate change. Their firsthand experiences with melting glaciers and disappearing ice serve as poignant reminders of the impact of global warming on our planet's ecosystems. As a result, their involvement in scientific expeditions aimed at studying these changes is seen as an essential contribution towards understanding and addressing this critical environmental issue.', Deepseek score=5
#   Topic 2920: stance='favor', color=1.000(green)
#     arg1='It is observed that climate change deniers are being provided with positions as "fact checkers" and are being financed by dark money. The spread of misinformation regarding climate change is being facilitated by these individuals, and a significant number of American users are being exposed to potentially misleading information. The actions of these individuals are being scrutinized, and a concern is being raised about the influence of funded misinformation campaigns on a large population.', Gemma score=4
#     arg2='It is widely acknowledged that the role of climate change deniers as fact-checkers on a platform with millions of users has raised concerns about the potential influence and misinformation they may disseminate, particularly when funded by sources like Koch brothers. As such, there are calls for greater transparency in media practices to ensure accurate information regarding climate change is presented to the public.', Deepseek score=5
#   Topic 2921: stance='favor', color=1.000(green)
#     arg1='It is recognized that trees and forests are being utilized worldwide to apply a heat shield to the planet, with the evaporation of transpiring water generating clouds that reflect solar warming rays back into space. The formation of these clouds is being observed, and it is understood that a significant portion of all clouds are being created in this manner.  Investments in the preservation and expansion of forests are being considered as a crucial element in mitigating the effects of climate change, with the protection of these natural systems being prioritized.', Gemma score=4
#     arg2='It is widely acknowledged that trees and forests play a crucial role in protecting the planet from climate change by forming clouds through their transpiring water, which reflects solar rays back to space. This natural heat shield helps mitigate global warming, as evidenced by numerous studies and reports emphasizing the importance of preserving these carbon-absorbing ecosystems for our survival.', Deepseek score=5
#   Topic 2922: stance='favor', color=1.000(green)
#     arg1='It is recognized that decisions have been made which have weakened protections for endangered species and rescinded vital conservation policies. Furthermore, the ability to base decisions on scientific research has been undermined. Consequently, actions to address climate change are being jeopardized, and the future of wildlife, communities, and all people are being threatened. It is urged that Congress steps up and leads on climate action to mitigate the ongoing detrimental effects.', Gemma score=4
#     arg2='It is widely acknowledged that decisions by the administration to pull back on actions addressing climate change will be devastating for the future of wildlife, communities, and all of us. The weakening of environmental policies such as Bernhardt's undermining of the Interior’s ability to make decisions based on scientific research has been met with concern. Every single GOP Senator voted to confirm this action just a week ago. It is urged that Congress step up in addressing climate change to protect wildlife and communities from its devastating effects.', Deepseek score=5
#   Topic 2931: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant challenges are being presented by evolving technology, the demands of #climatechange, and shifting public tastes, particularly within the agricultural sector.  The need for adaptive and mitigative agricultural approaches, alongside healthy farming practices, is increasingly being highlighted.  Furthermore, interventions focused on nutritional health, such as the #OwnAKitchenGardenCampaign and the #TheYoungFarmersClub, are being explored.  A multi-sectoral forum, integrating science and law, is being convened to address the impacts of climate change on food and agriculture, specifically within Connecticut, and to champion solutions for a sustainable future.', Gemma score=4
#     arg2='It is widely recognized that adaptive and mitigative agricultural approaches, healthy farming practices, and the development of innovative technologies are essential in addressing the challenges posed by climate change. The integration of science and law through multi-sectoral forums such as those hosted by institutions like UConn further underscores the collaborative efforts to tackle the impacts of climate change on food security and agriculture. As public tastes evolve and technology advances, it is imperative that agricultural interventions championing nutritional health initiatives continue to be championed by organizations like ISNHI and supported by young farmers through platforms such as The Young Farmers Club.', Deepseek score=5
#   Topic 2951: stance='favor', color=1.000(green)
#     arg1='It is observed that action is being spurred on climate change through movements like Extinction Rebellion in the UK.  Increased attention is being drawn to the urgency of the situation, and efforts are being made to promote electric vehicle adoption.  The need for immediate and impactful responses is being recognized, and strategies are being developed to address the escalating challenges presented by the changing climate.', Gemma score=4
#     arg2='It is widely acknowledged that environmental activism, such as the actions of groups like Extinction Rebellion, can potentially lead to increased efforts towards combating climate change. These protests and their associated media coverage are believed to have raised public awareness about the urgency of addressing global warming issues, thereby putting pressure on governments and industries to take action against climate change.', Deepseek score=5
#   Topic 2953: stance='favor', color=1.000(green)
#     arg1='It is observed that dramatic weather events, including those in Ireland and elsewhere, are increasingly being linked to climate change. The fingerprint of climate change is becoming more evident through these occurrences. It is recognized that these events are being intensified, and the increasing frequency and severity of these occurrences are being attributed to broader climate shifts. It is urged that further investigation and monitoring of these events are undertaken to better understand the extent of the impact and to inform mitigation strategies.', Gemma score=4
#     arg2='It is increasingly recognized that dramatic weather events, such as those observed in Ireland and elsewhere last year, are revealing the 'fingerprint of climate change' with increasing clarity. These events underscore the growing evidence of a changing climate, which continues to manifest through extreme weather patterns.', Deepseek score=5
#   Topic 2957: stance='favor', color=1.000(green)
#     arg1='It is recognized that significant legal challenges are being mounted regarding Exxon's actions and statements concerning climate change.  Investigations into the company's involvement are being pursued, and attempts are being made to limit the scope of these inquiries.  The implications of these legal battles are being assessed globally, with concerns being raised about the potential impact on corporate accountability and the understanding of climate-related risks.  It is understood that a global response is being shaped by these developments, emphasizing the need for transparency and a thorough examination of the role of major corporations in addressing climate-related issues.', Gemma score=4
#     arg2='It is widely recognized that the U.S. Supreme Court has consistently rejected efforts by major corporations, such as Exxon, to limit investigations into their statements and actions regarding climate change. These decisions underscore the ongoing scrutiny of corporate responsibility in addressing environmental concerns, particularly concerning transparency on climate-related issues.', Deepseek score=5
#   Topic 2969: stance='favor', color=0.900(green)
#     arg1='It is observed that significant shifts in global environments are occurring, prompting concerns about the implications for communities and infrastructure.  Questions are raised regarding the acknowledgement of these changes by certain groups, particularly when faced with demonstrable evidence of environmental degradation.  It is noted that actions, or lack thereof, are being scrutinized, with some prioritizing short-term gains over long-term sustainability.  The potential for future consequences, including the displacement of populations and the deterioration of built environments, is being recognized, and the need for proactive measures is increasingly apparent.  It is recognized that a failure to address these issues will have significant and lasting repercussions.', Gemma score=4
#     arg2='It is widely acknowledged that cities are sinking into the ocean, necessitating the reassignment of missionaries by the IMB due to climate change. Despite studies published since the 1970s highlighting the truth about global warming, evangelicals continue to express skepticism and doubt regarding human-driven climate change. This stance often involves a deep-seated belief in divine intervention rather than acknowledging the role of human activity as a dominant driver of environmental degradation.', Deepseek score=5

# %%
# Cross-tabulation analysis
print("=== CROSS-TABULATION ANALYSIS ===")
print("STANCE vs COLOR CATEGORY:")
cross_tab = pd.crosstab(df[stance_col], df['color_category'])
print(cross_tab)
print()

# Performance matrix
print("AVERAGE SCORES BY STANCE AND COLOR CATEGORY:")
pivot_score1 = df.pivot_table(values=score1_col, index=stance_col, columns='color_category', aggfunc='mean')
pivot_score2 = df.pivot_table(values=score2_col, index=stance_col, columns='color_category', aggfunc='mean')

print(f"\n{model1_name} averages:")
print(pivot_score1.fillna('N/A').round(2))
print(f"\n{model2_name} averages:")
print(pivot_score2.fillna('N/A').round(2))
# Out:
# === CROSS-TABULATION ANALYSIS ===
# STANCE vs COLOR CATEGORY:
# color_category  balanced  believer_heavy  denier_heavy
# stance
# against               22               0           110
# favor                 27            2760             0
# polarized             52               0             0
#
# AVERAGE SCORES BY STANCE AND COLOR CATEGORY:
#
# Gemma averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             3.95            N/A     3.781818
# favor               4.04       4.107246          N/A
# polarized           3.69            N/A          N/A
#
# Deepseek averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             2.68            N/A     2.654545
# favor               3.04       3.781159          N/A
# polarized           2.65            N/A          N/A

# %%
# Create comprehensive visualizations
print("\n=== CREATING VISUALIZATIONS ===")
fig = plt.figure(figsize=(20, 15))

# 1. Score distribution by stance
ax1 = plt.subplot(3, 3, 1)
stance_means = df.groupby(stance_col)[[score1_col, score2_col]].mean()
stance_means.plot(kind='bar', ax=ax1, color=palette_colors)
ax1.set_title('Average Scores by Stance')
ax1.set_ylabel('Average Score')
ax1.legend([model1_name, model2_name])
ax1.tick_params(axis='x', rotation=45)

# 2. Score distribution by color category
ax2 = plt.subplot(3, 3, 2)
color_means = df.groupby('color_category')[[score1_col, score2_col]].mean()
color_means.plot(kind='bar', ax=ax2, color=palette_colors)
ax2.set_title('Average Scores by Opinion Distribution')
ax2.set_ylabel('Average Score')
ax2.legend([model1_name, model2_name])
ax2.tick_params(axis='x', rotation=45)

# 3. Scatter plot with color coding
ax3 = plt.subplot(3, 3, 3)
scatter = ax3.scatter(df[score1_col], df[score2_col], c=df[color_col], cmap='RdYlGn', alpha=0.7, s=60)
ax3.plot([1, 5], [1, 5], 'k--', alpha=0.5, label='Equal scores')
ax3.set_xlabel(f'{model1_name} Scores')
ax3.set_ylabel(f'{model2_name} Scores')
ax3.set_title(f'{model1_name} vs {model2_name}\n(Color = Opinion Distribution)')
ax3.legend()
ax3.grid(True, alpha=0.3)
plt.colorbar(scatter, ax=ax3, label='Color (0=Red/Deniers, 1=Green/Believers)')

# 4. Box plots by stance
#ax4 = plt.subplot(3, 3, 4)
#df.boxplot(column=[score1_col, score2_col], by=stance_col, ax=ax4)
#ax4.set_title('Score Distribution by Stance')
#ax4.set_ylabel('Score')

# 5. Color distribution histogram
ax5 = plt.subplot(3, 3, 5)
ax5.hist(df[color_col], bins=20, alpha=0.7, edgecolor='black')
ax5.set_xlabel('Color Value')
ax5.set_ylabel('Frequency')
ax5.set_title('Distribution of Opinion Balance\n(0=Deniers, 0.5=Polarized, 1=Believers)')
ax5.axvline(x=0.33, color='red', linestyle='--', alpha=0.7, label='Denier threshold')
ax5.axvline(x=0.67, color='green', linestyle='--', alpha=0.7, label='Believer threshold')
ax5.legend()

# 6. Heatmap of average scores
ax6 = plt.subplot(3, 3, 6)
heatmap_data = df.pivot_table(values=[score1_col, score2_col], index=stance_col, columns='color_category', aggfunc='mean')
if not heatmap_data.empty:
    sns.heatmap(heatmap_data, annot=True, cmap='viridis', ax=ax6, fmt='.2f')
    ax6.set_title('Average Scores Heatmap\n(Stance vs Opinion Distribution)')

# 7. Difference analysis by stance
ax7 = plt.subplot(3, 3, 7)
df['score_diff'] = df[score1_col] - df[score2_col]
df.boxplot(column='score_diff', by=stance_col, ax=ax7)
ax7.set_title(f'Score Differences by Stance\n({model1_name} - {model2_name})')
ax7.set_ylabel('Score Difference')

# 8. Model performance by color
ax8 = plt.subplot(3, 3, 8)
# Create bins for color analysis
df['color_bin'] = pd.cut(df[color_col], bins=5, labels=['Very Red', 'Red', 'Yellow', 'Green', 'Very Green'])
color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()
color_perf.plot(kind='bar', ax=ax8, color=palette_colors)
ax8.set_title('Performance Across Opinion Spectrum')
ax8.set_ylabel('Average Score')
ax8.legend([model1_name, model2_name])
ax8.tick_params(axis='x', rotation=45)

# 9. Correlation analysis
ax9 = plt.subplot(3, 3, 9)
ax9.scatter(df[color_col], df[score1_col], alpha=0.6, label=model1_name, color='blue')
ax9.scatter(df[color_col], df[score2_col], alpha=0.6, label=model2_name, color='orange')
ax9.set_xlabel('Color (Opinion Distribution)')
ax9.set_ylabel('Score')
ax9.set_title('Scores vs Opinion Distribution')
ax9.legend()
ax9.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# === CREATING VISUALIZATIONS ===
# /tmp/ipykernel_1324321/1169726615.py:68: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()

# %%
# Detailed analysis
print("\n=== DETAILED ANALYSIS ===")

# Correlation between color and scores
corr_color_score1 = df[color_col].corr(df[score1_col])
corr_color_score2 = df[color_col].corr(df[score2_col])

print("CORRELATION ANALYSIS:")
print(f"Color vs {model1_name} scores: {corr_color_score1:.4f}")
print(f"Color vs {model2_name} scores: {corr_color_score2:.4f}")
print(f"{model1_name} vs {model2_name} scores: {df[score1_col].corr(df[score2_col]):.4f}")
print()

# Performance in different opinion environments
print("MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:")
for category, desc in [('denier_heavy', 'Denier-heavy topics (Red zone)'),
                       ('balanced', 'Polarized topics (Yellow zone)'),
                       ('believer_heavy', 'Believer-heavy topics (Green zone)')]:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        print(f"\n{desc}:")
        print(f"  Topics: {len(cat_data)}")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        # Test if there's a significant difference between models in this category
        if len(cat_data) > 1:
            t_stat_cat, p_val_cat = stats.ttest_rel(cat_data[score1_col], cat_data[score2_col])
            print(f"  Significant difference between models: {'Yes' if p_val_cat < 0.05 else 'No'} (p={p_val_cat:.4f})")

# Best and worst performing topics
print(f"\n=== BEST AND WORST PERFORMING TOPICS ===")

# Best Model 1 performance
best_m1 = df.loc[df[score1_col].idxmax()]
print(f"BEST {model1_name} performance (Score: {best_m1[score1_col]}):")
color_desc = "red" if best_m1[color_col] < 0.33 else "green" if best_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m1[stance_col]}', color={best_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m1[arg1_col]}', {model1_name} score={best_m1[score1_col]}")
print(f"  {arg2_col}='{best_m1[arg2_col]}', {model2_name} score={best_m1[score2_col]}")

# Worst Model 1 performance
worst_m1 = df.loc[df[score1_col].idxmin()]
print(f"\nWORST {model1_name} performance (Score: {worst_m1[score1_col]}):")
color_desc = "red" if worst_m1[color_col] < 0.33 else "green" if worst_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m1[stance_col]}', color={worst_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m1[arg1_col]}', {model1_name} score={worst_m1[score1_col]}")
print(f"  {arg2_col}='{worst_m1[arg2_col]}', {model2_name} score={worst_m1[score2_col]}")

# Best Model 2 performance
best_m2 = df.loc[df[score2_col].idxmax()]
print(f"\nBEST {model2_name} performance (Score: {best_m2[score2_col]}):")
color_desc = "red" if best_m2[color_col] < 0.33 else "green" if best_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m2[stance_col]}', color={best_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m2[arg1_col]}', {model1_name} score={best_m2[score1_col]}")
print(f"  {arg2_col}='{best_m2[arg2_col]}', {model2_name} score={best_m2[score2_col]}")

# Worst Model 2 performance
worst_m2 = df.loc[df[score2_col].idxmin()]
print(f"\nWORST {model2_name} performance (Score: {worst_m2[score2_col]}):")
color_desc = "red" if worst_m2[color_col] < 0.33 else "green" if worst_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m2[stance_col]}', color={worst_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m2[arg1_col]}', {model1_name} score={worst_m2[score1_col]}")
print(f"  {arg2_col}='{worst_m2[arg2_col]}', {model2_name} score={worst_m2[score2_col]}")

# Summary insights
print(f"\n=== KEY INSIGHTS ===")
print("STANCE-BASED INSIGHTS:")
stance_summary = df.groupby(stance_col)[[score1_col, score2_col]].mean()
best_stance_m1 = stance_summary[score1_col].idxmax()
best_stance_m2 = stance_summary[score2_col].idxmax()
print(f"  {model1_name} performs best on '{best_stance_m1}' topics")
print(f"  {model2_name} performs best on '{best_stance_m2}' topics")

print("\nOPINION DISTRIBUTION INSIGHTS:")
color_summary = df.groupby('color_category')[[score1_col, score2_col]].mean()
if not color_summary.empty:
    best_color_m1 = color_summary[score1_col].idxmax() if len(color_summary) > 0 else 'N/A'
    best_color_m2 = color_summary[score2_col].idxmax() if len(color_summary) > 0 else 'N/A'
    print(f"  {model1_name} performs best in '{best_color_m1}' opinion environments")
    print(f"  {model2_name} performs best in '{best_color_m2}' opinion environments")

# Overall winner
if df[score1_col].mean() > df[score2_col].mean():
    overall_better = model1_name
    diff = df[score1_col].mean() - df[score2_col].mean()
elif df[score2_col].mean() > df[score1_col].mean():
    overall_better = model2_name
    diff = df[score2_col].mean() - df[score1_col].mean()
else:
    overall_better = "Tie"
    diff = 0

print(f"\nOVERALL BETTER MODEL: {overall_better}")
if diff > 0:
    print(f"  Average advantage: {diff:.3f} points")
# Out:
# === DETAILED ANALYSIS ===
# CORRELATION ANALYSIS:
# Color vs Gemma scores: 0.2066
# Color vs Deepseek scores: 0.3302
# Gemma vs Deepseek scores: 0.2268
#
# MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:
#
# Denier-heavy topics (Red zone):
#   Topics: 110
#   Gemma avg: 3.78
#   Deepseek avg: 2.65
#   Significant difference between models: Yes (p=0.0000)
#
# Polarized topics (Yellow zone):
#   Topics: 101
#   Gemma avg: 3.84
#   Deepseek avg: 2.76
#   Significant difference between models: Yes (p=0.0000)
#
# Believer-heavy topics (Green zone):
#   Topics: 2760
#   Gemma avg: 4.11
#   Deepseek avg: 3.78
#   Significant difference between models: Yes (p=0.0000)
#
# === BEST AND WORST PERFORMING TOPICS ===
# BEST Gemma performance (Score: 5):
#   Topic: stance='favor', color=0.956(green)
#   arg1='It is increasingly recognized that significant reductions in meat and dairy consumption are being advocated, driven by concerns regarding mass extinctions, climate change catastrophes, and widespread animal abuse. The impact of animal agriculture on climate change is being highlighted, and a shift towards plant-based diets is being viewed as a crucial step in safeguarding the survival of future generations and the planet itself.  Recommendations for reducing meat and dairy consumption and adopting plant-based meals are being actively promoted as a means of mitigating these serious global challenges.', Gemma score=5
#   arg2='It has been widely acknowledged that the widespread adoption of plant-based diets, primarily driven by concerns over mass extinction, climate catastrophes, and animal abuse, is contributing to healthier lifestyles for humans while inadvertently improving livestock welfare. Opponents who challenge these dietary changes are seen as fighting against their own survival needs, those of their children, and the very survival of the planet itself. The necessity for a collective shift towards plant-based diets in order to mitigate climate change impacts has become increasingly clear.', Deepseek score=4
#
# WORST Gemma performance (Score: 1):
#   Topic: stance='favor', color=0.964(green)
#   arg1='It is observed that considerable concern exists regarding the understanding of climate change, with assertions of disbelief frequently presented. The implications of such assertions are recognized, and the impact of dismissing the issue is acknowledged. It is noted that a lack of comprehension regarding the complexities of the situation is frequently expressed, and the consequences of this lack of understanding are recognized. The need for a more informed approach to the issue is increasingly apparent.', Gemma score=1
#   arg2='It is widely acknowledged that the denial or skepticism towards climate change, often expressed in dismissive and derogatory terms by some individuals, reflects a level of ignorance regarding its existence and impacts. This stance implies a lack of understanding about the scientific consensus on global warming and its potential consequences for humanity and the environment.', Deepseek score=4
#
# BEST Deepseek performance (Score: 5):
#   Topic: stance='favor', color=0.921(green)
#   arg1='It is observed that dangerous climate change denial is being supported by figures like Bush’s former EPA chief and Trump, aligning with the interests of big corporations and the super rich.  The acceptance of deregulation and tax breaks for polluting industries is being facilitated, while the participation in the Paris Agreement is being avoided.  The continuation of investments in harmful industries and the disregard for environmental consequences are being prioritized, leading to the degradation of the earth and threats to public health.  It is recognized that the protection of corporate profits and the interests of a select few are being prioritized over the well-being of the planet and its inhabitants.', Gemma score=4
#   arg2='It has been widely acknowledged that there exists a convergence between support for Trump and climate change denial, which converges at a point concerning big corporate interests and the interests of the super-rich. This alignment is exemplified by policies such as tax breaks for billionaires and deregulation of harmful industries, which are defended under the guise of climate change denial. These actions not only protect high pollution investments but also allow companies like Dow to continue making billions at the expense of destroying the earth and our health.', Deepseek score=5
#
# WORST Deepseek performance (Score: 1):
#   Topic: stance='against', color=0.008(red)
#   arg1='Significant shifts in global temperatures have been observed, and adjustments to climate patterns have been suggested.  Changes in global temperatures have been noted, and self-correcting mechanisms have been indicated.  Alterations to global climate have been suggested, and adjustments to global climate have been indicated.', Gemma score=3
#   arg2='The complexities of climate change have been repeatedly demonstrated through various natural cycles, such as solar radiation variations and oceanic currents, which can influence global temperature patterns independently of human activity. These long-term climatic shifts are supported by historical evidence from ice core samples, sediment layers, and tree rings that show fluctuations in Earth's climate predating significant industrialization.', Deepseek score=1
#
# === KEY INSIGHTS ===
# STANCE-BASED INSIGHTS:
#   Gemma performs best on 'favor' topics
#   Deepseek performs best on 'favor' topics
#
# OPINION DISTRIBUTION INSIGHTS:
#   Gemma performs best in 'believer_heavy' opinion environments
#   Deepseek performs best in 'believer_heavy' opinion environments
#
# OVERALL BETTER MODEL: Gemma
#   Average advantage: 0.381 points

# %% [markdown]
# ## Violin Plot

# %%
# --- Visualization ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Violin plot
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# Boxplot
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# 3. Difference distribution (instead of hexbin)
diff = df[score2_col] - df[score1_col]
sns.histplot(diff, bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")


# Heatmap of agreement
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_{filename_output}.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Dashboard
#  1. Violin plot considering all the scores by stance.
#  2. Boxplot considering all the scores by stance.
#  3. Difference distribution.
#  4. Heatmap (agreement)
#  5. Violin plot model 1 by stance.
#  6. Violin plot model 2 by stance.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# --- Visualization ---
fig, axes = plt.subplots(3, 2, figsize=(14, 14))

# --- Row 1 ---
# 1. Violin plot (overall)
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# 2. Boxplot (overall)
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# --- Row 2 ---
# 3. Difference distribution
df["diff"] = df[score2_col] - df[score1_col]
sns.histplot(df["diff"], bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")

# 4. Heatmap (agreement)
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

# --- Row 3 ---
# 5. Violin by stance (palette)
sns.violinplot(
    x="stance", y=score1_col, data=df,
    ax=axes[2,0],
    palette= pallete_stance_model1, # green_palette_stance = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"},
    order=["favor","against","polarized"]
)
axes[2,0].set_title(f"{model1_name} Scores by Stance", color=color_title_model1) #color_title_green="#196f3d"
axes[2,0].set_ylabel("Score")
axes[2,0].set_xlabel("Stance")

# 6. Violin by stance (Deepseek, orange palette)
sns.violinplot(
    x="stance", y=score2_col, data=df,
    ax=axes[2,1],
    palette= pallete_stance_model2,# orange_palette_stance = {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"},
    order=["favor","against","polarized"]
)
axes[2,1].set_title(f"{model2_name} Scores by Stance", color=color_title_model2 ) # color_title_green = "#7e5109"
axes[2,1].set_ylabel("Score")
axes[2,1].set_xlabel("Stance")


plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_JudgeGemma_Args-{filename_output}.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1324321/2608110707.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_1324321/2608110707.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
