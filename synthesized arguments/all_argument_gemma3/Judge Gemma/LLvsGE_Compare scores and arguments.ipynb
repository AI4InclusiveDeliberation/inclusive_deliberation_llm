# %% [markdown]
# # Analysis of results
#
# Distribution of scores assigned by Model Gemma3 as Judge when comparing the performance of language model pairs: Deepseek vs Llama
#
# By: Gabriela Díaz

# %% [markdown]
# ## Extreme values analysis

# %%
# Import section
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
###################################
# Colors definition for models
###################################

color_GE_0shot = '#ffac37'
color_GE_1shot = '#ffc575'
# LL '#009e73','#0bd9a1'
color_LL_0shot = '#009e73'
color_LL_1shot = '#0bd9a1'
# DS '#0077bb','#60b8eb'
color_DS_0shot = '#0077bb'
color_DS_1shot = '#60b8eb'
palette_stance_blue =  {"favor": "#1F4BE6", "against": "#023BD3", "polarized": "#9FB2F5"} #blue
palette_stance_orange =  {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"} #orange
palette_stance_green = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"} #green

color_title_green="#196f3d"
color_title_orange = "#7e5109"
color_title_blue = "#0F4ABD"

# %%
# =============================================================================
# CONFIGURATION 
#  Change next variables to compare different models. 
# =============================================================================

# filename 
filename_scores = 'jgemma_ll_ge.csv' #this file contain scores for the two models that are compared. 
filename_output = '_ll_vs_ge_'

# Model names for labeling
model1_name = 'Llama'
model2_name = 'Gemma'

# Column mappings - change these to match your data structure
score1_col = 'score1'  # Column name for model 1 scores
score2_col = 'score2'  # Column name for model 2 scores
arg1_col = 'arg1'      # Column name for model 1 arguments
arg2_col = 'arg2'      # Column name for model 2 arguments

# Other column names
color_col = 'color'
stance_col = 'stance'

# Colors
palette_colors = [color_LL_1shot,color_GE_1shot]

# Colors for the last violin
pallete_stance_model1 = palette_stance_green
pallete_stance_model2 = palette_stance_orange 
color_title_model1 = color_title_green
color_title_model2 = color_title_orange

df = pd.read_csv(filename_scores)

# %%
print(f"=== {model1_name.upper()} vs {model2_name.upper()} COMPARISON BY STANCE AND MODEL ===\n")

# Display sample of the data
print("DATA OVERVIEW:")
print(f"Total topics analyzed: {len(df)}")
print(f"Stance distribution: {df[stance_col].value_counts().to_dict()}")
print(f"Color range: {df[color_col].min():.3f} to {df[color_col].max():.3f}")
print(f"Models being compared: {model1_name} vs {model2_name}")
print()

# Basic statistics by model
print("=== MODEL COMPARISON ===")
print("OVERALL MODEL PERFORMANCE:")
print(f"{model1_name} - Mean: {df[score1_col].mean():.2f}, Std: {df[score1_col].std():.2f}")
print(f"{model2_name} - Mean: {df[score2_col].mean():.2f}, Std: {df[score2_col].std():.2f}")

# Statistical test between models
t_stat, p_value = stats.ttest_rel(df[score1_col], df[score2_col])
print(f"\nPaired t-test between models:")
print(f"  T-statistic: {t_stat:.4f}")
print(f"  P-value: {p_value:.4f}")
print(f"  Significant difference: {'Yes' if p_value < 0.05 else 'No'}")

# Model wins
model1_wins = (df[score1_col] > df[score2_col]).sum()
model2_wins = (df[score2_col] > df[score1_col]).sum()
ties = (df[score1_col] == df[score2_col]).sum()

print(f"\nHead-to-head comparison:")
print(f"  {model1_name} wins: {model1_wins} topics")
print(f"  {model2_name} wins: {model2_wins} topics")
print(f"  Ties: {ties} topics")
print()

# Analysis by stance
print("=== ANALYSIS BY STANCE ===")
print("PERFORMANCE BY STANCE:")
for stance in df[stance_col].unique():
    stance_data = df[df[stance_col] == stance]
    print(f"\n{stance.upper()} topics ({len(stance_data)} topics):")
    print(f"  Average color value: {stance_data[color_col].mean():.3f}")
    print(f"  {model1_name} - Mean: {stance_data[score1_col].mean():.2f}, Std: {stance_data[score1_col].std():.2f}")
    print(f"  {model2_name} - Mean: {stance_data[score2_col].mean():.2f}, Std: {stance_data[score2_col].std():.2f}")
    
    # Model comparison within this stance
    m1_wins = (stance_data[score1_col] > stance_data[score2_col]).sum()
    m2_wins = (stance_data[score2_col] > stance_data[score1_col]).sum()
    ties = (stance_data[score1_col] == stance_data[score2_col]).sum()
    print(f"  Within {stance}: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()

# Color-based analysis (opinion distribution)
print("=== COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===")
def categorize_color(color_val):
    if color_val < 0.33:
        return 'denier_heavy'  # Red zone
    elif color_val > 0.67:
        return 'believer_heavy'  # Green zone
    else:
        return 'balanced'  # Yellow zone (polarized)

df['color_category'] = df[color_col].apply(categorize_color)

print("PERFORMANCE BY OPINION DISTRIBUTION:")
for category in ['denier_heavy', 'balanced', 'believer_heavy']:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        color_range = f"{cat_data[color_col].min():.3f}-{cat_data[color_col].max():.3f}"
        print(f"\n{category.upper().replace('_', ' ')} topics ({len(cat_data)} topics, color: {color_range}):")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        m1_wins = (cat_data[score1_col] > cat_data[score2_col]).sum()
        m2_wins = (cat_data[score2_col] > cat_data[score1_col]).sum()
        ties = (cat_data[score1_col] == cat_data[score2_col]).sum()
        print(f"  Model performance: {model1_name} wins {m1_wins}, {model2_name} wins {m2_wins}, Ties {ties}")

print()
# Out:
# === LLAMA vs GEMMA COMPARISON BY STANCE AND MODEL ===
#
# DATA OVERVIEW:
# Total topics analyzed: 2971
# Stance distribution: {'favor': 2787, 'against': 132, 'polarized': 52}
# Color range: 0.000 to 1.000
# Models being compared: Llama vs Gemma
#
# === MODEL COMPARISON ===
# OVERALL MODEL PERFORMANCE:
# Llama - Mean: 4.06, Std: 0.75
# Gemma - Mean: 3.58, Std: 0.86
#
# Paired t-test between models:
#   T-statistic: 30.3123
#   P-value: 0.0000
#   Significant difference: Yes
#
# Head-to-head comparison:
#   Llama wins: 1722 topics
#   Gemma wins: 475 topics
#   Ties: 774 topics
#
# === ANALYSIS BY STANCE ===
# PERFORMANCE BY STANCE:
#
# FAVOR topics (2787 topics):
#   Average color value: 0.964
#   Llama - Mean: 4.12, Std: 0.68
#   Gemma - Mean: 3.64, Std: 0.84
#   Within favor: Llama wins 1600, Gemma wins 434, Ties 753
#
# POLARIZED topics (52 topics):
#   Average color value: 0.518
#   Llama - Mean: 3.29, Std: 1.16
#   Gemma - Mean: 2.50, Std: 0.64
#   Within polarized: Llama wins 39, Gemma wins 10, Ties 3
#
# AGAINST topics (132 topics):
#   Average color value: 0.162
#   Llama - Mean: 3.25, Std: 1.24
#   Gemma - Mean: 2.77, Std: 0.77
#   Within against: Llama wins 83, Gemma wins 31, Ties 18
#
# === COLOR-BASED ANALYSIS (OPINION DISTRIBUTION) ===
# PERFORMANCE BY OPINION DISTRIBUTION:
#
# DENIER HEAVY topics (110 topics, color: 0.000-0.328):
#   Llama avg: 3.16
#   Gemma avg: 2.70
#   Model performance: Llama wins 68, Gemma wins 26, Ties 16
#
# BALANCED topics (101 topics, color: 0.333-0.667):
#   Llama avg: 3.54
#   Gemma avg: 2.75
#   Model performance: Llama wins 76, Gemma wins 18, Ties 7
#
# BELIEVER HEAVY topics (2760 topics, color: 0.672-1.000):
#   Llama avg: 4.12
#   Gemma avg: 3.65
#   Model performance: Llama wins 1578, Gemma wins 431, Ties 751

# %%
# Find extreme cases
print("=== EXTREME CASES ANALYSIS ===")

# Lowest scores
min_score = min(df[score1_col].min(), df[score2_col].min())
print(f"LOWEST SCORE FOUND: {min_score}")

min_score1_rows = df[df[score1_col] == min_score]
min_score2_rows = df[df[score2_col] == min_score]

if not min_score1_rows.empty:
    print(f"\n{model1_name} lowest scores:")
    for idx, row in min_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not min_score2_rows.empty:
    print(f"\n{model2_name} lowest scores:")
    for idx, row in min_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")
# Out:
# === EXTREME CASES ANALYSIS ===
# LOWEST SCORE FOUND: 1
#
# Llama lowest scores:
#   Topic 11: stance='polarized', color=0.574(yellow)
#     arg1='The notion that human activity is the primary driver of current climate change has been questioned by some, who argue that there is no scientific proof to support this claim; however, the settled science on climate change remains a topic of debate among experts, with some suggesting that government grants may influence the outcome of research, while others emphasize the importance of specialized research in various fields, leaving room for alternative perspectives on the issue.', Llama score=1
#     arg2='It has been asserted that there is no scientific proof of anthropogenic climate change, and that the assertion of ‘settled science’ has been used to ignore contrary evidence; it has been suggested that government grants corrupt science, and that the focus on climate change has been driven by specialized research, assuming that there’s time for its results to be beneficial.', Gemma score=2
#   Topic 40: stance='against', color=0.132(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent claims of a rapidly accelerating global warming trend have been repeatedly challenged, with observations of temperature fluctuations seemingly dismissed as irrelevant. Concerns regarding the validity of data and the potential for manipulation have been voiced, suggesting that interpretations of climate trends are subject to influence. The assertion that current warming is solely attributable to human activity has been questioned, with the possibility of alternative explanations remaining uninvestigated. The notion that a singular, easily quantifiable cause for climate change is being presented has been met with skepticism, and the pursuit of diverse perspectives has been discouraged.', Gemma score=2
#   Topic 51: stance='polarized', color=0.426(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It has been asserted that the world is being negatively impacted by climate change, alongside concerns regarding the suppression of LGBTQ+ rights and widespread poverty; simultaneously, it has been suggested that changes near a body of water were altered, and it has been argued that extreme views on both the left and right are being considered; it has been maintained that extreme beliefs on the left, such as the recognition of healthcare as a human right and the need to address global warming, are being challenged, while equally extreme views on the right, including the denial of scientific evidence, are being considered; it has been repeatedly suggested that a rational middle ground is not possible for certain issues.', Gemma score=2
#   Topic 84: stance='favor', color=0.964(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that considerable concern exists regarding the understanding of climate change, with assertions of disbelief frequently presented. The implications of such assertions are recognized, and the impact of dismissing the issue is acknowledged. It is noted that a lack of comprehension regarding the complexities of the situation is frequently expressed, and the consequences of this lack of understanding are recognized. The need for a more informed approach to the issue is increasingly apparent.', Gemma score=2
#   Topic 98: stance='favor', color=0.897(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns are frequently raised regarding various aspects of the world, including individual expression and the perceived distortions of reality.  Disagreements are repeatedly voiced, and criticisms are persistently directed.  The impact of these ongoing debates is being recognized, and the need for a shift in focus is increasingly apparent.  It is understood that a resolution to these persistent concerns requires a reevaluation of priorities and a move towards constructive engagement.', Gemma score=2
#   Topic 157: stance='favor', color=0.712(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant concerns are being raised regarding the apparent dismissal of global warming, with considerable attention being directed towards the actions of a prominent figure.  The reduction in the absorption of carbon dioxide by forests is being noted, alongside the apparent disregard for the issue by certain individuals.  Furthermore, the rise of populism and fascism is being linked to a lack of attention to the effects of a changing climate, and the apprehension of a global crisis is being expressed.  It is understood that a serious response to the observed changes is being demanded, given the potential for significant consequences.', Gemma score=2
#   Topic 162: stance='favor', color=0.778(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that claims regarding a ‘Chinese hoax’ related to climate change are being advanced. Significant increases in global temperatures are being noted, alongside heightened occurrences of severe wildfires. The reduction in the number of trees absorbing carbon dioxide, due to widespread deforestation, is also being recognized. Consequently, efforts to address the situation are being considered, with a focus on mitigating the observed impacts and acknowledging the complexities of the issue.', Gemma score=2
#   Topic 171: stance='favor', color=0.930(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that increased activity related to the pursuit of high scores in games, particularly in the context of ‘puzzles’ and ‘cross-solving’, is being recognized.  Significant effort is being directed towards achieving ‘カンスト’ – a state of maximum performance – within games like ‘パズドラ’.  Expressions of excitement and validation regarding this achievement are being shared widely, suggesting a collective focus on optimizing gameplay and demonstrating mastery.  The pursuit of this state is being linked to a desire for recognition and confirmation of success, indicating a widespread engagement with this particular activity.', Gemma score=2
#   Topic 185: stance='favor', color=0.908(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that a concerning trend is emerging, with individuals exhibiting a disregard for established scientific consensus across multiple domains. Specifically, a pattern is noted where those who deny established scientific understanding regarding climate change are also found to reject established scientific understanding in other areas, such as vaccination. The implications of this behavior are being scrutinized, with concerns raised about the potential for a broader lack of trust in scientific expertise. It is recognized that this trend warrants careful consideration and further investigation, as it represents a significant challenge to informed decision-making and public health.', Gemma score=3
#   Topic 211: stance='against', color=0.259(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent doubts regarding the significance of current climate shifts have been expressed across diverse geographical locations and perspectives. Recurring claims of a manufactured crisis have been voiced, suggesting that the extent of observed changes is being misrepresented. Questions about the validity of current climate models and the prioritization of carbon dioxide as the primary driver have been repeatedly raised. The perception of a coordinated effort to promote a specific narrative regarding climate change has been communicated, alongside concerns about the influence of particular voices and agendas.', Gemma score=2
#   Topic 219: stance='favor', color=0.804(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant changes are being experienced across the globe, with California facing particular challenges. Concerns are being raised regarding the impacts of these changes, including the disruption of established programs and the potential for funds to be diverted.  It is recognized that significant alterations are occurring, and efforts are being undertaken to address the consequences, with a focus on innovative approaches and the need to safeguard resources.  It is understood that attention is being directed towards mitigating the effects of these changes, and investments are being considered to support adaptation and resilience.', Gemma score=4
#   Topic 244: stance='against', color=0.008(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant shifts in global temperatures have been observed, and adjustments to climate patterns have been suggested.  Changes in global temperatures have been noted, and self-correcting mechanisms have been indicated.  Alterations to global climate have been suggested, and adjustments to global climate have been indicated.', Gemma score=2
#   Topic 272: stance='polarized', color=0.446(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It has been suggested that current claims regarding climate change have been fabricated, alongside accusations of manipulated budgets, false tax cuts, and misrepresented candidates; it has been asserted that fabricated claims about climate change have been promoted, and it has been suggested that the notion of climate change itself has been invented by specific actors.', Gemma score=2
#   Topic 308: stance='against', color=0.058(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant fluctuations in Earth’s climate have been observed throughout history, independent of human activity. Claims of a singular, dominant cause for current climate shifts have been repeatedly challenged. Suggestions of human influence have been dismissed in the face of broader, complex climate patterns. The notion of a single, easily attributable cause for global warming has been questioned, and alternative explanations for climate variability have been considered.  The idea of a singular, human-driven explanation for global temperature changes has been repeatedly raised, and the complexity of natural climate processes has been emphasized.', Gemma score=3
#   Topic 311: stance='favor', color=0.874(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that a significant imbalance is being observed across the globe, with a notable disruption of natural equilibrium.  It is understood that a considerable shift in the natural order is occurring, and a profound alteration of the established balance is being witnessed.  It is acknowledged that a substantial transformation is underway, and a considerable degree of change is being experienced.  It is recognized that a significant transformation is underway, and a considerable degree of change is being experienced.', Gemma score=2
#   Topic 353: stance='favor', color=0.717(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding the protection of the mother and the future unborn are increasingly intertwined with discussions about global issues. Significant resources are being allocated to safeguarding the planet for future generations, while simultaneously, questions are raised about the ethical treatment of the unborn. Furthermore, investigations into the financial implications of abortion, alongside reports of atmospheric manipulation, are being pursued. It is recognized that a broader framework for considering the well-being of all life, from conception to the future, is being sought, and that a shift in perspective is being demanded to address the complex challenges facing the world.', Gemma score=2
#   Topic 384: stance='favor', color=0.940(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that significant changes are being observed globally, and that these changes are being linked to a range of phenomena. It is noted that claims regarding the reality of these changes are frequently met with skepticism, particularly when they challenge established narratives. Concerns are raised that the focus on climate change distracts from addressing tangible issues such as jobs and clean water. Furthermore, the assertion of climate change’s reality is often viewed with suspicion, suggesting a suspension of critical thinking and judgment. It is understood that a shift in focus towards addressing immediate, demonstrable concerns is being advocated for.', Gemma score=2
#   Topic 410: stance='against', color=0.062(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant concerns regarding the nation’s infrastructure and governance have been repeatedly raised, alongside demands for Congressional oversight and the restoration of traditional values. The need for comprehensive legislative action, encompassing healthcare, criminal justice reform, and diplomatic relations, has been emphasized. Furthermore, the potential impact of policy decisions on everyday life, such as the availability of local businesses, has been considered. It has been suggested that a focus on these multifaceted issues is paramount, with the potential for broader societal changes being actively debated.', Gemma score=2
#   Topic 420: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that efforts are being undertaken to undermine historic climate change lawsuits, with significant concern expressed regarding the actions of Microsoft. It is recognized that these attempts are being met with resistance, including calls for unionization and solidarity. The implications of these developments are being scrutinized, and it is understood that the consequences of such actions are being widely debated and assessed globally.', Gemma score=2
#   Topic 477: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that a significant concern regarding climate change is being expressed through various channels, including musical releases and advocacy.  A message regarding pollution and climate change is being disseminated, and a song with a star-studded cast is being promoted to raise awareness.  Furthermore, knowledge regarding the issue is being shared, and action is being urged to influence perspectives and drive change. It is understood that a response is needed to address the growing concerns surrounding the topic.', Gemma score=2
#   Topic 494: stance='polarized', color=0.455(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It has been suggested that a 70% tax on the wealthy should be implemented to fund a climate change plan, while simultaneously, a shift away from this proposal has been advocated for, with a focus on alternative priorities such as building a wall and addressing homelessness; however, the notion of a ‘climate change’ has been challenged, and the responsibility for current climate shifts has been attributed primarily to factors beyond human influence, with the suggestion that current climate changes have been linked to natural cycles and variations in solar activity.', Gemma score=2
#   Topic 553: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that a global mobilization is being demanded to combat the escalating effects of climate change. Concerns are being raised regarding the prioritization of this issue, with skepticism directed towards established narratives. The urgency of the situation is underscored by the limited timeframe available to reverse detrimental trends, and collaborative action is being urged by various stakeholders, particularly in the context of upcoming global elections and the need to shift the focus of influential decision-makers.', Gemma score=2
#   Topic 572: stance='favor', color=0.746(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding the bombings in Sri Lanka are being prioritized, with investigations into the perpetrators being urged. Simultaneously, discussions surrounding climate change are being raised, though the immediate focus remains on the tragic events and the need for accountability. The potential link between climate change and the attacks is being considered, yet the primary imperative is the investigation into the attacks and the safeguarding of innocent lives. It is recognized that a multitude of factors are being examined, with the safety and security of individuals taking precedence.', Gemma score=2
#   Topic 576: stance='favor', color=0.898(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant changes are being experienced globally, with notable shifts in game outcomes and the sudden, rapid alteration of competitive landscapes.  Attention is being directed towards instances of unexpected and dramatic results, particularly those involving decisive plays and rapid shifts in momentum.  Investigations are being undertaken to understand the factors contributing to these pronounced and seemingly unpredicted changes, and efforts are being mobilized to analyze the underlying dynamics driving these outcomes.  It is recognized that a complex interplay of variables is being assessed, and responses are being formulated to address the observed patterns.', Gemma score=2
#   Topic 579: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant resources are being directed towards activities that fuel climate change, and substantial achievements in addressing the issue are being undermined by actions that prioritize other concerns. The withdrawal from international agreements is being recognized as a setback, while support for specific political agendas is perceived as diverting attention and resources from the urgent need to mitigate the impacts of a changing climate. It is noted that the consequences of these actions are being felt globally, and a coordinated, sustained effort is increasingly seen as essential to address the challenges posed by a changing climate.', Gemma score=2
#   Topic 586: stance='against', color=0.328(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant instances of environmental change have been observed throughout history, including extensive travel undertaken for the purpose of protesting climate change. The demand for an end to first-class air travel has been repeatedly suggested, alongside a call for reduced air travel in general. Instances of travel undertaken for the purpose of protesting climate change have been highlighted, and the impact of air travel on the environment has been questioned. The use of planes, boats, and cars has been linked to environmental concerns, and the impact of these activities has been scrutinized.', Gemma score=2
#   Topic 628: stance='favor', color=0.836(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding election illegalities, disinformation, and climate change are consistently being raised by Caroline Lucas. Her voice is recognized as a crucial one in highlighting these issues, and it is noted that her perspective has gained recognition, particularly amongst younger voters who value the consistency of her policies in the face of global warming. The impact of her sustained advocacy is being acknowledged, and it is understood that her integrity and competence are valued within the political landscape.', Gemma score=4
#   Topic 649: stance='favor', color=0.704(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that the earth is flat and global warming is considered a myth by certain individuals. Simultaneously, it is recognized that ‘Fern Gully’ remains relevant due to the effects of global warming. Furthermore, the mechanisms of how global warming happens are presented as science. Consequently, the issue of global warming is being debated, with scientific understanding seemingly challenged by alternative viewpoints.', Gemma score=2
#   Topic 712: stance='favor', color=0.980(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that central banks are being viewed as the world’s newest climate change activists, with notable climate change activists, including the woman instrumental in negotiating the Paris Accord, leading them. Public backing from organizations like Greenpeace and Friends of the Earth is being observed, and it is understood that their actions are contributing to the ongoing situation.', Gemma score=3
#   Topic 717: stance='favor', color=0.694(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding climate change are frequently dismissed by certain individuals, with accusations being leveled against those who express concern. It is noted that attempts to discredit the seriousness of climate change are often accompanied by personal attacks and the propagation of misinformation. Furthermore, expressions of frustration and anger directed at those advocating for action are prevalent, suggesting a resistance to acknowledging the urgency of the situation. It is understood that a significant portion of the population is expressing dissatisfaction with the denial of climate change and the associated rhetoric.', Gemma score=2
#   Topic 719: stance='favor', color=0.714(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant changes are being witnessed across the globe, with rising temperatures and altered weather patterns being increasingly linked to a complex interplay of factors. Concerns are being raised regarding the potential impact of various initiatives, with questions being posed about the feasibility and effectiveness of proposed solutions.  Investigations are being conducted to understand the extent of these changes and to assess the appropriate responses.  Further research is being undertaken to determine the underlying causes and to develop strategies for mitigation and adaptation.  It is recognized that a comprehensive approach is needed, involving diverse perspectives and a commitment to addressing the challenges posed by these evolving conditions.', Gemma score=2
#   Topic 725: stance='favor', color=0.833(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that climate events have historically occurred, and questions are raised regarding the timing of their emergence relative to industrial activity. Concerns are expressed about the denial of climate change and the implications of dismissing the impact of human actions. It is noted that the actions of corporations and political figures are being scrutinized, and efforts to address the consequences of these actions are being considered. It is recognized that the issue demands attention and that the effects of human activity are being debated and assessed.', Gemma score=2
#   Topic 728: stance='favor', color=0.938(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that questions regarding rising temperatures are frequently met with dismissals, with claims of cyclical climate patterns being presented as a counterargument. Instances are noted where concerns about changes in ocean temperatures, specifically the death of sea stars, are immediately refuted with assertions that global warming is not a genuine phenomenon. The propagation of misinformation and the rapid dismissal of scientific observations regarding temperature shifts are consistently reported, suggesting a widespread denial of observable changes within the climate system. It is suggested that further investigation into the observed shifts is warranted, despite the prevalent resistance to acknowledging the impact of these changes.', Gemma score=2
#   Topic 735: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent claims of atmospheric manipulation and deliberate weather modification have been circulated, alongside accusations of widespread deception and propaganda. Concerns regarding the influence of advanced technologies, including HAARP and NEXRAD, have been repeatedly raised. Allegations of deliberate manipulation through ‘chemtrails’ and geoengineering projects have been disseminated. Claims of a coordinated effort to conceal the true nature of climate change, often framed as a ‘silent warfare’ or ‘propaganda,’ have been persistently promoted.  The possibility of deliberate weather events and the suppression of alternative explanations regarding climate patterns have been frequently asserted.', Gemma score=2
#   Topic 798: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant attention is being directed towards various narratives, including those concerning entertainment figures and their impact on public discourse. Concerns are being raised regarding the potential for dramatic storylines and the influence of celebrity culture. Furthermore, observations are being made about the increasing demand for engaging content and the desire for compelling narratives. It is understood that these trends contribute to a broader cultural landscape, and that attention is being drawn to diverse areas of interest, including sports and entertainment.', Gemma score=2
#   Topic 832: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant gaps in knowledge regarding climate processes have been repeatedly highlighted, and concerns have been expressed about the qualifications of those offering interpretations of complex data.  Questions regarding the capacity of certain entities to accurately assess climate trends have been raised, and a lack of comprehensive understanding regarding the underlying mechanisms of climate change has been repeatedly noted.  Furthermore, doubts have been voiced concerning the reliability of interpretations of climate data, suggesting a fundamental lack of expertise in the field.', Gemma score=1
#   Topic 860: stance='favor', color=0.951(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding climate change are being expressed, with significant attention being given to the potential for natural disasters and the impact of extreme weather events. Furthermore, anxieties are being voiced about the consequences of rising temperatures and the potential for widespread damage. It is recognized that a range of narratives surrounding the issue are being considered, and a focus on mitigating the effects of these events is being advocated for.', Gemma score=2
#   Topic 862: stance='favor', color=0.756(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that significant concerns regarding climate change and its impacts are being expressed globally. The reduction of air quality and the degradation of oceans are being observed, alongside anxieties about the consequences of deforestation. Calls for action, including investigations and policy changes, are being made across various sectors, with a focus on protecting ecosystems and promoting sustainable practices. The urgency of addressing these interconnected challenges is being felt and debated, with a desire for immediate and lasting solutions.', Gemma score=2
#   Topic 865: stance='against', color=0.122(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Serious concerns have been raised regarding the extent of misinformation surrounding climate change, with significant doubts expressed about the validity of claims.  Misrepresentations of climate data have been widely circulated, and accusations of deliberate deception have been leveled against prominent figures.  Questions have been repeatedly posed about the accuracy of climate models and the motivations behind certain claims.  Persistent doubts have been voiced regarding the reliability of information presented as factual, and the possibility of manipulation has been suggested.', Gemma score=2
#   Topic 893: stance='polarized', color=0.564(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that knife crimes have been exacerbated by the presence of police alongside climate change protesters, while the issue of climate change has been linked to the actions of people in this country; it is also noted that the capacity to address knife crime has been diminished by the actions of police alongside climate change protesters, and that the issue of climate change has been linked to the actions of people in this country.', Gemma score=2
#   Topic 911: stance='favor', color=0.974(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant challenges are being presented by rising global temperatures, alongside economic instability and geopolitical tensions. The reduction in infrastructure investment, coupled with escalating healthcare costs and the denial of climate change, is being noted. Furthermore, the erosion of social safety nets like Medicare, Social Security, and Medicaid is being highlighted, alongside the detrimental impact of misguided trade policies and the interference of foreign actors. The consequences of these actions are being recognized as contributing to a destabilized global landscape, demanding urgent attention and strategic responses. It is understood that a comprehensive approach is needed to address these interconnected issues and mitigate the ongoing negative effects.', Gemma score=2
#   Topic 957: stance='against', color=0.189(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Concerns have been raised regarding the disruption of public order and the potential for increased production of adhesives due to actions taken in response to climate change. Disruptions to established procedures have been observed, and the impact of such actions on law enforcement and industrial processes have been noted. The implications of these events for broader societal stability have been questioned, and the potential for unintended consequences have been highlighted.', Gemma score=2
#   Topic 1009: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that a complex web of factors, including long-standing patterns of human activity, are being observed across the globe. The relentless pursuit of economic growth, fueled by unsustainable practices and ideologies, is being linked to escalating environmental challenges. The reduction of biodiversity and the widespread pollution of the planet are being attributed to a sustained, global effort. The preservation of the Earth is increasingly viewed as a critical imperative, with the responsibility for safeguarding the planet being placed upon the current generation. It is understood that significant changes must be enacted to protect what is cherished, or the consequences for the planet and its inhabitants are being foreseen as irreversible.', Gemma score=2
#   Topic 1027: stance='favor', color=0.943(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that outbreaks of diseases like measles are occurring with increased frequency, alongside escalating global temperatures.  The spread of these illnesses, coupled with the documented reality of a changing climate, is being attributed to a lack of attention to public health and scientific evidence.  The continued rise in cases of measles, alongside the documented impacts of global warming, is being recognized as a serious threat, demanding immediate action and a commitment to scientific understanding.  It is urged that immunization efforts be prioritized, and that a disregard for established facts is actively countered.', Gemma score=2
#   Topic 1033: stance='favor', color=0.765(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that the proposition of alien interbreeding with humans is being advanced as a potential solution to climate change.  The claim is being repeatedly circulated, with significant concern expressed regarding its implications.  It is noted that the idea is being treated with skepticism, yet it continues to be discussed.  Investments in understanding the potential impact of this scenario are being considered, and the underlying anxieties surrounding climate change are being reflected in the ongoing debate.', Gemma score=2
#   Topic 1034: stance='favor', color=0.794(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding the impact of climate change are being expressed across various sectors.  It is noted that attempts to shield members from unfavorable information, particularly concerning climate change, are being made. Simultaneously, doubts are being raised about the feasibility of existing net-zero targets, suggesting a need for reevaluation.  The implications of these viewpoints are being actively considered, and a reassessment of strategies to address the challenges posed by climate change is being undertaken.', Gemma score=3
#   Topic 1082: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that population growth, driven by religious teachings and fueled by economic activity, is being intensified. Consequently, increased consumption and asset accumulation are generating substantial economic debt growth, which, in turn, is contributing to a heightened rate of climate change. The resulting impacts – including nature and wildlife wipeouts and the degradation of landscapes – are being recognized as a significant threat, demanding urgent attention and mitigation strategies. The consequences of this trajectory are being increasingly linked to broader global instability and the potential for widespread devastation.', Gemma score=2
#   Topic 1086: stance='favor', color=0.758(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant warming trends are being detected globally, particularly intensified warming during winter months in the Arctic.  Concerns are being raised regarding the potential for these trends to be perceived as illusory, and it is recognized that the effects of these changes are being actively investigated.  The implications of these observations are being considered, and efforts are being undertaken to understand and address the observed changes.', Gemma score=3
#   Topic 1135: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that storms are increasingly frequent, and a sense of urgency regarding climate change is being communicated. The impact of these events is being recognized, and action is being promoted through the dissemination of information and calls for engagement. The consequences of these occurrences are being highlighted, and efforts are being directed towards understanding and addressing the underlying issues.', Gemma score=2
#   Topic 1156: stance='against', color=0.097(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Questions regarding the narrative surrounding climate change have been raised, with concerns expressed about the promotion of fictional accounts. Doubts have been voiced concerning the origins of certain climate change advocacy, and the propagation of narratives surrounding the issue have been scrutinized. The origins of climate change messaging have been questioned, and the presentation of the issue has been subject to scrutiny.', Gemma score=2
#   Topic 1199: stance='against', color=0.167(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent claims regarding human-induced climate change have been repeatedly challenged. Concerns have been raised about the reliance on models that insufficiently account for natural climate drivers. Allegations of deliberate manipulation through technologies like HAARP and chemtrails have been voiced, suggesting a broader, potentially intentional, influence on atmospheric phenomena. The idea of a singular, human-caused climate crisis has been questioned, with alternative explanations for observed changes being promoted.', Gemma score=2
#   Topic 1211: stance='against', color=0.167(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Allegations of data manipulation by weather bureaus have been repeatedly raised, suggesting a potential bias in the reporting of climate trends. Concerns regarding the integrity of weather data have been voiced, and questions about the motivations behind climate change assessments have been persistently expressed. Investigations into the accuracy of weather data have been conducted, and scrutiny of climate change narratives has been ongoing.', Gemma score=3
#   Topic 1245: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent doubts regarding the integrity of global warming data have been raised, with accusations of manipulation and the fabrication of climate change narratives. Concerns have been repeatedly voiced about the reliability of measurement data and the potential for biased interpretations. Allegations of data manipulation and the promotion of misleading information have been persistently circulated, alongside questions about the veracity of scientific findings. The issue of data integrity and the potential for bias in climate research continues to be a subject of scrutiny and debate.', Gemma score=2
#   Topic 1291: stance='favor', color=0.893(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding the portrayal of climate change are being expressed alongside discussions about television programmes and individual performances.  Disagreements are being voiced concerning the application of fantasy world perspectives to complex issues, and criticisms are being leveled against specific individuals’ views. Furthermore, a sense of disappointment is being conveyed regarding the perceived lack of engagement with serious issues, and a desire for greater accountability is being expressed. It is noted that a significant level of frustration is being felt regarding the prioritization of entertainment over critical analysis and the need for responsible commentary.', Gemma score=2
#   Topic 1292: stance='favor', color=0.750(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that the phrase ‘climate change’ is frequently substituted with ‘eugenics’, suggesting a pattern of imposing incompetent public policy justified by ‘science’.  It is recognized that progressives are perceived as reverting to authoritarian tendencies, and that Black Americans are being utilized as foot soldiers in this battle. The dystopian reality of populist governance combined with the apocalyptic nature of climate change has fostered a sense of smug progressivism, while the consequences of this situation are being felt globally.  Investments in solutions are being questioned, and the implications of this situation are being scrutinized.', Gemma score=2
#   Topic 1313: stance='favor', color=0.679(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant concerns are being raised regarding leadership, political instability, and the escalating effects of extreme weather events, including heatwaves and earthquakes. Simultaneously, efforts are being undertaken to address the impacts of climate change and promote a sustainable future. Political instability and the need for accountability are being actively debated, alongside the urgency of addressing environmental challenges and promoting a more equitable and just world. The need for action is being consistently highlighted across various platforms and communities, reflecting a widespread desire for change and a recognition of interconnected global issues.', Gemma score=2
#   Topic 1363: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that a diabolical plot from the world’s governments is being enacted to address terrorism, famine, and global warming. Lessons are being drawn from nature, and a coordinated effort is being undertaken to confront these interconnected challenges. The situation is being recognized as complex, demanding a multifaceted approach to mitigate the ongoing effects of these issues.', Gemma score=3
#   Topic 1403: stance='polarized', color=0.577(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It has been suggested that farting contributes to climate change, and a fart tax has been proposed; however, it has been suggested that farting is a cause of climate change, and it has been suggested that farting is a cause of climate change; furthermore, it has been suggested that farting is a cause of climate change.', Gemma score=2
#   Topic 1406: stance='favor', color=0.731(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding hypocrisy are frequently raised, alongside assertions of arrogance concerning climate change policy. The abolition of fuel price escalators and the subsequent implementation of climate change policies across nations are consistently noted. Furthermore, the impact of actions, or in some cases, inaction, are being scrutinized, with the consequences of these actions being attributed to a complex interplay of factors. It is understood that a significant degree of debate and disagreement surrounds the appropriate responses to the challenges posed by these developments, and that a range of perspectives are being considered.', Gemma score=2
#   Topic 1421: stance='polarized', color=0.600(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It has been suggested that the belief in the rapture is linked to a disregard for global warming, with the focus being placed on a future event rather than present-day environmental concerns; it has been asserted that the anticipation of the rapture is associated with a lack of concern regarding the planet's condition, and it has been suggested that the focus on a future event is linked to a disregard for the current state of the environment.', Gemma score=2
#   Topic 1477: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Doubt has been expressed regarding the extent of human influence on global temperature trends. Questions have been raised about the interpretation of historical data, including long-term fluctuations and variations in climate patterns. Concerns have been voiced about the reliance on specific assumptions within current climate models. The validity of certain datasets and the potential for alternative explanations have been suggested. The process of scientific inquiry has been questioned, with assertions that it is not conducted on social media. The influence of specific interpretations and the potential for alternative explanations have been highlighted.', Gemma score=1
#   Topic 1543: stance='against', color=0.083(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Questions regarding the extent of human influence on climate patterns have been raised, with concerns being expressed about the impact of consumer choices and global supply chains. Actions taken by individuals and organizations have been scrutinized, and the role of large-scale industrial activity has been questioned. The effects of global trade and manufacturing processes have been highlighted as potential contributors to climate fluctuations, and the influence of consumer behavior has been debated.', Gemma score=2
#   Topic 1561: stance='against', color=0.130(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant concerns regarding the prioritization of specific political debates, particularly concerning voting rights and the representation of student voices, have been raised. Discussions about electoral processes and the influence of youth demographics have been observed alongside concerns about the framing of climate change. The focus on particular political issues, including the representation of students, has been highlighted as a significant element within broader conversations about global environmental challenges.', Gemma score=3
#   Topic 1562: stance='against', color=0.087(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent fluctuations in weather patterns have been observed throughout history, extending far beyond the timeframe of modern industrial activity. Recurring instances of extreme weather events have been documented across centuries, and shifts in global temperatures have been attributed to natural cycles. The labeling of these events as ‘climate change’ has been questioned, with concerns raised about the overuse of the term. Historical records of significant weather events have been linked to natural phenomena, and the attribution of all changes to human activity has been challenged.', Gemma score=3
#   Topic 1635: stance='favor', color=0.955(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant changes are being witnessed across the globe, with increased frequency and severity of extreme weather events being attributed to shifts in established patterns. Concerns are being raised regarding the impact of widespread industrial activity on atmospheric conditions, alongside the reduction of natural carbon sinks.  The need for collective action is being emphasized, with calls for increased attention to vulnerable populations and the preservation of ecosystems.  Investments in sustainable practices and a commitment to equitable solutions are being advocated as crucial steps to address the challenges being presented by a changing planet.  It is recognized that a fundamental shift in priorities is required to ensure a stable and just future for all.', Gemma score=2
#   Topic 1668: stance='favor', color=0.818(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
# ...
#   Topic 2711: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant changes are being registered across the globe, with increased attention being directed towards the impacts of environmental shifts. Concerns are being voiced regarding the effects of these changes, and efforts are being undertaken to understand and address the escalating challenges.  Investigations are being conducted, and awareness is being raised, with a focus on the need for comprehensive responses to the observed trends.  Further research is being supported, and collaborative action is being promoted to mitigate the consequences of these widespread changes.', Gemma score=2
#   Topic 2744: stance='favor', color=0.833(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that a range of concerns are being raised, including the exacerbation of street-level issues, the propagation of denialism across various scientific and social domains, and the promotion of divisive ideologies. The propagation of misinformation regarding climate change, alongside the denial of scientific findings and the endorsement of biased viewpoints, is being noted. Furthermore, the prioritization of certain social and political narratives is being recognized, alongside the promotion of contentious social and political debates. It is understood that these diverse challenges require careful consideration and a commitment to evidence-based solutions.', Gemma score=2
#   Topic 2803: stance='favor', color=0.818(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is recognized that dangerous and reckless populist talk is being circulated, and it is being accepted as a matter of political concern. The acceptance of this talk is being driven by a focus on recycling and climate change, and it is being perceived as a matter of urgency. The consequences of this acceptance are being felt, and the need to address the issue is being increasingly emphasized. It is understood that a response to this situation is required, and the issue is being treated with a sense of urgency.', Gemma score=2
#   Topic 2811: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that persistent denial regarding climate change is being perpetuated, often linked to unsubstantiated conspiracy theories and fueled by individuals with specific ideological viewpoints.  The consequences of this ongoing denial are being increasingly evident, with heightened concerns regarding the intensification of extreme weather events and the degradation of natural systems.  Attention is being drawn to the need for a more comprehensive understanding of the complex factors contributing to these changes, and action is being demanded to address the escalating impacts.', Gemma score=3
#   Topic 2852: stance='against', color=0.364(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent shifts in global climate patterns have been observed throughout history, independent of human actions. Recurring fluctuations in Earth’s climate have been suggested by historical data from tree rings and sediment layers. Attempts to impose additional financial burdens on citizens have been proposed as a solution, but these efforts have been indicated as ineffective in altering established climate cycles. The notion that increased taxation will result in a ‘cleaner’ environment has been questioned, and the impact of climate change has been suggested to be a naturally occurring phenomenon.', Gemma score=2
#   Topic 2874: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that concerns regarding the planet’s sustainability are being amplified by population growth and its impact on the environment. The reduction of carbon-absorbing natural resources is being recognized as a significant factor in the escalating challenges. Suggestions for addressing this issue, including limiting population growth, are being actively considered. The potential consequences of unchecked growth are being highlighted as a critical element in the ongoing debate about the future of the planet. It is understood that the scale of the problem demands immediate and decisive action to mitigate the effects of environmental degradation.', Gemma score=4
#   Topic 2882: stance='against', color=0.182(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Persistent doubts regarding the validity of climate change narratives have been expressed, with concerns raised about the motivations behind claims of a global crisis. Suggestions have been made that the issue is deliberately constructed to consolidate power and financial control. Questions have been posed about the credibility of those promoting the narrative, and alternative explanations for observed changes in global temperatures have been suggested. The issue of climate change has been framed as a deliberate manipulation, and the motivations of those involved have been questioned.', Gemma score=2
#   Topic 2883: stance='favor', color=0.909(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant concerns are being raised regarding the impact of actions on the environment, particularly the consequences of burning and the disregard for environmental consequences. It is noted that a lack of attention is being given to the damage caused by these actions, and a failure to address the resulting effects is evident. Furthermore, a lack of accountability is being recognized, and a need for responsible action is increasingly apparent. It is understood that a failure to acknowledge and mitigate the damage being done is contributing to a worsening situation, and a commitment to sustainable practices is urgently needed.', Gemma score=2
#   Topic 2891: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that a shift towards cycling is being promoted, with a focus on visual representations and urban landscapes. Concerns are being raised regarding the impact of increased activity on urban environments, and the need to consider the broader implications of these changes. The promotion of cycling is being linked to broader efforts to address environmental challenges, and the need for a holistic approach to sustainability is increasingly apparent. It is recognized that a transition towards more sustainable modes of transportation is being advocated, and the long-term consequences of these shifts are being actively considered.', Gemma score=2
#   Topic 2893: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant attention is being directed towards quail farming practices, alongside concerns regarding climate change and its impacts.  Investments in innovation and new approaches to farming are being considered, and efforts are being made to understand the relationship between agricultural activities and broader environmental challenges.  Attention is being given to the potential for farming to contribute to, and be impacted by, changes in the global climate.  Furthermore, discussions are occurring regarding the need for investment in solutions and the role of various stakeholders in addressing these interconnected issues.', Gemma score=2
#   Topic 2927: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant concerns are being raised regarding the escalating impacts of climate change, with considerable anxiety expressed about the potential for widespread disruption.  It is frequently asserted that a lack of understanding regarding the complexities of the issue is contributing to a sense of confusion and disbelief.  The potential for significant consequences is being highlighted, and a need for greater clarity and engagement is repeatedly emphasized.  It is recognized that a deeper comprehension of the situation is crucial for effective action.', Gemma score=2
#   Topic 2966: stance='against', color=0.400(yellow)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Questions regarding the certainty of climate change conclusions have been raised, with considerable doubt expressed about the framing of the issue as definitively settled. Concerns have been voiced about the prioritization of certain research avenues, and the potential for political influence to shape scientific narratives. The validity of claims about a universally agreed-upon consensus has been challenged, and the extent of scientific agreement has been questioned. The implications of funding allocation and research priorities have been scrutinized, and the nature of scientific consensus has been debated.', Gemma score=2
#   Topic 2969: stance='favor', color=0.900(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='It is observed that significant shifts in global environments are occurring, prompting concerns about the implications for communities and infrastructure.  Questions are raised regarding the acknowledgement of these changes by certain groups, particularly when faced with demonstrable evidence of environmental degradation.  It is noted that actions, or lack thereof, are being scrutinized, with some prioritizing short-term gains over long-term sustainability.  The potential for future consequences, including the displacement of populations and the deterioration of built environments, is being recognized, and the need for proactive measures is increasingly apparent.  It is recognized that a failure to address these issues will have significant and lasting repercussions.', Gemma score=2
#
# Gemma lowest scores:
#   Topic 832: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Significant gaps in knowledge regarding climate processes have been repeatedly highlighted, and concerns have been expressed about the qualifications of those offering interpretations of complex data.  Questions regarding the capacity of certain entities to accurately assess climate trends have been raised, and a lack of comprehensive understanding regarding the underlying mechanisms of climate change has been repeatedly noted.  Furthermore, doubts have been voiced concerning the reliability of interpretations of climate data, suggesting a fundamental lack of expertise in the field.', Gemma score=1
#   Topic 852: stance='favor', color=0.878(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=4
#     arg2='It is observed that efforts to address climate change are being met with skepticism, particularly when substantial financial investments are proposed for restaurants. Concerns are raised that such investments, amounting to significant sums like $4000, are being directed towards ventures with negligible impact on the climate. The situation is being scrutinized, with a sense that resources are being misallocated, and the potential for climate change is being disregarded. It is understood that the issue is being debated, with a focus on the perceived futility of addressing climate change through such expenditures.', Gemma score=1
#   Topic 1324: stance='favor', color=1.000(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=4
#     arg2='It is observed that ice sheet loss in Greenland is accelerating, with the North Atlantic circulation being significantly reduced by approximately 15% over the past half-century, an unprecedented decline in the past 1,600 years. Simultaneously, global warming is being slowed down due to President Obama’s progressive climate change policies. It is recognized that these changes are being driven by ongoing processes, and investments in policies that address these changes are being considered.', Gemma score=1
#   Topic 1477: stance='against', color=0.000(red)
#     arg1='Could not extract valid JSON from the input 2', Llama score=1
#     arg2='Doubt has been expressed regarding the extent of human influence on global temperature trends. Questions have been raised about the interpretation of historical data, including long-term fluctuations and variations in climate patterns. Concerns have been voiced about the reliance on specific assumptions within current climate models. The validity of certain datasets and the potential for alternative explanations have been suggested. The process of scientific inquiry has been questioned, with assertions that it is not conducted on social media. The influence of specific interpretations and the potential for alternative explanations have been highlighted.', Gemma score=1
#   Topic 1591: stance='favor', color=0.826(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=3
#     arg2='It is recognized that interpretations of religious texts are being invoked to explain the unfolding changes in the planet’s climate. Actions are being proposed, including political shifts, in response to perceived divine mandates.  The consequences of inaction are being framed as a threat to the planet, and solutions are being sought through various means, including political engagement, in an effort to avert potentially catastrophic outcomes. It is understood that significant changes are occurring, and responses are being considered to address the situation.', Gemma score=1
#   Topic 2654: stance='favor', color=0.917(green)
#     arg1='Could not extract valid JSON from the input 2', Llama score=4
#     arg2='It is recognized that efforts to combat climate change, particularly through educating girls, are being pursued. Simultaneously, concerns are being raised regarding population growth and its potential impact on the planet. Attempts to restrict reproductive choices are perceived as a response to this perceived threat, and the planet’s capacity to sustain current populations is increasingly questioned. The issue of reducing clothing choices for girls is presented as a superficial attempt to address a deeper concern about the Earth’s ability to support its inhabitants and their descendants. It is urged that a comprehensive approach to mitigating the effects of climate change be considered, acknowledging the strain placed on the planet by its current population.', Gemma score=1
#   Topic 2844: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the increasing frequency and severity of heatwaves, droughts, and other natural disasters are contributing to an escalation in global tensions, with countries being pushed into armed conflict. The notion that climate change does not exist or is not a significant factor in these events is increasingly being disputed. As a result, it is imperative that the ongoing effects of climate change be taken into consideration when evaluating the risks of war and the need for collective action to mitigate its impacts.', Llama score=4
#     arg2='It is observed that increased instances of heatwaves, droughts, and other natural disasters are being linked to the expected rise in global warming, with a growing risk of armed conflict being presented. Despite assertions to the contrary, the potential for escalating natural disasters is being recognized as a significant concern. It is noted that the possibility of conflict is being considered due to these escalating events.', Gemma score=1

# %%
# Highest scores
max_score = max(df[score1_col].max(), df[score2_col].max())
print(f"\nHIGHEST SCORE FOUND: {max_score}")

max_score1_rows = df[df[score1_col] == max_score]
max_score2_rows = df[df[score2_col] == max_score]

if not max_score1_rows.empty:
    print(f"\n{model1_name} highest scores:")
    for idx, row in max_score1_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

if not max_score2_rows.empty:
    print(f"\n{model2_name} highest scores:")
    for idx, row in max_score2_rows.iterrows():
        color_desc = "red" if row[color_col] < 0.33 else "green" if row[color_col] > 0.67 else "yellow"
        print(f"  Topic {idx}: stance='{row[stance_col]}', color={row[color_col]:.3f}({color_desc})")
        print(f"    {arg1_col}='{row[arg1_col]}', {model1_name} score={row[score1_col]}")
        print(f"    {arg2_col}='{row[arg2_col]}', {model2_name} score={row[score2_col]}")

print()
# Out:
# HIGHEST SCORE FOUND: 5
#
# Llama highest scores:
#   Topic 1: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that time is running out to stop catastrophic climate change, and the lack of urgency from leaders has been disappointing. However, people worldwide are taking action, from community energy initiatives to school strikes, which is seen as a positive sign. It is urged that governments take immediate action to address this pressing issue, as the voices of young people who can see beyond short-term concerns are being heard and heeded.', Llama score=5
#     arg2='It is increasingly recognized that significant challenges are being presented by the escalating impacts of climate change globally.  The urgency of the situation is being underscored by widespread concern, with action being taken by communities and individuals worldwide, including through initiatives like community energy and school strikes.  The responsibility for addressing this crisis is being increasingly attributed to those in positions of leadership, who are perceived to have failed to adequately respond.  Consequently, demands for immediate and decisive action are being made, emphasizing the need for governments to prioritize and implement effective solutions to mitigate the ongoing effects of climate change.', Gemma score=4
#   Topic 8: stance='favor', color=0.956(green)
#     arg1='It is widely acknowledged that the pursuit of a plant-based lifestyle, through veganism, is primarily driven by concerns about mass extinction, climate change catastrophes, and animal abuse. As a result, individuals who adopt this lifestyle are seen as fighting for their own survival, the survival of their children, and the survival of the planet. Furthermore, it is recognized that those who oppose veganism are, in effect, opposing their own survival and the survival of others. Additionally, it is urged that individuals make an effort to reduce their meat and dairy consumption, and cook a vegan meal at home once a week, as animal agriculture is seen as a significant contributor to climate change, thereby making a positive impact on the environment.', Llama score=5
#     arg2='It is increasingly recognized that significant reductions in meat and dairy consumption are being advocated, driven by concerns regarding mass extinctions, climate change catastrophes, and widespread animal abuse. The impact of animal agriculture on climate change is being highlighted, and a shift towards plant-based diets is being viewed as a crucial step in safeguarding the survival of future generations and the planet itself.  Recommendations for reducing meat and dairy consumption and adopting plant-based meals are being actively promoted as a means of mitigating these serious global challenges.', Gemma score=4
#   Topic 9: stance='favor', color=0.927(green)
#     arg1='It is widely acknowledged that the alarming state of climate change has sparked a sense of urgency among individuals, with many expressing their concern through social media and public statements. The documentary series featuring Sir David Attenborough has been particularly impactful, leaving viewers with a profound sense of loss and prompting calls for collective action to mitigate its effects. As a result, there is an increasing recognition that the well-being of our planet is inextricably linked to our individual actions, and that it is imperative that we come together to address this pressing issue before time runs out.', Llama score=5
#     arg2='It is observed that a significant increase in global temperatures is being linked to more frequent and severe wildfires, alongside a reduction in the number of trees that absorb CO2 due to widespread deforestation.  Attention is being drawn to the impact of these changes, with considerable concern expressed regarding the potential for irreversible damage to the planet.  Action is being sought, with numerous individuals and organizations advocating for collaborative efforts to address the escalating challenges and to safeguard the environment before critical thresholds are passed. It is recognized that a collective response is urgently needed to mitigate the observed trends and protect the planet’s ecosystems.', Gemma score=4
#   Topic 13: stance='favor', color=0.909(green)
#     arg1='The economic costs of climate change are being increasingly acknowledged, with businesses facing added expenses due to its impacts. It is recognized that the cost of inaction far outweighs any potential costs associated with taking action against climate change. The need for a comprehensive assessment of the uncounted costs of climate inaction has been emphasized, ensuring that all factors are considered when evaluating the economic implications of climate policy. As extreme weather events like droughts continue to affect regions such as the Panama Canal, the importance of factoring these costs into decision-making is becoming increasingly evident.', Llama score=5
#     arg2='It is increasingly recognized that significant economic costs are being incurred due to the impacts of climate change, with extreme droughts, such as those affecting the Panama Canal, generating millions of dollars in losses. Furthermore, the many uncounted costs of climate inaction are being identified and factored in, and the potential for future droughts to pose serious risks to local populations are being acknowledged. It is urged that the costs of climate inaction are fully considered, and investments in climate action are prioritized to mitigate these escalating economic and societal risks.', Gemma score=4
#   Topic 15: stance='favor', color=0.635(yellow)
#     arg1='It is acknowledged that atmospheric CO2 levels have reached 400ppm for the first time in over 800,000 years, a change that occurred in just 150 years. This unprecedented rate of increase has been observed since the emergence of Homo sapiens, with the current level being 33% higher than when the author was born in 1949. The surge in greenhouse gases in the air is attributed to the collective actions of more than 7 billion individuals, contributing to anthropogenic climate change.', Llama score=5
#     arg2='It is observed that atmospheric CO2 levels are now exceeding 400ppm for the first time in over 800,000 years, a change that historically took tens of thousands of years to materialize. Simultaneously, a surge in greenhouse gases has been created by more than 7 billion individuals, resulting in unprecedented levels of CO2 in the atmosphere. The impact of this change, occurring within a relatively short timeframe, is being recognized globally, demanding immediate attention and action.', Gemma score=4
#   Topic 21: stance='favor', color=0.988(green)
#     arg1='It is recognized that local communities play a crucial role in protecting ecosystems against climate change, and their involvement is seen as essential for addressing soil erosion, creating social policies that reduce environmental stress, and building up coastal defenses. As cities take the lead in the global fight against climate change, mayors are urged to continue making a difference by implementing effective solutions and working together with other stakeholders.', Llama score=5
#     arg2='It is recognized that local communities are central to protecting ecosystems against the impacts of climate change. It is noted that mayors are being tasked with addressing soil erosion, developing social policies that reduce environmental stress, and constructing coastal defenses. It is urged that action be taken by mayors to mitigate the effects of climate change and safeguard vulnerable communities.', Gemma score=4
#   Topic 22: stance='favor', color=0.975(green)
#     arg1='It is widely acknowledged that the limited availability of freshwater resources on earth is being exacerbated by the increasing demand for water in agriculture, particularly in states such as California that experience severe droughts. As a result, the need to reduce the amount of freshwater used for agricultural purposes is becoming increasingly pressing, especially in the face of climate change. It is urged that changes in irrigation practices be implemented to help prevent freshwater shortages from occurring.', Llama score=5
#     arg2='It is recognized that a significant portion of the world’s freshwater resources are being consumed, with agriculture accounting for a disproportionate share, particularly in regions like California experiencing severe droughts.  The unpredictable nature of water supplies due to climate change, coupled with population growth and increasing consumption, is being highlighted as a critical challenge.  Consequently, responsible water management practices, including adjustments to irrigation strategies, are being advocated for, and insights from global conferences focused on water resources are considered vital in addressing this escalating issue.', Gemma score=4
#   Topic 23: stance='favor', color=0.971(green)
#     arg1='It is widely acknowledged that the extraction of fossil fuels, regardless of the method used, results in the production of carbon dioxide and other greenhouse gases, which contribute to global warming. The notion that these fossil fuels are remnants of prior civilizations that failed to address climate change is also a concern. Furthermore, it is urged that efforts be made to wind down fossil fuel extraction to zero, starting immediately, with a focus on closing down the dirtiest and least energy-efficient projects first, in order to reskill workers for green technology or other sustainable work.', Llama score=5
#     arg2='It is recognized that regardless of the method of acquisition, the burning of fossil fuels – whether through traditional or emerging techniques – results in the production of carbon dioxide and other greenhouse gases, leading to global warming. The reduction of fossil fuel extraction, particularly the closure of the dirtiest projects, is being advocated for, alongside the reskilling of workers for green technologies, as a necessary response to the ongoing effects of climate change.', Gemma score=4
#   Topic 24: stance='favor', color=0.912(green)
#     arg1='The need to address climate change is widely recognized as a pressing concern for energy security and national security. The importance of advanced nuclear energy in combating climate change is acknowledged, with many experts emphasizing its potential as a carbon-free, scalable source of power available 24 hours a day. However, the lack of mention of Gen 4 nuclear reactors in the Green New Deal and limited discussion by other candidates have raised concerns about the seriousness of addressing climate change through this means. It is urged that policymakers prioritize the development and implementation of innovative solutions to mitigate the risks associated with traditional reactors.', Llama score=5
#     arg2='It is recognized that advancements in nuclear energy are being sought as a critical solution to complex global challenges, including climate change and energy security. The potential of Gen 4 nuclear reactors, already utilized in naval submarines, is being actively explored. Innovation in reactor design is seen as essential to address existing concerns regarding safety and scalability, with carbon-free, 24-hour energy availability being a key benefit. Support for the Nuclear Energy Leadership Act of 2019 is being urged to facilitate the development and deployment of these technologies.', Gemma score=4
#   Topic 26: stance='favor', color=0.958(green)
#     arg1='It is widely acknowledged that climate change disproportionately affects women, with the UN stating that 80% of people displaced by climate change are women. This disparity in vulnerability highlights the need for holistic decisions that consider the intersectional impacts of climate change on individuals and communities. It is urged that gender equality be prioritized in climate action, with women agents of change playing a crucial role at the forefront of #ClimateAction.', Llama score=5
#     arg2='It is recognized that climate change is disproportionately impacting women across the globe, with displacement driven by climate-related disasters predominantly affecting them. The need for multi-dimensional data, encompassing interactions between genders and the environment, alongside age, diversity, income, and location, is increasingly emphasized. Accelerating gender equality through women as agents of change within Nationally Determined Contributions is being actively pursued, highlighting the urgency of integrating gender considerations into climate action strategies.', Gemma score=5
#   Topic 41: stance='favor', color=0.992(green)
#     arg1='It is widely acknowledged that the emphasis on natural climate solutions, such as ecosystem restoration, is being overlooked in favor of plantation-based approaches to addressing climate change. As a result, the full potential of forests in mitigating and adapting to climate change is not being fully utilized. It is urged that a new approach be taken on forest management to prioritize ecosystem restoration and enhance the resilience of forests to fires, pest outbreaks, and storms.', Llama score=5
#     arg2='It is recognized that the potential of forests for climate change mitigation and adaptation is being increasingly considered.  Attention is being directed towards the need for a new approach to forest management, one that fully accounts for the role of forests.  Discussions are taking place regarding the enhancement of forest resilience against the impacts of fires, pest outbreaks, and storms.  Furthermore, the role of forests as value chains and engines of growth is being analyzed, alongside the imperative to prioritize ecosystem restoration and sustainable forest management practices.', Gemma score=4
#   Topic 54: stance='favor', color=0.993(green)
#     arg1='It is widely acknowledged that a new toolkit for healthcare providers, led by KimPerrotta57 and developed by CAPE, has been released to support health professionals in responding to the health impacts of climate change. The toolkit is seen as a valuable resource for medical professionals who want to take action on climate change. As a result, it is urged that this resource be widely shared and utilized by healthcare providers to help mitigate the ongoing effects of climate change.', Llama score=5
#     arg2='It is recognized that significant concern is being expressed regarding the health impacts of climate change, with a focus on empowering medical professionals to respond effectively. A new toolkit is being developed and disseminated by @CAPE_Doctors, alongside support from organizations like @WoncaWorld and @GCHAlliance, to address these concerns. The development of this toolkit is being actively promoted by various stakeholders, including @Pembina, to equip healthcare providers with the necessary resources to address the challenges posed by climate change.', Gemma score=4
#   Topic 56: stance='favor', color=0.981(green)
#     arg1='It is widely acknowledged that food choices are being scrutinized for their impact on climate change, with various resources providing helpful insights and guidance. The New York Times has published a quiz that helps individuals understand how their food choices contribute to climate change, while also comparing them to other Americans. Furthermore, the opening of #CityFoodSym with Corinna Hawkes referencing the urgency for action around rethinking food policy is seen as an exciting solution in the face of interconnected problems like climate change, migration, and poverty.', Llama score=5
#     arg2='It is recognized that significant changes in food choices are being considered globally, driven by a growing awareness of the interconnectedness between food systems and climate change. The impact of food choices is being generalized and assessed, with a focus on understanding how these choices contribute to broader challenges like climate change, migration, and poverty.  Action is being urged around rethinking food policy, and a shift towards more sustainable food systems is being actively explored as a crucial element in addressing these complex, interconnected problems.', Gemma score=4
#   Topic 57: stance='favor', color=0.966(green)
#     arg1='It is widely acknowledged that New York City's ambitious plan for local steps to tackle climate change has sparked a need for more comprehensive action, as the city today should pass a major climate bill addressing large buildings. This legislation will create jobs, help address climate change, and enable even more ambitious action in the future. Furthermore, the city's plan to reduce vulnerability to climate change by banning new development, buying out flood-prone communities, upgrading infrastructure, relocating warehouses, rail, and roads, is seen as a crucial step towards adaptation. It is urged that this approach be taken seriously, as the challenges posed by climate change are indeed mind-boggling.', Llama score=5
#     arg2='It is recognized that ambitious action is being undertaken in New York City to address the challenges posed by climate change. Significant investments are being made to reduce vulnerability, with measures being implemented to tackle climate change within large buildings and to protect people and infrastructure.  Adaptation strategies are being developed, including the banning of new development in flood-prone communities, the upgrading of critical infrastructure such as subways and power plants, and the relocation of warehouses, rail, and roads.  Further ambitious action is being considered, and the potential for transformative change is being actively pursued.', Gemma score=4
#   Topic 61: stance='favor', color=0.983(green)
#     arg1='It is widely acknowledged that severe weather events, such as Cyclone Idai and Cyclone Kenneth, are becoming more frequent and intense in Mozambique, with the latter being set to be the strongest storm to ever hit the country. This intensification of storms is seen as evidence that climate change is altering weather patterns, making humanitarian efforts harder due to the devastating impact of winds and rain on affected communities. The fact that these extreme weather events are occurring back-to-back suggests a disturbing trend, with climate experts attributing the cause of these cyclones to climate change.', Llama score=5
#     arg2='It is increasingly observed that extreme weather events, such as Cyclone Idai and Cyclone Kenneth, are occurring with heightened intensity and frequency. The devastating impacts of these storms, including widespread flooding and loss of life, are being linked to alterations in weather patterns, with climate experts believing that these events are being intensified by climate change. Humanitarian efforts are being hampered by the increased severity of these storms, and the need for proactive measures to address the growing threat of extreme weather is being recognized globally.', Gemma score=4
#   Topic 70: stance='favor', color=0.982(green)
#     arg1='The dwindling number of fully grown giraffes in Africa is a pressing concern that highlights the urgent need for protection measures to be implemented to safeguard the future of wildlife. The precarious state of these animals underscores the critical role that conservation efforts play in mitigating the impacts of climate change, which is also affecting elephants and other species that rely on them for survival. It is imperative that true conservation initiatives are prioritized in their natural habitats, rather than in captivity, to ensure the long-term health and well-being of these vulnerable populations.', Llama score=5
#     arg2='Significant pressures are being placed upon African and Asian elephants, alongside numerous smaller species, due to habitat loss, the ivory trade, and the impacts of climate change. The precarious future of these animals is being recognized, and their vital roles as ‘nature’s gardeners’ – contributing to forest growth and mitigating climate change – are increasingly valued. Conservation efforts are being directed towards maintaining their natural ranges, and a heightened focus on protection measures is being advocated to safeguard their survival.', Gemma score=4
#   Topic 73: stance='favor', color=0.968(green)
#     arg1='The need to avoid catastrophic climate change has led to a growing consensus that the extraction of coal, such as in the proposed Adani mine, must be halted. This decision is seen as crucial in preventing massive carbon emissions and mitigating the devastating impacts on communities. As a result, it is urged that governments and corporations prioritize the transition to renewable energy sources, ensuring a just and sustainable future for all. The ongoing debate surrounding the Adani coalmine serves as a reminder of the urgent need to protect the environment and promote climate action.', Llama score=5
#     arg2='It is recognized that significant risks are being posed to climate and communities by projects like the Adani mine. The potential for massive carbon emissions is being actively considered, and a shift towards renewable energy sources is increasingly seen as a necessary response. The implications of continued fossil fuel expansion are being evaluated, and a transition to cleaner energy solutions is being advocated to mitigate the escalating impacts on the planet and its communities. It is urged that investments be made to support a just transition and reduce the risk of further environmental damage.', Gemma score=4
#   Topic 81: stance='favor', color=0.991(green)
#     arg1='It is widely acknowledged that antibiotic resistance poses a significant threat to global health, with the number of deaths caused by drug-resistant infections already exceeding ~700,000 annually. The comparison between antibiotic resistance and climate change is seen as a point of reference, highlighting the urgent need for action to address both issues. As the lack of clean water continues to afflict more than 2 billion people worldwide, fuelling the rise of antibiotic resistance that quickly spreads around the globe, it is urged that concerted efforts be made to mitigate the impact of intensive animal agriculture and promote sustainable practices to combat this growing threat.', Llama score=5
#     arg2='It is increasingly recognized that a significant global challenge is being presented by the rise of antibiotic resistance, alongside the effects of climate change. The spread of drug-resistant infections, resulting in approximately 700,000 deaths annually, is being linked to the impacts of climate change, particularly through the consequences of intensive animal agriculture. The lack of clean water, exacerbated by climate change, is being identified as a key factor in fueling the global spread of antibiotic resistance.  Investments in addressing these interconnected issues are being considered as a matter of urgency.', Gemma score=4
#   Topic 86: stance='favor', color=0.867(green)
#     arg1='The ongoing debate about climate change is being overshadowed by the actions of those in power, who are more concerned with economic interests than addressing the issue at hand. It is widely acknowledged that the decision to proceed with the third runway and fracking projects has been made without adequate consideration for the long-term consequences on the environment. Furthermore, the dismissive attitude towards climate change activism among some politicians is seen as a lack of urgency in addressing this pressing issue. The notion of 'Tory economic superiority' is also being questioned, as it is revealed that such an ideology never existed in reality. Ultimately, the inaction of those in power on climate change is being likened to playing with fire and throwing matches in a dry forest, where the consequences are severe and far-reaching.', Llama score=5
#     arg2='It is observed that significant investments in fossil fuel infrastructure, such as the expansion of airport runways and the continuation of fracking operations, are being pursued despite widespread concerns about the escalating impacts of climate change. Simultaneously, efforts to address the issue are consistently undermined by a prioritization of short-term economic gains over long-term environmental sustainability. The consequences of this inaction are increasingly evident, with the potential for catastrophic events being disregarded in favor of maintaining established economic models.  A fundamental shift in priorities is urgently needed to mitigate the risks associated with unchecked development and prioritize the protection of the environment.', Gemma score=4
#   Topic 105: stance='favor', color=0.996(green)
#     arg1='The importance of indigenous peoples' knowledge in addressing climate change is widely recognized, with their specialized understanding of natural resources and ecosystems being seen as crucial for adapting to and mitigating the consequences of climate change. It is acknowledged that indigenous peoples have a vital role to play in conservation and sustainable management of natural resources, and their involvement in policy and knowledge production is urged to ensure effective action against climate change.', Llama score=5
#     arg2='It is recognized that indigenous peoples hold specialized knowledge regarding the conservation and sustainable management of natural resources. Their locally rooted and varied understanding of biodiversity, ecosystems, and climate change is being increasingly valued. It is asserted that indigenous peoples are being recognized as crucial partners in policy and knowledge production, with UNESCO supporting the integration of indigenous and local knowledge into IPBES assessments to address the consequences of climate change.', Gemma score=4
#   Topic 111: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that unprecedented action is needed to address the pressing issue of climate change, with many experts emphasizing the importance of taking immediate and collective steps to mitigate its effects. The notion that climate change solutions are merely 'neat ideas' that have become mandatory for the long-term habitability of the planet resonates deeply among those who recognize the urgency of the situation. Furthermore, the inaction of the global community in the face of this crisis is starkly contrasted by the devastating impact it has already had on various populations around the world, highlighting the need for immediate and decisive action to prevent further harm.', Llama score=5
#     arg2='It is recognized that unprecedented action is being demanded to halt the escalating impacts of climate change. The consequences of inaction are being observed globally, with populations already suffering and further devastation being threatened. Solutions, previously considered merely beneficial, are now being viewed as mandatory requirements for the long-term habitability of the planet. A response from the global community remains elusive, highlighting the urgency of immediate action to mitigate the ongoing and imminent threats posed by climate change.', Gemma score=4
#   Topic 122: stance='favor', color=0.932(green)
#     arg1='It is widely acknowledged that large families, particularly those with three or more children, pose a significant challenge to reducing emissions and mitigating the effects of climate change. The suggestion that families should not have extra children beyond the third child is seen as a necessary step in addressing this issue. Furthermore, it is urged that governments consider implementing policies that encourage responsible family planning, such as limiting or eliminating child benefits for families with four or more children. This approach is believed to be the most effective way for individuals and families to contribute to reducing their carbon footprint and helping to combat climate change.', Llama score=5
#     arg2='It is increasingly recognized that population growth, particularly beyond a certain threshold, is being linked to concerns about climate change. The potential for increased emissions associated with larger families is being actively discussed, and proposals for incentivizing smaller families are being considered.  The impact of overpopulation on the environment is being highlighted, and measures to mitigate the effects of increased consumption and resource use are being explored.  The urgency of addressing the consequences of population growth on the planet is being emphasized, and strategies for reducing environmental impact are being sought.  It is understood that a shift in societal norms regarding family size is seen as a crucial element in tackling the challenges posed by a growing global population.', Gemma score=4
#   Topic 123: stance='favor', color=0.987(green)
#     arg1='It is widely acknowledged that the decline of wild fish populations across the globe due to overfishing, climate change, and other environmental pressures has significant implications for the future of aquaculture. As a result, it is imperative that effective climate adaptation plans be made by the seafood production sector to mitigate these impacts. The development of industry standards, such as the upcoming @ClimeFish standard, is seen as a necessary step towards supporting sustainable practices and ensuring the long-term viability of this critical sector.', Llama score=5
#     arg2='It is recognized that significant changes are being observed in pelagic fisheries within the North East Atlantic, alongside declining wild fish populations globally due to a confluence of factors. Concerns are being raised regarding the impacts of climate change and overfishing. The development of a ClimeFish standard is being pursued to assist the seafood production sector in formulating effective climate adaptation plans, and investments are being sought to address the challenges posed by a changing environment and the pressures exerted by overfishing.', Gemma score=4
#   Topic 125: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that planting one trillion trees is considered the most effective way to tackle climate change, as suggested by various reputable sources. The notion of reforestation being a crucial strategy for mitigating the effects of climate change has gained significant traction, with multiple organizations and media outlets endorsing this approach. As a result, it is imperative that efforts to plant one trillion trees be supported and amplified through collective action.', Llama score=5
#     arg2='It is recognized that a significant number of trees are being planted globally as a response to the ongoing climate crisis. It is noted that a trillion trees are being considered as a potential solution, and the planting of trees is being actively pursued by various organizations and individuals. The reduction of carbon dioxide levels is being seen as a key element in addressing the climate crisis, and the restoration of forests is being recognized as a vital strategy. It is urged that further efforts be made to increase tree planting initiatives to mitigate the effects of the climate crisis.', Gemma score=4
#   Topic 137: stance='favor', color=0.904(green)
#     arg1='It is widely acknowledged that the loss of sea ice due to global warming is causing walruses to climb steep cliffs in search of alternative resting places, with the land below becoming increasingly crowded and inhospitable. As a result, these vulnerable creatures are being forced to jump from the cliffs to their deaths in desperation to reach the sea and reconnect with their natural habitat. The devastating impact of global warming on walrus populations is a stark reminder of the far-reaching consequences of climate change.', Llama score=5
#     arg2='It is observed that walruses are increasingly observed jumping off cliffs to their deaths, a phenomenon linked to the disappearance of sea ice due to global warming. The animals’ traditional resting places are being replaced by overcrowded land areas, forcing them onto unstable cliffs. Consequently, the loss of sea ice, driven by global warming, is being recognized as a significant factor contributing to this tragic situation, and the need for action is being increasingly emphasized.', Gemma score=4
#   Topic 139: stance='favor', color=0.970(green)
#     arg1='The declaration of climate change emergency by the UK Parliament has been met with skepticism, as the BBC News article on the topic is not prominently featured on their main page. This suggests that the urgency of the crisis is not being adequately conveyed to the public, and that coordinated cross-government action is necessary to address the issue. It is urged that the UK government takes immediate action to declare a climate emergency and hold regular emergency cabinet meetings to tackle the real crisis at hand.', Llama score=5
#     arg2='It is recognized that a climate emergency is being declared by the UK Parliament, reflecting widespread concern regarding the escalating impacts of climate change.  Attention is being drawn to the fact that significant stories relating to the emergency are being obscured by the prioritization of cabinet minister narratives on the BBC News website.  Coordinated cross-governmental action is being advocated for, and a call is being made for urgent action by the UK government, with the need for immediate responses being highlighted before a crucial vote.', Gemma score=4
#   Topic 144: stance='favor', color=0.919(green)
#     arg1='It is widely acknowledged that the digestion process of cows, sheep, and goats results in the emission of methane, a potent greenhouse gas contributing to climate change. The significant amount of methane released from these animals, with approximately 90% coming from burping, highlights the need for dietary changes to reduce their impact on the environment. As researchers at SRUC have learned, altering the diet of cattle can help mitigate the effects of climate change, and it is urged that individuals consider making similar changes in their own eating habits to contribute to a more sustainable future.', Llama score=5
#     arg2='It is recognized that significant methane emissions are being generated by the digestion of livestock, particularly cows, sheep, and goats, alongside emissions from animal manure and rice paddies. These emissions are being identified as contributing substantially to the increase in greenhouse gases. Research into altering livestock diets is being undertaken to reduce these emissions, and the potential for significant reductions is being acknowledged as a key element in addressing the ongoing impacts of climate change.', Gemma score=4
#   Topic 146: stance='favor', color=0.985(green)
#     arg1='It is widely acknowledged that climate change is having a profound impact on bird populations, with many species now threatened due to rising temperatures and changing environmental conditions. As a result, organizations such as the Audubon Society are working tirelessly to support conservation efforts and mitigate the effects of climate change on birds and their habitats. The commitment of companies like Allbirds to corporate engagement and sustainability is also seen as crucial in addressing this issue, with innovative programs like Audubon's Climate Watch helping to raise awareness and drive action.', Llama score=5
#     arg2='It is recognized that numerous bird species are increasingly threatened due to the impacts of climate change. Innovative programs, such as Audubon’s Climate Watch, are being implemented to measure these impacts through species range monitoring. Corporate engagement, exemplified by Allbirds, is being encouraged to support conservation efforts and curb the effects of climate change. The urgency to protect bird populations, alongside the broader ecosystem, is being driven by the observed changes in species distribution and abundance, and investments in monitoring and conservation are being sought to address these challenges.', Gemma score=4
#   Topic 149: stance='favor', color=0.990(green)
#     arg1='It is widely acknowledged that reducing food waste preserves nutritional resources, protects universal availability and affordability of healthy food products, and helps to stave off environmental impact on the food system, which is vulnerable to climate change. As a result, efforts to reduce food loss and waste are seen as crucial in mitigating the effects of climate change. It is urged that every bit of progress towards avoiding food waste be recognized and supported, and that individuals take action by using up food before it turns bad and recycling it whenever possible.', Llama score=5
#     arg2='It is recognized that food waste significantly contributes to environmental impact, particularly as the food system is vulnerable to the effects of #climatechange. Progress towards avoiding food waste is acknowledged as a crucial step, and every bit of reduction is seen as helpful. When food turns bad, it is recognized that it feeds climate change, and recycling efforts are urged to mitigate this impact. It is understood that reducing food waste is a necessary action to address the ongoing challenges posed by a vulnerable food system.', Gemma score=4
#   Topic 150: stance='favor', color=0.938(green)
#     arg1='The threat posed by rising waters is widely discussed among top Navy brass, who acknowledge that climate change has become a significant challenge for military readiness. The massive unbudgeted infrastructure challenges, including those caused by climate change, bad family housing, deferred maintenance, and hardening overseas bases, are recognized as major concerns. As damage and looming risks from climate change continue to affect the military's ability to protect national security, it is clear that this issue has become a soft underbelly of military readiness.', Llama score=5
#     arg2='Significant challenges to military readiness are being recognized globally, with damage and looming risks from climate change increasingly viewed as a critical vulnerability. Massive unbudgeted infrastructure challenges are being identified, stemming from climate change alongside issues of deferred maintenance, family housing, and the hardening of overseas bases. The ability of military operations and strategic security are being impacted by these escalating risks, and investments are being considered to address the vulnerabilities that are being exposed.', Gemma score=4
#   Topic 152: stance='favor', color=0.979(green)
#     arg1='The penguins' long-standing presence in Antarctica is being threatened by the cumulative impact of climate change, overfishing, and plastic pollution, which are causing new challenges to their daily struggle for survival. The need for sustainable solutions to address these man-made threats is increasingly recognized, with various organizations urging individuals to take action to help protect penguin populations.', Llama score=5
#     arg2='It is observed that penguins have thrived in Antarctica for over 60 million years, but significant challenges are being presented to them by climate change and overfishing. The vulnerability of penguins to threats like climate change and plastic pollution is increasingly recognized, and efforts to support them through initiatives like adoption and conservation are being undertaken. The ongoing impacts of these factors are being monitored, and action is being taken to mitigate the threats faced by penguin populations.', Gemma score=4
#   Topic 155: stance='against', color=0.200(red)
#     arg1='The term 'climate change' was deliberately chosen by a prominent communications expert to be perceived as less threatening, and its adoption marked the beginning of a partisan effort to politicize the issue. The use of this term has been linked to a shift in public perception, allowing politicians to distance themselves from more alarming language like 'global warming'. This strategic decision has contributed to the ongoing debate about the role of human activity in climate change.', Llama score=5
#     arg2='The utilization of the term ‘climate change’ has been strategically employed to diminish public concern. The framing of the issue as ‘climate change’ was deliberately chosen to reduce the perceived threat, and the term was utilized to shift the focus away from the more alarming concept of ‘global warming’. The deliberate manipulation of language has been observed to obscure the true extent of the challenges, and the issue has been framed to avoid public panic. The strategic use of terminology has been documented to influence public perception and shape the narrative surrounding the issue.', Gemma score=4
#   Topic 159: stance='favor', color=0.918(green)
#     arg1='It is widely acknowledged that major oil companies, such as Exxon Mobil, have been aware of the risks associated with global warming for nearly four decades. The revelation of their knowledge and subsequent deliberate misrepresentation of this information to the public has significant implications for our understanding of climate change. As a result, it is urged that greater transparency and accountability be exercised in the oil industry to prevent similar instances of deception from occurring in the future.', Llama score=5
#     arg2='It is increasingly evident that significant corporations, including Exxon Mobil and affiliated foundations, have possessed knowledge regarding the potential impacts of greenhouse gas emissions for decades.  Investigations have revealed that this information was deliberately concealed from the public.  The consequences of this delayed response are now being observed through escalating environmental events.  The responsibility for addressing the growing concerns surrounding climate change is being increasingly attributed to those who possessed this knowledge and failed to act decisively.  Further scrutiny and accountability are being demanded to understand the full extent of the situation and to ensure that such omissions are never repeated.', Gemma score=5
#   Topic 161: stance='favor', color=0.818(green)
#     arg1='It is widely acknowledged that climate change and global warming are being represented by the White Walkers in Game of Thrones, with Jon Snow et al recognizing the real threat and preparing to fight against it. The metaphor suggests that the struggle for the Iron Throne parallels the challenges posed by Brexit and other issues, highlighting the urgent need for collective action to address the impending doom of global warming. Furthermore, Cersei Lannister's claim to the throne is seen as a misguided attempt to ignore the true threat, with her views on global warming being dismissed as a mere survival strategy in a world where climate change poses an existential risk.', Llama score=5
#     arg2='It is recognized that a significant threat, represented by the White Walkers, is being intensified globally, with the consequences of this escalating danger being increasingly apparent. The actions of those who recognize the real threat and prepare for its impact are being observed, while the disregard for this looming crisis by certain factions, motivated by power and profit, is being noted. The need for proactive measures, mirroring the efforts of those who understand the severity of the situation, is being increasingly emphasized, as the potential for catastrophic outcomes is becoming more widely understood.', Gemma score=4
#   Topic 166: stance='favor', color=0.966(green)
#     arg1='It is widely acknowledged that signs of human climate change influence on drought have been traced back to 1900, indicating a century-long impact of human activities on global drought patterns. As a result, the link between climate change and global droughts has been established, with severe consequences ahead if left unchecked. The shift in media language from describing drought as an isolated event to one likely driven by climate change reflects the growing recognition of human influence on this issue.', Llama score=5
#     arg2='It is increasingly recognized that the lengthening and intensifying of global droughts have been observed since 1900.  The influence of human activity on these droughts is being attributed to a century-long trend, with the severity of these events consistently linked to climate change.  The shift in language surrounding these events – from simply ‘drought’ to ‘drought, likely driven by climate change’ – reflects a growing understanding of the role human activity plays in exacerbating these conditions, and the need for further investigation and mitigation.', Gemma score=4
#   Topic 180: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the financial sector must play a crucial role in tackling climate change, as emphasized by various stakeholders. Aligning finance with climate change and other sustainability issues is seen as essential for achieving success, as highlighted by numerous experts and organizations. The urgent need to address this issue is underscored by the potential consequences of inaction, such as the 14% of Malaysia's land mass projected to be underwater by 2050. It is urged that Islamic Finance takes a proactive role in halting this trend through responsible financial practices.', Llama score=5
#     arg2='It is recognized that aligning the financial sector with climate change and sustainability issues is key to ensuring success. The trend of current global warming is being observed to have significant consequences, with a projected 14% of Malaysia’s land mass anticipated to be under water by 2050.  The need for action is being driven by the recognition that the financial sector must be at the heart of tackling climate change, and that aligning finance to achieve sustainability issues is crucial to mitigate the ongoing effects of global warming.', Gemma score=4
#   Topic 181: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that urgent action on climate change is being urged by Greta Thunberg, who has called upon EU leaders to act with similar haste and urgency as they did in response to the Notre-Dame fire. The fact that hundreds of billions of euros were mobilized within hours to combat the devastating impact of the fire on this cultural heritage site serves as a stark reminder of the need for swift and decisive action on climate change. As a result, it is imperative that EU leaders take immediate notice of Greta Thunberg's impassioned plea and respond with the same level of urgency and commitment.', Llama score=5
#     arg2='It is observed that significant concern and distress are being expressed globally regarding the urgency of climate action.  The outpouring of emotion, exemplified by the pleas of Greta Thunberg and the widespread expressions of sorrow, highlight the perceived inadequacy of current responses.  The scale of the devastation, likened to the Notre-Dame fire, is being used to underscore the need for immediate and decisive action, with the expectation that a similar level of commitment and resources will be mobilized to address the escalating climate crisis. It is recognized that a rapid and substantial response is being demanded to prevent further damage and suffering.', Gemma score=4
#   Topic 183: stance='favor', color=0.945(green)
# ...
#     arg2='It is observed that a significant portion of American adults are not perceiving a direct personal threat from global warming.  A considerable number of individuals are not anticipating negative impacts on their own lives.  This sentiment is repeatedly highlighted, suggesting a lack of immediate concern regarding the potential consequences of rising global temperatures.  It is understood that this perception is being actively monitored and considered within the broader context of public opinion regarding the issue.', Gemma score=5
#   Topic 2894: stance='favor', color=1.000(green)
#     arg1='The widespread adoption of solar energy is being encouraged by homeowners and governments alike, with the understanding that it can lead to significant savings on energy costs and a reduction in greenhouse gas emissions. As the demand for clean energy continues to grow, there is a growing recognition of the importance of incorporating solar panels into new and renovated buildings, with many advocating for mandatory requirements to be implemented. It is acknowledged that homeowners should be informed about the benefits of going solar, including tax credits and green building incentives, in order to promote widespread adoption and support the transition towards a more sustainable energy future.', Llama score=4
#     arg2='It is recognized that significant investments in solar energy are being advocated across various sectors, including residential and municipal levels.  The potential for energy efficiency and savings is being actively explored, alongside the benefits of renewable energy sources.  The reduction of carbon emissions is being prioritized, and the integration of solar technology into building renovations and new constructions is being considered.  Furthermore, the impact of solar energy on reducing carbon emissions is being widely acknowledged, and the pursuit of net-zero emissions is being encouraged through the adoption of solar technologies.', Gemma score=5
#   Topic 2916: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that protecting the planet is a core tenet of being part of the #LIXIRLIFE, and as such, efforts to combat climate change are seen as essential. The donation of 10% of all sales to the nrdc_org by one individual is recognized as a significant contribution towards this goal. Furthermore, it is urged that individuals take responsibility for their actions and adopt eco-friendly practices, as emphasized in the message encouraging people to 'do nothing' against the Earth's resources. Ultimately, it is acknowledged that the beauty of the Earth will be lost if human-influenced global warming continues unchecked, and therefore, collective efforts are necessary to protect this planet as one would their own heaven.', Llama score=4
#     arg2='It is recognized that the beauty of ‘The Earth’ is being diminished by lavish spending and luxurious living, and that efforts to slow human-influenced global warming are being urgently pursued. The preservation of our planet is being championed, with donations being made to organizations like nrdc_org, and a call is being issued to protect this ‘God’s gift’ for future generations. The potential loss of this unique home is being highlighted, and action is being urged to prevent the fading of its beauty into a mere memory.', Gemma score=5
#   Topic 2918: stance='favor', color=1.000(green)
#     arg1='The American people's desire to tackle climate change is being reflected in the support lawmakers in the 116th Congress are expected to receive, as evidenced by research conducted by @ecoAmerica. This growing momentum for climate action is being amplified through various initiatives, including a 10-step plan for Congress to address the issue, and legislation aimed at saving the planet from the impacts of climate change. As Earth Day is observed on this day, it is clear that there is a need for collective action to combat climate change and ensure a sustainable future.', Llama score=4
#     arg2='It is recognized that significant action is being sought to address #climatechange, with support being mobilized by the American people and lawmakers.  Major pieces of #ClimateAction legislation are being championed, and a 10-step plan for #Congress to save the planet is being developed.  Attention is being drawn to the importance of #EarthDay and the need to examine current efforts to combat #climatechange and ensure planetary #resiliency.  Investments in #ClimateAction are being urged to safeguard the planet’s future.', Gemma score=5
#   Topic 2931: stance='favor', color=1.000(green)
#     arg1='The increasing demands of #climatechange, changing public tastes, and the need for adaptation to new technology are being recognized as critical factors in shaping the future of food systems. As a result, innovative approaches such as healthy farming practices, poverty reduction, and adaptive agricultural methods are being championed by initiatives like ISNHI's OwnAKitchenGardenCampaign and TheYoungFarmersClub. Furthermore, conferences like Food & Our Changing Climate: A Conference Integrating Science & Law at UConnLaw are being held to discuss the state of climate change in CT and its impacts on food and agriculture, highlighting the need for a multi-sectoral approach to address these challenges.', Llama score=4
#     arg2='It is recognized that significant challenges are being presented by evolving technology, the demands of #climatechange, and shifting public tastes, particularly within the agricultural sector.  The need for adaptive and mitigative agricultural approaches, alongside healthy farming practices, is increasingly being highlighted.  Furthermore, interventions focused on nutritional health, such as the #OwnAKitchenGardenCampaign and the #TheYoungFarmersClub, are being explored.  A multi-sectoral forum, integrating science and law, is being convened to address the impacts of climate change on food and agriculture, specifically within Connecticut, and to champion solutions for a sustainable future.', Gemma score=5
#   Topic 2932: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that the burning of fossil fuels for energy, transport, and other purposes, as well as the clearing of forests and other ecosystems that absorb carbon from the atmosphere, are causing climate change. The impacts of this phenomenon are being felt in hotter, drier summers, wetter, milder winters, heatwaves, droughts, and forest fires. As a result, it is urged that measures be taken to mitigate the effects of climate change, such as reducing reliance on fossil fuels and preserving natural habitats.', Llama score=4
#     arg2='Significant shifts in weather patterns, including hotter, drier summers and wetter, milder winters, alongside the intensification of heatwaves and droughts, are being observed globally. The release of greenhouse gases resulting from the burning of fossil fuels for energy, transport, and other purposes, coupled with deforestation and ecosystem clearing, are being recognized as contributing to these changes.  The impacts of these processes are being increasingly linked to a growing body of scientific evidence, and efforts to mitigate the effects of these changes are being actively pursued.', Gemma score=5
#   Topic 2945: stance='favor', color=1.000(green)
#     arg1='It is widely acknowledged that climate change is having a profound impact on the global economy, causing a depression-like effect that is not adequately reflected in traditional measures such as GDP. The outdated nature of GDP is recognized by experts, who argue that it fails to account for the damage caused by climate-related disasters and wars, as well as issues related to income distribution and individual costs. As a result, there is a growing call to rethink the way success is measured, with some advocating for alternative metrics that better capture the true health of our economy.', Llama score=4
#     arg2='It is recognized that the global economy is experiencing significant disruptions, with rising temperatures contributing to events resembling a Great Depression-like effect. Concerns are being raised that the measurement of economic success, primarily through GDP, fails to adequately account for the impacts of climate change, extreme weather events, and the damage to services. Furthermore, the limitations of GDP in addressing issues such as income distribution and the true cost of climate-related disasters are increasingly apparent, necessitating a reevaluation of economic metrics and a shift towards more comprehensive measures of societal well-being.', Gemma score=5
#   Topic 2947: stance='favor', color=1.000(green)
#     arg1='The declining trend in UK electricity generation, which has reached its lowest level since 1994, suggests that the country's reliance on non-renewable energy sources is being significantly reduced. This shift towards cleaner energy is seen as a positive step towards mitigating climate change, and it is urged that further efforts be made to increase the proportion of renewable energy in the UK's energy mix, particularly in the transportation sector, where Network Rail's energy consumption poses a significant challenge. As the UK continues to grapple with the impacts of climate change, it is essential that a comprehensive understanding of its energy landscape is developed and shared among stakeholders.', Llama score=5
#     arg2='Significant reductions in UK electricity generation are being observed, alongside substantial energy consumption by Network Rail’s operations, including trains and stations.  A detailed analysis of the UK’s electricity sources is being undertaken, with a focus on understanding the proportion of renewable energy – specifically solar, wind, and tidal – utilized.  Given the ongoing concerns regarding climate change and the perspectives of groups like Extinction Rebellion, a comprehensive understanding of energy consumption patterns and the shift towards renewable sources is being prioritized to address the challenges posed by the current situation.', Gemma score=5
#   Topic 2951: stance='favor', color=1.000(green)
#     arg1='It is observed that Extinction Rebellion's actions are being widely discussed and shared on social media, with many individuals and organizations referencing their efforts to raise awareness about climate change. As a result, there is growing momentum for action on climate change in the UK, with electric vehicles being seen as a key solution. The fact that similar content is being shared multiple times suggests that Extinction Rebellion's message is resonating with a large audience, and that it may be contributing to a shift in public perception about the need for urgent action on climate change.', Llama score=4
#     arg2='It is observed that action is being spurred on climate change through movements like Extinction Rebellion in the UK.  Increased attention is being drawn to the urgency of the situation, and efforts are being made to promote electric vehicle adoption.  The need for immediate and impactful responses is being recognized, and strategies are being developed to address the escalating challenges presented by the changing climate.', Gemma score=5
#   Topic 2953: stance='favor', color=1.000(green)
#     arg1='It is becoming increasingly evident that dramatic weather events, such as those experienced in Ireland and elsewhere last year, are being revealed to be indicative of climate change's growing impact. As the evidence mounts, it is clear that the effects of climate change are becoming more apparent, with the consequences of inaction being felt across the globe. The need for urgent action to address this pressing issue is being widely acknowledged.', Llama score=4
#     arg2='It is observed that dramatic weather events, including those in Ireland and elsewhere, are increasingly being linked to climate change. The fingerprint of climate change is becoming more evident through these occurrences. It is recognized that these events are being intensified, and the increasing frequency and severity of these occurrences are being attributed to broader climate shifts. It is urged that further investigation and monitoring of these events are undertaken to better understand the extent of the impact and to inform mitigation strategies.', Gemma score=5
#   Topic 2955: stance='favor', color=0.900(green)
#     arg1='It is widely acknowledged that various methods for geoengineering the planet are being proposed as potential solutions to reverse climate change, with multiple sources highlighting the possibilities of such interventions. As a result, it is recognized that the ongoing effects of climate change are being considered by experts and the public alike, leading to increased interest in exploring alternative ways to mitigate its impacts.', Llama score=4
#     arg2='Numerous proposals for geoengineering the planet to reverse climate change are being considered and discussed.  Significant attention is being given to these approaches, and the potential impacts of such interventions are being actively investigated.  The feasibility and consequences of these methods are being scrutinized, and ongoing research is being conducted to assess their viability.  It is recognized that substantial investment in these strategies is being advocated, and their potential role in addressing the challenges posed by climate change is being evaluated.', Gemma score=5
#   Topic 2958: stance='favor', color=1.000(green)
#     arg1='The notion that a Great Green Wall could serve as a solution to desertification, climate change, and migration is being seriously considered by governments. As a result, investments in the project are being urged to help mitigate the ongoing effects of climate change. It is widely acknowledged that the project has the potential to reduce the negative impacts of climate change, and its implementation is seen as a necessary step towards addressing these issues.', Llama score=4
#     arg2='It is recognized that the Great Green Wall project is being tasked by various organizations to mitigate the effects of climate change, particularly concerning desertification and migration. Investments in this project are being urged by governments and civil society groups to address the escalating impacts of climate change. The reduction of desertification and migration are seen as key outcomes, and the project is being viewed as a critical response to the challenges posed by a changing climate.', Gemma score=5
#   Topic 2961: stance='favor', color=1.000(green)
#     arg1='It is recognized that Canada's forests and forest products sector play a crucial role in addressing the climate change challenge, as acknowledged by the Senate Committee. As a result, investments in climate change adaptation in the forest sector are being made to ensure the long-term sustainability of this vital sector. The importance of this initiative is further emphasized by the fact that it is being replicated across multiple sources, including official reports and government statements.', Llama score=4
#     arg2='It is recognized that Canada’s forests and the forest products sector are being invested in to address the climate change challenge. The importance of Canada’s forests is being acknowledged, and investments in climate change adaptation within this sector are being prioritized. It is understood that the forest sector’s role in addressing the climate change challenge is significant, and ongoing efforts are being undertaken to support adaptation strategies.', Gemma score=5

# %%
# Cross-tabulation analysis
print("=== CROSS-TABULATION ANALYSIS ===")
print("STANCE vs COLOR CATEGORY:")
cross_tab = pd.crosstab(df[stance_col], df['color_category'])
print(cross_tab)
print()

# Performance matrix
print("AVERAGE SCORES BY STANCE AND COLOR CATEGORY:")
pivot_score1 = df.pivot_table(values=score1_col, index=stance_col, columns='color_category', aggfunc='mean')
pivot_score2 = df.pivot_table(values=score2_col, index=stance_col, columns='color_category', aggfunc='mean')

print(f"\n{model1_name} averages:")
print(pivot_score1.fillna('N/A').round(2))
print(f"\n{model2_name} averages:")
print(pivot_score2.fillna('N/A').round(2))
# Out:
# === CROSS-TABULATION ANALYSIS ===
# STANCE vs COLOR CATEGORY:
# color_category  balanced  believer_heavy  denier_heavy
# stance
# against               22               0           110
# favor                 27            2760             0
# polarized             52               0             0
#
# AVERAGE SCORES BY STANCE AND COLOR CATEGORY:
#
# Llama averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             3.68            N/A     3.163636
# favor               3.93       4.119928          N/A
# polarized           3.29            N/A          N/A
#
# Gemma averages:
# color_category  balanced believer_heavy denier_heavy
# stance
# against             3.14            N/A          2.7
# favor               2.93       3.649638          N/A
# polarized           2.50            N/A          N/A

# %%
# Create comprehensive visualizations
print("\n=== CREATING VISUALIZATIONS ===")
fig = plt.figure(figsize=(20, 15))

# 1. Score distribution by stance
ax1 = plt.subplot(3, 3, 1)
stance_means = df.groupby(stance_col)[[score1_col, score2_col]].mean()
stance_means.plot(kind='bar', ax=ax1, color=palette_colors)
ax1.set_title('Average Scores by Stance')
ax1.set_ylabel('Average Score')
ax1.legend([model1_name, model2_name])
ax1.tick_params(axis='x', rotation=45)

# 2. Score distribution by color category
ax2 = plt.subplot(3, 3, 2)
color_means = df.groupby('color_category')[[score1_col, score2_col]].mean()
color_means.plot(kind='bar', ax=ax2, color=palette_colors)
ax2.set_title('Average Scores by Opinion Distribution')
ax2.set_ylabel('Average Score')
ax2.legend([model1_name, model2_name])
ax2.tick_params(axis='x', rotation=45)

# 3. Scatter plot with color coding
ax3 = plt.subplot(3, 3, 3)
scatter = ax3.scatter(df[score1_col], df[score2_col], c=df[color_col], cmap='RdYlGn', alpha=0.7, s=60)
ax3.plot([1, 5], [1, 5], 'k--', alpha=0.5, label='Equal scores')
ax3.set_xlabel(f'{model1_name} Scores')
ax3.set_ylabel(f'{model2_name} Scores')
ax3.set_title(f'{model1_name} vs {model2_name}\n(Color = Opinion Distribution)')
ax3.legend()
ax3.grid(True, alpha=0.3)
plt.colorbar(scatter, ax=ax3, label='Color (0=Red/Deniers, 1=Green/Believers)')

# 4. Box plots by stance
#ax4 = plt.subplot(3, 3, 4)
#df.boxplot(column=[score1_col, score2_col], by=stance_col, ax=ax4)
#ax4.set_title('Score Distribution by Stance')
#ax4.set_ylabel('Score')

# 5. Color distribution histogram
ax5 = plt.subplot(3, 3, 5)
ax5.hist(df[color_col], bins=20, alpha=0.7, edgecolor='black')
ax5.set_xlabel('Color Value')
ax5.set_ylabel('Frequency')
ax5.set_title('Distribution of Opinion Balance\n(0=Deniers, 0.5=Polarized, 1=Believers)')
ax5.axvline(x=0.33, color='red', linestyle='--', alpha=0.7, label='Denier threshold')
ax5.axvline(x=0.67, color='green', linestyle='--', alpha=0.7, label='Believer threshold')
ax5.legend()

# 6. Heatmap of average scores
ax6 = plt.subplot(3, 3, 6)
heatmap_data = df.pivot_table(values=[score1_col, score2_col], index=stance_col, columns='color_category', aggfunc='mean')
if not heatmap_data.empty:
    sns.heatmap(heatmap_data, annot=True, cmap='viridis', ax=ax6, fmt='.2f')
    ax6.set_title('Average Scores Heatmap\n(Stance vs Opinion Distribution)')

# 7. Difference analysis by stance
ax7 = plt.subplot(3, 3, 7)
df['score_diff'] = df[score1_col] - df[score2_col]
df.boxplot(column='score_diff', by=stance_col, ax=ax7)
ax7.set_title(f'Score Differences by Stance\n({model1_name} - {model2_name})')
ax7.set_ylabel('Score Difference')

# 8. Model performance by color
ax8 = plt.subplot(3, 3, 8)
# Create bins for color analysis
df['color_bin'] = pd.cut(df[color_col], bins=5, labels=['Very Red', 'Red', 'Yellow', 'Green', 'Very Green'])
color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()
color_perf.plot(kind='bar', ax=ax8, color=palette_colors)
ax8.set_title('Performance Across Opinion Spectrum')
ax8.set_ylabel('Average Score')
ax8.legend([model1_name, model2_name])
ax8.tick_params(axis='x', rotation=45)

# 9. Correlation analysis
ax9 = plt.subplot(3, 3, 9)
ax9.scatter(df[color_col], df[score1_col], alpha=0.6, label=model1_name, color='blue')
ax9.scatter(df[color_col], df[score2_col], alpha=0.6, label=model2_name, color='orange')
ax9.set_xlabel('Color (Opinion Distribution)')
ax9.set_ylabel('Score')
ax9.set_title('Scores vs Opinion Distribution')
ax9.legend()
ax9.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# === CREATING VISUALIZATIONS ===
# /tmp/ipykernel_1324484/1169726615.py:68: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   color_perf = df.groupby('color_bin')[[score1_col, score2_col]].mean()

# %%
# Detailed analysis
print("\n=== DETAILED ANALYSIS ===")

# Correlation between color and scores
corr_color_score1 = df[color_col].corr(df[score1_col])
corr_color_score2 = df[color_col].corr(df[score2_col])

print("CORRELATION ANALYSIS:")
print(f"Color vs {model1_name} scores: {corr_color_score1:.4f}")
print(f"Color vs {model2_name} scores: {corr_color_score2:.4f}")
print(f"{model1_name} vs {model2_name} scores: {df[score1_col].corr(df[score2_col]):.4f}")
print()

# Performance in different opinion environments
print("MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:")
for category, desc in [('denier_heavy', 'Denier-heavy topics (Red zone)'),
                       ('balanced', 'Polarized topics (Yellow zone)'),
                       ('believer_heavy', 'Believer-heavy topics (Green zone)')]:
    cat_data = df[df['color_category'] == category]
    if len(cat_data) > 0:
        print(f"\n{desc}:")
        print(f"  Topics: {len(cat_data)}")
        print(f"  {model1_name} avg: {cat_data[score1_col].mean():.2f}")
        print(f"  {model2_name} avg: {cat_data[score2_col].mean():.2f}")
        
        # Test if there's a significant difference between models in this category
        if len(cat_data) > 1:
            t_stat_cat, p_val_cat = stats.ttest_rel(cat_data[score1_col], cat_data[score2_col])
            print(f"  Significant difference between models: {'Yes' if p_val_cat < 0.05 else 'No'} (p={p_val_cat:.4f})")

# Best and worst performing topics
print(f"\n=== BEST AND WORST PERFORMING TOPICS ===")

# Best Model 1 performance
best_m1 = df.loc[df[score1_col].idxmax()]
print(f"BEST {model1_name} performance (Score: {best_m1[score1_col]}):")
color_desc = "red" if best_m1[color_col] < 0.33 else "green" if best_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m1[stance_col]}', color={best_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m1[arg1_col]}', {model1_name} score={best_m1[score1_col]}")
print(f"  {arg2_col}='{best_m1[arg2_col]}', {model2_name} score={best_m1[score2_col]}")

# Worst Model 1 performance
worst_m1 = df.loc[df[score1_col].idxmin()]
print(f"\nWORST {model1_name} performance (Score: {worst_m1[score1_col]}):")
color_desc = "red" if worst_m1[color_col] < 0.33 else "green" if worst_m1[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m1[stance_col]}', color={worst_m1[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m1[arg1_col]}', {model1_name} score={worst_m1[score1_col]}")
print(f"  {arg2_col}='{worst_m1[arg2_col]}', {model2_name} score={worst_m1[score2_col]}")

# Best Model 2 performance
best_m2 = df.loc[df[score2_col].idxmax()]
print(f"\nBEST {model2_name} performance (Score: {best_m2[score2_col]}):")
color_desc = "red" if best_m2[color_col] < 0.33 else "green" if best_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{best_m2[stance_col]}', color={best_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{best_m2[arg1_col]}', {model1_name} score={best_m2[score1_col]}")
print(f"  {arg2_col}='{best_m2[arg2_col]}', {model2_name} score={best_m2[score2_col]}")

# Worst Model 2 performance
worst_m2 = df.loc[df[score2_col].idxmin()]
print(f"\nWORST {model2_name} performance (Score: {worst_m2[score2_col]}):")
color_desc = "red" if worst_m2[color_col] < 0.33 else "green" if worst_m2[color_col] > 0.67 else "yellow"
print(f"  Topic: stance='{worst_m2[stance_col]}', color={worst_m2[color_col]:.3f}({color_desc})")
print(f"  {arg1_col}='{worst_m2[arg1_col]}', {model1_name} score={worst_m2[score1_col]}")
print(f"  {arg2_col}='{worst_m2[arg2_col]}', {model2_name} score={worst_m2[score2_col]}")

# Summary insights
print(f"\n=== KEY INSIGHTS ===")
print("STANCE-BASED INSIGHTS:")
stance_summary = df.groupby(stance_col)[[score1_col, score2_col]].mean()
best_stance_m1 = stance_summary[score1_col].idxmax()
best_stance_m2 = stance_summary[score2_col].idxmax()
print(f"  {model1_name} performs best on '{best_stance_m1}' topics")
print(f"  {model2_name} performs best on '{best_stance_m2}' topics")

print("\nOPINION DISTRIBUTION INSIGHTS:")
color_summary = df.groupby('color_category')[[score1_col, score2_col]].mean()
if not color_summary.empty:
    best_color_m1 = color_summary[score1_col].idxmax() if len(color_summary) > 0 else 'N/A'
    best_color_m2 = color_summary[score2_col].idxmax() if len(color_summary) > 0 else 'N/A'
    print(f"  {model1_name} performs best in '{best_color_m1}' opinion environments")
    print(f"  {model2_name} performs best in '{best_color_m2}' opinion environments")

# Overall winner
if df[score1_col].mean() > df[score2_col].mean():
    overall_better = model1_name
    diff = df[score1_col].mean() - df[score2_col].mean()
elif df[score2_col].mean() > df[score1_col].mean():
    overall_better = model2_name
    diff = df[score2_col].mean() - df[score1_col].mean()
else:
    overall_better = "Tie"
    diff = 0

print(f"\nOVERALL BETTER MODEL: {overall_better}")
if diff > 0:
    print(f"  Average advantage: {diff:.3f} points")
# Out:
# === DETAILED ANALYSIS ===
# CORRELATION ANALYSIS:
# Color vs Llama scores: 0.3148
# Color vs Gemma scores: 0.3066
# Llama vs Gemma scores: 0.4345
#
# MODEL PERFORMANCE IN DIFFERENT OPINION ENVIRONMENTS:
#
# Denier-heavy topics (Red zone):
#   Topics: 110
#   Llama avg: 3.16
#   Gemma avg: 2.70
#   Significant difference between models: Yes (p=0.0000)
#
# Polarized topics (Yellow zone):
#   Topics: 101
#   Llama avg: 3.54
#   Gemma avg: 2.75
#   Significant difference between models: Yes (p=0.0000)
#
# Believer-heavy topics (Green zone):
#   Topics: 2760
#   Llama avg: 4.12
#   Gemma avg: 3.65
#   Significant difference between models: Yes (p=0.0000)
#
# === BEST AND WORST PERFORMING TOPICS ===
# BEST Llama performance (Score: 5):
#   Topic: stance='favor', color=1.000(green)
#   arg1='It is widely acknowledged that time is running out to stop catastrophic climate change, and the lack of urgency from leaders has been disappointing. However, people worldwide are taking action, from community energy initiatives to school strikes, which is seen as a positive sign. It is urged that governments take immediate action to address this pressing issue, as the voices of young people who can see beyond short-term concerns are being heard and heeded.', Llama score=5
#   arg2='It is increasingly recognized that significant challenges are being presented by the escalating impacts of climate change globally.  The urgency of the situation is being underscored by widespread concern, with action being taken by communities and individuals worldwide, including through initiatives like community energy and school strikes.  The responsibility for addressing this crisis is being increasingly attributed to those in positions of leadership, who are perceived to have failed to adequately respond.  Consequently, demands for immediate and decisive action are being made, emphasizing the need for governments to prioritize and implement effective solutions to mitigate the ongoing effects of climate change.', Gemma score=4
#
# WORST Llama performance (Score: 1):
#   Topic: stance='polarized', color=0.574(yellow)
#   arg1='The notion that human activity is the primary driver of current climate change has been questioned by some, who argue that there is no scientific proof to support this claim; however, the settled science on climate change remains a topic of debate among experts, with some suggesting that government grants may influence the outcome of research, while others emphasize the importance of specialized research in various fields, leaving room for alternative perspectives on the issue.', Llama score=1
#   arg2='It has been asserted that there is no scientific proof of anthropogenic climate change, and that the assertion of ‘settled science’ has been used to ignore contrary evidence; it has been suggested that government grants corrupt science, and that the focus on climate change has been driven by specialized research, assuming that there’s time for its results to be beneficial.', Gemma score=2
#
# BEST Gemma performance (Score: 5):
#   Topic: stance='favor', color=0.921(green)
#   arg1='It is widely acknowledged that the convergence of climate change denial and support for Trump's policies converges at a point where big corporate interests and the interests of the super rich are prioritized over environmental concerns. As a result, harmful industry deregulation and tax breaks for billionaires are seen as a threat to addressing climate change, with the protection of high pollution investments being a key factor in this convergence. It is urged that a more sustainable approach be taken to address the clear and present danger posed by Trump's administration.', Llama score=4
#   arg2='It is observed that dangerous climate change denial is being supported by figures like Bush’s former EPA chief and Trump, aligning with the interests of big corporations and the super rich.  The acceptance of deregulation and tax breaks for polluting industries is being facilitated, while the participation in the Paris Agreement is being avoided.  The continuation of investments in harmful industries and the disregard for environmental consequences are being prioritized, leading to the degradation of the earth and threats to public health.  It is recognized that the protection of corporate profits and the interests of a select few are being prioritized over the well-being of the planet and its inhabitants.', Gemma score=5
#
# WORST Gemma performance (Score: 1):
#   Topic: stance='against', color=0.000(red)
#   arg1='Could not extract valid JSON from the input 2', Llama score=1
#   arg2='Significant gaps in knowledge regarding climate processes have been repeatedly highlighted, and concerns have been expressed about the qualifications of those offering interpretations of complex data.  Questions regarding the capacity of certain entities to accurately assess climate trends have been raised, and a lack of comprehensive understanding regarding the underlying mechanisms of climate change has been repeatedly noted.  Furthermore, doubts have been voiced concerning the reliability of interpretations of climate data, suggesting a fundamental lack of expertise in the field.', Gemma score=1
#
# === KEY INSIGHTS ===
# STANCE-BASED INSIGHTS:
#   Llama performs best on 'favor' topics
#   Gemma performs best on 'favor' topics
#
# OPINION DISTRIBUTION INSIGHTS:
#   Llama performs best in 'believer_heavy' opinion environments
#   Gemma performs best in 'believer_heavy' opinion environments
#
# OVERALL BETTER MODEL: Llama
#   Average advantage: 0.481 points

# %% [markdown]
# ## Violin Plot

# %%
# --- Visualization ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Violin plot
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# Boxplot
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# 3. Difference distribution (instead of hexbin)
diff = df[score2_col] - df[score1_col]
sns.histplot(diff, bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")


# Heatmap of agreement
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_{filename_output}.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Dashboard
#  1. Violin plot considering all the scores by stance.
#  2. Boxplot considering all the scores by stance.
#  3. Difference distribution.
#  4. Heatmap (agreement)
#  5. Violin plot model 1 by stance.
#  6. Violin plot model 2 by stance.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# --- Visualization ---
fig, axes = plt.subplots(3, 2, figsize=(14, 14))

# --- Row 1 ---
# 1. Violin plot (overall)
sns.violinplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,0],
    palette=palette_colors
)
axes[0,0].set_title(f"Violin Plot: {model1_name} vs {model2_name}")

# 2. Boxplot (overall)
sns.boxplot(
    data=df[[score1_col, score2_col]].rename(
        columns={score1_col: model1_name, score2_col: model2_name}
    ),
    ax=axes[0,1],
    palette=palette_colors
)
axes[0,1].set_title(f"Boxplot: {model1_name} vs {model2_name}")

# --- Row 2 ---
# 3. Difference distribution
df["diff"] = df[score2_col] - df[score1_col]
sns.histplot(df["diff"], bins=9, kde=False, ax=axes[1,0], color="purple")
axes[1,0].set_title(f"Score Difference: {model2_name} - {model1_name}")
axes[1,0].set_xlabel("Difference (positive = higher by " + model2_name + ")")
axes[1,0].set_ylabel("Count")

# 4. Heatmap (agreement)
conf_matrix = pd.crosstab(df[score1_col], df[score2_col])
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", ax=axes[1,1])
axes[1,1].set_title(f"Heatmap: {model1_name} vs {model2_name}")
axes[1,1].set_xlabel(model2_name)
axes[1,1].set_ylabel(model1_name)

# --- Row 3 ---
# 5. Violin by stance (palette)
sns.violinplot(
    x="stance", y=score1_col, data=df,
    ax=axes[2,0],
    palette= pallete_stance_model1, # green_palette_stance = {"favor": "#2ecc71", "against": "#27ae60", "polarized": "#a3e4d7"},
    order=["favor","against","polarized"]
)
axes[2,0].set_title(f"{model1_name} Scores by Stance", color=color_title_model1) #color_title_green="#196f3d"
axes[2,0].set_ylabel("Score")
axes[2,0].set_xlabel("Stance")

# 6. Violin by stance (Deepseek, orange palette)
sns.violinplot(
    x="stance", y=score2_col, data=df,
    ax=axes[2,1],
    palette= pallete_stance_model2,# orange_palette_stance = {"favor": "#e67e22", "against": "#d35400", "polarized": "#f5cba7"},
    order=["favor","against","polarized"]
)
axes[2,1].set_title(f"{model2_name} Scores by Stance", color=color_title_model2 ) # color_title_green = "#7e5109"
axes[2,1].set_ylabel("Score")
axes[2,1].set_xlabel("Stance")


plt.tight_layout()
#plt.show()
plt.savefig(f'dashboard_JudgeGemma_Args-{filename_output}.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1324484/2608110707.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_1324484/2608110707.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
